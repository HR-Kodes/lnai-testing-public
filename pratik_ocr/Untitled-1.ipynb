# %%
final_data={
    "srn":"M27873561",
    "userId":"BIPULKUMARSINGH6690@GMAIL.COM",
    "Dir_wt_DIN":[{"panData":{"pan":"DKJPA2449M","fName":"Pratik","midName":"","surName":"Agarwal","dob":"09/07/2000","fullName":"Pratik Agarwal"}}]
}

# %%
import requests
import json
from requests_toolbelt.multipart.encoder import MultipartEncoder

url = "https://www.mca.gov.in/bin/mca/login"

headers = {
    "Origin": "www.mca.gov.in",
    "Content-Length": "235",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.199 Safari/537.36",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Accept": "*/*",
    "X-Requested-With": "XMLHttpRequest",
    "Sec-Ch-Ua-Platform": "Windows"
}
#bipul's id
data="data=Ut8pBOc0RSM6iYqffqN1orWH0Ee6A57QEKGmyHa5KnuzzybQ%2BjY2pMJIsLZw9DznTxfJeWvJFEcqsU2aZC33AC2nYaU60TNo8VjomCHN2dDSdHEC2enwIeEWCNR42vj7gfXFsvEwLfoO25%2BUKeho68x7N0qx56oyIAoVHQsAH1VP5mEoz%2FgNjOF8O12Av4DsLLckO7DUNCnmr%2FYByWESRw%3D%3D"
# data = "data=Ut8pBOc0RSM6iYqffqN1os8UC0wHR0dnkdWUh91bTVvbkOR1FwhDJFzabaerMcr6%2FKsnM50rkp32gFLlPIvLY2azrsy%2BFmeaecxebsQ2rMsFc5GCTglQP0xS6U9zJnDCxVSO%2FiBgttZcMB90cNHgz%2B0kcdVPhzscUk4MJrzqZ9QkqBmCdHexvs5UjIBYenkatE%2Fnm4ESsXitdWOpE9hTrg%3D%3D"
# data='data=Ut8pBOc0RSM6iYqffqN1os8UC0wHR0dnkdWUh91bTVvbkOR1FwhDJFzabaerMcr6%2FKsnM50rkp32gFLlPIvLY2azrsy%2BFmeaecxebsQ2rMsFc5GCTglQP0xS6U9zJnDCxVSO%2FiBgttZcMB90cNHgz%2B0kcdVPhzscUk4MJrzqZ9QkqBmCdHexvs5UjIBYenkatE%2Fnm4ESsXitdWOpE9hTrg%3D%3D'
response = requests.post(url, headers=headers, data=data)
set_cookie_value = response.headers.get('Set-Cookie')
start_index = set_cookie_value.find("session-token=") + len("session-token=")
end_index = set_cookie_value.find(";", start_index)
session_token = set_cookie_value[start_index:end_index]

# %%
payload1 = {"requestBody":{"action":"onload","operation":"onload","referenceNumber":"","srn":"dfs"}}

# %%
payload1['requestBody']['srn']=final_data['srn']

# %%
data=f"formData={json.dumps(payload1)}"

# %%
import requests

url = 'https://www.mca.gov.in/bin/fillip/srnDetails'

headers = {
    'Host': 'www.mca.gov.in',
    'Cookie': f'cookiesession1=678B28690FE85E2F44A6F01E56B5BE61; alertPopup=true; deviceId=4d23ogqkdbe; session-token={session_token}',
    'Content-Length': '966',
    'Sec-Ch-Ua':'', 
    'Sec-Ch-Ua-Mobile': '?0',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.199 Safari/537.36',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Accept': '*/*',
    'Csrf-Token': 'undefined',
    'X-Requested-With': 'XMLHttpRequest',
    'Sec-Ch-Ua-Platform': "",
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Dest': 'empty',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/Fillip.html',
    'Accept-Encoding': 'gzip, deflate',
    'Accept-Language': 'en-US,en;q=0.9'
} 

response = requests.post(url, headers=headers, data=data)
response.text
# Out:
# '{"resCode":200,"resStr":"{\\"error\\":\\"\\",\\"message\\":\\"Data Fetched Successfully\\",\\"data\\":{\\"status\\":\\"Approved\\",\\"reason\\":\\"\\",\\"formData\\":{\\"formIntegrationId\\":\\"1-477XDFF\\",\\"purpose\\":\\"New Incorporation\\",\\"cin\\":\\"\\",\\"llpin\\":\\"\\",\\"NICcode1\\":\\"52291\\",\\"NICcode2\\":\\"79120\\",\\"NICcode3\\":\\"79110\\",\\"NICCode1Desc\\":\\"Activities of travel agents and tour operators\\",\\"NICCode2Desc\\":\\"Tour operator activities\\",\\"NICCode3Desc\\":\\"Travel agency activities\\",\\"proposedname1\\":\\"VOYAGENIC LLP\\",\\"proposedname2\\":\\"\\",\\"formAttachment\\":[{\\"attachmentLabel\\":\\"RUN LLP Attachment\\",\\"attachmentCategory\\":\\"Attachment\\",\\"activityFileName\\":\\"Clarification Letter along with attachments.pdf\\",\\"activityFileSrcType\\":\\"I\\",\\"activityFileExt\\":\\"pdf\\",\\"activityFileSize\\":\\"102429\\",\\"activityComments\\":\\"153168082:RUN LLP Attachment:Document added successfully.\\",\\"attachmentDMSId
# ...

# %%
c_name1=json.loads(json.loads(response.text)['resStr'])['data']['formData']['proposedname1']

# %%
payload2=r'''{"requestBody":{"operation":"Save","integrationId":"1-ABC","referenceNumber":null,"srn":"","formId":"Homogeneous","formName":"FiLLiP","formDescription":"","formVersion":"1.2","userId":"BIPULKUMARSINGH6690@GMAIL.COM","CIN":null,"SRFOStatus":"Draft/Pending Submission","formData":{"formIntegrationId":"1-Test","isRegistered":"Y","srn":"M27873561","incorporationType":"New Incorporation","cin":null,"proposedName":"VOYAGENIC LLP","attachment":false,"attachment2a":false,"attachment2c":false,"attachment2d":false,"attachment2e":false,"significanceProposedName":null,"vernacularLanguage":null,"isRegisteredPending":null,"particulars":null},"formAttachment":[]}}'''

# %%
payload2_json=json.loads(payload2)

# %%
payload2_json
# Out:
# {'requestBody': {'operation': 'Save',
#   'integrationId': '1-ABC',
#   'referenceNumber': None,
#   'srn': '',
#   'formId': 'Homogeneous',
#   'formName': 'FiLLiP',
#   'formDescription': '',
#   'formVersion': '1.2',
#   'userId': 'BIPULKUMARSINGH6690@GMAIL.COM',
#   'CIN': None,
#   'SRFOStatus': 'Draft/Pending Submission',
#   'formData': {'formIntegrationId': '1-Test',
#    'isRegistered': 'Y',
#    'srn': 'M27873561',
#    'incorporationType': 'New Incorporation',
#    'cin': None,
#    'proposedName': 'VOYAGENIC LLP',
#    'attachment': False,
#    'attachment2a': False,
#    'attachment2c': False,
#    'attachment2d': False,
#    'attachment2e': False,
#    'significanceProposedName': None,
#    'vernacularLanguage': None,
#    'isRegisteredPending': None,
#    'particulars': None},
#   'formAttachment': []}}

# %%
payload2_json['requestBody']['formData'].keys()
# Out:
# dict_keys(['formIntegrationId', 'isRegistered', 'srn', 'incorporationType', 'cin', 'proposedName', 'attachment', 'attachment2a', 'attachment2c', 'attachment2d', 'attachment2e', 'significanceProposedName', 'vernacularLanguage', 'isRegisteredPending', 'particulars'])

# %%
payload2_json['requestBody']['formData']['srn']=final_data['srn']

# %%
payload2_json['requestBody']['formData']['proposedName']=c_name1

# %%
payload2_json['requestBody']['userId']=final_data['userId']

# %%
#Save and continue
import requests

url = 'https://www.mca.gov.in/bin/fillip/OnloadSubmit'

headers = {
    'Host': 'www.mca.gov.in',
    'Cookie': f'cookiesession1=678B28690FE85E2F44A6F01E56B5BE61; session-token={session_token}',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Origin': 'https://www.mca.gov.in',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/Fillip.html',
    }

payload = f"formData={json.dumps(payload2_json)}"
response = requests.post(url, headers=headers, data=payload)
response.text
# Out:
# '{"resCode":200,"resStr":"{\\r\\n\\t\\"error\\": \\"\\",\\r\\n\\t\\"message\\": \\"Data Added Successfully\\",\\r\\n\\t\\"data\\": {\\r\\n\\t\\t\\"integrationId\\": \\"1-4RWDHU5\\",\\r\\n\\t\\t\\"formIntegrationId\\": \\"1-4RWDHU7\\",\\r\\n\\t\\t\\"referenceNumber\\": \\"1-10394093453\\",\\r\\n\\t\\t\\"srn\\": \\"\\",\\r\\n\\t\\t\\"dateTime\\": \\"\\",\\r\\n\\t\\t\\"srnStatus\\":\\"Draft/Pending Submission\\",\\r\\n\\t\\t\\"formType\\":\\"\\"\\r\\n\\t}\\r\\n}"}'

# %%
response.headers
# Out:
# {'Referrer-Policy': 'same-origin', 'X-Frame-Options': 'SAMEORIGIN, SAMEORIGIN', 'X-Content-Type-Options': 'nosniff', 'Content-Encoding': 'gzip', 'X-AEM': 'MCA', 'X-Dispatcher': '1', 'X-UA-Compatible': 'IE=edge', 'X-XSS-Protection': '1; mode=block', 'Content-Security-Policy': "upgrade-insecure-requests; default-src 'self' https://pdfbuilder.mca.gov.in http://pdfbuilder.mca.gov.in http://mca.gov.in/ https://mca.gov.in/ http://www.mca.gov.in/ https://www.mca.gov.in/ http://mca21.gov.in/ https://mca21.gov.in/ http://www.mca21.gov.in/ https://www.mca21.gov.in/ https://www.mygov.in/ https://www.boportal.mca.gov.in/ http://www.boportal.mca.gov.in/ https://sso.mca.gov.in/ http://sso.mca.gov.in/ ; script-src 'self' 'unsafe-inline' 'unsafe-eval' https://cdn.jsdelivr.net/npm/disable-devtool http://cdn.jsdelivr.net/npm/disable-devtool https://v3chat.mca.gov.in/ http://v3chat.mca.gov.in/ http://mca.gov.in/ https://mca.gov.in/ http://www.mca.gov.in/ https://www.mca.gov.in/ http://mca21.gov.in/ htt
# ...

# %%
intId=json.loads(json.loads(response.text)['resStr'])['data']['integrationId']

# %%
formIntId=json.loads(json.loads(response.text)['resStr'])['data']['formIntegrationId']

# %%
ref_no=json.loads(json.loads(response.text)['resStr'])['data']['referenceNumber']

# %%
#Proof of Office address along with NOC, if applicable (Conveyance / Lease deed/Rent Agreement along with rent receipts)

import requests

url = 'https://www.mca.gov.in/bin/mca/dms/addservice'
file_path = r"/home/pratik/Downloads/Application.pdf"


headers = {
    'Cookie': f'cookiesession1=678B28690FE85E2F44A6F01E56B5BE61;session-token={session_token}',
    'Origin': 'https://www.mca.gov.in',
}

# Open the file in binary mode
with open(file_path, 'rb') as file:
    payload = {
        'file': ('a.pdf', file, 'application/pdf'),
        'folder': '175057615',
        'filemetadata': '{"form":"FiLLiP","srn":"{ref_no}","documentType":"Attachment","module":"FiLLiP","userid":"FiLLiP","applicationId":"{ref_no}","attachmentCategory":"pdf","attachmentLabel":"3eAdressProof"}'
    }
    response = requests.post(url, headers=headers, files=payload)

# Check the response
if response.status_code == 200:
    print('File uploaded successfully')
    print('Response: ',response.text)
else:
    print('Failed to upload the file')
# Out:
# File uploaded successfully
# Response:  {"attachmentLabel":"3eAdressProof","attachmentCategory":"Attachment","activityFileName":"a.pdf","activityFileSrcPath":"175057615","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"15761","attachmentDMSId":"355092894","totalNoOfPages":"1","activityFileDate":"08/09/2023","publicDocument":"Y","activityComments":"175057615:3eAdressProof:Document added successfully.","folderName":"175057615","folderId":"175057615","version":"","addedBy":"Fo User"}

# %%
att_resp1=json.loads(response.text)

# %%
# Copy of Utility Bills Attachment 

import requests

url = 'https://www.mca.gov.in/bin/mca/dms/addservice'
file_path = r"/home/pratik/Downloads/Application.pdf"


# session_token = 'your_session_token'

# Set the headers
headers = {
    'Cookie': f'cookiesession1=678B28690FE85E2F44A6F01E56B5BE61; alertPopup=true; session-token={session_token}',
    'Origin': 'https://www.mca.gov.in',
}

# Open the file in binary mode
with open(file_path, 'rb') as file:
    # Create the multipart form-data payload
    payload = {
        'file': ('b.pdf', file, 'application/pdf'),
        'folder': '174820662',
        # 'filemetadata': '{"form":"FiLLiP","srn":"1-10263623405","documentType":"Attachment","module":"FiLLiP","userid":"FiLLiP","applicationId":"1-10263623405","attachmentCategory":"pdf","attachmentLabel":"3eUtilityBills"}'
        'filemetadata': f'{{"form":"FiLLiP","srn":"{ref_no}","documentType":"Attachment","module":"FiLLiP","userid":"FiLLiP","applicationId":{ref_no},"attachmentCategory":"pdf","attachmentLabel":"3eUtilityBills"}}'
    }

    # Send the POST request
    response = requests.post(url, headers=headers, files=payload)

# Check the response
if response.status_code == 200:
    print('File uploaded successfully')
    print('Response: ',response.text)
else:
    print('Failed to upload the file')
# Out:
# File uploaded successfully
# Response:  {"attachmentLabel":"3eUtilityBills","attachmentCategory":"Attachment","activityFileName":"b.pdf","activityFileSrcPath":"174820662","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"15761","attachmentDMSId":"355092941","totalNoOfPages":"1","activityFileDate":"08/09/2023","publicDocument":"Y","activityComments":"174820662:3eUtilityBills:Document added successfully.","folderName":"174820662","folderId":"174820662","version":"","addedBy":"Fo User"}

# %%
att_resp2=json.loads(response.text)

# %%
import requests

url = "https://www.mca.gov.in/bin/cbdtPanValidate"

headers = {
    "Host": "www.mca.gov.in",
    "Cookie": "alertPopup=true; cookiesession1=678B28690FE85E2F44A6F01E56B5BE61; deviceId=fgxd0i986mf; session-token=eyJhbGciOiJIUzUxMiJ9..COB1cWVfa_ht2IteYb9kimRudJVsvVZfDc9uECpJ1ckkc0srbIoPPGp-m1-_MI9vmVqaF1B_ADovjwXrXejV6w; sessionID=c46bebb7-6bd1-451e-98d4-e0bb2f324c09",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Accept": "*/*",
    "Csrf-Token": "undefined",
    "X-Requested-With": "XMLHttpRequest",
    "Origin": "https://www.mca.gov.in",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/Fillip.html",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.5790.171 Safari/537.36",
    "Accept-Encoding": "gzip, deflate",
    "Accept-Language": "en-US,en;q=0.9"
}

    
# pan_data1 = final_data['Dir_wt_DIN'][0]['panData']
# data = {
#     "panData": f'{pan_data1}'
# }
data = {
    "panData": '{"pan":"DKJPA2449M","fName":"Pratik","midName":"","surName":"Agarwal","dob":"09/07/2000","fullName":"Pratik Agarwal"}'
}
response = requests.post(url, headers=headers, data=data)

print("Response Status Code:", response.status_code)
print("Response Content:", response.text)
# Out:
# Response Status Code: 200
# Response Content: {"resCode":200,"resStr":"{\"status\":\"true\"}"}

# %%
#(B) Particulars of individual designated partners not having DIN/DPIN
#(iii) Whether the present residential address same as permanent residential address
#Proof of Identity attachment 


import requests

url = 'https://www.mca.gov.in/bin/mca/dms/addservice'
# file_path = r"C:\\Users\vyomg\Downloads\_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg"
file_path = r"/home/pratik/Downloads/Application.pdf"


headers = {
    'Cookie': f'cookiesession1=678B28690FE85E2F44A6F01E56B5BE61; alertPopup=true; session-token={session_token}',
    'Origin': 'https://www.mca.gov.in',
}

# Open the file in binary mode
with open(file_path, 'rb') as file:
    payload = {
        'file': ('c.pdf', file, 'application/pdf'),
        'folder': '174820662',
        'filemetadata': '{"form":"FiLLiP","srn":"{ref_no}","documentType":"Attachment","module":"FiLLiP","userid":"FiLLiP","applicationId":"{ref_no}","attachmentCategory":"pdf","attachmentLabel":"6bIdentityProof"}'
    }
    response = requests.post(url, headers=headers, files=payload)

# Check the response
if response.status_code == 200:
    print('File uploaded successfully')
    print('Response: ',response.text)
else:
    print('Failed to upload the file')
# Out:
# File uploaded successfully
# Response:  {"attachmentLabel":"6bIdentityProof","attachmentCategory":"Attachment","activityFileName":"c.pdf","activityFileSrcPath":"174820662","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"15761","attachmentDMSId":"355095347","totalNoOfPages":"1","activityFileDate":"08/09/2023","publicDocument":"Y","activityComments":"174820662:6bIdentityProof:Document added successfully.","folderName":"174820662","folderId":"174820662","version":"","addedBy":"Fo User"}

# %%
att_resp3=json.loads(response.text)

# %%
#(B) Particulars of individual designated partners not having DIN/DPIN
#(iii) Whether the present residential address same as permanent residential address
#Residential Proof attachment 

import requests

url = 'https://www.mca.gov.in/bin/mca/dms/addservice'
# file_path = r"C:\\Users\vyomg\Downloads\_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg"
# file_path="Application.pdf"


headers = {
    'Cookie': f'cookiesession1=678B28690FE85E2F44A6F01E56B5BE61; alertPopup=true; session-token={session_token}',
    'Origin': 'https://www.mca.gov.in',
}

# Open the file in binary mode
with open(file_path, 'rb') as file:
    payload = {
        'file': ('d.pdf', file, 'application/pdf'),
        'folder': '174820662',
        'filemetadata': '{"form":"FiLLiP","srn":"{ref_no}","documentType":"Attachment","module":"FiLLiP","userid":"FiLLiP","applicationId":"{ref_no}","attachmentCategory":"pdf","attachmentLabel":"6bResidentialProof"}'
    }
    response = requests.post(url, headers=headers, files=payload)

# Check the response
if response.status_code == 200:
    print('File uploaded successfully')
    print('Response: ',response.text)
else:
    print('Failed to upload the file')
# Out:
# File uploaded successfully
# Response:  {"attachmentLabel":"6bResidentialProof","attachmentCategory":"Attachment","activityFileName":"d.pdf","activityFileSrcPath":"174820662","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"15761","attachmentDMSId":"355095642","totalNoOfPages":"1","activityFileDate":"08/09/2023","publicDocument":"Y","activityComments":"174820662:6bResidentialProof:Document added successfully.","folderName":"174820662","folderId":"174820662","version":"","addedBy":"Fo User"}

# %%
att_resp4=json.loads(response.text)

# %%
#(D) Particulars of bodies corporate and their nominees as designated partners having not DIN/DPIN
#(iii) Particulars of the person signing on behalf of the body corporate as nominee
#Verify PAN

import requests

url = "https://www.mca.gov.in/bin/cbdtPanValidate"

headers = {
    "Host": "www.mca.gov.in",
    "Cookie": f"cookiesession1=678B28690FE85E2F44A6F01E56B5BE61; session-token={session_token}",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/Fillip.html",
    }

payload = {
    "panData": '{"pan": "FZMPB2968E","fName": "JAY","midName": "","surName": "BHATTARAI","dob": "05/05/2001","fullName": "JAY BHATTARAI"}'
}

response = requests.post(url, headers=headers, data=payload)


if response.status_code == 200:
    print(response.text)
else:
    print(f"Error: {response.status_code} - {response.reason}")
# Out:
# {"resCode":200,"resStr":"{\"status\":\"true\"}"}

# %%
#(D) Particulars of bodies corporate and their nominees as designated partners having not DIN/DPIN
#Submit a copy of the proof of identity and proof of address
#Proof of identity

import requests

url = 'https://www.mca.gov.in/bin/mca/dms/addservice'
# file_path = r"C:\\Users\vyomg\Downloads\_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg"
# file_path="Application.pdf"


headers = {
    'Cookie': f'cookiesession1=678B28690FE85E2F44A6F01E56B5BE61; alertPopup=true; session-token={session_token}',
    'Origin': 'https://www.mca.gov.in',
}

# Open the file in binary mode
with open(file_path, 'rb') as file:
    payload = {
        'file': ('e.pdf', file, 'application/pdf'),
        'folder': '174820662',
        'filemetadata': '{"form":"FiLLiP","srn":"{ref_no}","documentType":"Attachment","module":"FiLLiP","userid":"FiLLiP","applicationId":"{ref_no}","attachmentCategory":"pdf","attachmentLabel":"6bIdentityProof"}'
    }
    response = requests.post(url, headers=headers, files=payload)

# Check the response
if response.status_code == 200:
    print('File uploaded successfully')
    print('Response: ',response.text)
else:
    print('Failed to upload the file')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[139], line 18
#      12 headers = {
#      13     'Cookie': f'cookiesession1=678B28690FE85E2F44A6F01E56B5BE61; alertPopup=true; session-token={session_token}',
#      14     'Origin': 'https://www.mca.gov.in',
#      15 }
#      17 # Open the file in binary mode
# ---> 18 with open(file_path, 'rb') as file:
#      19     payload = {
#      20         'file': ('e.pdf', file, 'application/pdf'),
#      21         'folder': '174820662',
#      22         'filemetadata': '{"form":"FiLLiP","srn":"{ref_no}","documentType":"Attachment","module":"FiLLiP","userid":"FiLLiP","applicationId":"{ref_no}","attachmentCategory":"pdf","attachmentLabel":"6bIdentityProof"}'
#      23     }
#      24     response = requests.post(url, headers=headers, files=payload)
#
# ...

# %%
att_resp5=json.loads(response.text)

# %%
#(D) Particulars of bodies corporate and their nominees as designated partners having not DIN/DPIN
#Submit a copy of the proof of identity and proof of address
#Residential proof

import requests

url = 'https://www.mca.gov.in/bin/mca/dms/addservice'
# file_path = r"C:\\Users\vyomg\Downloads\_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg"
# file_path="Application.pdf"
file_path = r"/home/pratik/Downloads/Application.pdf"




headers = {
    'Cookie': f'cookiesession1=678B28690FE85E2F44A6F01E56B5BE61; alertPopup=true; session-token={session_token}',
    'Origin': 'https://www.mca.gov.in',
}

# Open the file in binary mode
with open(file_path, 'rb') as file:
    payload = {
        'file': ('f.pdf', file, 'application/pdf'),
        'folder': '174820662',
        'filemetadata': '{"form":"FiLLiP","srn":"{ref_no}","documentType":"Attachment","module":"FiLLiP","userid":"FiLLiP","applicationId":"{ref_no}","attachmentCategory":"pdf","attachmentLabel":"6bResidentialProof"}'
    }
    response = requests.post(url, headers=headers, files=payload)

# Check the response
if response.status_code == 200:
    print('File uploaded successfully')
    print('Response: ',response.text)
else:
    print('Failed to upload the file')
# Out:
# File uploaded successfully
# Response:  {"attachmentLabel":"6bResidentialProof","attachmentCategory":"Attachment","activityFileName":"f.pdf","activityFileSrcPath":"174820662","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"15761","attachmentDMSId":"355100381","totalNoOfPages":"1","activityFileDate":"08/09/2023","publicDocument":"Y","activityComments":"174820662:6bResidentialProof:Document added successfully.","folderName":"174820662","folderId":"174820662","version":"","addedBy":"Fo User"}

# %%
att_resp6=json.loads(response.text)

# %%
payload3i=r'''{"requestBody":{"operation":"Save","integrationId":"1-4RW0D0D","referenceNumber":"1-10393480669","srn":"","formId":"Homogeneous","formName":"FiLLiP","formDescription":"","formVersion":"1.2","userId":"BIPULKUMARSINGH6690@GMAIL.COM","CIN":null,"SRFOStatus":"Draft/Pending Submission","formData":{"formIntegrationId":"1-4RW0D0Z","isRegistered":"Y","srn":"M27873561","incorporationType":"New Incorporation","cin":null,"proposedName":"VOYAGENIC LLP","attachment":false,"attachment2a":false,"attachment2c":false,"attachment2d":false,"attachment2e":false,"significanceProposedName":null,"vernacularLanguage":null,"isRegisteredPending":null,"particulars":null,"registeredAddress":{"addressI":"asdad","addressII":"dadad","country":"India","pin":"560019","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state":"Karnataka","longitude":"11","latitude":"11","policeStation":"kARNATKA","phone":null,"mobile":"620014066","fax":null,"email":"GOLUPRATIK001@GMAIL.COM","registrarOfficeName":"Registrar of Companies, Karnataka"},"buissnessactivity":[{"srno":"1","industrySubClass":"Axxx010","description":"abc rtd","primary":"No"},{"srno":"2","industrySubClass":"bxxx010","description":"fghty rtd","primary":"yes"}],"mainIndustrialNICcode":"52291","mainIndustrialDescriptionOfNIC":"Activities of travel agents and tour operators","otherIndustrialNICcode":"79120","otherIndustrialDescriptionOfNIC":"Tour operator activities","NICCode3":"79110","NICCode3Desc":"Travel agency activities","numberOfDesignatedPartnersValidDIN_DPIN":"0","numberOfDesignatedPartnersNotValidDIN_DPIN":"2","individualValidDINorDPIN":"0","individualNotValidDINorDPIN":"2","nominiesValidDINorDPIN":"0","nominiesNotValidDINorDPIN":"0","numberOfPartnersOtherThanDesignatedPartnerValidDINorDPIN":"0","numberOfPartnersOtherThanDesignatedPartnerNotValidDINorDPIN":"0","individualOtherThanDesignatedPartnerValidDINorDPIN":"0","individualOtherThanDesignatedPartnerNotValidDINorDPIN":"0","nominiesOtherThanDesignatedPartnerValidDINorDPIN":"0","nominiesOtherThanDesignatedPartnerNotValidDINorDPIN":"0","totalNumberValidDesignatedPartners":"0","totalNumberNotValidDesignatedPartners":"2","MCALLPFiLLiPIndPartner":[{"Category":"Particulars of individual designated partners not having DIN/DPIN","firstName":"Pratik","middleName":"","surname":"Agarwal","fatherFirstName":"Dilip ","fatherMiddleName":"Kumar","fathersurname":"Agarwal","gender":"Male","dateofBirth":"07/09/2000","nationality":"India","isResidentInIndia":"Y","isPanPassport":"PAN","panPassportDetails":"DKJPA2449M","placeOfBirthState":"Jharkhand","placeOfBirthDistrict":"Koderma","partnerIsCitizenofIndia":"Y","occupationType":"Professional","descriptionOfOthers":null,"areaOfOccupation":"Professional","otherAreaOfOccupation":null,"educationalQualification":"Bachelor's degree","otherEducation":null,"mobileNo":"+916200104066","emailid":"golupratik001@gmail.com","proodOfIdentity":"Aadhaar","residentialproof":"Electricity Bill","identityProofNo":"456640096331","residentialProofNo":"21313131231231313","numberOfsharesHeld":null,"paidupvalueofsharesheld":null,"formOfContribution":"Other than cash","otherModeOfPayment":"cheque","monetaryValueOfContributionInFigures":"50000","monetaryValueOfContributionInWords":" Fifty Thousand","numberOfLLPpartner":"0","numberOfcompanyDirector":"0","presentAddressSameAddressAsPremanent":"Y","durationStayedAtPresentAddressYears":null,"durationStayedAtPresentAddressMonth":null,"addressOfPreviousResidence":null,"designatedpartnerID":"","name":"","isResidentIndia":"Y","paid":"","modeOfPay":"Other than cash","monetaryValueInFigures":"50000","monetaryValueInwords":" Fifty Thousand","numberOfLLP":"","numberOfCompanyHoldAsDirector":"5","partnerFirstName":"Pratik","partnerMiddleName":"","partnerSurname":"Agarwal","partnerFatherFirstname":"Dilip ","partnerFatherMiddlename":"Kumar","partnerFatherSurname":"Agarwal","partnerGender":"Male","partnerDateofBirth":"07/09/2000","partnerNationality":"India","partnerIsResidentIndia":"Y","isPanPass":"PAN","panPassDetails":"BUOPE2342B","partnerPlaceofBirthState":"","partnerPlaceofBirthDistrict":"Nagpur","OccupationType":"Professional","isresidentofIndia":"Y","numberofsharesheld":"100","passportOrPAN":"PAN","emailID":"golupratik001@gmail.com","previousResidence ":"","numberOfSharesHeld":"","PaidupvalueShares":"","ListOfbodyParnerIndOfficeAddress":{"bodyParnerIndOfficeAddress":[{"addressType":"Permanent Address","addressI":"ads","addressII":"adad","country":"India","pin":"560019","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state":"Karnataka","policeStation":"Karnataka","phone":null},{"addressType":"Present Address","addressI":"ads","addressII":"adad","country":"India","pin":"560019","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state":"Karnataka","policeStation":"Karnataka","phone":null},{"addressType":"Registered Address","addressI":"ads","addressII":"adad","country":"India","pin":"560019","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state":"Karnataka","policeStation":"Karnataka","phone":null}]}},{"Category":"Particulars of individual designated partners not having DIN/DPIN","firstName":"JAY","middleName":"","surname":"BHATTARAI","fatherFirstName":"adasd","fatherMiddleName":"asda","fathersurname":"adsa","gender":"Male","dateofBirth":"05/05/2001","nationality":"India","isResidentInIndia":"Y","isPanPassport":"PAN","panPassportDetails":"FZMPB2968E","placeOfBirthState":"Karnataka","placeOfBirthDistrict":"Chitradurga","partnerIsCitizenofIndia":"Y","occupationType":"Professional","descriptionOfOthers":null,"areaOfOccupation":"Professional","otherAreaOfOccupation":null,"educationalQualification":"Master degree","otherEducation":null,"mobileNo":"+917050541423","emailid":"pratikagarwal0102@gmail.com","proodOfIdentity":"Aadhaar","residentialproof":"Electricity Bill","identityProofNo":"798000043919","residentialProofNo":"7324123775","numberOfsharesHeld":null,"paidupvalueofsharesheld":null,"formOfContribution":"Other than cash","otherModeOfPayment":"cheque","monetaryValueOfContributionInFigures":"50000","monetaryValueOfContributionInWords":" Fifty Thousand","numberOfLLPpartner":"0","numberOfcompanyDirector":"0","presentAddressSameAddressAsPremanent":"Y","durationStayedAtPresentAddressYears":null,"durationStayedAtPresentAddressMonth":null,"addressOfPreviousResidence":null,"designatedpartnerID":"","name":"","isResidentIndia":"Y","paid":"","modeOfPay":"Other than cash","monetaryValueInFigures":"50000","monetaryValueInwords":" Fifty Thousand","numberOfLLP":"","numberOfCompanyHoldAsDirector":"5","partnerFirstName":"JAY","partnerMiddleName":"","partnerSurname":"BHATTARAI","partnerFatherFirstname":"adasd","partnerFatherMiddlename":"asda","partnerFatherSurname":"adsa","partnerGender":"Male","partnerDateofBirth":"05/05/2001","partnerNationality":"India","partnerIsResidentIndia":"Y","isPanPass":"PAN","panPassDetails":"BUOPE2342B","partnerPlaceofBirthState":"","partnerPlaceofBirthDistrict":"Nagpur","OccupationType":"Professional","isresidentofIndia":"Y","numberofsharesheld":"100","passportOrPAN":"PAN","emailID":"pratikagarwal0102@gmail.com","previousResidence ":"","numberOfSharesHeld":"","PaidupvalueShares":"","ListOfbodyParnerIndOfficeAddress":{"bodyParnerIndOfficeAddress":[{"addressType":"Permanent Address","addressI":"adsd","addressII":"asda","country":"India","pin":"560019","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state":"Karnataka","policeStation":"Karnataka","phone":null},{"addressType":"Present Address","addressI":"adsd","addressII":"asda","country":"India","pin":"560019","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state":"Karnataka","policeStation":"Karnataka","phone":null},{"addressType":"Registered Address","addressI":"adsd","addressII":"asda","country":"India","pin":"560019","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state":"Karnataka","policeStation":"Karnataka","phone":null}]}}]},"formAttachment":[{"attachmentLabel":"3eAdressProof","attachmentCategory":"Attachment","activityFileName":"captcha_image1.jpg","activityFileSrcPath":"175057615","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"5216","attachmentDMSId":"355084914","totalNoOfPages":"1","activityFileDate":"08/09/2023","publicDocument":"Y","activityComments":"175057615:3eAdressProof:Document added successfully.","folderName":"175057615","folderId":"175057615","version":"","addedBy":"Fo User"},{"attachmentLabel":"3eUtilityBills","attachmentCategory":"Attachment","activityFileName":"captcha_image2.jpg","activityFileSrcPath":"175057615","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"5231","attachmentDMSId":"355086108","totalNoOfPages":"1","activityFileDate":"08/09/2023","publicDocument":"Y","activityComments":"175057615:3eUtilityBills:Document added successfully.","folderName":"175057615","folderId":"175057615","version":"","addedBy":"Fo User"},{"attachmentLabel":"6bIdentityProof","attachmentCategory":"Attachment","activityFileName":"captcha_image1.jpg","activityFileSrcPath":"175057615","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"5216","attachmentDMSId":"355094704","totalNoOfPages":"1","activityFileDate":"08/09/2023","publicDocument":"Y","activityComments":"175057615:6bIdentityProof:Document added successfully.","folderName":"175057615","folderId":"175057615","version":"","addedBy":"Fo User"},{"attachmentLabel":"6bResidentialProof","attachmentCategory":"Attachment","activityFileName":"captcha_image2.jpg","activityFileSrcPath":"175057615","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"5231","attachmentDMSId":"355096074","totalNoOfPages":"1","activityFileDate":"08/09/2023","publicDocument":"Y","activityComments":"175057615:6bResidentialProof:Document added successfully.","folderName":"175057615","folderId":"175057615","version":"","addedBy":"Fo User"},{"attachmentLabel":"6bIdentityProof","attachmentCategory":"Attachment","activityFileName":"captcha_image2.jpg","activityFileSrcPath":"175057615","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"5231","attachmentDMSId":"355098510","totalNoOfPages":"1","activityFileDate":"08/09/2023","publicDocument":"Y","activityComments":"175057615:6bIdentityProof:Document added successfully.","folderName":"175057615","folderId":"175057615","version":"","addedBy":"Fo User"},{"attachmentLabel":"6bResidentialProof","attachmentCategory":"Attachment","activityFileName":"captcha_image1.jpg","activityFileSrcPath":"175057615","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"5216","attachmentDMSId":"355098549","totalNoOfPages":"1","activityFileDate":"08/09/2023","publicDocument":"Y","activityComments":"175057615:6bResidentialProof:Document added successfully.","folderName":"175057615","folderId":"175057615","version":"","addedBy":"Fo User"}]}}
'''

# %%
payload3i_json=json.loads(payload3i)

# %%
payload3_json=payload3i_json

# %%
payload3i_json
# Out:
# {'requestBody': {'operation': 'Save',
#   'integrationId': '1-4RW0D0D',
#   'referenceNumber': '1-10393480669',
#   'srn': '',
#   'formId': 'Homogeneous',
#   'formName': 'FiLLiP',
#   'formDescription': '',
#   'formVersion': '1.2',
#   'userId': 'BIPULKUMARSINGH6690@GMAIL.COM',
#   'CIN': None,
#   'SRFOStatus': 'Draft/Pending Submission',
#   'formData': {'formIntegrationId': '1-4RW0D0Z',
#    'isRegistered': 'Y',
#    'srn': 'M27873561',
#    'incorporationType': 'New Incorporation',
#    'cin': None,
#    'proposedName': 'VOYAGENIC LLP',
#    'attachment': False,
#    'attachment2a': False,
#    'attachment2c': False,
#    'attachment2d': False,
#    'attachment2e': False,
#    'significanceProposedName': None,
#    'vernacularLanguage': None,
#    'isRegisteredPending': None,
#    'particulars': None,
#    'registeredAddress': {'addressI': 'asdad',
#     'addressII': 'dadad',
#     'country': 'India',
#     'pin': '560019',
#     'area': 'Gaviopuram Extension',
# ...

# %%
payload3_json['requestBody'].keys()
# Out:
# dict_keys(['operation', 'integrationId', 'referenceNumber', 'srn', 'formId', 'formName', 'formDescription', 'formVersion', 'userId', 'CIN', 'SRFOStatus', 'formData', 'formAttachment'])

# %%
payload3_json['requestBody']['integrationId']=intId
payload3_json['requestBody']['referenceNumber']=ref_no

# %%
payload3_json['requestBody']['userId']=final_data['userId']

# %%
payload3_json['requestBody']['formData']['formIntegrationId']=formIntId
payload3_json['requestBody']['formData']['srn']=final_data['srn']
payload3_json['requestBody']['formData']['proposedName']=c_name1
payload3_json['requestBody']['formData']['registeredAddress']={'addressI': 'afsdad',
   'addressII': 'dadad',
   'country': 'India',
   'pin': '560019',
   'area': 'Gaviopuram Extension',
   'city': 'Bangalore South',
   'district': 'Bangalore',
   'state': 'Karnataka',
   'longitude': '11',
   'latitude': '11',
   'policeStation': 'kARNATKA',
   'phone': None,
   'mobile': '620014066',
   'fax': None,
   'email': 'GOLUPRATIK001@GMAIL.COM',
   'registrarOfficeName': 'Registrar of Companies, Karnataka'}

# %%
formAttachment=[]
formAttachment.append(att_resp1)
formAttachment.append(att_resp2)
formAttachment.append(att_resp3)
formAttachment.append(att_resp4)
formAttachment.append(att_resp5)
formAttachment.append(att_resp6)
payload3_json['requestBody']['formAttachment']=formAttachment

# %%
payload3_json
# Out:
# {'requestBody': {'operation': 'Save',
#   'integrationId': '1-4RWDHU5',
#   'referenceNumber': '1-10394093453',
#   'srn': '',
#   'formId': 'Homogeneous',
#   'formName': 'FiLLiP',
#   'formDescription': '',
#   'formVersion': '1.2',
#   'userId': 'BIPULKUMARSINGH6690@GMAIL.COM',
#   'CIN': None,
#   'SRFOStatus': 'Draft/Pending Submission',
#   'formData': {'formIntegrationId': '1-4RWDHU7',
#    'isRegistered': 'Y',
#    'srn': 'M27873561',
#    'incorporationType': 'New Incorporation',
#    'cin': None,
#    'proposedName': 'VOYAGENIC LLP',
#    'attachment': False,
#    'attachment2a': False,
#    'attachment2c': False,
#    'attachment2d': False,
#    'attachment2e': False,
#    'significanceProposedName': None,
#    'vernacularLanguage': None,
#    'isRegisteredPending': None,
#    'particulars': None,
#    'registeredAddress': {'addressI': 'afsdad',
#     'addressII': 'dadad',
#     'country': 'India',
#     'pin': '560019',
#     'area': 'Gaviopuram Extension',
# ...

# %%
import requests

url = 'https://www.mca.gov.in/bin/fillip/OnloadSubmit'

headers = {
    'Host': 'www.mca.gov.in',
    'Cookie': f'cookiesession1=678B28690FE85E2F44A6F01E56B5BE61; alertPopup=true; session-token={session_token}',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Origin': 'https://www.mca.gov.in',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/Fillip.html',
    }

updated_payload = f"formData={json.dumps(payload3_json)}"
response = requests.post(url, headers=headers, data=updated_payload)
response.text
# Out:
# '{"resCode":200,"resStr":"{\\r\\n\\t\\"error\\": \\"\\",\\r\\n\\t\\"message\\": \\"Data Added Successfully\\",\\r\\n\\t\\"data\\": {\\r\\n\\t\\t\\"integrationId\\": \\"1-4RWDHU5\\",\\r\\n\\t\\t\\"formIntegrationId\\": \\"1-4RWDHU7\\",\\r\\n\\t\\t\\"referenceNumber\\": \\"1-10394093453\\",\\r\\n\\t\\t\\"srn\\": \\"\\",\\r\\n\\t\\t\\"dateTime\\": \\"\\",\\r\\n\\t\\t\\"srnStatus\\":\\"Draft/Pending Submission\\",\\r\\n\\t\\t\\"formType\\":\\"\\"\\r\\n\\t}\\r\\n}"}'
