# %%
with open("data.json") as f:
    a=f.read()

# %%
import json

# %%
json.loads(json.loads(a)['guidejson'])['rootPanel']['items']['panel_1846244155']['items']
# Out:
# {'guidetextdraw': {'templateId': 'guideContainer-rootPanel-panel_1846244155-guidetextdraw__',
#   'id': '',
#   'jcr:path': '/content/forms/af/mca-forms/login-and-registration/login-screen/jcr:content/guideContainer/rootPanel/items/panel_1846244155/items/guidetextdraw',
#   '_value': '<p>Welcome to MCA</p>\n',
#   'css': 'welcome-text-login',
#   'name': 'welcomeText',
#   'text': '<p>Welcome to MCA</p>\n',
#   'guideNodeClass': 'guideTextDraw',
#   'sling:resourceType': 'fd/af/components/guidetextdraw',
#   'textIsRich': 'true',
#   'documentFragmentVariables': []},
#  'guidetextdraw_1259122058': {'templateId': 'guideContainer-rootPanel-panel_1846244155-guidetextdraw_1259122058__',
#   'id': '',
#   'jcr:path': '/content/forms/af/mca-forms/login-and-registration/login-screen/jcr:content/guideContainer/rootPanel/items/panel_1846244155/items/guidetextdraw_1259122058',
#   '_value': '<p>LLP Filing and Services</p>\n',
#   'name': 'loginLLPText',
#   'visible': False,
# ...

# %%
json.loads(json.loads(a)['guidejson'])['rootPanel']['items']['panel_1846244155']['items']['submit']['clickExp']
# Out:
# '\ntry {\n    eval("debugger;\\nlocalStorage.removeItem(\\"clientIp\\");\\ndelete_cookie(\\"session-token\\");\\nsessionStorage.clear();\\n\\nif (window.guideBridge.validate([], this.panel.somExpression)) {\\n  loginErrorText.visible = false;\\n  var userRole;\\n  var userName = $(\\".userID input[type=\'text\']\\").val().toUpperCase();\\n  var password12 = $(\\".password input[type=\'password\']\\").val();\\n  var password13 = calcSHA1(password12);\\n  var clientIp = atob(localStorage.getItem(\\"clientIp\\"));\\n  var deviceId = localStorage.getItem(\\"deviceId\\");\\n  if(deviceId === null){\\n    //deviceId = Math.random().toString(36).slice(2) + clientIp;\\n    deviceId = Math.random().toString(36).slice(2);\\n    localStorage.setItem(\\"deviceId\\",deviceId);\\n  }\\n  var paramData = getParameterByName(\\"paramData\\");\\n  function parseJwt (token) {\\n    var base64Url = token.split(\'.\')[1];\\n    var base64 = base64Url.replace(/-/g, \'+\').replace(/_/g, \'/\');\\n    var j
# ...
