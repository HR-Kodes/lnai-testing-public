# %%
import json
import pandas as pd
with open('new_final.json') as f:
    inp=json.load(f)

# %%
inp['url']
# Out:
# {'3eAdressProofURL': 'https://legalnitiai.s3.ap-south-1.amazonaws.com/GST-reg/Electricity+bill+(1).pdf',
#  '3eUtilityBillsURL': 'https://legalnitiai.s3.ap-south-1.amazonaws.com/GST-reg/Electricity+bill+(1).pdf',
#  '6bIdentityProof1URL': 'https://legalnitiai.s3.ap-south-1.amazonaws.com/GST-reg/sachin_aadhar_merged+(1).pdf',
#  '6bResidentialProof1URL': 'https://legalnitiai.s3.ap-south-1.amazonaws.com/GST-reg/Sachin_Bank+(1).pdf',
#  '6bIdentityProof2URL': 'https://legalnitiai.s3.ap-south-1.amazonaws.com/GST-reg/Jay_aadhar_PAN-Jay_merged+(1).pdf',
#  '6bResidentialProof2URL': 'https://legalnitiai.s3.ap-south-1.amazonaws.com/GST-reg/Jay_Bank+(1).pdf',
#  'valuationCert10aURL': 'https://legalnitiai.s3.ap-south-1.amazonaws.com/image/WhatsApp+Image+2023-08-12+at+15.50.17.jpg',
#  'subscriberConsentURL': 'https://legalnitiai.s3.ap-south-1.amazonaws.com/image/WhatsApp+Image+2023-08-12+at+15.50.17.jpg'}

# %%
srn_value=inp['payload']['srn']

# %%
srn_value
# Out:
# 'M28186110'

# %%
def save(payload):
    url = 'https://www.mca.gov.in/bin/fillip/OnloadSubmit'
    headers = {
        'Host': 'www.mca.gov.in',
        'Cookie': 'cookiesession1=678B2869144E6B476733B93A4104896E; alertPopup=true; deviceId=4d23ogqkdbe; session-token={eyJhbGciOiJIUzUxMiJ9..RDMSwBO-oXVVKxnHj-svxPbXw4kjNKGg6cK1EZlXHUGaLJ3SOKHF6rrRVYC0echwQPp9gOY6sgv2CVyOAxJnOg; sessionID=3c799a0b-62b0-4149-ab4c-4a2229fe3923}',
        'Content-Length': '966',
        'Sec-Ch-Ua':'', 
        'Sec-Ch-Ua-Mobile': '?0',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.199 Safari/537.36',
        'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'Accept': '*/*',
        'Csrf-Token': 'undefined',
        'X-Requested-With': 'XMLHttpRequest',
        'Sec-Ch-Ua-Platform': "",
        'Origin': 'https://www.mca.gov.in',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Dest': 'empty',
        'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/Fillip.html',
        'Accept-Encoding': 'gzip, deflate',
        'Accept-Language': 'en-US,en;q=0.9'
    }

    while True:
        response = requests.post(url, headers=headers, data=payload)
        if json.loads(response.text)['resCode'] == 200:
            return response.text

# %%
import requests
import json
from requests_toolbelt.multipart.encoder import MultipartEncoder

url = "https://www.mca.gov.in/bin/mca/login"

headers = {
    "Origin": "www.mca.gov.in",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest",
}
data="data=Ut8pBOc0RSM6iYqffqN1oiyj9WvJGiJEVVlWEbrO16gkiUbYKGssebXlM%2Bcc1l6%2FH53ORIVejkqRQNJO6whx4OCP6P3nRpnWDjVVIN5IRbmcNMmCFHf2ri7KqE4SRlNjYCw9u2LKROliTfvv63AV9eiPCiRWO5aLhpI2CVZau9pnzCFWwsAby4nwrZ19gu8G0zsW1uZyNhasaqAt7a%2F%2FLQ%3D%3D"
# data = "data=Ut8pBOc0RSM6iYqffqN1os8UC0wHR0dnkdWUh91bTVvbkOR1FwhDJFzabaerMcr6%2FKsnM50rkp32gFLlPIvLY2azrsy%2BFmeaecxebsQ2rMsFc5GCTglQP0xS6U9zJnDCxVSO%2FiBgttZcMB90cNHgz%2B0kcdVPhzscUk4MJrzqZ9QkqBmCdHexvs5UjIBYenkatE%2Fnm4ESsXitdWOpE9hTrg%3D%3D"
# data="data=Ut8pBOc0RSM6iYqffqN1oiyj9WvJGiJEVVlWEbrO16gkiUbYKGssebXlM%2Bcc1l6%2FH53ORIVejkqRQNJO6whx4OCP6P3nRpnWDjVVIN5IRbmcNMmCFHf2ri7KqE4SRlNjYCw9u2LKROliTfvv63AV9eiPCiRWO5aLhpI2CVZau9pnzCFWwsAby4nwrZ19gu8G0zsW1uZyNhasaqAt7a%2F%2FLQ%3D%3D"
# data='data=Ut8pBOc0RSM6iYqffqN1os8UC0wHR0dnkdWUh91bTVvbkOR1FwhDJFzabaerMcr6%2FKsnM50rkp32gFLlPIvLY2azrsy%2BFmeaecxebsQ2rMsFc5GCTglQP0xS6U9zJnDCxVSO%2FiBgttZcMB90cNHgz%2B0kcdVPhzscUk4MJrzqZ9QkqBmCdHexvs5UjIBYenkatE%2Fnm4ESsXitdWOpE9hTrg%3D%3D'
response = requests.post(url, headers=headers, data=data)
set_cookie_value = response.headers.get('Set-Cookie')
start_index = set_cookie_value.find("session-token=") + len("session-token=")
end_index = set_cookie_value.find(";", start_index)
session_token = set_cookie_value[start_index:end_index]

# %%
response.headers
# Out:
# {'Referrer-Policy': 'same-origin', 'X-Frame-Options': 'SAMEORIGIN, SAMEORIGIN', 'X-Content-Type-Options': 'nosniff', 'Content-Encoding': 'gzip', 'X-AEM': 'MCA', 'X-Dispatcher': '1', 'X-UA-Compatible': 'IE=edge', 'X-XSS-Protection': '1; mode=block', 'Content-Security-Policy': "upgrade-insecure-requests; default-src 'self' https://pdfbuilder.mca.gov.in http://pdfbuilder.mca.gov.in http://mca.gov.in/ https://mca.gov.in/ http://www.mca.gov.in/ https://www.mca.gov.in/ http://mca21.gov.in/ https://mca21.gov.in/ http://www.mca21.gov.in/ https://www.mca21.gov.in/ https://www.mygov.in/ https://www.boportal.mca.gov.in/ http://www.boportal.mca.gov.in/ https://sso.mca.gov.in/ http://sso.mca.gov.in/ ; script-src 'self' 'unsafe-inline' 'unsafe-eval' https://cdn.jsdelivr.net/npm/disable-devtool http://cdn.jsdelivr.net/npm/disable-devtool https://v3chat.mca.gov.in/ http://v3chat.mca.gov.in/ http://mca.gov.in/ https://mca.gov.in/ http://www.mca.gov.in/ https://www.mca.gov.in/ http://mca21.gov.in/ https://mca21.gov.in/ http://www.mca21.gov.in/ https://www.mca21.gov.in/ https://www.mygov.in/ http://www.feedrapp.info https://www.feedrapp.info https://feedrapp.info seal.entrust.net; img-src 'self' https://cbpssubscriber.mygov.in http://mca.gov.in/ https://mca.gov.in/ http://www.mca.gov.in/ https://www.mca.gov.in/ http://mca21.gov.in/ https://mca21.gov.in/ http://www.mca21.gov.in/ https://www.mca21.gov.in/ https://www.mygov.in/ seal.entrust.net  data: blob: filesystem:;style-src 'self' 'unsafe-inline' http://mca.gov.in/ https://mca.gov.in/ http://www.mca.gov.in/ https://www.mca.gov.in/ http://mca21.gov.in/ https://mca21.gov.in/ http://www.mca21.gov.in/ https://www.mca21.gov.in/ https://www.mygov.in/; font-src 'self' http://mca.gov.in/ https://mca.gov.in/ http://www.mca.gov.in/ https://www.mca.gov.in/ http://mca21.gov.in/ https://mca21.gov.in/ http://www.mca21.gov.in/ https://www.mca21.gov.in/ https://www.mygov.in/; child-src 'self' http://mca.gov.in/ https://mca.gov.in/ http://www.mca.gov.in/ https://www.mca.gov.in/ http://mca21.gov.in/ https://mca21.gov.in/ http://www.mca21.gov.in/ https://www.mca21.gov.in/ https://www.mygov.in/; object-src 'self' http://mca.gov.in/ https://mca.gov.in/ http://www.mca.gov.in/ https://www.mca.gov.in/ http://mca21.gov.in/ https://mca21.gov.in/ http://www.mca21.gov.in/ https://www.mca21.gov.in/ https://www.mygov.in/; media-src 'self' blob: mediastream http://mca.gov.in/ https://mca.gov.in/ http://www.mca.gov.in/ https://www.mca.gov.in/ http://mca21.gov.in/ https://mca21.gov.in/ http://www.mca21.gov.in/ https://www.mca21.gov.in/ https://www.mygov.in/; connect-src 'self' https://pdfbuilder.mca.gov.in http://pdfbuilder.mca.gov.in http://www.mca.gov.in/ https://www.mca.gov.in/  wss: ws: https: ; frame-src 'self' https://www.facebook.com/ https://www.youtube.com/ http://www.feedrapp.info data: blob:", 'Access-Control-Allow-Origin': 'http://pdfbuilder.mca.gov.in', 'Content-Length': '798', 'Expires': 'Wed, 20 Sep 2023 09:44:33 GMT', 'Cache-Control': 'max-age=0, no-cache, no-store', 'Pragma': 'no-cache', 'Date': 'Wed, 20 Sep 2023 09:44:33 GMT', 'Connection': 'keep-alive', 'Set-Cookie': 'session-token=eyJhbGciOiJIUzUxMiJ9..WRwD0LvDWJxs2e3rmDvvgawZg9DQj0X7JdmXuM8mrkDnWPg30xdS5UG-wKoeQPKPDv5yu5wflxTa-7bxoaM6IA; Path=/; Expires=Wed, 20-Sep-2023 13:44:33 GMT; Max-Age=14400, sessionID=37adcd4b-8322-442e-94da-0e138b1e5e48; Path=/; Expires=Wed, 20-Sep-2023 13:44:33 GMT; Max-Age=14400, deviceId=fgxd0i986mf; Path=/; Expires=Wed, 20-Sep-2023 13:44:33 GMT; Max-Age=14400', 'Vary': 'Accept-Encoding, User-Agent'}

# %%
payload = {"requestBody":{"action":"onload","operation":"onload","referenceNumber":"","srn":"dfs"}}
payload['requestBody']['srn']=srn_value

# %%
url = 'https://www.mca.gov.in/bin/fillip/srnDetails'
headers = {
    'Host': 'www.mca.gov.in',
    'Cookie': f'cookiesession1=678B28690FE85E2F44A6F01E56B5BE61; session-token={session_token}',
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    'Origin': 'https://www.mca.gov.in',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/Fillip.html',
}
data=f"formData={json.dumps(payload)}"
response = requests.post(url, headers=headers, data=data)
response.text
# Out:
# '{"resCode":200,"resStr":"{\\"error\\":\\"\\",\\"message\\":\\"Data Fetched Successfully\\",\\"data\\":{\\"status\\":\\"Approved\\",\\"reason\\":\\"\\",\\"formData\\":{\\"formIntegrationId\\":\\"1-4ZFF8RJ\\",\\"purpose\\":\\"New Incorporation\\",\\"cin\\":\\"\\",\\"llpin\\":\\"\\",\\"NICcode1\\":\\"52291\\",\\"NICcode2\\":\\"79120\\",\\"NICcode3\\":\\"79110\\",\\"NICCode1Desc\\":\\"Activities of travel agents and tour operators\\",\\"NICCode2Desc\\":\\"Tour operator activities\\",\\"NICCode3Desc\\":\\"Travel agency activities\\",\\"proposedname1\\":\\"VOYAGENICTRAVELS LLP\\",\\"proposedname2\\":\\"VOYAGERAGENIC LLP\\",\\"formAttachment\\":[{\\"attachmentLabel\\":\\"RUN LLP\\",\\"attachmentCategory\\":\\"Forms\\",\\"activityFileName\\":\\"M28186110.pdf\\",\\"activityFileSrcType\\":\\"I\\",\\"activityFileExt\\":\\"pdf\\",\\"activityFileSize\\":\\"27348\\",\\"activityComments\\":\\"Generated PDF Stored Successfully\\",\\"attachmentDMSId\\":\\"362099739\\",\\"totalNoOfPages\\":\\"1\\",\\"activityFileDate\\":\\"09/03/2023 12:02:22\\",\\"publicDocument\\":\\"Y\\",\\"folderName\\":\\"M28186110\\",\\"folderId\\":\\"178072512\\",\\"versionNo\\":\\"0\\",\\"addedBy\\":\\"Fo User\\"},{\\"attachmentLabel\\":\\"RUN LLP\\",\\"attachmentCategory\\":\\"Forms\\",\\"activityFileName\\":\\"M28186110.pdf\\",\\"activityFileSrcType\\":\\"I\\",\\"activityFileExt\\":\\"pdf\\",\\"activityFileSize\\":\\"27348\\",\\"activityComments\\":\\"Generated PDF Stored Successfully\\",\\"attachmentDMSId\\":\\"362099738\\",\\"totalNoOfPages\\":\\"1\\",\\"activityFileDate\\":\\"09/03/2023 12:02:22\\",\\"publicDocument\\":\\"Y\\",\\"folderName\\":\\"M28186110\\",\\"folderId\\":\\"178072512\\",\\"versionNo\\":\\"0\\",\\"addedBy\\":\\"Fo User\\"},{\\"attachmentLabel\\":\\"RUN LLP\\",\\"attachmentCategory\\":\\"Forms\\",\\"activityFileName\\":\\"M28186110.pdf\\",\\"activityFileSrcType\\":\\"I\\",\\"activityFileExt\\":\\"pdf\\",\\"activityFileSize\\":\\"27348\\",\\"activityComments\\":\\"Generated PDF Stored Successfully\\",\\"attachmentDMSId\\":\\"362099741\\",\\"totalNoOfPages\\":\\"1\\",\\"activityFileDate\\":\\"09/03/2023 12:02:22\\",\\"publicDocument\\":\\"Y\\",\\"folderName\\":\\"M28186110\\",\\"folderId\\":\\"178072512\\",\\"versionNo\\":\\"0\\",\\"addedBy\\":\\"Fo User\\"},{\\"attachmentLabel\\":\\"Receipt\\",\\"attachmentCategory\\":\\"Receipt\\",\\"activityFileName\\":\\"M28186110_Receipt.pdf\\",\\"activityFileSrcType\\":\\"I\\",\\"activityFileExt\\":\\"pdf\\",\\"activityFileSize\\":\\"2314\\",\\"activityComments\\":\\"178072512:dorUpdated:Document added successfully.\\",\\"attachmentDMSId\\":\\"362100075\\",\\"totalNoOfPages\\":\\"1\\",\\"activityFileDate\\":\\"09/03/2023 12:04:59\\",\\"publicDocument\\":\\"Y\\",\\"folderName\\":\\"178072512\\",\\"folderId\\":\\"178072512\\",\\"versionNo\\":\\"0\\",\\"addedBy\\":\\"Fo User\\"},{\\"attachmentLabel\\":\\"RUN LLP\\",\\"attachmentCategory\\":\\"Forms\\",\\"activityFileName\\":\\"M28186110.pdf\\",\\"activityFileSrcType\\":\\"I\\",\\"activityFileExt\\":\\"pdf\\",\\"activityFileSize\\":\\"204529\\",\\"activityComments\\":\\"Generated PDF Stored Successfully\\",\\"attachmentDMSId\\":\\"363336632\\",\\"totalNoOfPages\\":\\"1\\",\\"activityFileDate\\":\\"09/07/2023 14:30:52\\",\\"publicDocument\\":\\"Y\\",\\"folderName\\":\\"178072512\\",\\"folderId\\":\\"178072512\\",\\"versionNo\\":\\"0\\",\\"addedBy\\":\\"Fo User\\"},{\\"attachmentLabel\\":\\"RUN LLP Attachment\\",\\"attachmentCategory\\":\\"Attachment\\",\\"activityFileName\\":\\"Clarification Letter voyagenic3 (1).pdf\\",\\"activityFileSrcType\\":\\"I\\",\\"activityFileExt\\":\\"pdf\\",\\"activityFileSize\\":\\"200794\\",\\"activityComments\\":\\"178570308:RUN LLP Attachment:Document added successfully.\\",\\"attachmentDMSId\\":\\"363336211\\",\\"totalNoOfPages\\":\\"1\\",\\"activityFileDate\\":\\"09/07/2023 14:30:26\\",\\"publicDocument\\":\\"Y\\",\\"folderName\\":\\"z4Hc7508885288465\\",\\"folderId\\":\\"178570308\\",\\"versionNo\\":\\"0\\",\\"addedBy\\":\\"Fo Us ...

# %%
data
# Out:
# 'formData={"requestBody": {"action": "onload", "operation": "onload", "referenceNumber": "", "srn": "M28186110"}}'

# %%
c_name1=json.loads(json.loads(response.text)['resStr'])['data']['formData']['proposedname1']
import urllib.parse

formData = "%7B%22requestBody%22%3A%7B%22operation%22%3A%22Save%22%2C%22integrationId%22%3A%221-ABC%22%2C%22referenceNumber%22%3Anull%2C%22srn%22%3A%22%22%2C%22formId%22%3A%22Homogeneous%22%2C%22formName%22%3A%22FiLLiP%22%2C%22formDescription%22%3A%22%22%2C%22formVersion%22%3A%221.2%22%2C%22userId%22%3A%22KASHVIJAIN19%40GMAIL.COM%22%2C%22CIN%22%3Anull%2C%22SRFOStatus%22%3A%22Draft%2FPending+Submission%22%2C%22formData%22%3A%7B%22formIntegrationId%22%3A%221-Test%22%2C%22isRegistered%22%3A%22Y%22%2C%22srn%22%3A%22M28067253%22%2C%22incorporationType%22%3A%22New+Incorporation%22%2C%22cin%22%3Anull%2C%22proposedName%22%3A%22INVITEFULFUSION+LLP%22%2C%22attachment%22%3Afalse%2C%22attachment2a%22%3Afalse%2C%22attachment2c%22%3Afalse%2C%22attachment2d%22%3Afalse%2C%22attachment2e%22%3Afalse%2C%22significanceProposedName%22%3Anull%2C%22vernacularLanguage%22%3Anull%2C%22isRegisteredPending%22%3Anull%2C%22particulars%22%3Anull%7D%2C%22formAttachment%22%3A%5B%5D%7D%7D"
# Manually parse the data
decoded_data = urllib.parse.unquote_plus(formData,encoding='utf-8')
data_start = decoded_data.find('{')

data_end = decoded_data.rfind('}') + 1
data_str = decoded_data[data_start:data_end]
a=(json.loads((data_str)))
a['requestBody']['srn']=""
a['requestBody']['formData']['srn']=srn_value
a['requestBody']['formData']['proposedName']=c_name1

# %%
a['requestBody']['userId']=inp['payload']['userId']

# %%
a
# Out:
# {'requestBody': {'operation': 'Save',
#   'integrationId': '1-ABC',
#   'referenceNumber': None,
#   'srn': '',
#   'formId': 'Homogeneous',
#   'formName': 'FiLLiP',
#   'formDescription': '',
#   'formVersion': '1.2',
#   'userId': 'CASRIKANTH0224@GMAIL.COM',
#   'CIN': None,
#   'SRFOStatus': 'Draft/Pending Submission',
#   'formData': {'formIntegrationId': '1-Test',
#    'isRegistered': 'Y',
#    'srn': 'M28186110',
#    'incorporationType': 'New Incorporation',
#    'cin': None,
#    'proposedName': 'VOYAGENICTRAVELS LLP',
#    'attachment': False,
#    'attachment2a': False,
#    'attachment2c': False,
#    'attachment2d': False,
#    'attachment2e': False,
#    'significanceProposedName': None,
#    'vernacularLanguage': None,
#    'isRegisteredPending': None,
#    'particulars': None},
#   'formAttachment': []}}

# %%
#Save and continue
import requests

url = 'https://www.mca.gov.in/bin/fillip/OnloadSubmit'
headers = {
    'Host': 'www.mca.gov.in',
    'Cookie': 'cookiesession1=678B2869144E6B476733B93A4104896E;session-token={session_token}',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Origin': 'https://www.mca.gov.in',
   }

payload = f"formData={json.dumps(a)}"
response = requests.post(url, headers=headers, data=payload)
response.text
# Out:
# '{"resCode":200,"resStr":"{\\r\\n\\t\\"error\\": \\"\\",\\r\\n\\t\\"message\\": \\"Data Added Successfully\\",\\r\\n\\t\\"data\\": {\\r\\n\\t\\t\\"integrationId\\": \\"1-5389EW0\\",\\r\\n\\t\\t\\"formIntegrationId\\": \\"1-5389EW2\\",\\r\\n\\t\\t\\"referenceNumber\\": \\"1-11079186336\\",\\r\\n\\t\\t\\"srn\\": \\"\\",\\r\\n\\t\\t\\"dateTime\\": \\"\\",\\r\\n\\t\\t\\"srnStatus\\":\\"Draft/Pending Submission\\",\\r\\n\\t\\t\\"formType\\":\\"\\"\\r\\n\\t}\\r\\n}"}'

# %%
json.loads(json.loads(response.text)['resStr'])['data']
# Out:
# {'integrationId': '1-5389EW0',
#  'formIntegrationId': '1-5389EW2',
#  'referenceNumber': '1-11079186336',
#  'srn': '',
#  'dateTime': '',
#  'srnStatus': 'Draft/Pending Submission',
#  'formType': ''}

# %%
formintid=json.loads(json.loads(response.text)['resStr'])['data']['formIntegrationId']
intid=json.loads(json.loads(response.text)['resStr'])['data']['integrationId']
ref_no=json.loads(json.loads(response.text)['resStr'])['data']['referenceNumber']

# %%
import requests

def upload_file_from_url(session_token, file_url, ref_no, filename, folder, attachment_category, attachment_label):
    # Download the file from the URL
    response = requests.get(file_url)
    
    if response.status_code != 200:
        print(f'Failed to download file from URL: {file_url}')
        return

    # Prepare the headers
    headers = {
        'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
        'Origin': 'https://www.mca.gov.in',
    }

    # Upload the downloaded file
    payload = {
        'file': (filename, response.content, 'image/jpeg'),
        'folder': folder,
        'filemetadata': f'{{"form":"FiLLiP","srn":"{ref_no}","documentType":"Attachment","module":"FiLLiP","userid":"FiLLiP","applicationId":"{ref_no}","attachmentCategory":"{attachment_category}","attachmentLabel":"{attachment_label}"}}'
    }

    url = 'https://www.mca.gov.in/bin/mca/dms/addservice'
    upload_response = requests.post(url, headers=headers, files=payload)

    # Check the upload response
    if upload_response.status_code == 200:
        print('File uploaded successfully')
        print('Upload Response: ', upload_response.text)
        return upload_response.text
    else:
        print('Failed to upload the file')

# %%
inp['payload'].keys()
# Out:
# dict_keys(['srn', 'panData', 'registeredAddress', 'mainIndustrialNICcode', 'mainIndustrialDescriptionOfNIC', 'otherIndustrialNICcode', 'otherIndustrialDescriptionOfNIC', 'NICCode3', 'NICCode3Desc', 'numberOfDesignatedPartnersValidDIN_DPIN', 'numberOfDesignatedPartnersNotValidDIN_DPIN', 'individualValidDINorDPIN', 'individualNotValidDINorDPIN', 'nominiesValidDINorDPIN', 'nominiesNotValidDINorDPIN', 'numberOfPartnersOtherThanDesignatedPartnerValidDINorDPIN', 'numberOfPartnersOtherThanDesignatedPartnerNotValidDINorDPIN', 'individualOtherThanDesignatedPartnerValidDINorDPIN', 'individualOtherThanDesignatedPartnerNotValidDINorDPIN', 'nominiesOtherThanDesignatedPartnerValidDINorDPIN', 'nominiesOtherThanDesignatedPartnerNotValidDINorDPIN', 'totalNumberValidDesignatedPartners', 'totalNumberNotValidDesignatedPartners', 'MCALLPFiLLiPIndPartner', 'userId'])

# %%
#Proof of Office address along with NOC, if applicable (Conveyance / Lease deed/Rent Agreement along with rent receipts)

s3_url = inp['url']['3eAdressProofURL'] 
folder = ""
attachment_category = s3_url.split('/')[-1].split('.')[-1]
attachment_label = "3eAdressProof"
filename=s3_url.split('/')[-1]
response=json.loads(upload_file_from_url(session_token, s3_url, ref_no,filename, folder, attachment_category, attachment_label))
response['folderName']=response['folderId']
response
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[94], line 8
#       6 attachment_label = "3eAdressProof"
#       7 filename=s3_url.split('/')[-1]
# ----> 8 response=json.loads(upload_file_from_url(session_token, s3_url, ref_no,filename, folder, attachment_category, attachment_label))
#       9 response['folderName']=response['folderId']
#      10 response
#
# Cell In[92], line 5, in upload_file_from_url(session_token, file_url, ref_no, filename, folder, attachment_category, attachment_label)
#       3 def upload_file_from_url(session_token, file_url, ref_no, filename, folder, attachment_category, attachment_label):
#       4     # Download the file from the URL
# ----> 5     response = requests.get(file_url)
#       7     if response.status_code != 200:
#       8         print(f'Failed to download file from URL: {file_url}')
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/api.py?line=61'>62</a> def get(url, params=None, **kwargs):
#      <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/api.py?line=62'>63</a>     r"""Sends a GET request.
#      <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/api.py?line=63'>64</a>
#      <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/api.py?line=64'>65</a>     :param url: URL for the new :class:`Request` object.
#    (...)
#      <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/api.py?line=69'>70</a>     :rtype: requests.Response
#      <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/api.py?line=70'>71</a>     """
# ---> <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/api.py?line=72'>73</a>     return request("get", url, params=params, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/api.py?line=54'>55</a> # By using the 'with' statement we are sure the session is closed, thus we
#      <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/api.py?line=55'>56</a> # avoid leaving sockets open which can trigger a ResourceWarning in some
#      <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/api.py?line=56'>57</a> # cases, and look like a memory leak in others.
#      <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/api.py?line=57'>58</a> with sessions.Session() as session:
# ---> <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/api.py?line=58'>59</a>     return session.request(method=method, url=url, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/sessions.py?line=583'>584</a> send_kwargs = {
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/sessions.py?line=584'>585</a>     "timeout": timeout,
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/sessions.py?line=585'>586</a>     "allow_redirects": allow_redirects,
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/sessions.py?line=586'>587</a> }
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/sessions.py?line=587'>588</a> send_kwargs.update(settings)
# --> <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/sessions.py?line=588'>589</a> resp = self.send(prep, **send_kwargs)
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/sessions.py?line=590'>591</a> return resp
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:747, in Session.send(self, request, **kwargs)
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/sessions.py?line=743'>744</a>         pass
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/sessions.py?line=745'>746</a> if not stream:
# --> <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/sessions.py?line=746'>747</a>     r.content
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/sessions.py?line=748'>749</a> return r
#
# File ~/.local/lib/python3.10/site-packages/requests/models.py:899, in Response.content(self)
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/models.py?line=896'>897</a>         self._content = None
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/models.py?line=897'>898</a>     else:
# --> <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/models.py?line=898'>899</a>         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/models.py?line=900'>901</a> self._content_consumed = True
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/models.py?line=901'>902</a> # don't need to release the connection; that's been handled by urllib3
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/models.py?line=902'>903</a> # since we exhausted the data.
#
# File ~/.local/lib/python3.10/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/models.py?line=813'>814</a> if hasattr(self.raw, "stream"):
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/models.py?line=814'>815</a>     try:
# --> <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/models.py?line=815'>816</a>         yield from self.raw.stream(chunk_size, decode_content=True)
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/models.py?line=816'>817</a>     except ProtocolError as e:
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/requests/models.py?line=817'>818</a>         raise ChunkedEncodingError(e)
#
# File ~/.local/lib/python3.10/site-packages/urllib3/response.py:575, in HTTPResponse.stream(self, amt, decode_content)
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/urllib3/response.py?line=572'>573</a> else:
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/urllib3/response.py?line=573'>574</a>     while not is_fp_closed(self._fp):
# --> <a href='file:///home/pratik/.local/lib/python3.10/site-packages/urllib3/response.py?line=574'>575</a>         data = self.read(amt=amt, decode_content=decode_content)
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/urllib3/response.py?line=576'>577</a>         if data:
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/urllib3/response.py?line=577'>578</a>             yield data
#
# File ~/.local/lib/python3.10/site-packages/urllib3/response.py:518, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/urllib3/response.py?line=515'>516</a> else:
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/urllib3/response.py?line=516'>517</a>     cache_content = False
# --> <a href='file:///home/pratik/.local/lib/python3.10/site-packages/urllib3/response.py?line=517'>518</a>     data = self._fp.read(amt) if not fp_closed else b""
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/urllib3/response.py?line=518'>519</a>     if (
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/urllib3/response.py?line=519'>520</a>         amt != 0 and not data
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/urllib3/response.py?line=520'>521</a>     ):  # Platform-specific: Buggy versions of Python.
#    (...)
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/urllib3/response.py?line=526'>527</a>         # not properly close the connection in all cases. There is
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/urllib3/response.py?line=527'>528</a>         # no harm in redundantly calling close.
#     <a href='file:///home/pratik/.local/lib/python3.10/site-packages/urllib3/response.py?line=528'>529</a>         self._fp.close()
#
# File /usr/lib/python3.10/http/client.py:466, in HTTPResponse.read(self, amt)
#     <a href='file:///usr/lib/python3.10/http/client.py?line=462'>463</a> if self.length is not None and amt > self.length:
#     <a href='file:///usr/lib/python3.10/http/client.py?line=463'>464</a>     # clip the read to the "end of response"
#     <a href='file:///usr/lib/python3.10/http/client.py?line=464'>465</a>     amt = self.length
# --> <a href='file:///usr/lib/python3.10/http/client.py?line=465'>466</a> s = self.fp.read(amt)
#     <a href='file:///usr/lib/python3.10/http/client.py?line=466'>467</a> if not s and amt:
#     <a href='file:///usr/lib/python3.10/http/client.py?line=467'>468</a>     # Ideally, we would raise IncompleteRead if the content-length
#     <a href='file:///usr/lib/python3.10/http/client.py?line=468'>469</a>     # wasn't satisfied, but it might break compatibility.
#     <a href='file:///usr/lib/python3.10/http/client.py?line=469'>470</a>     self._close_conn()
#
# File /usr/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     <a href='file:///usr/lib/python3.10/socket.py?line=702'>703</a> while True:
#     <a href='file:///usr/lib/python3.10/socket.py?line=703'>704</a>     try:
# --> <a href='file:///usr/lib/python3.10/socket.py?line=704'>705</a>         return self._sock.recv_into(b)
#     <a href='file:///usr/lib/python3.10/socket.py?line=705'>706</a>     except timeout:
#     <a href='file:///usr/lib/python3.10/socket.py?line=706'>707</a>         self._timeout_occurred = True
#
# File /usr/lib/python3.10/ssl.py:1274, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    <a href='file:///usr/lib/python3.10/ssl.py?line=1269'>1270</a>     if flags != 0:
#    <a href='file:///usr/lib/python3.10/ssl.py?line=1270'>1271</a>         raise ValueError(
#    <a href='file:///usr/lib/python3.10/ssl.py?line=1271'>1272</a>           "non-zero flags not allowed in calls to recv_into() on %s" %
#    <a href='file:///usr/lib/python3.10/ssl.py?line=1272'>1273</a>           self.__class__)
# -> <a href='file:///usr/lib/python3.10/ssl.py?line=1273'>1274</a>     return self.read(nbytes, buffer)
#    <a href='file:///usr/lib/python3.10/ssl.py?line=1274'>1275</a> else:
#    <a href='file:///usr/lib/python3.10/ssl.py?line=1275'>1276</a>     return super().recv_into(buffer, nbytes, flags)
#
# File /usr/lib/python3.10/ssl.py:1130, in SSLSocket.read(self, len, buffer)
#    <a href='file:///usr/lib/python3.10/ssl.py?line=1127'>1128</a> try:
#    <a href='file:///usr/lib/python3.10/ssl.py?line=1128'>1129</a>     if buffer is not None:
# -> <a href='file:///usr/lib/python3.10/ssl.py?line=1129'>1130</a>         return self._sslobj.read(len, buffer)
#    <a href='file:///usr/lib/python3.10/ssl.py?line=1130'>1131</a>     else:
#    <a href='file:///usr/lib/python3.10/ssl.py?line=1131'>1132</a>         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
att_resp1=response

# %%
# Copy of Utility Bills Attachment 

s3_url = inp['url']['3eUtilityBillsURL']  
folder = ""
attachment_category = s3_url.split('/')[-1].split('.')[-1]
attachment_label = "3eUtilityBills"
filename=s3_url.split('/')[-1]
response=json.loads(upload_file_from_url(session_token, s3_url, ref_no,filename, folder, attachment_category, attachment_label))
response['folderName']=response['folderId']
response
# Out:
# File uploaded successfully
# Upload Response:  {"attachmentLabel":"3eUtilityBills","attachmentCategory":"Attachment","activityFileName":"Electricity+bill+(1).pdf","activityFileSrcPath":"180069554","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"294662","attachmentDMSId":"367140894","totalNoOfPages":"1","activityFileDate":"09/20/2023","publicDocument":"Y","activityComments":"180069554:3eUtilityBills:Document added successfully.","folderName":"","folderId":"180069554","version":"","addedBy":"Fo User"}
# {'attachmentLabel': '3eUtilityBills',
#  'attachmentCategory': 'Attachment',
#  'activityFileName': 'Electricity+bill+(1).pdf',
#  'activityFileSrcPath': '180069554',
#  'activityFileSrcType': 'I',
#  'activityFileExt': 'pdf',
#  'activityFileSize': '294662',
#  'attachmentDMSId': '367140894',
#  'totalNoOfPages': '1',
#  'activityFileDate': '09/20/2023',
#  'publicDocument': 'Y',
#  'activityComments': '180069554:3eUtilityBills:Document added successfully.',
#  'folderName': '180069554',
#  'folderId': '180069554',
#  'version': '',
#  'addedBy': 'Fo User'}

# %%
att_resp2=response

# %%
#(B) Particulars of individual designated partners not having DIN/DPIN
#(i) Basic details of Designated partner
#Verify Pan 

import requests

url = "https://www.mca.gov.in/bin/cbdtPanValidate"

headers = {
    "Host": "www.mca.gov.in",
    "Cookie": f"cookiesession1=678B2869144E6B476733B93A4104896E; deviceId=4d23ogqkdbe; alertPopup=true; session-token={session_token}",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://www.mca.gov.in",
}

payload = {
    "panData": json.dumps(inp['payload']['panData'])
}

response = requests.post(url, headers=headers, data=payload)


if response.status_code == 200:
    print(response.text)
else:
    print("renter")
# Out:
# {"resCode":200,"resStr":"{\"status\":\"true\"}"}

# %%
#(B) Particulars of individual designated partners not having DIN/DPIN
#(iii) Whether the present residential address same as permanent residential address
#Proof of Identity attachment 


s3_url = inp['url']['6bIdentityProof1URL']  
folder = ""
attachment_category = s3_url.split('/')[-1].split('.')[-1].replace("+"," ")
attachment_label = "6bIdentityProof"
filename=s3_url.split('/')[-1]
response=json.loads(upload_file_from_url(session_token, s3_url, ref_no,filename, folder, attachment_category, attachment_label))
response['folderName']=response['folderId']
response
# Out:
# File uploaded successfully
# Upload Response:  {"attachmentLabel":"6bIdentityProof","attachmentCategory":"Attachment","activityFileName":"sachin_aadhar_merged+(1).pdf","activityFileSrcPath":"180069554","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"225573","attachmentDMSId":"367140994","totalNoOfPages":"2","activityFileDate":"09/20/2023","publicDocument":"Y","activityComments":"180069554:6bIdentityProof:Document added successfully.","folderName":"","folderId":"180069554","version":"","addedBy":"Fo User"}
# {'attachmentLabel': '6bIdentityProof',
#  'attachmentCategory': 'Attachment',
#  'activityFileName': 'sachin_aadhar_merged+(1).pdf',
#  'activityFileSrcPath': '180069554',
#  'activityFileSrcType': 'I',
#  'activityFileExt': 'pdf',
#  'activityFileSize': '225573',
#  'attachmentDMSId': '367140994',
#  'totalNoOfPages': '2',
#  'activityFileDate': '09/20/2023',
#  'publicDocument': 'Y',
#  'activityComments': '180069554:6bIdentityProof:Document added successfully.',
#  'folderName': '180069554',
#  'folderId': '180069554',
#  'version': '',
#  'addedBy': 'Fo User'}

# %%
att_resp3=response

# %%
#(B) Particulars of individual designated partners not having DIN/DPIN
#(iii) Whether the present residential address same as permanent residential address
#Residential Proof attachment 

s3_url = inp['url']['6bResidentialProof1URL']   
folder = ""
attachment_category = s3_url.split('/')[-1].split('.')[-1].replace("+",' ')
attachment_label = "6bResidentialProof"
filename=s3_url.split('/')[-1]
response=json.loads(upload_file_from_url(session_token, s3_url, ref_no,filename, folder, attachment_category, attachment_label))
response['folderName']=response['folderId']
response
# Out:
# File uploaded successfully
# Upload Response:  {"attachmentLabel":"6bResidentialProof","attachmentCategory":"Attachment","activityFileName":"Sachin_Bank+(1).pdf","activityFileSrcPath":"180069554","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"152870","attachmentDMSId":"367141076","totalNoOfPages":"11","activityFileDate":"09/20/2023","publicDocument":"Y","activityComments":"180069554:6bResidentialProof:Document added successfully.","folderName":"","folderId":"180069554","version":"","addedBy":"Fo User"}
# {'attachmentLabel': '6bResidentialProof',
#  'attachmentCategory': 'Attachment',
#  'activityFileName': 'Sachin_Bank+(1).pdf',
#  'activityFileSrcPath': '180069554',
#  'activityFileSrcType': 'I',
#  'activityFileExt': 'pdf',
#  'activityFileSize': '152870',
#  'attachmentDMSId': '367141076',
#  'totalNoOfPages': '11',
#  'activityFileDate': '09/20/2023',
#  'publicDocument': 'Y',
#  'activityComments': '180069554:6bResidentialProof:Document added successfully.',
#  'folderName': '180069554',
#  'folderId': '180069554',
#  'version': '',
#  'addedBy': 'Fo User'}

# %%
att_resp4=response

# %%
#(D) Particulars of bodies corporate and their nominees as designated partners having not DIN/DPIN
#(iii) Particulars of the person signing on behalf of the body corporate as nominee
#Verify PAN

import requests

url = "https://www.mca.gov.in/bin/cbdtPanValidate"

headers = {
    "Host": "www.mca.gov.in",
    "Cookie": "cookiesession1=678B2869144E6B476733B93A4104896E; deviceId=4d23ogqkdbe; alertPopup=true; session-token=eyJhbGciOiJIUzUxMiJ9..P3NoD8FXq31muTmemEWkAUt58f01-bLJ4678e8H_dpezUDKyplvchopljZJOWPzQLa9P0BzVujSwQw-57DepoQ; sessionID=23faae5e-871e-404e-9b0a-a13e05f7716d",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://www.mca.gov.in",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/Fillip.html",
}

payload = {
    "panData": '{"pan": "FZMPB2968E","fName": "JAY","midName": "","surName": "BHATTARAI","dob": "05/05/2001","fullName": "JAY BHATTARAI"}'
}

response = requests.post(url, headers=headers, data=payload)


if response.status_code == 200:
    print(response.text)
else:
    print(f"Error: {response.status_code} - {response.reason}")
# Out:
# {"resCode":200,"resStr":"{\"status\":\"true\"}"}

# %%
#(D) Particulars of bodies corporate and their nominees as designated partners having not DIN/DPIN
#Submit a copy of the proof of identity and proof of address
#Proof of identity

s3_url = inp['url']['6bIdentityProof2URL']    
folder = ""
attachment_category = s3_url.split('/')[-1].split('.')[-1].replace("+",' ')
attachment_label = "6bIdentityProof"
filename=s3_url.split('/')[-1]
response=json.loads(upload_file_from_url(session_token, s3_url, ref_no,filename, folder, attachment_category, attachment_label))
response['folderName']=response['folderId']
response
# Out:
# File uploaded successfully
# Upload Response:  {"attachmentLabel":"6bIdentityProof","attachmentCategory":"Attachment","activityFileName":"Jay_aadhar_PAN-Jay_merged+(1).pdf","activityFileSrcPath":"180069554","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"368940","attachmentDMSId":"367141162","totalNoOfPages":"2","activityFileDate":"09/20/2023","publicDocument":"Y","activityComments":"180069554:6bIdentityProof:Document added successfully.","folderName":"","folderId":"180069554","version":"","addedBy":"Fo User"}
# {'attachmentLabel': '6bIdentityProof',
#  'attachmentCategory': 'Attachment',
#  'activityFileName': 'Jay_aadhar_PAN-Jay_merged+(1).pdf',
#  'activityFileSrcPath': '180069554',
#  'activityFileSrcType': 'I',
#  'activityFileExt': 'pdf',
#  'activityFileSize': '368940',
#  'attachmentDMSId': '367141162',
#  'totalNoOfPages': '2',
#  'activityFileDate': '09/20/2023',
#  'publicDocument': 'Y',
#  'activityComments': '180069554:6bIdentityProof:Document added successfully.',
#  'folderName': '180069554',
#  'folderId': '180069554',
#  'version': '',
#  'addedBy': 'Fo User'}

# %%
att_resp5=response

# %%
#(D) Particulars of bodies corporate and their nominees as designated partners having not DIN/DPIN
#Submit a copy of the proof of identity and proof of address
#Residential proof

s3_url = inp['url']['6bResidentialProof2URL']  
folder = ""
attachment_category = s3_url.split('/')[-1].split('.')[-1]
attachment_label = "6bResidentialProof"
filename=s3_url.split('/')[-1]
response=json.loads(upload_file_from_url(session_token, s3_url, ref_no,filename, folder, attachment_category, attachment_label))
response['folderName']=response['folderId']
response
# Out:
# File uploaded successfully
# Upload Response:  {"attachmentLabel":"6bResidentialProof","attachmentCategory":"Attachment","activityFileName":"Jay_Bank+(1).pdf","activityFileSrcPath":"180069554","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"34948","attachmentDMSId":"367141188","totalNoOfPages":"4","activityFileDate":"09/20/2023","publicDocument":"Y","activityComments":"180069554:6bResidentialProof:Document added successfully.","folderName":"","folderId":"180069554","version":"","addedBy":"Fo User"}
# {'attachmentLabel': '6bResidentialProof',
#  'attachmentCategory': 'Attachment',
#  'activityFileName': 'Jay_Bank+(1).pdf',
#  'activityFileSrcPath': '180069554',
#  'activityFileSrcType': 'I',
#  'activityFileExt': 'pdf',
#  'activityFileSize': '34948',
#  'attachmentDMSId': '367141188',
#  'totalNoOfPages': '4',
#  'activityFileDate': '09/20/2023',
#  'publicDocument': 'Y',
#  'activityComments': '180069554:6bResidentialProof:Document added successfully.',
#  'folderName': '180069554',
#  'folderId': '180069554',
#  'version': '',
#  'addedBy': 'Fo User'}

# %%
att_resp6=response

# %%
payload=r'''{"requestBody":{"operation":"Save","integrationId":"1-4POF4HH","referenceNumber":"1-10259800181","srn":"","formId":"Homogeneous","formName":"FiLLiP","formDescription":"","formVersion":"1.2","userId":"KASHVIJAIN19@GMAIL.COM","CIN":null,"SRFOStatus":"Draft/Pending Submission","formData":{"formIntegrationId":"1-4POF4HJ","isRegistered":"Y","srn":"M27873561","incorporationType":"New Incorporation","cin":null,"proposedName":"INVITEFULFUSION LLP","attachment":false,"attachment2a":false,"attachment2c":false,"attachment2d":false,"attachment2e":false,"significanceProposedName":null,"vernacularLanguage":null,"isRegisteredPending":null,"particulars":null,"registeredAddress":{"addressI":"The principal BMS College","addressII":"Educational Institution","country":"India","pin":"560085","area":"Banashankari III Stage","city":"Bangalore South","district":"Bangalore","state":"Karnataka","longitude":"73.859207","latitude":"18.528851","policeStation":"banashankari","phone":null,"mobile":"9319421653","fax":null,"email":"Sachuuuu1428@gmail.com","registrarOfficeName":"Registrar of Companies, Karnataka"},"buissnessactivity":[{"srno":"1","industrySubClass":"Axxx010","description":"abc rtd","primary":"No"},{"srno":"2","industrySubClass":"bxxx010","description":"fghty rtd","primary":"yes"}],"mainIndustrialNICcode":"52291","mainIndustrialDescriptionOfNIC":"Activities of travel agents and tour operators","otherIndustrialNICcode":"79120","otherIndustrialDescriptionOfNIC":"Tour operator activities","NICCode3":"79110","NICCode3Desc":"Travel agency activities","numberOfDesignatedPartnersValidDIN_DPIN":"0","numberOfDesignatedPartnersNotValidDIN_DPIN":"2","individualValidDINorDPIN":"0","individualNotValidDINorDPIN":"2","nominiesValidDINorDPIN":"0","nominiesNotValidDINorDPIN":"0","numberOfPartnersOtherThanDesignatedPartnerValidDINorDPIN":"0","numberOfPartnersOtherThanDesignatedPartnerNotValidDINorDPIN":"0","individualOtherThanDesignatedPartnerValidDINorDPIN":"0","individualOtherThanDesignatedPartnerNotValidDINorDPIN":"0","nominiesOtherThanDesignatedPartnerValidDINorDPIN":"0","nominiesOtherThanDesignatedPartnerNotValidDINorDPIN":"0","totalNumberValidDesignatedPartners":"0","totalNumberNotValidDesignatedPartners":"2","MCALLPFiLLiPIndPartner":[{"Category":"Particulars of individual designated partners not having DIN/DPIN","firstName":"SACHIN","middleName":"","surname":"MADHESIYA","fatherFirstName":"RAJU","fatherMiddleName":"PRASAD","fathersurname":"MADHESIYA","gender":"Male","dateofBirth":"12/14/1998","nationality":"India","isResidentInIndia":"Y","isPanPassport":"PAN","panPassportDetails":"HQRPM8960H","placeOfBirthState":"Uttar Pradesh","placeOfBirthDistrict":"Agra","partnerIsCitizenofIndia":"Y","occupationType":"Private Employment","descriptionOfOthers":null,"areaOfOccupation":"Private Employment","otherAreaOfOccupation":null,"educationalQualification":"Bachelor's degree","otherEducation":null,"mobileNo":"+919319421653","emailid":"Sachuuuu1428@gmail.com","proodOfIdentity":"Aadhaar","residentialproof":"Bank Statement","identityProofNo":"798000043919","residentialProofNo":"7324123775","numberOfsharesHeld":null,"paidupvalueofsharesheld":null,"formOfContribution":"Other than cash","otherModeOfPayment":"CHEQUE","monetaryValueOfContributionInFigures":"50000","monetaryValueOfContributionInWords":" Fifty Thousand","numberOfLLPpartner":"0","numberOfcompanyDirector":"0","presentAddressSameAddressAsPremanent":"Y","durationStayedAtPresentAddressYears":null,"durationStayedAtPresentAddressMonth":null,"addressOfPreviousResidence":null,"designatedpartnerID":"","name":"","isResidentIndia":"Y","paid":"","modeOfPay":"Other than cash","monetaryValueInFigures":"50000","monetaryValueInwords":" Fifty Thousand","numberOfLLP":"","numberOfCompanyHoldAsDirector":"5","partnerFirstName":"SACHIN","partnerMiddleName":"","partnerSurname":"MADHESIYA","partnerFatherFirstname":"RAJU","partnerFatherMiddlename":"PRASAD","partnerFatherSurname":"MADHESIYA","partnerGender":"Male","partnerDateofBirth":"12/14/1998","partnerNationality":"India","partnerIsResidentIndia":"Y","isPanPass":"PAN","panPassDetails":"BUOPE2342B","partnerPlaceofBirthState":"","partnerPlaceofBirthDistrict":"Nagpur","OccupationType":"Private Employment","isresidentofIndia":"Y","numberofsharesheld":"100","passportOrPAN":"PAN","emailID":"Sachuuuu1428@gmail.com","previousResidence ":"","numberOfSharesHeld":"","PaidupvalueShares":"","ListOfbodyParnerIndOfficeAddress":{"bodyParnerIndOfficeAddress":[{"addressType":"Permanent Address","addressI":"ward no 9 gandhi nagar","addressII":"hariharapura","country":"India","pin":"272164","area":"Hariharpur","city":"Dhanghata","district":"Sant Kabir Nagar","state":"Uttar Pradesh","policeStation":"Hariharpur","phone":"05542282600"},{"addressType":"Present Address","addressI":"ward no 9 gandhi nagar","addressII":"hariharapura","country":"India","pin":"272164","area":"Hariharpur","city":"Dhanghata","district":"Sant Kabir Nagar","state":"Uttar Pradesh","policeStation":"Hariharpur","phone":"05542282600"},{"addressType":"Registered Address","addressI":"ward no 9 gandhi nagar","addressII":"hariharapura","country":"India","pin":"272164","area":"Hariharpur","city":"Dhanghata","district":"Sant Kabir Nagar","state":"Uttar Pradesh","policeStation":"Hariharpur","phone":"05542282600"}]}},{"Category":"Particulars of individual designated partners not having DIN/DPIN","firstName":"JAY","middleName":"","surname":"BHATTARAI","fatherFirstName":"DURGA","fatherMiddleName":"PRASAD","fathersurname":"BHATTARAI","gender":"Male","dateofBirth":"05/05/2001","nationality":"India","isResidentInIndia":"Y","isPanPassport":"PAN","panPassportDetails":"FZMPB2968E","placeOfBirthState":"Karnataka","placeOfBirthDistrict":"Ballari","partnerIsCitizenofIndia":"Y","occupationType":"Private Employment","descriptionOfOthers":null,"areaOfOccupation":"Private Employment","otherAreaOfOccupation":null,"educationalQualification":"Bachelor's degree","otherEducation":null,"mobileNo":"+919916371230","emailid":"bhattaraijay23@gmail.com","proodOfIdentity":"Aadhaar","residentialproof":"Bank Statement","identityProofNo":"581808086216","residentialProofNo":"90862388116","numberOfsharesHeld":null,"paidupvalueofsharesheld":null,"formOfContribution":"Other than cash","otherModeOfPayment":"cheque","monetaryValueOfContributionInFigures":"50000","monetaryValueOfContributionInWords":" Fifty Thousand","numberOfLLPpartner":"0","numberOfcompanyDirector":"0","presentAddressSameAddressAsPremanent":"Y","durationStayedAtPresentAddressYears":null,"durationStayedAtPresentAddressMonth":null,"addressOfPreviousResidence":null,"designatedpartnerID":"","name":"","isResidentIndia":"Y","paid":"","modeOfPay":"Other than cash","monetaryValueInFigures":"50000","monetaryValueInwords":" Fifty Thousand","numberOfLLP":"","numberOfCompanyHoldAsDirector":"5","partnerFirstName":"JAY","partnerMiddleName":"","partnerSurname":"BHATTARAI","partnerFatherFirstname":"DURGA","partnerFatherMiddlename":"PRASAD","partnerFatherSurname":"BHATTARAI","partnerGender":"Male","partnerDateofBirth":"05/05/2001","partnerNationality":"India","partnerIsResidentIndia":"Y","isPanPass":"PAN","panPassDetails":"BUOPE2342B","partnerPlaceofBirthState":"","partnerPlaceofBirthDistrict":"Nagpur","OccupationType":"Private Employment","isresidentofIndia":"Y","numberofsharesheld":"100","passportOrPAN":"PAN","emailID":"bhattaraijay23@gmail.com","previousResidence ":"","numberOfSharesHeld":"","PaidupvalueShares":"","ListOfbodyParnerIndOfficeAddress":{"bodyParnerIndOfficeAddress":[{"addressType":"Permanent Address","addressI":"BMSCE Boys Hostel","addressII":"bms college","country":"India","pin":"560004","area":"Basavanagudi","city":"Bangalore","district":"Bangalore","state":"Karnataka","policeStation":"Basavangudi","phone":"08026622130"},{"addressType":"Present Address","addressI":"BMSCE Boys Hostel","addressII":"bms college","country":"India","pin":"560004","area":"Basavanagudi","city":"Bangalore","district":"Bangalore","state":"Karnataka","policeStation":"Basavangudi","phone":"08026622130"},{"addressType":"Registered Address","addressI":"BMSCE Boys Hostel","addressII":"bms college","country":"India","pin":"560004","area":"Basavanagudi","city":"Bangalore","district":"Bangalore","state":"Karnataka","policeStation":"Basavangudi","phone":"08026622130"}]}}]},"formAttachment":[{"attachmentLabel":"6bIdentityProof","attachmentCategory":"Attachment","activityFileName":"_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg","activityFileSrcPath":"174794298","activityFileSrcType":"I","activityFileExt":"jpeg","activityFileSize":"112861","attachmentDMSId":"353841117","totalNoOfPages":"1","activityFileDate":"08/02/2023","publicDocument":"Y","activityComments":"174794298:6bIdentityProof:Document added successfully.","folderName":"174794298","folderId":"174794298","version":"","addedBy":"Fo User"},{"attachmentLabel":"6bResidentialProof","attachmentCategory":"Attachment","activityFileName":"_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg","activityFileSrcPath":"174794298","activityFileSrcType":"I","activityFileExt":"jpeg","activityFileSize":"112861","attachmentDMSId":"353841124","totalNoOfPages":"1","activityFileDate":"08/02/2023","publicDocument":"Y","activityComments":"174794298:6bResidentialProof:Document added successfully.","folderName":"174794298","folderId":"174794298","version":"","addedBy":"Fo User"},{"attachmentLabel":"6bIdentityProof","attachmentCategory":"Attachment","activityFileName":"_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg","activityFileSrcPath":"174794298","activityFileSrcType":"I","activityFileExt":"jpeg","activityFileSize":"112861","attachmentDMSId":"353841130","totalNoOfPages":"1","activityFileDate":"08/02/2023","publicDocument":"Y","activityComments":"174794298:6bIdentityProof:Document added successfully.","folderName":"174794298","folderId":"174794298","version":"","addedBy":"Fo User"},{"attachmentLabel":"6bResidentialProof","attachmentCategory":"Attachment","activityFileName":"_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg","activityFileSrcPath":"174794298","activityFileSrcType":"I","activityFileExt":"jpeg","activityFileSize":"112861","attachmentDMSId":"353841133","totalNoOfPages":"1","activityFileDate":"08/02/2023","publicDocument":"Y","activityComments":"174794298:6bResidentialProof:Document added successfully.","folderName":"174794298","folderId":"174794298","version":"","addedBy":"Fo User"},{"attachmentLabel":"3eAdressProof","attachmentCategory":"Attachment","activityFileName":"_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg","activityFileSrcPath":"174794298","activityFileSrcType":"I","activityFileExt":"jpeg","activityFileSize":"112861","attachmentDMSId":"353841170","totalNoOfPages":"1","activityFileDate":"08/02/2023","publicDocument":"Y","activityComments":"174794298:3eAdressProof:Document added successfully.","folderName":"174794298","folderId":"174794298","version":"","addedBy":"Fo User"},{"attachmentLabel":"3eUtilityBills","attachmentCategory":"Attachment","activityFileName":"_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg","activityFileSrcPath":"174794298","activityFileSrcType":"I","activityFileExt":"jpeg","activityFileSize":"112861","attachmentDMSId":"353841174","totalNoOfPages":"1","activityFileDate":"08/02/2023","publicDocument":"Y","activityComments":"174794298:3eUtilityBills:Document added successfully.","folderName":"174794298","folderId":"174794298","version":"","addedBy":"Fo User"}]}}'''

# %%
final_submit=json.loads(payload)

# %%
final_submit['requestBody']['formData']['registeredAddress']=inp['payload']['registeredAddress']
final_submit['requestBody']['formData']['registeredAddress']
# Out:
# {'addressI': 'BMS College ofEngineering',
#  'addressII': 'Bull Temple Road',
#  'country': 'India',
#  'pin': '560019',
#  'area': 'Gaviopuram Extension',
#  'city': 'Bangalore South',
#  'district': 'Bangalore',
#  'state': 'Karnataka',
#  'longitude': '73.859207',
#  'latitude': '18.528851',
#  'policeStation': 'banashankari',
#  'phone': None,
#  'mobile': '9319421653',
#  'fax': None,
#  'email': 'Sachuuuu1428@gmail.com',
#  'registrarOfficeName': 'Registrar of Companies, Karnataka'}

# %%
final_submit['requestBody']['formData']['buissnessactivity']=inp['payload']['buissnessactivity']
final_submit['requestBody']['formData']['buissnessactivity']
# Out:
# [{'srno': '1',
#   'industrySubClass': 'Axxx010',
#   'description': 'abc rtd',
#   'primary': 'No'},
#  {'srno': '2',
#   'industrySubClass': 'bxxx010',
#   'description': 'fghty rtd',
#   'primary': 'yes'}]

# %%
final_submit
# Out:
# {'requestBody': {'operation': 'Save',
#   'integrationId': '1-4POF4HH',
#   'referenceNumber': '1-10259800181',
#   'srn': '',
#   'formId': 'Homogeneous',
#   'formName': 'FiLLiP',
#   'formDescription': '',
#   'formVersion': '1.2',
#   'userId': 'KASHVIJAIN19@GMAIL.COM',
#   'CIN': None,
#   'SRFOStatus': 'Draft/Pending Submission',
#   'formData': {'formIntegrationId': '1-4POF4HJ',
#    'isRegistered': 'Y',
#    'srn': 'M27873561',
#    'incorporationType': 'New Incorporation',
#    'cin': None,
#    'proposedName': 'INVITEFULFUSION LLP',
#    'attachment': False,
#    'attachment2a': False,
#    'attachment2c': False,
#    'attachment2d': False,
#    'attachment2e': False,
#    'significanceProposedName': None,
#    'vernacularLanguage': None,
#    'isRegisteredPending': None,
#    'particulars': None,
#    'registeredAddress': {'addressI': 'BMS College ofEngineering',
#     'addressII': 'Bull Temple Road',
#     'country': 'India',
#     'pin': '560019',
#     'area': 'Gaviopuram Extension',
#     'city': 'Bangalore South',
#     'district': 'Bangalore',
#     'state': 'Karnataka',
#     'longitude': '73.859207',
#     'latitude': '18.528851',
#     'policeStation': 'banashankari',
#     'phone': None,
#     'mobile': '9319421653',
#     'fax': None,
#     'email': 'Sachuuuu1428@gmail.com',
#     'registrarOfficeName': 'Registrar of Companies, Karnataka'},
#    'buissnessactivity': [{'srno': '1',
#      'industrySubClass': 'Axxx010',
#      'description': 'abc rtd',
#      'primary': 'No'},
#     {'srno': '2',
#      'industrySubClass': 'bxxx010',
#      'description': 'fghty rtd',
#      'primary': 'yes'}],
#    'mainIndustrialNICcode': '52291',
#    'mainIndustrialDescriptionOfNIC': 'Activities of travel agents and tour operators',
#    'otherIndustrialNICcode': '79120',
#    'otherIndustrialDescriptionOfNIC': 'Tour operator activities',
#    'NICCode3': '79110',
#    'NICCode3Desc': 'Travel agency activities',
#    'numberOfDesignatedPartnersValidDIN_DPIN': '0',
#    'numberOfDesignatedPartnersNotValidDIN_DPIN': '2',
#    'individualValidDINorDPIN': '0',
#    'individualNotValidDINorDPIN': '2',
#    'nominiesValidDINorDPIN': '0',
#    'nominiesNotValidDINorDPIN': '0',
#    'numberOfPartnersOtherThanDesignatedPartnerValidDINorDPIN': '0',
#    'numberOfPartnersOtherThanDesignatedPartnerNotValidDINorDPIN': '0',
#    'individualOtherThanDesignatedPartnerValidDINorDPIN': '0',
#    'individualOtherThanDesignatedPartnerNotValidDINorDPIN': '0',
#    'nominiesOtherThanDesignatedPartnerValidDINorDPIN': '0',
#    'nominiesOtherThanDesignatedPartnerNotValidDINorDPIN': '0',
#    'totalNumberValidDesignatedPartners': '0',
#    'totalNumberNotValidDesignatedPartners': '2',
#    'MCALLPFiLLiPIndPartner': [{'Category': 'Particulars of individual designated partners not having DIN/DPIN',
#      'firstName': 'SACHIN',
#      'middleName': '',
#      'surname': 'MADHESIYA',
#      'fatherFirstName': 'RAJU',
#      'fatherMiddleName': 'PRASAD',
#      'fathersurname': 'MADHESIYA',
#      'gender': 'Male',
#      'dateofBirth': '12/14/1998',
#      'nationality': 'India',
#      'isResidentInIndia': 'Y',
#      'isPanPassport': 'PAN',
#      'panPassportDetails': 'HQRPM8960H',
#      'placeOfBirthState': 'Uttar Pradesh',
#      'placeOfBirthDistrict': 'Agra',
#      'partnerIsCitizenofIndia': 'Y',
#      'occupationType': 'Private Employment',
#      'descriptionOfOthers': None,
#      'areaOfOccupation': 'Private Employment',
#      'otherAreaOfOccupation': None,
#      'educationalQualification': "Bachelor's degree",
#      'otherEducation': None,
#      'mobileNo': '+919319421653',
#      'emailid': 'Sachuuuu1428@gmail.com',
#      'proodOfIdentity': 'Aadhaar',
#      'residentialproof': 'Bank Statement',
#      'identityProofNo': '798000043919',
#      'residentialProofNo': '7324123775',
#      'numberOfsharesHeld': None,
#      'paidupvalueofsharesheld': None,
#      'formOfContribution': 'Other than cash',
#      'otherModeOfPayment': 'CHEQUE',
#      'monetaryValueOfContributionInFigures': '50000',
#      'monetaryValueOfContributionInWords': ' Fifty Thousand',
#      'numberOfLLPpartner': '0',
#      'numberOfcompanyDirector': '0',
#      'presentAddressSameAddressAsPremanent': 'Y',
#      'durationStayedAtPresentAddressYears': None,
#      'durationStayedAtPresentAddressMonth': None,
#      'addressOfPreviousResidence': None,
#      'designatedpartnerID': '',
#      'name': '',
#      'isResidentIndia': 'Y',
#      'paid': '',
#      'modeOfPay': 'Other than cash',
#      'monetaryValueInFigures': '50000',
#      'monetaryValueInwords': ' Fifty Thousand',
#      'numberOfLLP': '',
#      'numberOfCompanyHoldAsDirector': '5',
#      'partnerFirstName': 'SACHIN',
#      'partnerMiddleName': '',
#      'partnerSurname': 'MADHESIYA',
#      'partnerFatherFirstname': 'RAJU',
#      'partnerFatherMiddlename': 'PRASAD',
#      'partnerFatherSurname': 'MADHESIYA',
#      'partnerGender': 'Male',
#      'partnerDateofBirth': '12/14/1998',
#      'partnerNationality': 'India',
#      'partnerIsResidentIndia': 'Y',
#      'isPanPass': 'PAN',
#      'panPassDetails': 'BUOPE2342B',
#      'partnerPlaceofBirthState': '',
#      'partnerPlaceofBirthDistrict': 'Nagpur',
#      'OccupationType': 'Private Employment',
#      'isresidentofIndia': 'Y',
#      'numberofsharesheld': '100',
#      'passportOrPAN': 'PAN',
#      'emailID': 'Sachuuuu1428@gmail.com',
#      'previousResidence ': '',
#      'numberOfSharesHeld': '',
#      'PaidupvalueShares': '',
#      'ListOfbodyParnerIndOfficeAddress': {'bodyParnerIndOfficeAddress': [{'addressType': 'Permanent Address',
#         'addressI': 'ward no 9 gandhi nagar',
#         'addressII': 'hariharapura',
#         'country': 'India',
#         'pin': '272164',
#         'area': 'Hariharpur',
#         'city': 'Dhanghata',
#         'district': 'Sant Kabir Nagar',
#         'state': 'Uttar Pradesh',
#         'policeStation': 'Hariharpur',
#         'phone': '05542282600'},
#        {'addressType': 'Present Address',
#         'addressI': 'ward no 9 gandhi nagar',
#         'addressII': 'hariharapura',
#         'country': 'India',
#         'pin': '272164',
#         'area': 'Hariharpur',
#         'city': 'Dhanghata',
#         'district': 'Sant Kabir Nagar',
#         'state': 'Uttar Pradesh',
#         'policeStation': 'Hariharpur',
#         'phone': '05542282600'},
#        {'addressType': 'Registered Address',
#         'addressI': 'ward no 9 gandhi nagar',
#         'addressII': 'hariharapura',
#         'country': 'India',
#         'pin': '272164',
#         'area': 'Hariharpur',
#         'city': 'Dhanghata',
#         'district': 'Sant Kabir Nagar',
#         'state': 'Uttar Pradesh',
#         'policeStation': 'Hariharpur',
#         'phone': '05542282600'}]}},
#     {'Category': 'Particulars of individual designated partners not having DIN/DPIN',
#      'firstName': 'JAY',
#      'middleName': '',
#      'surname': 'BHATTARAI',
#      'fatherFirstName': 'DURGA',
#      'fatherMiddleName': 'PRASAD',
#      'fathersurname': 'BHATTARAI',
#      'gender': 'Male',
#      'dateofBirth': '05/05/2001',
#      'nationality': 'India',
#      'isResidentInIndia': 'Y',
#      'isPanPassport': 'PAN',
#      'panPassportDetails': 'FZMPB2968E',
#      'placeOfBirthState': 'Karnataka',
#      'placeOfBirthDistrict': 'Ballari',
#      'partnerIsCitizenofIndia': 'Y',
#      'occupationType': 'Private Employment',
#      'descriptionOfOthers': None,
#      'areaOfOccupation': 'Private Employment',
#      'otherAreaOfOccupation': None,
#      'educationalQualification': "Bachelor's degree",
#      'otherEducation': None,
#      'mobileNo': '+919916371230',
#      'emailid': 'bhattaraijay23@gmail.com',
#      'proodOfIdentity': 'Aadhaar',
#      'residentialproof': 'Bank Statement',
#      'identityProofNo': '581808086216',
#      'residentialProofNo': '90862388116',
#      'numberOfsharesHeld': None,
#      'paidupvalueofsharesheld': None,
#      'formOfContribution': 'Other than cash',
#      'otherModeOfPayment': 'cheque',
#      'monetaryValueOfContributionInFigures': '50000',
#      'monetaryValueOfContributionInWords': ' Fifty Thousand',
#      'numberOfLLPpartner': '0',
#      'numberOfcompanyDirector': '0',
#      'presentAddressSameAddressAsPremanent': 'Y',
#      'durationStayedAtPresentAddressYears': None,
#      'durationStayedAtPresentAddressMonth': None,
#      'addressOfPreviousResidence': None,
#      'designatedpartnerID': '',
#      'name': '',
#      'isResidentIndia': 'Y',
#      'paid': '',
#      'modeOfPay': 'Other than cash',
#      'monetaryValueInFigures': '50000',
#      'monetaryValueInwords': ' Fifty Thousand',
#      'numberOfLLP': '',
#      'numberOfCompanyHoldAsDirector': '5',
#      'partnerFirstName': 'JAY',
#      'partnerMiddleName': '',
#      'partnerSurname': 'BHATTARAI',
#      'partnerFatherFirstname': 'DURGA',
#      'partnerFatherMiddlename': 'PRASAD',
#      'partnerFatherSurname': 'BHATTARAI',
#      'partnerGender': 'Male',
#      'partnerDateofBirth': '05/05/2001',
#      'partnerNationality': 'India',
#      'partnerIsResidentIndia': 'Y',
#      'isPanPass': 'PAN',
#      'panPassDetails': 'BUOPE2342B',
#      'partnerPlaceofBirthState': '',
#      'partnerPlaceofBirthDistrict': 'Nagpur',
#      'OccupationType': 'Private Employment',
#      'isresidentofIndia': 'Y',
#      'numberofsharesheld': '100',
#      'passportOrPAN': 'PAN',
#      'emailID': 'bhattaraijay23@gmail.com',
#      'previousResidence ': '',
#      'numberOfSharesHeld': '',
#      'PaidupvalueShares': '',
#      'ListOfbodyParnerIndOfficeAddress': {'bodyParnerIndOfficeAddress': [{'addressType': 'Permanent Address',
#         'addressI': 'BMSCE Boys Hostel',
#         'addressII': 'bms college',
#         'country': 'India',
#         'pin': '560004',
#         'area': 'Basavanagudi',
#         'city': 'Bangalore',
#         'district': 'Bangalore',
#         'state': 'Karnataka',
#         'policeStation': 'Basavangudi',
#         'phone': '08026622130'},
#        {'addressType': 'Present Address',
#         'addressI': 'BMSCE Boys Hostel',
#         'addressII': 'bms college',
#         'country': 'India',
#         'pin': '560004',
#         'area': 'Basavanagudi',
#         'city': 'Bangalore',
#         'district': 'Bangalore',
#         'state': 'Karnataka',
#         'policeStation': 'Basavangudi',
#         'phone': '08026622130'},
#        {'addressType': 'Registered Address',
#         'addressI': 'BMSCE Boys Hostel',
#         'addressII': 'bms college',
#         'country': 'India',
#         'pin': '560004',
#         'area': 'Basavanagudi',
#         'city': 'Bangalore',
#         'district': 'Bangalore',
#         'state': 'Karnataka',
#         'policeStation': 'Basavangudi',
#         'phone': '08026622130'}]}}]},
#   'formAttachment': [{'attachmentLabel': '6bIdentityProof',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': '_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg',
#     'activityFileSrcPath': '174794298',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'jpeg',
#     'activityFileSize': '112861',
#     'attachmentDMSId': '353841117',
#     'totalNoOfPages': '1',
#     'activityFileDate': '08/02/2023',
#     'publicDocument': 'Y',
#     'activityComments': '174794298:6bIdentityProof:Document added successfully.',
#     'folderName': '174794298',
#     'folderId': '174794298',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': '6bResidentialProof',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': '_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg',
#     'activityFileSrcPath': '174794298',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'jpeg',
#     'activityFileSize': '112861',
#     'attachmentDMSId': '353841124',
#     'totalNoOfPages': '1',
#     'activityFileDate': '08/02/2023',
#     'publicDocument': 'Y',
#     'activityComments': '174794298:6bResidentialProof:Document added successfully.',
#     'folderName': '174794298',
#     'folderId': '174794298',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': '6bIdentityProof',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': '_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg',
#     'activityFileSrcPath': '174794298',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'jpeg',
#     'activityFileSize': '112861',
#     'attachmentDMSId': '353841130',
#     'totalNoOfPages': '1',
#     'activityFileDate': '08/02/2023',
#     'publicDocument': 'Y',
#     'activityComments': '174794298:6bIdentityProof:Document added successfully.',
#     'folderName': '174794298',
#     'folderId': '174794298',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': '6bResidentialProof',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': '_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg',
#     'activityFileSrcPath': '174794298',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'jpeg',
#     'activityFileSize': '112861',
#     'attachmentDMSId': '353841133',
#     'totalNoOfPages': '1',
#     'activityFileDate': '08/02/2023',
#     'publicDocument': 'Y',
#     'activityComments': '174794298:6bResidentialProof:Document added successfully.',
#     'folderName': '174794298',
#     'folderId': '174794298',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': '3eAdressProof',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': '_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg',
#     'activityFileSrcPath': '174794298',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'jpeg',
#     'activityFileSize': '112861',
#     'attachmentDMSId': '353841170',
#     'totalNoOfPages': '1',
#     'activityFileDate': '08/02/2023',
#     'publicDocument': 'Y',
#     'activityComments': '174794298:3eAdressProof:Document added successfully.',
#     'folderName': '174794298',
#     'folderId': '174794298',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': '3eUtilityBills',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': '_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg',
#     'activityFileSrcPath': '174794298',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'jpeg',
#     'activityFileSize': '112861',
#     'attachmentDMSId': '353841174',
#     'totalNoOfPages': '1',
#     'activityFileDate': '08/02/2023',
#     'publicDocument': 'Y',
#     'activityComments': '174794298:3eUtilityBills:Document added successfully.',
#     'folderName': '174794298',
#     'folderId': '174794298',
#     'version': '',
#     'addedBy': 'Fo User'}]}}

# %%
inp['payload']['individualNotValidDINorDPIN']
# Out:
# '2'

# %%
# Access the value of 'individualValidDINorDPIN'
value = inp['payload']['individualNotValidDINorDPIN']

print("Value:", value)  # This will print: Value: 0
# Out:
# Value: 2

# %%
inp
# Out:
# {'payload': {'srn': 'M28186110',
#   'panData': {'pan': 'HQRPM8960H',
#    'fName': 'SACHIN',
#    'midName': '',
#    'surName': 'MADHESIYA',
#    'dob': '14/12/1998',
#    'fullName': 'SACHIN MADHESIYA'},
#   'registeredAddress': {'addressI': 'BMS College ofEngineering',
#    'addressII': 'Bull Temple Road',
#    'country': 'India',
#    'pin': '560019',
#    'area': 'Gaviopuram Extension',
#    'city': 'Bangalore South',
#    'district': 'Bangalore',
#    'state': 'Karnataka',
#    'longitude': '73.859207',
#    'latitude': '18.528851',
#    'policeStation': 'banashankari',
#    'phone': None,
#    'mobile': '9319421653',
#    'fax': None,
#    'email': 'Sachuuuu1428@gmail.com',
#    'registrarOfficeName': 'Registrar of Companies, Karnataka'},
#   'buissnessactivity': [{'srno': '1',
#     'industrySubClass': 'Axxx010',
#     'description': 'abc rtd',
#     'primary': 'No'},
#    {'srno': '2',
#     'industrySubClass': 'bxxx010',
#     'description': 'fghty rtd',
#     'primary': 'yes'}],
#   'mainIndustrialNICcode': '52291',
#   'mainIndustrialDescriptionOfNIC': 'Activities of travel agents and tour operators',
#   'otherIndustrialNICcode': '79120',
#   'otherIndustrialDescriptionOfNIC': 'Tour operator activities',
#   'NICCode3': '79110',
#   'NICCode3Desc': 'Travel agency activities',
#   'numberOfDesignatedPartnersValidDIN_DPIN': '0',
#   'numberOfDesignatedPartnersNotValidDIN_DPIN': '2',
#   'individualValidDINorDPIN': '0',
#   'individualNotValidDINorDPIN': '2',
#   'nominiesValidDINorDPIN': '0',
#   'nominiesNotValidDINorDPIN': '0',
#   'numberOfPartnersOtherThanDesignatedPartnerValidDINorDPIN': '0',
#   'numberOfPartnersOtherThanDesignatedPartnerNotValidDINorDPIN': '0',
#   'individualOtherThanDesignatedPartnerValidDINorDPIN': '0',
#   'individualOtherThanDesignatedPartnerNotValidDINorDPIN': '0',
#   'nominiesOtherThanDesignatedPartnerValidDINorDPIN': '0',
#   'nominiesOtherThanDesignatedPartnerNotValidDINorDPIN': '0',
#   'totalNumberValidDesignatedPartners': '0',
#   'totalNumberNotValidDesignatedPartners': '2',
#   'MCALLPFiLLiPIndPartner': [{'Category': 'Particulars of individual designated partners not having DIN/DPIN',
#     'firstName': 'SACHIN',
#     'middleName': '',
#     'surname': 'MADHESIYA',
#     'fatherFirstName': 'RAJU',
#     'fatherMiddleName': 'PRASAD',
#     'fathersurname': 'MADHESIYA',
#     'gender': 'Male',
#     'dateofBirth': '12/14/1998',
#     'nationality': 'India',
#     'isResidentInIndia': 'Y',
#     'isPanPassport': 'PAN',
#     'panPassportDetails': 'HQRPM8960H',
#     'placeOfBirthState': 'Uttar Pradesh',
#     'placeOfBirthDistrict': 'Agra',
#     'partnerIsCitizenofIndia': 'Y',
#     'occupationType': 'Private Employment',
#     'descriptionOfOthers': None,
#     'areaOfOccupation': 'Private Employment',
#     'otherAreaOfOccupation': None,
#     'educationalQualification': "Bachelor's degree",
#     'otherEducation': None,
#     'mobileNo': '+919319421653',
#     'emailid': 'Sachuuuu1428@gmail.com',
#     'proodOfIdentity': 'Aadhaar',
#     'residentialproof': 'Bank Statement',
#     'identityProofNo': '798000043919',
#     'residentialProofNo': '7324123775',
#     'numberOfsharesHeld': None,
#     'paidupvalueofsharesheld': None,
#     'formOfContribution': 'Other than cash',
#     'otherModeOfPayment': 'CHEQUE',
#     'monetaryValueOfContributionInFigures': '50000',
#     'monetaryValueOfContributionInWords': ' Fifty Thousand',
#     'numberOfLLPpartner': '0',
#     'numberOfcompanyDirector': '0',
#     'presentAddressSameAddressAsPremanent': 'Y',
#     'durationStayedAtPresentAddressYears': None,
#     'durationStayedAtPresentAddressMonth': None,
#     'addressOfPreviousResidence': None,
#     'designatedpartnerID': '',
#     'name': '',
#     'isResidentIndia': 'Y',
#     'paid': '',
#     'modeOfPay': 'Other than cash',
#     'monetaryValueInFigures': '50000',
#     'monetaryValueInwords': ' Fifty Thousand',
#     'numberOfLLP': '',
#     'numberOfCompanyHoldAsDirector': '5',
#     'partnerFirstName': 'SACHIN',
#     'partnerMiddleName': '',
#     'partnerSurname': 'MADHESIYA',
#     'partnerFatherFirstname': 'RAJU',
#     'partnerFatherMiddlename': 'PRASAD',
#     'partnerFatherSurname': 'MADHESIYA',
#     'partnerGender': 'Male',
#     'partnerDateofBirth': '12/14/1998',
#     'partnerNationality': 'India',
#     'partnerIsResidentIndia': 'Y',
#     'isPanPass': 'PAN',
#     'panPassDetails': 'BUOPE2342B',
#     'partnerPlaceofBirthState': '',
#     'partnerPlaceofBirthDistrict': 'Nagpur',
#     'OccupationType': 'Private Employment',
#     'isresidentofIndia': 'Y',
#     'numberofsharesheld': '100',
#     'passportOrPAN': 'PAN',
#     'emailID': 'Sachuuuu1428@gmail.com',
#     'previousResidence ': '',
#     'numberOfSharesHeld': '',
#     'PaidupvalueShares': '',
#     'ListOfbodyParnerIndOfficeAddress': {'bodyParnerIndOfficeAddress': [{'addressType': 'Permanent Address',
#        'addressI': 'ward no 9 gandhi nagar',
#        'addressII': 'hariharapura',
#        'country': 'India',
#        'pin': '272164',
#        'area': 'Hariharpur',
#        'city': 'Dhanghata',
#        'district': 'Sant Kabir Nagar',
#        'state': 'Uttar Pradesh',
#        'policeStation': 'Hariharpur',
#        'phone': '05542282600'},
#       {'addressType': 'Present Address',
#        'addressI': 'ward no 9 gandhi nagar',
#        'addressII': 'hariharapura',
#        'country': 'India',
#        'pin': '272164',
#        'area': 'Hariharpur',
#        'city': 'Dhanghata',
#        'district': 'Sant Kabir Nagar',
#        'state': 'Uttar Pradesh',
#        'policeStation': 'Hariharpur',
#        'phone': '05542282600'},
#       {'addressType': 'Registered Address',
#        'addressI': 'ward no 9 gandhi nagar',
#        'addressII': 'hariharapura',
#        'country': 'India',
#        'pin': '272164',
#        'area': 'Hariharpur',
#        'city': 'Dhanghata',
#        'district': 'Sant Kabir Nagar',
#        'state': 'Uttar Pradesh',
#        'policeStation': 'Hariharpur',
#        'phone': '05542282600'}]}},
#    {'Category': 'Particulars of individual designated partners not having DIN/DPIN',
#     'firstName': 'JAY',
#     'middleName': '',
#     'surname': 'BHATTARAI',
#     'fatherFirstName': 'DURGA',
#     'fatherMiddleName': 'PRASAD',
#     'fathersurname': 'BHATTARAI',
#     'gender': 'Male',
#     'dateofBirth': '05/05/2001',
#     'nationality': 'India',
#     'isResidentInIndia': 'Y',
#     'isPanPassport': 'PAN',
#     'panPassportDetails': 'FZMPB2968E',
#     'placeOfBirthState': 'Karnataka',
#     'placeOfBirthDistrict': 'Ballari',
#     'partnerIsCitizenofIndia': 'Y',
#     'occupationType': 'Private Employment',
#     'descriptionOfOthers': None,
#     'areaOfOccupation': 'Private Employment',
#     'otherAreaOfOccupation': None,
#     'educationalQualification': "Bachelor's degree",
#     'otherEducation': None,
#     'mobileNo': '+919916371230',
#     'emailid': 'bhattaraijay23@gmail.com',
#     'proodOfIdentity': 'Aadhaar',
#     'residentialproof': 'Bank Statement',
#     'identityProofNo': '581808086216',
#     'residentialProofNo': '90862388116',
#     'numberOfsharesHeld': None,
#     'paidupvalueofsharesheld': None,
#     'formOfContribution': 'Other than cash',
#     'otherModeOfPayment': 'cheque',
#     'monetaryValueOfContributionInFigures': '50000',
#     'monetaryValueOfContributionInWords': ' Fifty Thousand',
#     'numberOfLLPpartner': '0',
#     'numberOfcompanyDirector': '0',
#     'presentAddressSameAddressAsPremanent': 'Y',
#     'durationStayedAtPresentAddressYears': None,
#     'durationStayedAtPresentAddressMonth': None,
#     'addressOfPreviousResidence': None,
#     'designatedpartnerID': '',
#     'name': '',
#     'isResidentIndia': 'Y',
#     'paid': '',
#     'modeOfPay': 'Other than cash',
#     'monetaryValueInFigures': '50000',
#     'monetaryValueInwords': ' Fifty Thousand',
#     'numberOfLLP': '',
#     'numberOfCompanyHoldAsDirector': '5',
#     'partnerFirstName': 'JAY',
#     'partnerMiddleName': '',
#     'partnerSurname': 'BHATTARAI',
#     'partnerFatherFirstname': 'DURGA',
#     'partnerFatherMiddlename': 'PRASAD',
#     'partnerFatherSurname': 'BHATTARAI',
#     'partnerGender': 'Male',
#     'partnerDateofBirth': '05/05/2001',
#     'partnerNationality': 'India',
#     'partnerIsResidentIndia': 'Y',
#     'isPanPass': 'PAN',
#     'panPassDetails': 'BUOPE2342B',
#     'partnerPlaceofBirthState': '',
#     'partnerPlaceofBirthDistrict': 'Nagpur',
#     'OccupationType': 'Private Employment',
#     'isresidentofIndia': 'Y',
#     'numberofsharesheld': '100',
#     'passportOrPAN': 'PAN',
#     'emailID': 'bhattaraijay23@gmail.com',
#     'previousResidence ': '',
#     'numberOfSharesHeld': '',
#     'PaidupvalueShares': '',
#     'ListOfbodyParnerIndOfficeAddress': {'bodyParnerIndOfficeAddress': [{'addressType': 'Permanent Address',
#        'addressI': 'BMSCE Boys Hostel',
#        'addressII': 'bms college',
#        'country': 'India',
#        'pin': '560004',
#        'area': 'Basavanagudi',
#        'city': 'Bangalore',
#        'district': 'Bangalore',
#        'state': 'Karnataka',
#        'policeStation': 'Basavangudi',
#        'phone': '08026622130'},
#       {'addressType': 'Present Address',
#        'addressI': 'BMSCE Boys Hostel',
#        'addressII': 'bms college',
#        'country': 'India',
#        'pin': '560004',
#        'area': 'Basavanagudi',
#        'city': 'Bangalore',
#        'district': 'Bangalore',
#        'state': 'Karnataka',
#        'policeStation': 'Basavangudi',
#        'phone': '08026622130'},
#       {'addressType': 'Registered Address',
#        'addressI': 'BMSCE Boys Hostel',
#        'addressII': 'bms college',
#        'country': 'India',
#        'pin': '560004',
#        'area': 'Basavanagudi',
#        'city': 'Bangalore',
#        'district': 'Bangalore',
#        'state': 'Karnataka',
#        'policeStation': 'Basavangudi',
#        'phone': '08026622130'}]}},
#    {'Category': 'Particulars of individual designated partners having DIN/DPIN',
#     'designatedpartnerID': '09730656',
#     'name': 'RANA VIVEK SINGH',
#     'isResidentInIndia': 'Y',
#     'paidupvalueofsharesheld': None,
#     'numberOfsharesHeld': None,
#     'formOfContribution': 'Other than cash',
#     'otherModeOfPayment': 'CHEQUE',
#     'monetaryValueOfContributionInFigures': '50000',
#     'monetaryValueOfContributionInWords': ' Fifty Thousand',
#     'numberOfLLPpartner': '0',
#     'numberOfcompanyDirector': '0',
#     'isResidentIndia': 'Y',
#     'paid': '',
#     'modeOfPay': '',
#     'monetaryValueInFigures': '',
#     'monetaryValueInwords': '',
#     'numberOfLLP': '',
#     'numberOfCompanyHoldAsDirector': '',
#     'partnerFirstName': '',
#     'partnerMiddleName': '',
#     'partnerSurname': '',
#     'partnerFatherFirstname': '',
#     'partnerFatherMiddlename': '',
#     'partnerFatherSurname': '',
#     'partnerGender': '',
#     'partnerDateofBirth': '',
#     'partnerNationality': '',
#     'partnerIsResidentIndia': '',
#     'isPanPass': '',
#     'panPassDetails': '',
#     'partnerPlaceofBirthState': '',
#     'partnerPlaceofBirthDistrict': '',
#     'partnerIsCitizenofIndia': '',
#     'OccupationType': '',
#     'descriptionOfOthers': '',
#     'areaOfOccupation': '',
#     'otherAreaOfOccupation': '',
#     'educationalQualification': '',
#     'otherEducation': '',
#     'mobileNo': '',
#     'emailid': '',
#     'isresidentofIndia': 'Y',
#     'numberofsharesheld': '',
#     'firstName': '',
#     'middle Name': '',
#     'surname': '',
#     'fatherFirstName': '',
#     'fatherMiddleName': '',
#     'fathersurname': '',
#     'gender': '',
#     'dateofBirth': '',
#     'nationality': '',
#     'isPanPassport': '',
#     'panPassportDetails': '',
#     'passportOrPAN': '',
#     'placeOfBirthState': '',
#     'placeOfBirthDistrict': '',
#     'occupationType': '',
#     'emailID': '',
#     'presentAddressSameAddressAsPremanent': '',
#     'durationStayedAtPresentAddressYears': '',
#     'durationStayedAtPresentAddressMonth': '',
#     'addressOfPreviousResidence': '',
#     'previousResidence ': '',
#     'proodOfIdentity': '',
#     'identityProofNo': '',
#     'residentialproof': '',
#     'residentialProofNo': '',
#     'numberOfSharesHeld': '',
#     'PaidupvalueShares': ''}],
#   'userId': 'CASRIKANTH0224@GMAIL.COM'},
#  'url': {'3eAdressProofURL': 'https://legalnitiai.s3.ap-south-1.amazonaws.com/GST-reg/Electricity+bill+(1).pdf',
#   '3eUtilityBillsURL': 'https://legalnitiai.s3.ap-south-1.amazonaws.com/GST-reg/Electricity+bill+(1).pdf',
#   '6bIdentityProof1URL': 'https://legalnitiai.s3.ap-south-1.amazonaws.com/GST-reg/sachin_aadhar_merged+(1).pdf',
#   '6bResidentialProof1URL': 'https://legalnitiai.s3.ap-south-1.amazonaws.com/GST-reg/Sachin_Bank+(1).pdf',
#   '6bIdentityProof2URL': 'https://legalnitiai.s3.ap-south-1.amazonaws.com/GST-reg/Jay_aadhar_PAN-Jay_merged+(1).pdf',
#   '6bResidentialProof2URL': 'https://legalnitiai.s3.ap-south-1.amazonaws.com/GST-reg/Jay_Bank+(1).pdf',
#   'valuationCert10aURL': 'https://legalnitiai.s3.ap-south-1.amazonaws.com/image/WhatsApp+Image+2023-08-12+at+15.50.17.jpg',
#   'subscriberConsentURL': 'https://legalnitiai.s3.ap-south-1.amazonaws.com/image/WhatsApp+Image+2023-08-12+at+15.50.17.jpg'}}

# %%
# Check the conditions
if inp['payload']['individualNotValidDINorDPIN'] == 0:
    # If 'individualNotValidDINorDPIN' is 0, display a message
    print("Selected number should be greater than 0")
else:
    # If 'individualNotValidDINorDPIN' is not 0, find and display the specified category from 'MCALLPFiLLiPIndPartner'
    category_to_find = "Particulars of individual designated partners not having DIN/DPIN"
    if 'MCALLPFiLLiPIndPartner' in inp['payload']:
        partners_data = inp['payload']['MCALLPFiLLiPIndPartner']
        found_category_data = None

        for partner in partners_data:
            if partner.get('Category') == category_to_find:
                found_category_data = partner
                break

        if found_category_data is not None:
            # Display the found category data
            print(json.dumps(found_category_data, indent=4))
        else:
            print(f"Category '{category_to_find}' not found in MCALLPFiLLiPIndPartner")
# Out:
# {
#     "Category": "Particulars of individual designated partners not having DIN/DPIN",
#     "firstName": "SACHIN",
#     "middleName": "",
#     "surname": "MADHESIYA",
#     "fatherFirstName": "RAJU",
#     "fatherMiddleName": "PRASAD",
#     "fathersurname": "MADHESIYA",
#     "gender": "Male",
#     "dateofBirth": "12/14/1998",
#     "nationality": "India",
#     "isResidentInIndia": "Y",
#     "isPanPassport": "PAN",
#     "panPassportDetails": "HQRPM8960H",
#     "placeOfBirthState": "Uttar Pradesh",
#     "placeOfBirthDistrict": "Agra",
#     "partnerIsCitizenofIndia": "Y",
#     "occupationType": "Private Employment",
#     "descriptionOfOthers": null,
#     "areaOfOccupation": "Private Employment",
#     "otherAreaOfOccupation": null,
#     "educationalQualification": "Bachelor's degree",
#     "otherEducation": null,
#     "mobileNo": "+919319421653",
#     "emailid": "Sachuuuu1428@gmail.com",
#     "proodOfIdentity": "Aadhaar",
#     "residentialproof": "Bank Statement",
#     "identityProofNo": "798000043919",
#     "residentialProofNo": "7324123775",
#     "numberOfsharesHeld": null,
#     "paidupvalueofsharesheld": null,
#     "formOfContribution": "Other than cash",
#     "otherModeOfPayment": "CHEQUE",
#     "monetaryValueOfContributionInFigures": "50000",
#     "monetaryValueOfContributionInWords": " Fifty Thousand",
#     "numberOfLLPpartner": "0",
#     "numberOfcompanyDirector": "0",
#     "presentAddressSameAddressAsPremanent": "Y",
#     "durationStayedAtPresentAddressYears": null,
#     "durationStayedAtPresentAddressMonth": null,
#     "addressOfPreviousResidence": null,
#     "designatedpartnerID": "",
#     "name": "",
#     "isResidentIndia": "Y",
#     "paid": "",
#     "modeOfPay": "Other than cash",
#     "monetaryValueInFigures": "50000",
#     "monetaryValueInwords": " Fifty Thousand",
#     "numberOfLLP": "",
#     "numberOfCompanyHoldAsDirector": "5",
#     "partnerFirstName": "SACHIN",
#     "partnerMiddleName": "",
#     "partnerSurname": "MADHESIYA",
#     "partnerFatherFirstname": "RAJU",
#     "partnerFatherMiddlename": "PRASAD",
#     "partnerFatherSurname": "MADHESIYA",
#     "partnerGender": "Male",
#     "partnerDateofBirth": "12/14/1998",
#     "partnerNationality": "India",
#     "partnerIsResidentIndia": "Y",
#     "isPanPass": "PAN",
#     "panPassDetails": "BUOPE2342B",
#     "partnerPlaceofBirthState": "",
#     "partnerPlaceofBirthDistrict": "Nagpur",
#     "OccupationType": "Private Employment",
#     "isresidentofIndia": "Y",
#     "numberofsharesheld": "100",
#     "passportOrPAN": "PAN",
#     "emailID": "Sachuuuu1428@gmail.com",
#     "previousResidence ": "",
#     "numberOfSharesHeld": "",
#     "PaidupvalueShares": "",
#     "ListOfbodyParnerIndOfficeAddress": {
#         "bodyParnerIndOfficeAddress": [
#             {
#                 "addressType": "Permanent Address",
#                 "addressI": "ward no 9 gandhi nagar",
#                 "addressII": "hariharapura",
#                 "country": "India",
#                 "pin": "272164",
#                 "area": "Hariharpur",
#                 "city": "Dhanghata",
#                 "district": "Sant Kabir Nagar",
#                 "state": "Uttar Pradesh",
#                 "policeStation": "Hariharpur",
#                 "phone": "05542282600"
#             },
#             {
#                 "addressType": "Present Address",
#                 "addressI": "ward no 9 gandhi nagar",
#                 "addressII": "hariharapura",
#                 "country": "India",
#                 "pin": "272164",
#                 "area": "Hariharpur",
#                 "city": "Dhanghata",
#                 "district": "Sant Kabir Nagar",
#                 "state": "Uttar Pradesh",
#                 "policeStation": "Hariharpur",
#                 "phone": "05542282600"
#             },
#             {
#                 "addressType": "Registered Address",
#                 "addressI": "ward no 9 gandhi nagar",
#                 "addressII": "hariharapura",
#                 "country": "India",
#                 "pin": "272164",
#                 "area": "Hariharpur",
#                 "city": "Dhanghata",
#                 "district": "Sant Kabir Nagar",
#                 "state": "Uttar Pradesh",
#                 "policeStation": "Hariharpur",
#                 "phone": "05542282600"
#             }
#         ]
#     }
# }

# %%
final_submit['requestBody']['formData']['MCALLPFiLLiPIndPartner']=inp['payload']['MCALLPFiLLiPIndPartner']
final_submit['requestBody']['formData']['MCALLPFiLLiPIndPartner']
# Out:
# [{'Category': 'Particulars of individual designated partners not having DIN/DPIN',
#   'firstName': 'SACHIN',
#   'middleName': '',
#   'surname': 'MADHESIYA',
#   'fatherFirstName': 'RAJU',
#   'fatherMiddleName': 'PRASAD',
#   'fathersurname': 'MADHESIYA',
#   'gender': 'Male',
#   'dateofBirth': '12/14/1998',
#   'nationality': 'India',
#   'isResidentInIndia': 'Y',
#   'isPanPassport': 'PAN',
#   'panPassportDetails': 'HQRPM8960H',
#   'placeOfBirthState': 'Uttar Pradesh',
#   'placeOfBirthDistrict': 'Agra',
#   'partnerIsCitizenofIndia': 'Y',
#   'occupationType': 'Private Employment',
#   'descriptionOfOthers': None,
#   'areaOfOccupation': 'Private Employment',
#   'otherAreaOfOccupation': None,
#   'educationalQualification': "Bachelor's degree",
#   'otherEducation': None,
#   'mobileNo': '+919319421653',
#   'emailid': 'Sachuuuu1428@gmail.com',
#   'proodOfIdentity': 'Aadhaar',
#   'residentialproof': 'Bank Statement',
#   'identityProofNo': '798000043919',
#   'residentialProofNo': '7324123775',
#   'numberOfsharesHeld': None,
#   'paidupvalueofsharesheld': None,
#   'formOfContribution': 'Other than cash',
#   'otherModeOfPayment': 'CHEQUE',
#   'monetaryValueOfContributionInFigures': '50000',
#   'monetaryValueOfContributionInWords': ' Fifty Thousand',
#   'numberOfLLPpartner': '0',
#   'numberOfcompanyDirector': '0',
#   'presentAddressSameAddressAsPremanent': 'Y',
#   'durationStayedAtPresentAddressYears': None,
#   'durationStayedAtPresentAddressMonth': None,
#   'addressOfPreviousResidence': None,
#   'designatedpartnerID': '',
#   'name': '',
#   'isResidentIndia': 'Y',
#   'paid': '',
#   'modeOfPay': 'Other than cash',
#   'monetaryValueInFigures': '50000',
#   'monetaryValueInwords': ' Fifty Thousand',
#   'numberOfLLP': '',
#   'numberOfCompanyHoldAsDirector': '5',
#   'partnerFirstName': 'SACHIN',
#   'partnerMiddleName': '',
#   'partnerSurname': 'MADHESIYA',
#   'partnerFatherFirstname': 'RAJU',
#   'partnerFatherMiddlename': 'PRASAD',
#   'partnerFatherSurname': 'MADHESIYA',
#   'partnerGender': 'Male',
#   'partnerDateofBirth': '12/14/1998',
#   'partnerNationality': 'India',
#   'partnerIsResidentIndia': 'Y',
#   'isPanPass': 'PAN',
#   'panPassDetails': 'BUOPE2342B',
#   'partnerPlaceofBirthState': '',
#   'partnerPlaceofBirthDistrict': 'Nagpur',
#   'OccupationType': 'Private Employment',
#   'isresidentofIndia': 'Y',
#   'numberofsharesheld': '100',
#   'passportOrPAN': 'PAN',
#   'emailID': 'Sachuuuu1428@gmail.com',
#   'previousResidence ': '',
#   'numberOfSharesHeld': '',
#   'PaidupvalueShares': '',
#   'ListOfbodyParnerIndOfficeAddress': {'bodyParnerIndOfficeAddress': [{'addressType': 'Permanent Address',
#      'addressI': 'ward no 9 gandhi nagar',
#      'addressII': 'hariharapura',
#      'country': 'India',
#      'pin': '272164',
#      'area': 'Hariharpur',
#      'city': 'Dhanghata',
#      'district': 'Sant Kabir Nagar',
#      'state': 'Uttar Pradesh',
#      'policeStation': 'Hariharpur',
#      'phone': '05542282600'},
#     {'addressType': 'Present Address',
#      'addressI': 'ward no 9 gandhi nagar',
#      'addressII': 'hariharapura',
#      'country': 'India',
#      'pin': '272164',
#      'area': 'Hariharpur',
#      'city': 'Dhanghata',
#      'district': 'Sant Kabir Nagar',
#      'state': 'Uttar Pradesh',
#      'policeStation': 'Hariharpur',
#      'phone': '05542282600'},
#     {'addressType': 'Registered Address',
#      'addressI': 'ward no 9 gandhi nagar',
#      'addressII': 'hariharapura',
#      'country': 'India',
#      'pin': '272164',
#      'area': 'Hariharpur',
#      'city': 'Dhanghata',
#      'district': 'Sant Kabir Nagar',
#      'state': 'Uttar Pradesh',
#      'policeStation': 'Hariharpur',
#      'phone': '05542282600'}]}},
#  {'Category': 'Particulars of individual designated partners not having DIN/DPIN',
#   'firstName': 'JAY',
#   'middleName': '',
#   'surname': 'BHATTARAI',
#   'fatherFirstName': 'DURGA',
#   'fatherMiddleName': 'PRASAD',
#   'fathersurname': 'BHATTARAI',
#   'gender': 'Male',
#   'dateofBirth': '05/05/2001',
#   'nationality': 'India',
#   'isResidentInIndia': 'Y',
#   'isPanPassport': 'PAN',
#   'panPassportDetails': 'FZMPB2968E',
#   'placeOfBirthState': 'Karnataka',
#   'placeOfBirthDistrict': 'Ballari',
#   'partnerIsCitizenofIndia': 'Y',
#   'occupationType': 'Private Employment',
#   'descriptionOfOthers': None,
#   'areaOfOccupation': 'Private Employment',
#   'otherAreaOfOccupation': None,
#   'educationalQualification': "Bachelor's degree",
#   'otherEducation': None,
#   'mobileNo': '+919916371230',
#   'emailid': 'bhattaraijay23@gmail.com',
#   'proodOfIdentity': 'Aadhaar',
#   'residentialproof': 'Bank Statement',
#   'identityProofNo': '581808086216',
#   'residentialProofNo': '90862388116',
#   'numberOfsharesHeld': None,
#   'paidupvalueofsharesheld': None,
#   'formOfContribution': 'Other than cash',
#   'otherModeOfPayment': 'cheque',
#   'monetaryValueOfContributionInFigures': '50000',
#   'monetaryValueOfContributionInWords': ' Fifty Thousand',
#   'numberOfLLPpartner': '0',
#   'numberOfcompanyDirector': '0',
#   'presentAddressSameAddressAsPremanent': 'Y',
#   'durationStayedAtPresentAddressYears': None,
#   'durationStayedAtPresentAddressMonth': None,
#   'addressOfPreviousResidence': None,
#   'designatedpartnerID': '',
#   'name': '',
#   'isResidentIndia': 'Y',
#   'paid': '',
#   'modeOfPay': 'Other than cash',
#   'monetaryValueInFigures': '50000',
#   'monetaryValueInwords': ' Fifty Thousand',
#   'numberOfLLP': '',
#   'numberOfCompanyHoldAsDirector': '5',
#   'partnerFirstName': 'JAY',
#   'partnerMiddleName': '',
#   'partnerSurname': 'BHATTARAI',
#   'partnerFatherFirstname': 'DURGA',
#   'partnerFatherMiddlename': 'PRASAD',
#   'partnerFatherSurname': 'BHATTARAI',
#   'partnerGender': 'Male',
#   'partnerDateofBirth': '05/05/2001',
#   'partnerNationality': 'India',
#   'partnerIsResidentIndia': 'Y',
#   'isPanPass': 'PAN',
#   'panPassDetails': 'BUOPE2342B',
#   'partnerPlaceofBirthState': '',
#   'partnerPlaceofBirthDistrict': 'Nagpur',
#   'OccupationType': 'Private Employment',
#   'isresidentofIndia': 'Y',
#   'numberofsharesheld': '100',
#   'passportOrPAN': 'PAN',
#   'emailID': 'bhattaraijay23@gmail.com',
#   'previousResidence ': '',
#   'numberOfSharesHeld': '',
#   'PaidupvalueShares': '',
#   'ListOfbodyParnerIndOfficeAddress': {'bodyParnerIndOfficeAddress': [{'addressType': 'Permanent Address',
#      'addressI': 'BMSCE Boys Hostel',
#      'addressII': 'bms college',
#      'country': 'India',
#      'pin': '560004',
#      'area': 'Basavanagudi',
#      'city': 'Bangalore',
#      'district': 'Bangalore',
#      'state': 'Karnataka',
#      'policeStation': 'Basavangudi',
#      'phone': '08026622130'},
#     {'addressType': 'Present Address',
#      'addressI': 'BMSCE Boys Hostel',
#      'addressII': 'bms college',
#      'country': 'India',
#      'pin': '560004',
#      'area': 'Basavanagudi',
#      'city': 'Bangalore',
#      'district': 'Bangalore',
#      'state': 'Karnataka',
#      'policeStation': 'Basavangudi',
#      'phone': '08026622130'},
#     {'addressType': 'Registered Address',
#      'addressI': 'BMSCE Boys Hostel',
#      'addressII': 'bms college',
#      'country': 'India',
#      'pin': '560004',
#      'area': 'Basavanagudi',
#      'city': 'Bangalore',
#      'district': 'Bangalore',
#      'state': 'Karnataka',
#      'policeStation': 'Basavangudi',
#      'phone': '08026622130'}]}},
#  {'Category': 'Particulars of individual designated partners having DIN/DPIN',
#   'designatedpartnerID': '09730656',
#   'name': 'RANA VIVEK SINGH',
#   'isResidentInIndia': 'Y',
#   'paidupvalueofsharesheld': None,
#   'numberOfsharesHeld': None,
#   'formOfContribution': 'Other than cash',
#   'otherModeOfPayment': 'CHEQUE',
#   'monetaryValueOfContributionInFigures': '50000',
#   'monetaryValueOfContributionInWords': ' Fifty Thousand',
#   'numberOfLLPpartner': '0',
#   'numberOfcompanyDirector': '0',
#   'isResidentIndia': 'Y',
#   'paid': '',
#   'modeOfPay': '',
#   'monetaryValueInFigures': '',
#   'monetaryValueInwords': '',
#   'numberOfLLP': '',
#   'numberOfCompanyHoldAsDirector': '',
#   'partnerFirstName': '',
#   'partnerMiddleName': '',
#   'partnerSurname': '',
#   'partnerFatherFirstname': '',
#   'partnerFatherMiddlename': '',
#   'partnerFatherSurname': '',
#   'partnerGender': '',
#   'partnerDateofBirth': '',
#   'partnerNationality': '',
#   'partnerIsResidentIndia': '',
#   'isPanPass': '',
#   'panPassDetails': '',
#   'partnerPlaceofBirthState': '',
#   'partnerPlaceofBirthDistrict': '',
#   'partnerIsCitizenofIndia': '',
#   'OccupationType': '',
#   'descriptionOfOthers': '',
#   'areaOfOccupation': '',
#   'otherAreaOfOccupation': '',
#   'educationalQualification': '',
#   'otherEducation': '',
#   'mobileNo': '',
#   'emailid': '',
#   'isresidentofIndia': 'Y',
#   'numberofsharesheld': '',
#   'firstName': '',
#   'middle Name': '',
#   'surname': '',
#   'fatherFirstName': '',
#   'fatherMiddleName': '',
#   'fathersurname': '',
#   'gender': '',
#   'dateofBirth': '',
#   'nationality': '',
#   'isPanPassport': '',
#   'panPassportDetails': '',
#   'passportOrPAN': '',
#   'placeOfBirthState': '',
#   'placeOfBirthDistrict': '',
#   'occupationType': '',
#   'emailID': '',
#   'presentAddressSameAddressAsPremanent': '',
#   'durationStayedAtPresentAddressYears': '',
#   'durationStayedAtPresentAddressMonth': '',
#   'addressOfPreviousResidence': '',
#   'previousResidence ': '',
#   'proodOfIdentity': '',
#   'identityProofNo': '',
#   'residentialproof': '',
#   'residentialProofNo': '',
#   'numberOfSharesHeld': '',
#   'PaidupvalueShares': ''}]

# %%
inp['payload']['registeredAddress']
# Out:
# {'addressI': 'BMS College ofEngineering',
#  'addressII': 'Bull Temple Road',
#  'country': 'India',
#  'pin': '560019',
#  'area': 'Gaviopuram Extension',
#  'city': 'Bangalore South',
#  'district': 'Bangalore',
#  'state': 'Karnataka',
#  'longitude': '73.859207',
#  'latitude': '18.528851',
#  'policeStation': 'banashankari',
#  'phone': None,
#  'mobile': '9319421653',
#  'fax': None,
#  'email': 'Sachuuuu1428@gmail.com',
#  'registrarOfficeName': 'Registrar of Companies, Karnataka'}

# %%
payload_dict = json.loads(payload)

# Update the values
payload_dict['requestBody']['integrationId'] = intid
payload_dict['requestBody']['referenceNumber'] = ref_no
payload_dict['requestBody']['formData']['formIntegrationId'] = formintid
payload_dict['requestBody']['formData']['srn'] = srn_value
payload_dict['requestBody']['srn']=srn_value
# payload_dict['requestBody']['formData']['registeredAddress']['addressI']="RVCE"
payload_dict['requestBody']['formData']['registeredAddress']=inp['payload']['registeredAddress']

# %%
import urllib.parse

# Encode the plus sign separately and concatenate it with the phone number
plus_sign_encoded = urllib.parse.quote("+")
payload_dict['requestBody']['formData']['MCALLPFiLLiPIndPartner'][0]['mobileNo'] = plus_sign_encoded + "919319421653"

# %%
import urllib.parse

# Encode the plus sign separately and concatenate it with the phone number
plus_sign_encoded = urllib.parse.quote("+")
payload_dict['requestBody']['formData']['MCALLPFiLLiPIndPartner'][1]['mobileNo'] = plus_sign_encoded + "919916371230"

# %%
payload_dict['requestBody']['formAttachment']=[]
payload_dict['requestBody']['formAttachment'].append(att_resp1)
payload_dict['requestBody']['formAttachment'].append(att_resp2)
payload_dict['requestBody']['formAttachment'].append(att_resp3)
payload_dict['requestBody']['formAttachment'].append(att_resp4)
payload_dict['requestBody']['formAttachment'].append(att_resp5)
payload_dict['requestBody']['formAttachment'].append(att_resp6)

# %%
payload_dict['requestBody']['formData']['registeredAddress']=inp['payload']['registeredAddress']
payload_dict['requestBody']['formData']['proposedName']=c_name1

# %%
updated_payload = json.dumps(payload_dict)

# %%
final_submit_2=json.loads(updated_payload)

# %%
final_submit_2['requestBody']['userId']=inp['payload']['userId']

# %%
final_submit_2['requestBody']['formAttachment']
# Out:
# [{'attachmentLabel': '3eAdressProof',
#   'attachmentCategory': 'Attachment',
#   'activityFileName': 'Electricity+bill+(1).pdf',
#   'activityFileSrcPath': '180069554',
#   'activityFileSrcType': 'I',
#   'activityFileExt': 'pdf',
#   'activityFileSize': '294662',
#   'attachmentDMSId': '367140841',
#   'totalNoOfPages': '1',
#   'activityFileDate': '09/20/2023',
#   'publicDocument': 'Y',
#   'activityComments': '180069554:3eAdressProof:Document added successfully.',
#   'folderName': '180069554',
#   'folderId': '180069554',
#   'version': '',
#   'addedBy': 'Fo User'},
#  {'attachmentLabel': '3eUtilityBills',
#   'attachmentCategory': 'Attachment',
#   'activityFileName': 'Electricity+bill+(1).pdf',
#   'activityFileSrcPath': '180069554',
#   'activityFileSrcType': 'I',
#   'activityFileExt': 'pdf',
#   'activityFileSize': '294662',
#   'attachmentDMSId': '367140894',
#   'totalNoOfPages': '1',
#   'activityFileDate': '09/20/2023',
#   'publicDocument': 'Y',
#   'activityComments': '180069554:3eUtilityBills:Document added successfully.',
#   'folderName': '180069554',
#   'folderId': '180069554',
#   'version': '',
#   'addedBy': 'Fo User'},
#  {'attachmentLabel': '6bIdentityProof',
#   'attachmentCategory': 'Attachment',
#   'activityFileName': 'sachin_aadhar_merged+(1).pdf',
#   'activityFileSrcPath': '180069554',
#   'activityFileSrcType': 'I',
#   'activityFileExt': 'pdf',
#   'activityFileSize': '225573',
#   'attachmentDMSId': '367140994',
#   'totalNoOfPages': '2',
#   'activityFileDate': '09/20/2023',
#   'publicDocument': 'Y',
#   'activityComments': '180069554:6bIdentityProof:Document added successfully.',
#   'folderName': '180069554',
#   'folderId': '180069554',
#   'version': '',
#   'addedBy': 'Fo User'},
#  {'attachmentLabel': '6bResidentialProof',
#   'attachmentCategory': 'Attachment',
#   'activityFileName': 'Sachin_Bank+(1).pdf',
#   'activityFileSrcPath': '180069554',
#   'activityFileSrcType': 'I',
#   'activityFileExt': 'pdf',
#   'activityFileSize': '152870',
#   'attachmentDMSId': '367141076',
#   'totalNoOfPages': '11',
#   'activityFileDate': '09/20/2023',
#   'publicDocument': 'Y',
#   'activityComments': '180069554:6bResidentialProof:Document added successfully.',
#   'folderName': '180069554',
#   'folderId': '180069554',
#   'version': '',
#   'addedBy': 'Fo User'},
#  {'attachmentLabel': '6bIdentityProof',
#   'attachmentCategory': 'Attachment',
#   'activityFileName': 'Jay_aadhar_PAN-Jay_merged+(1).pdf',
#   'activityFileSrcPath': '180069554',
#   'activityFileSrcType': 'I',
#   'activityFileExt': 'pdf',
#   'activityFileSize': '368940',
#   'attachmentDMSId': '367141162',
#   'totalNoOfPages': '2',
#   'activityFileDate': '09/20/2023',
#   'publicDocument': 'Y',
#   'activityComments': '180069554:6bIdentityProof:Document added successfully.',
#   'folderName': '180069554',
#   'folderId': '180069554',
#   'version': '',
#   'addedBy': 'Fo User'},
#  {'attachmentLabel': '6bResidentialProof',
#   'attachmentCategory': 'Attachment',
#   'activityFileName': 'Jay_Bank+(1).pdf',
#   'activityFileSrcPath': '180069554',
#   'activityFileSrcType': 'I',
#   'activityFileExt': 'pdf',
#   'activityFileSize': '34948',
#   'attachmentDMSId': '367141188',
#   'totalNoOfPages': '4',
#   'activityFileDate': '09/20/2023',
#   'publicDocument': 'Y',
#   'activityComments': '180069554:6bResidentialProof:Document added successfully.',
#   'folderName': '180069554',
#   'folderId': '180069554',
#   'version': '',
#   'addedBy': 'Fo User'}]

# %%
import requests

url = 'https://www.mca.gov.in/bin/fillip/OnloadSubmit'

headers = {
    'Host': 'www.mca.gov.in',
    'Cookie': f'cookiesession1=678B2869144E6B476733B93A4104896E; alertPopup=true; deviceId=4d23ogqkdbe; session-token={session_token}',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Origin': 'https://www.mca.gov.in',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/Fillip.html',
}

updated_payload_2 = f"formData={json.dumps(final_submit_2)}"

response = requests.post(url, headers=headers, data=updated_payload_2)
response.text
# Out:
# '{"resCode":200,"resStr":"{\\r\\n\\t\\"error\\": \\"\\",\\r\\n\\t\\"message\\": \\"Data Added Successfully\\",\\r\\n\\t\\"data\\": {\\r\\n\\t\\t\\"integrationId\\": \\"1-535M5QJ\\",\\r\\n\\t\\t\\"formIntegrationId\\": \\"1-535M5QL\\",\\r\\n\\t\\t\\"referenceNumber\\": \\"1-11074742155\\",\\r\\n\\t\\t\\"srn\\": \\"\\",\\r\\n\\t\\t\\"dateTime\\": \\"\\",\\r\\n\\t\\t\\"srnStatus\\":\\"Draft/Pending Submission\\",\\r\\n\\t\\t\\"formType\\":\\"\\"\\r\\n\\t}\\r\\n}"}'

# %%
# df = pd.read_excel(r"C:\Users\vyomg\OneDrive\Desktop\2023-002-TIN-Annexure_1-Release_PAN_AO_code_Master_Other_than_Mumbai_v.9.2.xlsx")

# %%
import requests

url = 'https://www.mca.gov.in/bin/fillip/fillipAoCode'

pan_params = {
    'AO_NO': "93",
    'AO_CODE': "P"+"KAR",
    'RANGE_CODE': "224",
    'AO_TYPE': "W"
}

headers = {
    'Cookie': f'cookiesession1=678B2869144E6B476733B93A4104896E; deviceId=kvkef960kw9; alertPopup=true; session-token={session_token}',
    'Sec-Fetch-Dest': 'empty',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/Fillip.html?applicationHistory=eyJzcm4iOiIiLCJyZWZlcmVuY2UiOiIxLTEwMjgyMTE5NTA4IiwicHVycG9zZSI6Ik5ldyBJbmNvcnBvcmF0aW9uIn0%3D',
}

response = requests.get(url, params=pan_params, headers=headers)

if response.status_code == 200:
    print("Request successful!")
    print("Response text:")
    print(response.text)
else:
    print(f"Request failed with status code: {response.status_code}")
# Out:
# Request successful!
# Response text:
# {"resCode":200,"resStr":"{\n        \t\t\n        \t\t\"message\":\"Data fetched Successfully\",\n        \t\t\"data\":{\"is_valid\":1}\n        \t}"}

# %%
pan_valid=json.loads(json.loads(response.text)['resStr'])['data']['is_valid']

# %%
# #PAN Check isValid Code

# import requests
# import pandas as pd
# import json

# # Load the Excel file into a DataFrame
# df = pd.read_excel(r'C:\Users\vyomg\OneDrive\Desktop\2023-002-TIN-Annexure_1-Release_PAN_AO_code_Master_Other_than_Mumbai_v.9.2.xlsx')


# # Define the URL and headers
# url = 'https://www.mca.gov.in/bin/fillip/fillipAoCode'

# headers = {
#     'Cookie': 'cookiesession1=678B2869144E6B476733B93A4104896E; deviceId=kvkef960kw9; alertPopup=true; session-token=eyJhbGciOiJIUzUxMiJ9..yf69Pr5PyLY1G6RM6LSrix_53DnIoGkJc-bW2H6_i68gCP0onwPH5R55_NqzSlmA31IGib5DuSTCcCsBs6v0Ug; sessionID=d538f62e-3649-42f0-bb3e-9583ce778b00',
#     'Sec-Ch-Ua': '',
#     'Accept': 'application/json, text/javascript, */*; q=0.01',
#     'X-Requested-With': 'XMLHttpRequest',
#     'Sec-Ch-Ua-Mobile': '?0',
#     'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.5790.110 Safari/537.36',
#     'Sec-Ch-Ua-Platform': '',
#     'Sec-Fetch-Site': 'same-origin',
#     'Sec-Fetch-Mode': 'cors',
#     'Sec-Fetch-Dest': 'empty',
#     'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/Fillip.html?applicationHistory=eyJzcm4iOiIiLCJyZWZlcmVuY2UiOiIxLTEwMjgyMTE5NTA4IiwicHVycG9zZSI6Ik5ldyBJbmNvcnBvcmF0aW9uIn0%3D',
#     'Accept-Encoding': 'gzip, deflate',
#     'Accept-Language': 'en-US,en;q=0.9'
# }

# isValid = 0  # Initialize isValid to 0

# # Iterate through the rows of the DataFrame
# for index, row in df.iterrows():
#     pan_params = {
#         'AO_NO': str(row['AO NO.']),
#         'AO_CODE': str(row['AREA CODE']),
#         'RANGE_CODE': str(row['RANGE CODE']),
#         'AO_TYPE': str(row['AO TYPE'])
#     }

#     # Send the request
#     response = requests.get(url, params=pan_params, headers=headers)

#     if response.status_code == 200:
#         # Parse the response to check if 'isValid' is 1
#         pan_data = json.loads(json.loads(response.text)['resStr'])['data']
#         isValid = pan_data.get('is_valid', 0)

#         if isValid == 1:
#             print(f"Request {index + 1}:")
#             print(f"  'AO_NO': {pan_params['AO_NO']}")
#             print(f"  'AO_CODE': {pan_params['AO_CODE']}")
#             print(f"  'RANGE_CODE': {pan_params['RANGE_CODE']}")
#             print(f"  'AO_TYPE': {pan_params['AO_TYPE']}")
#             print("  isValid is 1. Stopping further requests.")
#             break  # Exit the loop since 'isValid' is 1
#     else:
#         print(f"Request {index + 1} failed with status code: {response.status_code}")

#     # You can add a delay here if necessary to avoid overloading the server
    
# if isValid != 1:
#     print("No 'isValid' value of 1 found in the responses.")

# %%
# import requests
# import pandas as pd
# import json

# # Load the Excel file into a DataFrame
# df = pd.read_excel(r'C:\Users\vyomg\OneDrive\Desktop\2023-002-TIN-Annexure_1-Release_PAN_AO_code_Master_Other_than_Mumbai_v.9.2.xlsx')

# # Define the URL and headers
# url = 'https://www.mca.gov.in/bin/fillip/fillipAoCode'

# headers = {
#     'Cookie': 'cookiesession1=678B2869144E6B476733B93A4104896E; deviceId=kvkef960kw9; alertPopup=true; session-token=eyJhbGciOiJIUzUxMiJ9..yf69Pr5PyLY1G6RM6LSrix_53DnIoGkJc-bW2H6_i68gCP0onwPH5R55_NqzSlmA31IGib5DuSTCcCsBs6v0Ug; sessionID=d538f62e-3649-42f0-bb3e-9583ce778b00',
#     'Sec-Ch-Ua': '',
#     'Accept': 'application/json, text/javascript, */*; q=0.01',
#     'X-Requested-With': 'XMLHttpRequest',
#     'Sec-Ch-Ua-Mobile': '?0',
#     'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.5790.110 Safari/537.36',
#     'Sec-Ch-Ua-Platform': '',
#     'Sec-Fetch-Site': 'same-origin',
#     'Sec-Fetch-Mode': 'cors',
#     'Sec-Fetch-Dest': 'empty',
#     'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/Fillip.html?applicationHistory=eyJzcm4iOiIiLCJyZWZlcmVuY2UiOiIxLTEwMjgyMTE5NTA4IiwicHVycG9zZSI6Ik5ldyBJbmNvcnBvcmF0aW9uIn0%3D',
#     'Accept-Encoding': 'gzip, deflate',
#     'Accept-Language': 'en-US,en;q=0.9'
# }

# isValid = 0  # Initialize isValid to 0
# count_is_valid_1 = 0  # Initialize a counter for isValid = 1

# # Iterate through the rows of the DataFrame
# for index, row in df.iterrows():
#     pan_params = {
#         'AO_NO': str(row['SR. NO.']),
#         'AO_CODE': str(row['RCC']),  # Modify the column names accordingly
#         'RANGE_CODE': str(row['RANGE CODE']),  # Modify the column names accordingly
#         'AO_TYPE': str(row['AO TYPE'])  # Modify the column names accordingly
#     }

#     # Send the request
#     response = requests.get(url, params=pan_params, headers=headers)

#     if response.status_code == 200:
#         # Parse the response to check if 'isValid' is 1
#         pan_data = json.loads(json.loads(response.text)['resStr'])['data']
#         isValid = pan_data.get('is_valid', 0)

#         if isValid == 1:
#             count_is_valid_1 += 1
#             print(f"Request {index + 1}:")
#             print(f"  'AO_NO': {pan_params['AO_NO']}")
#             print(f"  'AO_CODE': {pan_params['AO_CODE']}")
#             print(f"  'RANGE_CODE': {pan_params['RANGE_CODE']}")
#             print(f"  'AO_TYPE': {pan_params['AO_TYPE']}")
#             print("  isValid is 1.")

#     else:
#         print(f"Request {index + 1} failed with status code: {response.status_code}")

#     # You can add a delay here if necessary to avoid overloading the server

# if count_is_valid_1 > 0:
#     print(f"Total number of times 'isValid' is 1: {count_is_valid_1}")
# else:
#     print("No 'isValid' value of 1 found in the responses.")

# %%
# df = pd.read_excel(r"C:\Users\vyomg\OneDrive\Desktop\2020-019-Annexure-TAN_AO_code_master_v_4.9(1).xlsx")
# df

# %%
import requests

url = 'https://www.mca.gov.in/bin/fillip/fillipAoCode'

tan_params = {
    'AO_NO': "3",
    'AO_CODE': "T"+"KAR",
    'RANGE_CODE': "182",
    'AO_TYPE':"WT"
}

headers = {
    'Cookie': f'cookiesession1=678B2869144E6B476733B93A4104896E; session-token={session_token}',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/Fillip.html?applicationHistory=eyJzcm4iOiIiLCJyZWZlcmVuY2UiOiIxLTEwMjgyMTE5NTA4IiwicHVycG9zZSI6Ik5ldyBJbmNvcnBvcmF0aW9uIn0%3D',
}

response = requests.get(url, params=tan_params, headers=headers)

if response.status_code == 200:
    print("Request successful!")
    print("Response text:")
    print(response.text)
else:
    print(f"Request failed with status code: {response.status_code}")
# Out:
# Request successful!
# Response text:
# {"resCode":200,"resStr":"{\n        \t\t\n        \t\t\"message\":\"Data fetched Successfully\",\n        \t\t\"data\":{\"is_valid\":1}\n        \t}"}

# %%
tan_valid=json.loads(json.loads(response.text)['resStr'])['data']['is_valid']

# %%
# #TAN Check isValid Code

# import requests
# import pandas as pd
# import json

# # Load the Excel file into a DataFrame
# df = pd.read_excel(r"C:\Users\vyomg\OneDrive\Desktop\2020-019-Annexure-TAN_AO_code_master_v_4.9(1).xlsx")

# # Define the URL and headers
# url = 'https://www.mca.gov.in/bin/fillip/fillipAoCode'

# headers = {
#     'Cookie': 'cookiesession1=678B2869144E6B476733B93A4104896E; deviceId=kvkef960kw9; alertPopup=true; session-token=eyJhbGciOiJIUzUxMiJ9..yf69Pr5PyLY1G6RM6LSrix_53DnIoGkJc-bW2H6_i68gCP0onwPH5R55_NqzSlmA31IGib5DuSTCcCsBs6v0Ug; sessionID=d538f62e-3649-42f0-bb3e-9583ce778b00',
#     'Sec-Ch-Ua': '',
#     'Accept': 'application/json, text/javascript, */*; q=0.01',
#     'X-Requested-With': 'XMLHttpRequest',
#     'Sec-Ch-Ua-Mobile': '?0',
#     'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.5790.110 Safari/537.36',
#     'Sec-Ch-Ua-Platform': '',
#     'Sec-Fetch-Site': 'same-origin',
#     'Sec-Fetch-Mode': 'cors',
#     'Sec-Fetch-Dest': 'empty',
#     'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/Fillip.html?applicationHistory=eyJzcm4iOiIiLCJyZWZlcmVuY2UiOiIxLTEwMjgyMTE5NTA4IiwicHVycG9zZSI6Ik5ldyBJbmNvcnBvcmF0aW9uIn0%3D',
#     'Accept-Encoding': 'gzip, deflate',
#     'Accept-Language': 'en-US,en;q=0.9'
# }

# isValid = 0  # Initialize isValid to 0

# # Iterate through the rows of the DataFrame
# for index, row in df.iterrows():
#     pan_params = {
#         'AO_NO': str(row['AO NO.']),
#         'AO_CODE': str(row['AREA CODE']),
#         'RANGE_CODE': str(row['RANGE CODE']),
#         'AO_TYPE': str(row['AO TYPE'])
#     }

#     # Send the request
#     response = requests.get(url, params=pan_params, headers=headers)

#     if response.status_code == 200:
#         # Parse the response to check if 'isValid' is 1
#         pan_data = json.loads(json.loads(response.text)['resStr'])['data']
#         isValid = pan_data.get('is_valid', 0)

#         if isValid == 1:
#             print(f"Request {index + 1}:")
#             print(f"  'AO_NO': {pan_params['AO_NO']}")
#             print(f"  'AO_CODE': {pan_params['AO_CODE']}")
#             print(f"  'RANGE_CODE': {pan_params['RANGE_CODE']}")
#             print(f"  'AO_TYPE': {pan_params['AO_TYPE']}")
#             print("  isValid is 1. Stopping further requests.")
#             break  # Exit the loop since 'isValid' is 1
#     else:
#         print(f"Request {index + 1} failed with status code: {response.status_code}")

#     # You can add a delay here if necessary to avoid overloading the server
    
# if isValid != 1:
#     print("No 'isValid' value of 1 found in the responses.")

# %%
import requests

# Define the URL and headers
url = "https://www.mca.gov.in/bin/fillip/fillipAoCode"
headers = {
    "Host": "www.mca.gov.in",
    "Cookie": "cookiesession1=678B2869144E6B476733B93A4104896E; alertPopup=true; session-token={session_token}; deviceId=kvkef960kw9",
    "Sec-Ch-Ua": "",
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "X-Requested-With": "XMLHttpRequest",
    "Sec-Ch-Ua-Mobile": "?0",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.5845.97 Safari/537.36",
    "Sec-Ch-Ua-Platform": "",
    "Sec-Fetch-Site": "same-origin",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Dest": "empty",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/Fillip.html?applicationHistory=eyJzcm4iOiIiLCJyZWZlcmVuY2UiOiIxLTEwNzA2MzM5Nzc0IiwicHVycG9zZSI6Ik5ldyBJbmNvcnBvcmF0aW9uIn0%3D",
    "Accept-Encoding": "gzip, deflate",
    "Accept-Language": "en-US,en;q=0.9"
}

# Define the query parameters
params = {
    "AO_NO": "3",
    "AO_CODE": "TKAR",
    "RANGE_CODE": "182",
    "AO_TYPE": "WT"
}

# Send the GET request
response = requests.get(url, headers=headers, params=params)

# Check the response status code
if response.status_code == 200:
    print("Response content:")
    print(response.text)
else:
    print(f"Request failed with status code {response.status_code}")
# Out:
# Response content:
# {"resCode":200,"resStr":"{\n        \t\t\n        \t\t\"message\":\"Data fetched Successfully\",\n        \t\t\"data\":{\"is_valid\":1}\n        \t}"}

# %%
#10A File upload Attachment 

s3_url = inp['url']['valuationCert10aURL'] 
folder = ""
attachment_category = s3_url.split('/')[-1].split('.')[-1]
attachment_label = "valuationCert10a"
filename=s3_url.split('/')[-1].replace("+",' ')
response=json.loads(upload_file_from_url(session_token, s3_url, ref_no,filename, folder, attachment_category, attachment_label))
response['folderName']=response['folderId']
response
# Out:
# File uploaded successfully
# Upload Response:  {"attachmentLabel":"valuationCert10a","attachmentCategory":"Attachment","activityFileName":"WhatsApp Image 2023-08-12 at 15.50.17.jpg","activityFileSrcPath":"180069554","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"75044","attachmentDMSId":"367141290","totalNoOfPages":"1","activityFileDate":"09/20/2023","publicDocument":"Y","activityComments":"180069554:valuationCert10a:Document added successfully.","folderName":"","folderId":"180069554","version":"","addedBy":"Fo User"}
# {'attachmentLabel': 'valuationCert10a',
#  'attachmentCategory': 'Attachment',
#  'activityFileName': 'WhatsApp Image 2023-08-12 at 15.50.17.jpg',
#  'activityFileSrcPath': '180069554',
#  'activityFileSrcType': 'I',
#  'activityFileExt': 'jpg',
#  'activityFileSize': '75044',
#  'attachmentDMSId': '367141290',
#  'totalNoOfPages': '1',
#  'activityFileDate': '09/20/2023',
#  'publicDocument': 'Y',
#  'activityComments': '180069554:valuationCert10a:Document added successfully.',
#  'folderName': '180069554',
#  'folderId': '180069554',
#  'version': '',
#  'addedBy': 'Fo User'}

# %%
att_resp7=response

# %%
#Attachment and Declaration of Subscribers' sheet including consent.

s3_url = inp['url']['subscriberConsentURL'] 
folder = ""
attachment_category = s3_url.split('/')[-1].split('.')[-1]
attachment_label = "subscriberConsent"
filename=s3_url.split('/')[-1].replace("+"," ")
response=json.loads(upload_file_from_url(session_token, s3_url, ref_no,filename, folder, attachment_category, attachment_label))
response['folderName']=response['folderId']
response
# Out:
# File uploaded successfully
# Upload Response:  {"attachmentLabel":"subscriberConsent","attachmentCategory":"Attachment","activityFileName":"WhatsApp Image 2023-08-12 at 15.50.17.jpg","activityFileSrcPath":"180069554","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"75044","attachmentDMSId":"367141323","totalNoOfPages":"1","activityFileDate":"09/20/2023","publicDocument":"Y","activityComments":"180069554:subscriberConsent:Document added successfully.","folderName":"","folderId":"180069554","version":"","addedBy":"Fo User"}
# {'attachmentLabel': 'subscriberConsent',
#  'attachmentCategory': 'Attachment',
#  'activityFileName': 'WhatsApp Image 2023-08-12 at 15.50.17.jpg',
#  'activityFileSrcPath': '180069554',
#  'activityFileSrcType': 'I',
#  'activityFileExt': 'jpg',
#  'activityFileSize': '75044',
#  'attachmentDMSId': '367141323',
#  'totalNoOfPages': '1',
#  'activityFileDate': '09/20/2023',
#  'publicDocument': 'Y',
#  'activityComments': '180069554:subscriberConsent:Document added successfully.',
#  'folderName': '180069554',
#  'folderId': '180069554',
#  'version': '',
#  'addedBy': 'Fo User'}

# %%
att_resp8=response

# %%
final_submit_2['requestBody']['formData']["presentAddressSameAddressAsPremanent"]=''
final_submit_2['requestBody']['formData']["durationStayedAtPresentAddressYears"]=''
final_submit_2['requestBody']['formData']["durationStayedAtPresentAddressMonth"]=''
final_submit_2['requestBody']['formData']["addressOfPreviousResidence"]=''
final_submit_2['requestBody']['formData']["proodOfIdentity"]=''
final_submit_2['requestBody']['formData']["identityProofNo"]=''
final_submit_2['requestBody']['formData']["residentialproof"]=''
final_submit_2['requestBody']['formData']["residentialProofNo"]=''
final_submit_2['requestBody']['formData']["numberOfSharesHeld"]=''
final_submit_2['requestBody']['formData']["paidSharesHeld"]=''
final_submit_2['requestBody']['formData']["otherModeOfPayment"]=''
final_submit_2['requestBody']['formData']["monetaryValueOfContributionInFigures"]='100000'
final_submit_2['requestBody']['formData']["monetaryValueOfContributionInWords"]='One Lakh'
final_submit_2['requestBody']['formData']["numberOfLLPpartner"]=''
final_submit_2['requestBody']['formData']["numberOfcompanyDirector"]=''
final_submit_2['requestBody']['formData']["deductionAccounNumberTAN"]=''
final_submit_2['requestBody']['formData']["panAreacode"]='KAR'
final_submit_2['requestBody']['formData']["panAOtype"]='W'
final_submit_2['requestBody']['formData']["panRangecode"]='224'
final_submit_2['requestBody']['formData']["panAONo"]='93'
final_submit_2['requestBody']['formData']["tanAreacode"]='KAR'
final_submit_2['requestBody']['formData']["tanAOtype"] = 'WT'
final_submit_2['requestBody']['formData']["tanRangecode"]='182'
final_submit_2['requestBody']['formData']["tanAONo"]='3'
final_submit_2['requestBody']['formData']["sourceofIncome"]='Income from Business/profession '
final_submit_2['requestBody']['formData']["BusinessProfessionCode"]='20'
final_submit_2['requestBody']['formData']["dsc"]=''
final_submit_2['requestBody']['formData']["DIN"]='HQRPM8960H'
final_submit_2['requestBody']['formData']["name"]='SRIKANTH REDDY'
final_submit_2['requestBody']['formData']["decProfessionalFatherName"]='S SRINIVASA REDDY'
final_submit_2['requestBody']['formData']["relation"]='Son'
final_submit_2['requestBody']['formData']["profession"]='Chartered Accountant in whole time practice'
final_submit_2['requestBody']['formData']["practiceName"]='Institute of Chartered Accountants of India'
final_submit_2['requestBody']['formData']["practiceNumber"]='271843'
final_submit_2['requestBody']['formData']["regulatoryBody"]='Institute of Chartered Accountants of India'
final_submit_2['requestBody']['formData']["associate_fellow"]='Associate'
final_submit_2['requestBody']['formData']["dsc2"]=''

# %%
final_submit_2['requestBody']['formAttachment'].append(att_resp7)
final_submit_2['requestBody']['formAttachment'].append(att_resp8)

# %%
# final_submit_2['requestBody']['operation']="Save"

# %%
a={"formAttachment":[{"attachmentLabel":"3eAdressProof","attachmentCategory":"Attachment","activityFileName":"Electricity bill (1).pdf","activityFileSrcPath":"180002960","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"294662","attachmentDMSId":"366921755","totalNoOfPages":"1","activityFileDate":"09/19/2023","publicDocument":"Y","activityComments":"180002960:3eAdressProof:Document added successfully.","folderName":"180002960","folderId":"180002960","version":"","addedBy":"Fo User"},{"attachmentLabel":"6bIdentityProof","attachmentCategory":"Attachment","activityFileName":"sachin_aadhar_merged (1).pdf","activityFileSrcPath":"180024255","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"225573","attachmentDMSId":"366925991","totalNoOfPages":"2","activityFileDate":"09/19/2023","publicDocument":"Y","activityComments":"180024255:6bIdentityProof:Document added successfully.","folderName":"TVwf7442188041320","folderId":"180024255","version":"","addedBy":"Fo User"},{"attachmentLabel":"6bResidentialProof","attachmentCategory":"Attachment","activityFileName":"Sachin_Bank (1).pdf","activityFileSrcPath":"180024255","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"152870","attachmentDMSId":"366926090","totalNoOfPages":"11","activityFileDate":"09/19/2023","publicDocument":"Y","activityComments":"180024255:6bResidentialProof:Document added successfully.","folderName":"180024255","folderId":"180024255","version":"","addedBy":"Fo User"},{"attachmentLabel":"6bIdentityProof","attachmentCategory":"Attachment","activityFileName":"Jay_aadhar_PAN-Jay_merged (1).pdf","activityFileSrcPath":"180024255","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"368940","attachmentDMSId":"366926256","totalNoOfPages":"2","activityFileDate":"09/19/2023","publicDocument":"Y","activityComments":"180024255:6bIdentityProof:Document added successfully.","folderName":"180024255","folderId":"180024255","version":"","addedBy":"Fo User"},{"attachmentLabel":"6bResidentialProof","attachmentCategory":"Attachment","activityFileName":"Jay_Bank (1).pdf","activityFileSrcPath":"180024255","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"34948","attachmentDMSId":"366926350","totalNoOfPages":"4","activityFileDate":"09/19/2023","publicDocument":"Y","activityComments":"180024255:6bResidentialProof:Document added successfully.","folderName":"180024255","folderId":"180024255","version":"","addedBy":"Fo User"},{"attachmentLabel":"valuationCert10a","attachmentCategory":"Attachment","activityFileName":"Jay_Bank (1).pdf","activityFileSrcPath":"180024255","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"34948","attachmentDMSId":"366927478","totalNoOfPages":"4","activityFileDate":"09/19/2023","publicDocument":"Y","activityComments":"180024255:valuationCert10a:Document added successfully.","folderName":"180024255","folderId":"180024255","version":"","addedBy":"Fo User"},{"attachmentLabel":"subscriberConsent","attachmentCategory":"Attachment","activityFileName":"Jay_Bank (1).pdf","activityFileSrcPath":"180024255","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"34948","attachmentDMSId":"366927520","totalNoOfPages":"4","activityFileDate":"09/19/2023","publicDocument":"Y","activityComments":"180024255:subscriberConsent:Document added successfully.","folderName":"180024255","folderId":"180024255","version":"","addedBy":"Fo User"}]}

# %%
final_submit_2
# Out:
# {'requestBody': {'operation': 'Save',
#   'integrationId': '1-535M5QJ',
#   'referenceNumber': '1-11074742155',
#   'srn': 'M28186110',
#   'formId': 'Homogeneous',
#   'formName': 'FiLLiP',
#   'formDescription': '',
#   'formVersion': '1.2',
#   'userId': 'CASRIKANTH0224@GMAIL.COM',
#   'CIN': None,
#   'SRFOStatus': 'Draft/Pending Submission',
#   'formData': {'formIntegrationId': '1-535M5QL',
#    'isRegistered': 'Y',
#    'srn': 'M28186110',
#    'incorporationType': 'New Incorporation',
#    'cin': None,
#    'proposedName': 'VOYAGENICTRAVELS LLP',
#    'attachment': False,
#    'attachment2a': False,
#    'attachment2c': False,
#    'attachment2d': False,
#    'attachment2e': False,
#    'significanceProposedName': None,
#    'vernacularLanguage': None,
#    'isRegisteredPending': None,
#    'particulars': None,
#    'registeredAddress': {'addressI': 'BMS College ofEngineering',
#     'addressII': 'Bull Temple Road',
#     'country': 'India',
#     'pin': '560019',
#     'area': 'Gaviopuram Extension',
#     'city': 'Bangalore South',
#     'district': 'Bangalore',
#     'state': 'Karnataka',
#     'longitude': '73.859207',
#     'latitude': '18.528851',
#     'policeStation': 'banashankari',
#     'phone': None,
#     'mobile': '9319421653',
#     'fax': None,
#     'email': 'Sachuuuu1428@gmail.com',
#     'registrarOfficeName': 'Registrar of Companies, Karnataka'},
#    'buissnessactivity': [{'srno': '1',
#      'industrySubClass': 'Axxx010',
#      'description': 'abc rtd',
#      'primary': 'No'},
#     {'srno': '2',
#      'industrySubClass': 'bxxx010',
#      'description': 'fghty rtd',
#      'primary': 'yes'}],
#    'mainIndustrialNICcode': '52291',
#    'mainIndustrialDescriptionOfNIC': 'Activities of travel agents and tour operators',
#    'otherIndustrialNICcode': '79120',
#    'otherIndustrialDescriptionOfNIC': 'Tour operator activities',
#    'NICCode3': '79110',
#    'NICCode3Desc': 'Travel agency activities',
#    'numberOfDesignatedPartnersValidDIN_DPIN': '0',
#    'numberOfDesignatedPartnersNotValidDIN_DPIN': '2',
#    'individualValidDINorDPIN': '0',
#    'individualNotValidDINorDPIN': '2',
#    'nominiesValidDINorDPIN': '0',
#    'nominiesNotValidDINorDPIN': '0',
#    'numberOfPartnersOtherThanDesignatedPartnerValidDINorDPIN': '0',
#    'numberOfPartnersOtherThanDesignatedPartnerNotValidDINorDPIN': '0',
#    'individualOtherThanDesignatedPartnerValidDINorDPIN': '0',
#    'individualOtherThanDesignatedPartnerNotValidDINorDPIN': '0',
#    'nominiesOtherThanDesignatedPartnerValidDINorDPIN': '0',
#    'nominiesOtherThanDesignatedPartnerNotValidDINorDPIN': '0',
#    'totalNumberValidDesignatedPartners': '0',
#    'totalNumberNotValidDesignatedPartners': '2',
#    'MCALLPFiLLiPIndPartner': [{'Category': 'Particulars of individual designated partners not having DIN/DPIN',
#      'firstName': 'SACHIN',
#      'middleName': '',
#      'surname': 'MADHESIYA',
#      'fatherFirstName': 'RAJU',
#      'fatherMiddleName': 'PRASAD',
#      'fathersurname': 'MADHESIYA',
#      'gender': 'Male',
#      'dateofBirth': '12/14/1998',
#      'nationality': 'India',
#      'isResidentInIndia': 'Y',
#      'isPanPassport': 'PAN',
#      'panPassportDetails': 'HQRPM8960H',
#      'placeOfBirthState': 'Uttar Pradesh',
#      'placeOfBirthDistrict': 'Agra',
#      'partnerIsCitizenofIndia': 'Y',
#      'occupationType': 'Private Employment',
#      'descriptionOfOthers': None,
#      'areaOfOccupation': 'Private Employment',
#      'otherAreaOfOccupation': None,
#      'educationalQualification': "Bachelor's degree",
#      'otherEducation': None,
#      'mobileNo': '%2B919319421653',
#      'emailid': 'Sachuuuu1428@gmail.com',
#      'proodOfIdentity': 'Aadhaar',
#      'residentialproof': 'Bank Statement',
#      'identityProofNo': '798000043919',
#      'residentialProofNo': '7324123775',
#      'numberOfsharesHeld': None,
#      'paidupvalueofsharesheld': None,
#      'formOfContribution': 'Other than cash',
#      'otherModeOfPayment': 'CHEQUE',
#      'monetaryValueOfContributionInFigures': '50000',
#      'monetaryValueOfContributionInWords': ' Fifty Thousand',
#      'numberOfLLPpartner': '0',
#      'numberOfcompanyDirector': '0',
#      'presentAddressSameAddressAsPremanent': 'Y',
#      'durationStayedAtPresentAddressYears': None,
#      'durationStayedAtPresentAddressMonth': None,
#      'addressOfPreviousResidence': None,
#      'designatedpartnerID': '',
#      'name': '',
#      'isResidentIndia': 'Y',
#      'paid': '',
#      'modeOfPay': 'Other than cash',
#      'monetaryValueInFigures': '50000',
#      'monetaryValueInwords': ' Fifty Thousand',
#      'numberOfLLP': '',
#      'numberOfCompanyHoldAsDirector': '5',
#      'partnerFirstName': 'SACHIN',
#      'partnerMiddleName': '',
#      'partnerSurname': 'MADHESIYA',
#      'partnerFatherFirstname': 'RAJU',
#      'partnerFatherMiddlename': 'PRASAD',
#      'partnerFatherSurname': 'MADHESIYA',
#      'partnerGender': 'Male',
#      'partnerDateofBirth': '12/14/1998',
#      'partnerNationality': 'India',
#      'partnerIsResidentIndia': 'Y',
#      'isPanPass': 'PAN',
#      'panPassDetails': 'BUOPE2342B',
#      'partnerPlaceofBirthState': '',
#      'partnerPlaceofBirthDistrict': 'Nagpur',
#      'OccupationType': 'Private Employment',
#      'isresidentofIndia': 'Y',
#      'numberofsharesheld': '100',
#      'passportOrPAN': 'PAN',
#      'emailID': 'Sachuuuu1428@gmail.com',
#      'previousResidence ': '',
#      'numberOfSharesHeld': '',
#      'PaidupvalueShares': '',
#      'ListOfbodyParnerIndOfficeAddress': {'bodyParnerIndOfficeAddress': [{'addressType': 'Permanent Address',
#         'addressI': 'ward no 9 gandhi nagar',
#         'addressII': 'hariharapura',
#         'country': 'India',
#         'pin': '272164',
#         'area': 'Hariharpur',
#         'city': 'Dhanghata',
#         'district': 'Sant Kabir Nagar',
#         'state': 'Uttar Pradesh',
#         'policeStation': 'Hariharpur',
#         'phone': '05542282600'},
#        {'addressType': 'Present Address',
#         'addressI': 'ward no 9 gandhi nagar',
#         'addressII': 'hariharapura',
#         'country': 'India',
#         'pin': '272164',
#         'area': 'Hariharpur',
#         'city': 'Dhanghata',
#         'district': 'Sant Kabir Nagar',
#         'state': 'Uttar Pradesh',
#         'policeStation': 'Hariharpur',
#         'phone': '05542282600'},
#        {'addressType': 'Registered Address',
#         'addressI': 'ward no 9 gandhi nagar',
#         'addressII': 'hariharapura',
#         'country': 'India',
#         'pin': '272164',
#         'area': 'Hariharpur',
#         'city': 'Dhanghata',
#         'district': 'Sant Kabir Nagar',
#         'state': 'Uttar Pradesh',
#         'policeStation': 'Hariharpur',
#         'phone': '05542282600'}]}},
#     {'Category': 'Particulars of individual designated partners not having DIN/DPIN',
#      'firstName': 'JAY',
#      'middleName': '',
#      'surname': 'BHATTARAI',
#      'fatherFirstName': 'DURGA',
#      'fatherMiddleName': 'PRASAD',
#      'fathersurname': 'BHATTARAI',
#      'gender': 'Male',
#      'dateofBirth': '05/05/2001',
#      'nationality': 'India',
#      'isResidentInIndia': 'Y',
#      'isPanPassport': 'PAN',
#      'panPassportDetails': 'FZMPB2968E',
#      'placeOfBirthState': 'Karnataka',
#      'placeOfBirthDistrict': 'Ballari',
#      'partnerIsCitizenofIndia': 'Y',
#      'occupationType': 'Private Employment',
#      'descriptionOfOthers': None,
#      'areaOfOccupation': 'Private Employment',
#      'otherAreaOfOccupation': None,
#      'educationalQualification': "Bachelor's degree",
#      'otherEducation': None,
#      'mobileNo': '%2B919916371230',
#      'emailid': 'bhattaraijay23@gmail.com',
#      'proodOfIdentity': 'Aadhaar',
#      'residentialproof': 'Bank Statement',
#      'identityProofNo': '581808086216',
#      'residentialProofNo': '90862388116',
#      'numberOfsharesHeld': None,
#      'paidupvalueofsharesheld': None,
#      'formOfContribution': 'Other than cash',
#      'otherModeOfPayment': 'cheque',
#      'monetaryValueOfContributionInFigures': '50000',
#      'monetaryValueOfContributionInWords': ' Fifty Thousand',
#      'numberOfLLPpartner': '0',
#      'numberOfcompanyDirector': '0',
#      'presentAddressSameAddressAsPremanent': 'Y',
#      'durationStayedAtPresentAddressYears': None,
#      'durationStayedAtPresentAddressMonth': None,
#      'addressOfPreviousResidence': None,
#      'designatedpartnerID': '',
#      'name': '',
#      'isResidentIndia': 'Y',
#      'paid': '',
#      'modeOfPay': 'Other than cash',
#      'monetaryValueInFigures': '50000',
#      'monetaryValueInwords': ' Fifty Thousand',
#      'numberOfLLP': '',
#      'numberOfCompanyHoldAsDirector': '5',
#      'partnerFirstName': 'JAY',
#      'partnerMiddleName': '',
#      'partnerSurname': 'BHATTARAI',
#      'partnerFatherFirstname': 'DURGA',
#      'partnerFatherMiddlename': 'PRASAD',
#      'partnerFatherSurname': 'BHATTARAI',
#      'partnerGender': 'Male',
#      'partnerDateofBirth': '05/05/2001',
#      'partnerNationality': 'India',
#      'partnerIsResidentIndia': 'Y',
#      'isPanPass': 'PAN',
#      'panPassDetails': 'BUOPE2342B',
#      'partnerPlaceofBirthState': '',
#      'partnerPlaceofBirthDistrict': 'Nagpur',
#      'OccupationType': 'Private Employment',
#      'isresidentofIndia': 'Y',
#      'numberofsharesheld': '100',
#      'passportOrPAN': 'PAN',
#      'emailID': 'bhattaraijay23@gmail.com',
#      'previousResidence ': '',
#      'numberOfSharesHeld': '',
#      'PaidupvalueShares': '',
#      'ListOfbodyParnerIndOfficeAddress': {'bodyParnerIndOfficeAddress': [{'addressType': 'Permanent Address',
#         'addressI': 'BMSCE Boys Hostel',
#         'addressII': 'bms college',
#         'country': 'India',
#         'pin': '560004',
#         'area': 'Basavanagudi',
#         'city': 'Bangalore',
#         'district': 'Bangalore',
#         'state': 'Karnataka',
#         'policeStation': 'Basavangudi',
#         'phone': '08026622130'},
#        {'addressType': 'Present Address',
#         'addressI': 'BMSCE Boys Hostel',
#         'addressII': 'bms college',
#         'country': 'India',
#         'pin': '560004',
#         'area': 'Basavanagudi',
#         'city': 'Bangalore',
#         'district': 'Bangalore',
#         'state': 'Karnataka',
#         'policeStation': 'Basavangudi',
#         'phone': '08026622130'},
#        {'addressType': 'Registered Address',
#         'addressI': 'BMSCE Boys Hostel',
#         'addressII': 'bms college',
#         'country': 'India',
#         'pin': '560004',
#         'area': 'Basavanagudi',
#         'city': 'Bangalore',
#         'district': 'Bangalore',
#         'state': 'Karnataka',
#         'policeStation': 'Basavangudi',
#         'phone': '08026622130'}]}}],
#    'presentAddressSameAddressAsPremanent': '',
#    'durationStayedAtPresentAddressYears': '',
#    'durationStayedAtPresentAddressMonth': '',
#    'addressOfPreviousResidence': '',
#    'proodOfIdentity': '',
#    'identityProofNo': '',
#    'residentialproof': '',
#    'residentialProofNo': '',
#    'numberOfSharesHeld': '',
#    'paidSharesHeld': '',
#    'otherModeOfPayment': '',
#    'monetaryValueOfContributionInFigures': '100000',
#    'monetaryValueOfContributionInWords': 'One Lakh',
#    'numberOfLLPpartner': '',
#    'numberOfcompanyDirector': '',
#    'deductionAccounNumberTAN': '',
#    'panAreacode': 'KAR',
#    'panAOtype': 'W',
#    'panRangecode': '224',
#    'panAONo': '93',
#    'tanAreacode': 'KAR',
#    'tanAOtype': 'WT',
#    'tanRangecode': '182',
#    'tanAONo': '3',
#    'sourceofIncome': 'Income from Business/profession ',
#    'BusinessProfessionCode': '20',
#    'dsc': '',
#    'DIN': 'HQRPM8960H',
#    'name': 'SRIKANTH REDDY',
#    'decProfessionalFatherName': 'S SRINIVASA REDDY',
#    'relation': 'Son',
#    'profession': 'Chartered Accountant in whole time practice',
#    'practiceName': 'Institute of Chartered Accountants of India',
#    'practiceNumber': '271843',
#    'regulatoryBody': 'Institute of Chartered Accountants of India',
#    'associate_fellow': 'Associate',
#    'dsc2': ''},
#   'formAttachment': [{'attachmentLabel': '3eAdressProof',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': 'Electricity+bill+(1).pdf',
#     'activityFileSrcPath': '180069554',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'pdf',
#     'activityFileSize': '294662',
#     'attachmentDMSId': '367140841',
#     'totalNoOfPages': '1',
#     'activityFileDate': '09/20/2023',
#     'publicDocument': 'Y',
#     'activityComments': '180069554:3eAdressProof:Document added successfully.',
#     'folderName': '180069554',
#     'folderId': '180069554',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': '3eUtilityBills',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': 'Electricity+bill+(1).pdf',
#     'activityFileSrcPath': '180069554',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'pdf',
#     'activityFileSize': '294662',
#     'attachmentDMSId': '367140894',
#     'totalNoOfPages': '1',
#     'activityFileDate': '09/20/2023',
#     'publicDocument': 'Y',
#     'activityComments': '180069554:3eUtilityBills:Document added successfully.',
#     'folderName': '180069554',
#     'folderId': '180069554',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': '6bIdentityProof',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': 'sachin_aadhar_merged+(1).pdf',
#     'activityFileSrcPath': '180069554',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'pdf',
#     'activityFileSize': '225573',
#     'attachmentDMSId': '367140994',
#     'totalNoOfPages': '2',
#     'activityFileDate': '09/20/2023',
#     'publicDocument': 'Y',
#     'activityComments': '180069554:6bIdentityProof:Document added successfully.',
#     'folderName': '180069554',
#     'folderId': '180069554',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': '6bResidentialProof',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': 'Sachin_Bank+(1).pdf',
#     'activityFileSrcPath': '180069554',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'pdf',
#     'activityFileSize': '152870',
#     'attachmentDMSId': '367141076',
#     'totalNoOfPages': '11',
#     'activityFileDate': '09/20/2023',
#     'publicDocument': 'Y',
#     'activityComments': '180069554:6bResidentialProof:Document added successfully.',
#     'folderName': '180069554',
#     'folderId': '180069554',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': '6bIdentityProof',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': 'Jay_aadhar_PAN-Jay_merged+(1).pdf',
#     'activityFileSrcPath': '180069554',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'pdf',
#     'activityFileSize': '368940',
#     'attachmentDMSId': '367141162',
#     'totalNoOfPages': '2',
#     'activityFileDate': '09/20/2023',
#     'publicDocument': 'Y',
#     'activityComments': '180069554:6bIdentityProof:Document added successfully.',
#     'folderName': '180069554',
#     'folderId': '180069554',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': '6bResidentialProof',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': 'Jay_Bank+(1).pdf',
#     'activityFileSrcPath': '180069554',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'pdf',
#     'activityFileSize': '34948',
#     'attachmentDMSId': '367141188',
#     'totalNoOfPages': '4',
#     'activityFileDate': '09/20/2023',
#     'publicDocument': 'Y',
#     'activityComments': '180069554:6bResidentialProof:Document added successfully.',
#     'folderName': '180069554',
#     'folderId': '180069554',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': 'valuationCert10a',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': 'WhatsApp Image 2023-08-12 at 15.50.17.jpg',
#     'activityFileSrcPath': '180069554',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'jpg',
#     'activityFileSize': '75044',
#     'attachmentDMSId': '367141290',
#     'totalNoOfPages': '1',
#     'activityFileDate': '09/20/2023',
#     'publicDocument': 'Y',
#     'activityComments': '180069554:valuationCert10a:Document added successfully.',
#     'folderName': '180069554',
#     'folderId': '180069554',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': 'subscriberConsent',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': 'WhatsApp Image 2023-08-12 at 15.50.17.jpg',
#     'activityFileSrcPath': '180069554',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'jpg',
#     'activityFileSize': '75044',
#     'attachmentDMSId': '367141323',
#     'totalNoOfPages': '1',
#     'activityFileDate': '09/20/2023',
#     'publicDocument': 'Y',
#     'activityComments': '180069554:subscriberConsent:Document added successfully.',
#     'folderName': '180069554',
#     'folderId': '180069554',
#     'version': '',
#     'addedBy': 'Fo User'}]}}

# %%
json.dumps(final_submit_2['requestBody']['formAttachment'])
# Out:
# '[{"attachmentLabel": "3eAdressProof", "attachmentCategory": "Attachment", "activityFileName": "Electricity+bill+(1).pdf", "activityFileSrcPath": "180069554", "activityFileSrcType": "I", "activityFileExt": "pdf", "activityFileSize": "294662", "attachmentDMSId": "367140841", "totalNoOfPages": "1", "activityFileDate": "09/20/2023", "publicDocument": "Y", "activityComments": "180069554:3eAdressProof:Document added successfully.", "folderName": "180069554", "folderId": "180069554", "version": "", "addedBy": "Fo User"}, {"attachmentLabel": "3eUtilityBills", "attachmentCategory": "Attachment", "activityFileName": "Electricity+bill+(1).pdf", "activityFileSrcPath": "180069554", "activityFileSrcType": "I", "activityFileExt": "pdf", "activityFileSize": "294662", "attachmentDMSId": "367140894", "totalNoOfPages": "1", "activityFileDate": "09/20/2023", "publicDocument": "Y", "activityComments": "180069554:3eUtilityBills:Document added successfully.", "folderName": "180069554", "folderId": "180069554", "version": "", "addedBy": "Fo User"}, {"attachmentLabel": "6bIdentityProof", "attachmentCategory": "Attachment", "activityFileName": "sachin_aadhar_merged+(1).pdf", "activityFileSrcPath": "180069554", "activityFileSrcType": "I", "activityFileExt": "pdf", "activityFileSize": "225573", "attachmentDMSId": "367140994", "totalNoOfPages": "2", "activityFileDate": "09/20/2023", "publicDocument": "Y", "activityComments": "180069554:6bIdentityProof:Document added successfully.", "folderName": "180069554", "folderId": "180069554", "version": "", "addedBy": "Fo User"}, {"attachmentLabel": "6bResidentialProof", "attachmentCategory": "Attachment", "activityFileName": "Sachin_Bank+(1).pdf", "activityFileSrcPath": "180069554", "activityFileSrcType": "I", "activityFileExt": "pdf", "activityFileSize": "152870", "attachmentDMSId": "367141076", "totalNoOfPages": "11", "activityFileDate": "09/20/2023", "publicDocument": "Y", "activityComments": "180069554:6bResidentialProof:Document added successfully.", "folderName": "180069554", "folderId": "180069554", "version": "", "addedBy": "Fo User"}, {"attachmentLabel": "6bIdentityProof", "attachmentCategory": "Attachment", "activityFileName": "Jay_aadhar_PAN-Jay_merged+(1).pdf", "activityFileSrcPath": "180069554", "activityFileSrcType": "I", "activityFileExt": "pdf", "activityFileSize": "368940", "attachmentDMSId": "367141162", "totalNoOfPages": "2", "activityFileDate": "09/20/2023", "publicDocument": "Y", "activityComments": "180069554:6bIdentityProof:Document added successfully.", "folderName": "180069554", "folderId": "180069554", "version": "", "addedBy": "Fo User"}, {"attachmentLabel": "6bResidentialProof", "attachmentCategory": "Attachment", "activityFileName": "Jay_Bank+(1).pdf", "activityFileSrcPath": "180069554", "activityFileSrcType": "I", "activityFileExt": "pdf", "activityFileSize": "34948", "attachmentDMSId": "367141188", "totalNoOfPages": "4", "activityFileDate": "09/20/2023", "publicDocument": "Y", "activityComments": "180069554:6bResidentialProof:Document added successfully.", "folderName": "180069554", "folderId": "180069554", "version": "", "addedBy": "Fo User"}, {"attachmentLabel": "valuationCert10a", "attachmentCategory": "Attachment", "activityFileName": "WhatsApp Image 2023-08-12 at 15.50.17.jpg", "activityFileSrcPath": "180069554", "activityFileSrcType": "I", "activityFileExt": "jpg", "activityFileSize": "75044", "attachmentDMSId": "367141290", "totalNoOfPages": "1", "activityFileDate": "09/20/2023", "publicDocument": "Y", "activityComments": "180069554:valuationCert10a:Document added successfully.", "folderName": "180069554", "folderId": "180069554", "version": "", "addedBy": "Fo User"}, {"attachmentLabel": "subscriberConsent", "attachmentCategory": "Attachment", "activityFileName": "WhatsApp Image 2023-08-12 at 15.50.17.jpg", "activityFileSrcPath": "180069554", "activityFileSrcType": "I", "activityFileExt": "jpg", "activityFileSize": "75044", "attachmentDMSId": "367141323", "totalNoOfPages": "1 ...

# %%
import requests

url = 'https://www.mca.gov.in/bin/fillip/OnloadSubmit'

headers = {
    'Host': 'www.mca.gov.in',
    'Cookie': f'cookiesession1=678B2869144E6B476733B93A4104896E; alertPopup=true; deviceId=4d23ogqkdbe; session-token={session_token}',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Origin': 'https://www.mca.gov.in',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/Fillip.html',
}

updated_payload_2 = f"formData={json.dumps(final_submit_2)}"

response = requests.post(url, headers=headers, data=updated_payload_2)
response.text
# Out:
# '{"resCode":200,"resStr":"{\\n\\"error\\" : \\"Technical Error Occurred\\",\\n\\"message\\": \\"Not able to process your request.Kindly,contact the administrator.\\"\\n}"}'

# %%
payload = f"formData={json.dumps(final_submit_2)}"
response_text = save(payload)
response_text
# Out:
# '{"resCode":200,"resStr":"{\\n\\"error\\" : \\"Technical Error Occurred\\",\\n\\"message\\": \\"Not able to process your request.Kindly,contact the administrator.\\"\\n}"}'

# %%
response_text
# Out:
# '{"resCode":200,"resStr":"{\\n\\"error\\" : \\"Technical Error Occurred\\",\\n\\"message\\": \\"Not able to process your request.Kindly,contact the administrator.\\"\\n}"}'

# %%
final_submit_2
# Out:
# {'requestBody': {'operation': 'Submit',
#   'integrationId': '1-53260HK',
#   'referenceNumber': '1-11068950008',
#   'srn': 'M28186110',
#   'formId': 'Homogeneous',
#   'formName': 'FiLLiP',
#   'formDescription': '',
#   'formVersion': '1.2',
#   'userId': 'CASRIKANTH0224@GMAIL.COM',
#   'CIN': None,
#   'SRFOStatus': 'Draft/Pending Submission',
#   'formData': {'formIntegrationId': '1-53260HM',
#    'isRegistered': 'Y',
#    'srn': 'M28186110',
#    'incorporationType': 'New Incorporation',
#    'cin': None,
#    'proposedName': 'VOYAGENICTRAVELS LLP',
#    'attachment': False,
#    'attachment2a': False,
#    'attachment2c': False,
#    'attachment2d': False,
#    'attachment2e': False,
#    'significanceProposedName': None,
#    'vernacularLanguage': None,
#    'isRegisteredPending': None,
#    'particulars': None,
#    'registeredAddress': {'addressI': 'BMS College ofEngineering',
#     'addressII': 'Bull Temple Road',
#     'country': 'India',
#     'pin': '560019',
#     'area': 'Gaviopuram Extension',
#     'city': 'Bangalore South',
#     'district': 'Bangalore',
#     'state': 'Karnataka',
#     'longitude': '73.859207',
#     'latitude': '18.528851',
#     'policeStation': 'banashankari',
#     'phone': None,
#     'mobile': '9319421653',
#     'fax': None,
#     'email': 'Sachuuuu1428@gmail.com',
#     'registrarOfficeName': 'Registrar of Companies, Karnataka'},
#    'buissnessactivity': [{'srno': '1',
#      'industrySubClass': 'Axxx010',
#      'description': 'abc rtd',
#      'primary': 'No'},
#     {'srno': '2',
#      'industrySubClass': 'bxxx010',
#      'description': 'fghty rtd',
#      'primary': 'yes'}],
#    'mainIndustrialNICcode': '52291',
#    'mainIndustrialDescriptionOfNIC': 'Activities of travel agents and tour operators',
#    'otherIndustrialNICcode': '79120',
#    'otherIndustrialDescriptionOfNIC': 'Tour operator activities',
#    'NICCode3': '79110',
#    'NICCode3Desc': 'Travel agency activities',
#    'numberOfDesignatedPartnersValidDIN_DPIN': '0',
#    'numberOfDesignatedPartnersNotValidDIN_DPIN': '2',
#    'individualValidDINorDPIN': '0',
#    'individualNotValidDINorDPIN': '2',
#    'nominiesValidDINorDPIN': '0',
#    'nominiesNotValidDINorDPIN': '0',
#    'numberOfPartnersOtherThanDesignatedPartnerValidDINorDPIN': '0',
#    'numberOfPartnersOtherThanDesignatedPartnerNotValidDINorDPIN': '0',
#    'individualOtherThanDesignatedPartnerValidDINorDPIN': '0',
#    'individualOtherThanDesignatedPartnerNotValidDINorDPIN': '0',
#    'nominiesOtherThanDesignatedPartnerValidDINorDPIN': '0',
#    'nominiesOtherThanDesignatedPartnerNotValidDINorDPIN': '0',
#    'totalNumberValidDesignatedPartners': '0',
#    'totalNumberNotValidDesignatedPartners': '2',
#    'MCALLPFiLLiPIndPartner': [{'Category': 'Particulars of individual designated partners not having DIN/DPIN',
#      'firstName': 'SACHIN',
#      'middleName': '',
#      'surname': 'MADHESIYA',
#      'fatherFirstName': 'RAJU',
#      'fatherMiddleName': 'PRASAD',
#      'fathersurname': 'MADHESIYA',
#      'gender': 'Male',
#      'dateofBirth': '12/14/1998',
#      'nationality': 'India',
#      'isResidentInIndia': 'Y',
#      'isPanPassport': 'PAN',
#      'panPassportDetails': 'HQRPM8960H',
#      'placeOfBirthState': 'Uttar Pradesh',
#      'placeOfBirthDistrict': 'Agra',
#      'partnerIsCitizenofIndia': 'Y',
#      'occupationType': 'Private Employment',
#      'descriptionOfOthers': None,
#      'areaOfOccupation': 'Private Employment',
#      'otherAreaOfOccupation': None,
#      'educationalQualification': "Bachelor's degree",
#      'otherEducation': None,
#      'mobileNo': '%2B919319421653',
#      'emailid': 'Sachuuuu1428@gmail.com',
#      'proodOfIdentity': 'Aadhaar',
#      'residentialproof': 'Bank Statement',
#      'identityProofNo': '798000043919',
#      'residentialProofNo': '7324123775',
#      'numberOfsharesHeld': None,
#      'paidupvalueofsharesheld': None,
#      'formOfContribution': 'Other than cash',
#      'otherModeOfPayment': 'CHEQUE',
#      'monetaryValueOfContributionInFigures': '50000',
#      'monetaryValueOfContributionInWords': ' Fifty Thousand',
#      'numberOfLLPpartner': '0',
#      'numberOfcompanyDirector': '0',
#      'presentAddressSameAddressAsPremanent': 'Y',
#      'durationStayedAtPresentAddressYears': None,
#      'durationStayedAtPresentAddressMonth': None,
#      'addressOfPreviousResidence': None,
#      'designatedpartnerID': '',
#      'name': '',
#      'isResidentIndia': 'Y',
#      'paid': '',
#      'modeOfPay': 'Other than cash',
#      'monetaryValueInFigures': '50000',
#      'monetaryValueInwords': ' Fifty Thousand',
#      'numberOfLLP': '',
#      'numberOfCompanyHoldAsDirector': '5',
#      'partnerFirstName': 'SACHIN',
#      'partnerMiddleName': '',
#      'partnerSurname': 'MADHESIYA',
#      'partnerFatherFirstname': 'RAJU',
#      'partnerFatherMiddlename': 'PRASAD',
#      'partnerFatherSurname': 'MADHESIYA',
#      'partnerGender': 'Male',
#      'partnerDateofBirth': '12/14/1998',
#      'partnerNationality': 'India',
#      'partnerIsResidentIndia': 'Y',
#      'isPanPass': 'PAN',
#      'panPassDetails': 'BUOPE2342B',
#      'partnerPlaceofBirthState': '',
#      'partnerPlaceofBirthDistrict': 'Nagpur',
#      'OccupationType': 'Private Employment',
#      'isresidentofIndia': 'Y',
#      'numberofsharesheld': '100',
#      'passportOrPAN': 'PAN',
#      'emailID': 'Sachuuuu1428@gmail.com',
#      'previousResidence ': '',
#      'numberOfSharesHeld': '',
#      'PaidupvalueShares': '',
#      'ListOfbodyParnerIndOfficeAddress': {'bodyParnerIndOfficeAddress': [{'addressType': 'Permanent Address',
#         'addressI': 'ward no 9 gandhi nagar',
#         'addressII': 'hariharapura',
#         'country': 'India',
#         'pin': '272164',
#         'area': 'Hariharpur',
#         'city': 'Dhanghata',
#         'district': 'Sant Kabir Nagar',
#         'state': 'Uttar Pradesh',
#         'policeStation': 'Hariharpur',
#         'phone': '05542282600'},
#        {'addressType': 'Present Address',
#         'addressI': 'ward no 9 gandhi nagar',
#         'addressII': 'hariharapura',
#         'country': 'India',
#         'pin': '272164',
#         'area': 'Hariharpur',
#         'city': 'Dhanghata',
#         'district': 'Sant Kabir Nagar',
#         'state': 'Uttar Pradesh',
#         'policeStation': 'Hariharpur',
#         'phone': '05542282600'},
#        {'addressType': 'Registered Address',
#         'addressI': 'ward no 9 gandhi nagar',
#         'addressII': 'hariharapura',
#         'country': 'India',
#         'pin': '272164',
#         'area': 'Hariharpur',
#         'city': 'Dhanghata',
#         'district': 'Sant Kabir Nagar',
#         'state': 'Uttar Pradesh',
#         'policeStation': 'Hariharpur',
#         'phone': '05542282600'}]}},
#     {'Category': 'Particulars of individual designated partners not having DIN/DPIN',
#      'firstName': 'JAY',
#      'middleName': '',
#      'surname': 'BHATTARAI',
#      'fatherFirstName': 'DURGA',
#      'fatherMiddleName': 'PRASAD',
#      'fathersurname': 'BHATTARAI',
#      'gender': 'Male',
#      'dateofBirth': '05/05/2001',
#      'nationality': 'India',
#      'isResidentInIndia': 'Y',
#      'isPanPassport': 'PAN',
#      'panPassportDetails': 'FZMPB2968E',
#      'placeOfBirthState': 'Karnataka',
#      'placeOfBirthDistrict': 'Ballari',
#      'partnerIsCitizenofIndia': 'Y',
#      'occupationType': 'Private Employment',
#      'descriptionOfOthers': None,
#      'areaOfOccupation': 'Private Employment',
#      'otherAreaOfOccupation': None,
#      'educationalQualification': "Bachelor's degree",
#      'otherEducation': None,
#      'mobileNo': '%2B919916371230',
#      'emailid': 'bhattaraijay23@gmail.com',
#      'proodOfIdentity': 'Aadhaar',
#      'residentialproof': 'Bank Statement',
#      'identityProofNo': '581808086216',
#      'residentialProofNo': '90862388116',
#      'numberOfsharesHeld': None,
#      'paidupvalueofsharesheld': None,
#      'formOfContribution': 'Other than cash',
#      'otherModeOfPayment': 'cheque',
#      'monetaryValueOfContributionInFigures': '50000',
#      'monetaryValueOfContributionInWords': ' Fifty Thousand',
#      'numberOfLLPpartner': '0',
#      'numberOfcompanyDirector': '0',
#      'presentAddressSameAddressAsPremanent': 'Y',
#      'durationStayedAtPresentAddressYears': None,
#      'durationStayedAtPresentAddressMonth': None,
#      'addressOfPreviousResidence': None,
#      'designatedpartnerID': '',
#      'name': '',
#      'isResidentIndia': 'Y',
#      'paid': '',
#      'modeOfPay': 'Other than cash',
#      'monetaryValueInFigures': '50000',
#      'monetaryValueInwords': ' Fifty Thousand',
#      'numberOfLLP': '',
#      'numberOfCompanyHoldAsDirector': '5',
#      'partnerFirstName': 'JAY',
#      'partnerMiddleName': '',
#      'partnerSurname': 'BHATTARAI',
#      'partnerFatherFirstname': 'DURGA',
#      'partnerFatherMiddlename': 'PRASAD',
#      'partnerFatherSurname': 'BHATTARAI',
#      'partnerGender': 'Male',
#      'partnerDateofBirth': '05/05/2001',
#      'partnerNationality': 'India',
#      'partnerIsResidentIndia': 'Y',
#      'isPanPass': 'PAN',
#      'panPassDetails': 'BUOPE2342B',
#      'partnerPlaceofBirthState': '',
#      'partnerPlaceofBirthDistrict': 'Nagpur',
#      'OccupationType': 'Private Employment',
#      'isresidentofIndia': 'Y',
#      'numberofsharesheld': '100',
#      'passportOrPAN': 'PAN',
#      'emailID': 'bhattaraijay23@gmail.com',
#      'previousResidence ': '',
#      'numberOfSharesHeld': '',
#      'PaidupvalueShares': '',
#      'ListOfbodyParnerIndOfficeAddress': {'bodyParnerIndOfficeAddress': [{'addressType': 'Permanent Address',
#         'addressI': 'BMSCE Boys Hostel',
#         'addressII': 'bms college',
#         'country': 'India',
#         'pin': '560004',
#         'area': 'Basavanagudi',
#         'city': 'Bangalore',
#         'district': 'Bangalore',
#         'state': 'Karnataka',
#         'policeStation': 'Basavangudi',
#         'phone': '08026622130'},
#        {'addressType': 'Present Address',
#         'addressI': 'BMSCE Boys Hostel',
#         'addressII': 'bms college',
#         'country': 'India',
#         'pin': '560004',
#         'area': 'Basavanagudi',
#         'city': 'Bangalore',
#         'district': 'Bangalore',
#         'state': 'Karnataka',
#         'policeStation': 'Basavangudi',
#         'phone': '08026622130'},
#        {'addressType': 'Registered Address',
#         'addressI': 'BMSCE Boys Hostel',
#         'addressII': 'bms college',
#         'country': 'India',
#         'pin': '560004',
#         'area': 'Basavanagudi',
#         'city': 'Bangalore',
#         'district': 'Bangalore',
#         'state': 'Karnataka',
#         'policeStation': 'Basavangudi',
#         'phone': '08026622130'}]}}],
#    'presentAddressSameAddressAsPremanent': '',
#    'durationStayedAtPresentAddressYears': '',
#    'durationStayedAtPresentAddressMonth': '',
#    'addressOfPreviousResidence': '',
#    'proodOfIdentity': '',
#    'identityProofNo': '',
#    'residentialproof': '',
#    'residentialProofNo': '',
#    'numberOfSharesHeld': '',
#    'paidSharesHeld': '',
#    'otherModeOfPayment': '',
#    'monetaryValueOfContributionInFigures': '100000',
#    'monetaryValueOfContributionInWords': 'One Lakh',
#    'numberOfLLPpartner': '',
#    'numberOfcompanyDirector': '',
#    'deductionAccounNumberTAN': '',
#    'panAreacode': 'KAR',
#    'panAOtype': 'W',
#    'panRangecode': '224',
#    'panAONo': '93',
#    'tanAreacode': 'KAR',
#    'tanAOtype': 'WT',
#    'tanRangecode': '182',
#    'tanAONo': '3',
#    'sourceofIncome': 'Income from Business/profession ',
#    'BusinessProfessionCode': '20',
#    'dsc': '',
#    'DIN': 'HQRPM8960H',
#    'name': 'SRIKANTH REDDY',
#    'decProfessionalFatherName': 'S SRINIVASA REDDY',
#    'relation': 'Son',
#    'profession': 'Chartered Accountant in whole time practice',
#    'practiceName': 'Institute of Chartered Accountants of India',
#    'practiceNumber': '271843',
#    'regulatoryBody': 'Institute of Chartered Accountants of India',
#    'associate_fellow': 'Associate',
#    'dsc2': ''},
#   'formAttachment': [{'attachmentLabel': '3eAdressProof',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': 'Electricity+bill+(1).pdf',
#     'activityFileSrcPath': '180002960',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'pdf',
#     'activityFileSize': '294662',
#     'attachmentDMSId': '366952614',
#     'totalNoOfPages': '1',
#     'activityFileDate': '09/19/2023',
#     'publicDocument': 'Y',
#     'activityComments': '180002960:3eAdressProof:Document added successfully.',
#     'folderName': '180002960',
#     'folderId': '180002960',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': '3eUtilityBills',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': 'Electricity+bill+(1).pdf',
#     'activityFileSrcPath': '180002960',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'pdf',
#     'activityFileSize': '294662',
#     'attachmentDMSId': '366952637',
#     'totalNoOfPages': '1',
#     'activityFileDate': '09/19/2023',
#     'publicDocument': 'Y',
#     'activityComments': '180002960:3eUtilityBills:Document added successfully.',
#     'folderName': '180002960',
#     'folderId': '180002960',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': '6bIdentityProof',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': 'sachin_aadhar_merged+(1).pdf',
#     'activityFileSrcPath': '180002960',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'pdf',
#     'activityFileSize': '225573',
#     'attachmentDMSId': '366952660',
#     'totalNoOfPages': '2',
#     'activityFileDate': '09/19/2023',
#     'publicDocument': 'Y',
#     'activityComments': '180002960:6bIdentityProof:Document added successfully.',
#     'folderName': '180002960',
#     'folderId': '180002960',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': '6bResidentialProof',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': 'Sachin_Bank+(1).pdf',
#     'activityFileSrcPath': '180002960',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'pdf',
#     'activityFileSize': '152870',
#     'attachmentDMSId': '366952677',
#     'totalNoOfPages': '11',
#     'activityFileDate': '09/19/2023',
#     'publicDocument': 'Y',
#     'activityComments': '180002960:6bResidentialProof:Document added successfully.',
#     'folderName': '180002960',
#     'folderId': '180002960',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': '6bIdentityProof',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': 'Jay_aadhar_PAN-Jay_merged+(1).pdf',
#     'activityFileSrcPath': '180002960',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'pdf',
#     'activityFileSize': '368940',
#     'attachmentDMSId': '366952709',
#     'totalNoOfPages': '2',
#     'activityFileDate': '09/19/2023',
#     'publicDocument': 'Y',
#     'activityComments': '180002960:6bIdentityProof:Document added successfully.',
#     'folderName': '180002960',
#     'folderId': '180002960',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': '6bResidentialProof',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': 'Jay_Bank+(1).pdf',
#     'activityFileSrcPath': '180002960',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'pdf',
#     'activityFileSize': '34948',
#     'attachmentDMSId': '366952731',
#     'totalNoOfPages': '4',
#     'activityFileDate': '09/19/2023',
#     'publicDocument': 'Y',
#     'activityComments': '180002960:6bResidentialProof:Document added successfully.',
#     'folderName': '180002960',
#     'folderId': '180002960',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': 'valuationCert10a',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': 'WhatsApp Image 2023-08-12 at 15.50.17.jpg',
#     'activityFileSrcPath': '180002960',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'jpg',
#     'activityFileSize': '75044',
#     'attachmentDMSId': '366952802',
#     'totalNoOfPages': '1',
#     'activityFileDate': '09/19/2023',
#     'publicDocument': 'Y',
#     'activityComments': '180002960:valuationCert10a:Document added successfully.',
#     'folderName': '180002960',
#     'folderId': '180002960',
#     'version': '',
#     'addedBy': 'Fo User'},
#    {'attachmentLabel': 'subscriberConsent',
#     'attachmentCategory': 'Attachment',
#     'activityFileName': 'WhatsApp Image 2023-08-12 at 15.50.17.jpg',
#     'activityFileSrcPath': '180002960',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'jpg',
#     'activityFileSize': '75044',
#     'attachmentDMSId': '366952881',
#     'totalNoOfPages': '1',
#     'activityFileDate': '09/19/2023',
#     'publicDocument': 'Y',
#     'activityComments': '180002960:subscriberConsent:Document added successfully.',
#     'folderName': '180002960',
#     'folderId': '180002960',
#     'version': '',
#     'addedBy': 'Fo User'}]}}

# %%
final_submit_2['requestBody']['operation']="Submit"
payload = f"formData={json.dumps(final_submit_2)}"
response_text = save(payload)

# %%
response_text
# Out:
# '{"resCode":200,"resStr":"{\\n\\t\\t                   \\n\\t\\t                  \\t\\t\\t  \\"error\\" : \\"Technical Error Occurred\\",\\n\\t\\t                    \\t\\t  \\"message\\": \\"Not able to process your request.Kindly,contact the administrator.\\"\\n\\t\\t                   \\n\\t\\t                  \\t\\t   }"}'

# %%
ref_no
# Out:
# '1-10795589708'

# %%
import requests

# Define the URL and headers
url = "https://www.mca.gov.in/bin/fillip/OnloadSubmit"
headers = {
    "Host": "www.mca.gov.in",
    "Cookie": f"cookiesession1=678B2869144E6B476733B93A4104896E; session-token={session_token}",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Origin": "https://www.mca.gov.in",
    }
payload = {
    "formData": json.dumps({
        "requestBody": {
            "operation": "Load",
            "referenceNumber": ref_no,
            "srn": "",
            "formname": "FiLLiP"
        }
    })
}

# Send the POST request
response = requests.post(url, headers=headers, data=payload)

# Check the response
if response.status_code == 200:
    print("Request was successful.")
    print("Response content:")
    print(response.text)
else:
    print(f"Request failed with status code {response.status_code}:")
    print(response.text)
# Out:
# Request was successful.
# Response content:
# {"resCode":200,"resStr":"{\"error\":\"\",\"message\":\"Data Fetched Successfully\",\"data\":{\"status\":\"Draft/Pending Submission\",\"reason\":\"\",\"integrationId\":\"1-4YJEYBW\",\"eventDate\":\"\",\"lastUpdatedDate\":\"\",\"CIN\":\"\",\"formData\":{\"isRegistered\":\"Y\",\"srn\":\"M28067253\",\"formIntegrationId\":\"1-4YJEYBY\",\"incorporationType\":\"New Incorporation\",\"cin\":\"\",\"proposedName\":\"INVITEFULFUSION LLP\",\"significanceProposedName\":\"\",\"vernacularLanguage\":\"\",\"isRegisteredPending\":\"\",\"particulars\":\"\",\"registeredAddress\":{\"addressI\":\"RVCE\",\"addressII\":\"Educational Institution\",\"country\":\"India\",\"pin\":\"560085\",\"area\":\"Banashankari III Stage\",\"city\":\"Bangalore South\",\"district\":\"Bangalore\",\"state\":\"Karnataka\",\"longitude\":\"73.859207\",\"latitude\":\"18.528851\",\"policeStation\":\"banashankari\",\"phone\":\"\",\"mobile\":\"9319421653\",\"fax\":\"\",\"email\":\"Sachuuuu1428@gmail.com\",\"registrarOfficeName\":\"Registrar of Companies, Karnataka\"},\"mainIndustrialNICcode\":\"52291\",\"mainIndustrialDescriptionOfNIC\":\"Activities of travel agents and tour operators\",\"otherIndustrialNICcode\":\"79120\",\"otherIndustrialDescriptionOfNIC\":\"Tour operator activities\",\"numberOfDesignatedPartnersValidDIN_DPIN\":\"0\",\"numberOfDesignatedPartnersNotValidDIN_DPIN\":\"2\",\"individualValidDINorDPIN\":\"0\",\"individualNotValidDINorDPIN\":\"2\",\"nominiesValidDINorDPIN\":\"0\",\"nominiesNotValidDINorDPIN\":\"0\",\"numberOfPartnersOtherThanDesignatedPartnerValidDINorDPIN\":\"0\",\"numberOfPartnersOtherThanDesignatedPartnerNotValidDINorDPIN\":\"0\",\"individualOtherThanDesignatedPartnerValidDINorDPIN\":\"0\",\"individualOtherThanDesignatedPartnerNotValidDINorDPIN\":\"0\",\"nominiesOtherThanDesignatedPartnerValidDINorDPIN\":\"0\",\"nominiesOtherThanDesignatedPartnerNotValidDINorDPIN\":\"0\",\"totalNumberValidDesignatedPartners\":\"0\",\"totalNumberNotValidDesignatedPartners\":\"2\",\"monetaryValueOfContributionInFigures\":\"100000\",\"monetaryValueOfContributionInWords\":\"One Lakh\",\"panAreacode\":\"KAR\",\"panAOtype\":\"W\",\"panRangecode\":\"224\",\"panAONo\":\"93\",\"tanAreacode\":\"KAR\",\"tanAOtype\":\"WT\",\"tanRangecode\":\"182\",\"tanAONo\":\"3\",\"sourceofIncome\":\"Income from Business/profession\",\"BusinessProfessionCode\":\"20\",\"DIN\":\"HQRPM8960H\",\"name\":\"DESU SAI MANIKANTA\",\"relation\":\"Son\",\"profession\":\"Chartered Accountant in whole time practice\",\"practiceNumber\":\"263463\",\"regulatoryBody\":\"Institute of Company Secretaries of India\",\"associate_fellow\":\"Associate\",\"particulatOfNotVaidDIN_DPIN\":[{\"partnerFirstName\":\"SACHIN\",\"partnerMiddleName\":\"\",\"partnerSurname\":\"MADHESIYA\",\"partnerFatherFirstname\":\"RAJU\",\"partnerFatherMiddlename\":\"PRASAD\",\"partnerFatherSurname\":\"MADHESIYA\",\"partnerGender\":\"Male\",\"partnerDateofBirth\":\"12/14/1998\",\"partnerNationality\":\"India\",\"partnerIsResidentIndia\":\"Y\",\"isPanPass\":\"PAN\",\"panPassDetails\":\"HQRPM8960H\",\"partnerPlaceofBirthState\":\"Uttar Pradesh\",\"partnerPlaceofBirthDistrict\":\"Agra\",\"partnerIsCitizenofIndia\":\"Y\",\"OccupationType\":\"Private Employment\",\"descriptionOfOthers\":\"\",\"areaOfOccupation\":\"Private Employment\",\"otherAreaOfOccupation\":\"\",\"educationalQualification\":\"Bachelor's degree\",\"otherEducation\":\"\",\"mobileNo\":\"+919319421653\",\"emailid\":\"Sachuuuu1428@gmail.com\",\"durationStayedAtPresentAddressYears\":\"\",\"durationStayedAtPresentAddressMonth\":\"\",\"addressOfPreviousResidence\":\"\",\"proodOfIdentity\":\"Aadhaar\",\"identityProofNo\":\"798000043919\",\"residentialproof\":\"Bank Statement\",\"residentialProofNo\":\"7324123775\",\"numberOfSharesHeld\":\"\",\"paidSharesHeld\":\"\",\"formOfContribution\":\"Other than cash\",\"otherModeOfPayment\":\"CHEQUE\",\"monetaryValueOfContributionInFigures\":\"50000\",\"monetaryValueOfContributionInWords\":\" Fifty Thousand\",\"numberOfLLPpartner\":\"0\",\"num ...

# %%
nvd_details=json.loads(json.loads(response.text)['resStr'])['data']['formData']['particulatOfNotVaidDIN_DPIN']

# %%
f_details=json.loads(json.loads(response.text)['resStr'])['data']['MCALinkedFormDetails']

# %%
f9_py={'requestBody': {'serveAction': 'saveForm',
  'operation': 'Submit',
  'integrationId': '1-ABC',
  'referenceNumber': '1-ABC',
  'srn': '',
  'formId': '',
  'formName': 'LLP Form 9',
  'formDescription': '',
  'formVersion': '2',
  'userId': 'KASHVIJAIN19@GMAIL.COM',
  'boWorkStatus': '',
  'mcaComments': '',
  'SRFOStatus': 'Draft/Pending Submission',
  'fiLLiPReferenceNumber': ref_no,
  'formData': {'formIntegrationId': '1-xuvw',
   'LLPName': c_name1,
   'addressOfLLP': 'RVCE Educational Institution Banashankari III Stage Bangalore South 560085 Karnataka India',
   'addressLongitude': '',
   'addressPolice': '',
   'addressState': 'Karnataka',
   'addressLatitude': '',
   'addressCity': 'Bangalore South',
   'addressAreaLocality': 'Banashankari III Stage',
   'addressLine1': 'RVCE Educational Institution Banashankari III Stage Bangalore South 560085 Karnataka India',
   'addressCountry': 'India',
   'addressPincode': '560085',
   'addressDistrict': '',
   'totalNoOfPartners': '0',
   'individuals': '0',
   'nomineesOfBodyCorporate': '0',
   'consentDesignationPartner': '0',
   'designatedPartnerDetails': [{'partnerIDNo': None,
     'nameOfPartner': None,
     'nameOfbodyCorporate': None,
     'registrationNumber': None}],
   'registrationNumber': '',
   'dsc': ''}}}

# %%
f9_py
# Out:
# {'requestBody': {'serveAction': 'saveForm',
#   'operation': 'Submit',
#   'integrationId': '1-ABC',
#   'referenceNumber': '1-ABC',
#   'srn': '',
#   'formId': '',
#   'formName': 'LLP Form 9',
#   'formDescription': '',
#   'formVersion': '2',
#   'userId': 'KASHVIJAIN19@GMAIL.COM',
#   'boWorkStatus': '',
#   'mcaComments': '',
#   'SRFOStatus': 'Draft/Pending Submission',
#   'fiLLiPReferenceNumber': '1-10795589708',
#   'formData': {'formIntegrationId': '1-xuvw',
#    'LLPName': 'INVITEFULFUSION LLP',
#    'addressOfLLP': 'RVCE Educational Institution Banashankari III Stage Bangalore South 560085 Karnataka India',
#    'addressLongitude': '',
#    'addressPolice': '',
#    'addressState': 'Karnataka',
#    'addressLatitude': '',
#    'addressCity': 'Bangalore South',
#    'addressAreaLocality': 'Banashankari III Stage',
#    'addressLine1': 'RVCE Educational Institution Banashankari III Stage Bangalore South 560085 Karnataka India',
#    'addressCountry': 'India',
#    'addressPincode': '560085',
#    'addressDistrict': '',
#    'totalNoOfPartners': '0',
#    'individuals': '0',
#    'nomineesOfBodyCorporate': '0',
#    'consentDesignationPartner': '0',
#    'designatedPartnerDetails': [{'partnerIDNo': None,
#      'nameOfPartner': None,
#      'nameOfbodyCorporate': None,
#      'registrationNumber': None}],
#    'registrationNumber': '',
#    'dsc': ''}}}

# %%
#Save and continue
import requests

url = 'https://www.mca.gov.in/bin/fillip/OnloadSubmit'
headers = {
    'Host': 'www.mca.gov.in',
    'Cookie': 'cookiesession1=678B2869144E6B476733B93A4104896E;session-token={session_token}',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Origin': 'https://www.mca.gov.in',
   }

payload = f"formData={json.dumps(f9_py)}"
response = requests.post(url, headers=headers, data=payload)
response.text
# Out:
# '{"resCode":200,"resStr":"{\\n\\t\\t\\t\\t\\t    \\"error\\": \\"\\",\\n\\t\\t\\t\\t\\t    \\"message\\": \\"Data Added Successfully\\",\\n\\t\\t\\t\\t\\t    \\"data\\": {\\n\\t\\t\\t\\t\\t        \\"integrationId\\": \\"1-4YJEURX\\",\\n\\t\\t\\t\\t\\t        \\"formIntegrationId\\": \\"1-4YJEURZ\\",\\n\\t\\t\\t\\t\\t        \\"referenceNumber\\": \\"1-10795585101\\",\\n\\t\\t\\t\\t\\t        \\"srn\\": \\"M28176668\\",\\n\\t\\t\\t\\t\\t        \\"dateTime\\": \\"08/29/2023 19:45:10\\",\\n\\t\\t\\t\\t\\t        \\"srnStatus\\": \\"Pending for DSC Upload and Payment\\",\\n\\t\\t\\t\\t\\t        \\"formType\\": \\"NSTP\\"\\n\\t\\t\\t\\t\\t    }\\n\\t\\t\\t\\t\\t}"}'

# %%
f9_intid=json.loads(json.loads(response.text)['resStr'])['data']['integrationId']
f9_formintid=json.loads(json.loads(response.text)['resStr'])['data']['formIntegrationId']

# %%
f9_srn=json.loads(json.loads(response.text)['resStr'])['data']['srn']

# %%
f9_rf=json.loads(json.loads(response.text)['resStr'])['data']['referenceNumber']

# %%
new_payload={"requestBody":{"status":"Draft/Pending Submission","reason":"","integrationId":"1-4XL0XAQ","eventDate":"","lastUpdatedDate":"","CIN":"","formData":{"isRegistered":"Y","srn":"M28067253","formIntegrationId":"1-4XL0XAS","incorporationType":"New Incorporation","cin":"","proposedName":"INVITEFULFUSION LLP","significanceProposedName":"","vernacularLanguage":"","isRegisteredPending":"","particulars":"","registeredAddress":{"addressI":"RVCE","addressII":"Educational Institution","country":"India","pin":"560085","area":"Banashankari III Stage","city":"Bangalore South","district":"Bangalore","state":"Karnataka","longitude":"73.859207","latitude":"18.528851","policeStation":"banashankari","phone":"","mobile":"9319421653","fax":"","email":"Sachuuuu1428@gmail.com","registrarOfficeName":"Registrar of Companies, Karnataka"},"mainIndustrialNICcode":"56210","mainIndustrialDescriptionOfNIC":"Event catering","otherIndustrialNICcode":"","otherIndustrialDescriptionOfNIC":"","numberOfDesignatedPartnersValidDIN_DPIN":"0","numberOfDesignatedPartnersNotValidDIN_DPIN":"2","individualValidDINorDPIN":"0","individualNotValidDINorDPIN":"2","nominiesValidDINorDPIN":"0","nominiesNotValidDINorDPIN":"0","numberOfPartnersOtherThanDesignatedPartnerValidDINorDPIN":"0","numberOfPartnersOtherThanDesignatedPartnerNotValidDINorDPIN":"0","individualOtherThanDesignatedPartnerValidDINorDPIN":"0","individualOtherThanDesignatedPartnerNotValidDINorDPIN":"0","nominiesOtherThanDesignatedPartnerValidDINorDPIN":"0","nominiesOtherThanDesignatedPartnerNotValidDINorDPIN":"0","totalNumberValidDesignatedPartners":"0","totalNumberNotValidDesignatedPartners":"2","monetaryValueOfContributionInFigures":"100000","monetaryValueOfContributionInWords":" One Lakh","panAreacode":"KAR","panAOtype":"W","panRangecode":"224","panAONo":"93","tanAreacode":"KAR","tanAOtype":"WT","tanRangecode":"182","tanAONo":"3","sourceofIncome":"Income from Business/profession","BusinessProfessionCode":"20","DIN":"HQRPM8960H","name":"DESU SAI MANIKANTA","relation":"Son","profession":"Chartered Accountant in whole time practice","practiceNumber":"263463","regulatoryBody":"Institute of Chartered Accountants of India","associate_fellow":"Associate","particulatOfNotVaidDIN_DPIN":[{"partnerFirstName":"SACHIN","partnerMiddleName":"","partnerSurname":"MADHESIYA","partnerFatherFirstname":"RAJU","partnerFatherMiddlename":"PRASAD","partnerFatherSurname":"MADHESIYA","partnerGender":"Male","partnerDateofBirth":"12/14/1998","partnerNationality":"India","partnerIsResidentIndia":"Y","isPanPass":"PAN","panPassDetails":"HQRPM8960H","partnerPlaceofBirthState":"Uttar Pradesh","partnerPlaceofBirthDistrict":"Agra","partnerIsCitizenofIndia":"Y","OccupationType":"Private Employment","descriptionOfOthers":"","areaOfOccupation":"Private Employment","otherAreaOfOccupation":"","educationalQualification":"Bachelor's degree","otherEducation":"","mobileNo":"+919319421653","emailid":"Sachuuuu1428@gmail.com","durationStayedAtPresentAddressYears":"","durationStayedAtPresentAddressMonth":"","addressOfPreviousResidence":"","proodOfIdentity":"Aadhaar","identityProofNo":"798000043919","residentialproof":"Bank Statement","residentialProofNo":"7324123775","numberOfSharesHeld":"","paidSharesHeld":"","formOfContribution":"Other than cash","otherModeOfPayment":"CHEQUE","monetaryValueOfContributionInFigures":"50000","monetaryValueOfContributionInWords":" Fifty Thousand","numberOfLLPpartner":"0","numberOfcompanyDirector":"0","permanentAddress":[{"addressI":"ward no 9 gandhi nagar","addressII":"hariharapura","country":"India","pin":"272164","area":"Hariharpur","city":"Dhanghata","district":"Sant Kabir Nagar","state":"Uttar Pradesh","policeStation":"Hariharpur","phone":"05542282600"}],"presentAddressSameAddressAsPremanent":"Y","presentAddress":[{"addressI":"ward no 9 gandhi nagar","addressII":"hariharapura","country":"India","pin":"272164","area":"Hariharpur","city":"Dhanghata","district":"Sant Kabir Nagar","state":"Uttar Pradesh","policeStation":"Hariharpur","phone":"05542282600"}]},{"partnerFirstName":"JAY","partnerMiddleName":"","partnerSurname":"BHATTARAI","partnerFatherFirstname":"DURGA","partnerFatherMiddlename":"PRASAD","partnerFatherSurname":"BHATTARAI","partnerGender":"Male","partnerDateofBirth":"05/05/2001","partnerNationality":"India","partnerIsResidentIndia":"Y","isPanPass":"PAN","panPassDetails":"FZMPB2968E","partnerPlaceofBirthState":"Karnataka","partnerPlaceofBirthDistrict":"Ballari","partnerIsCitizenofIndia":"Y","OccupationType":"Private Employment","descriptionOfOthers":"","areaOfOccupation":"Private Employment","otherAreaOfOccupation":"","educationalQualification":"Bachelor's degree","otherEducation":"","mobileNo":"+919916371230","emailid":"bhattaraijay23@gmail.com","durationStayedAtPresentAddressYears":"","durationStayedAtPresentAddressMonth":"","addressOfPreviousResidence":"","proodOfIdentity":"Aadhaar","identityProofNo":"581808086216","residentialproof":"Bank Statement","residentialProofNo":"90862388116","numberOfSharesHeld":"","paidSharesHeld":"","formOfContribution":"Other than cash","otherModeOfPayment":"cheque","monetaryValueOfContributionInFigures":"50000","monetaryValueOfContributionInWords":" Fifty Thousand","numberOfLLPpartner":"0","numberOfcompanyDirector":"0","permanentAddress":[{"addressI":"BMSCE Boys Hostel","addressII":"bms college","country":"India","pin":"560004","area":"Basavanagudi","city":"Bangalore","district":"Bangalore","state":"Karnataka","policeStation":"Basavangudi","phone":"08026622130"}],"presentAddressSameAddressAsPremanent":"Y","presentAddress":[{"addressI":"BMSCE Boys Hostel","addressII":"bms college","country":"India","pin":"560004","area":"Basavanagudi","city":"Bangalore","district":"Bangalore","state":"Karnataka","policeStation":"Basavangudi","phone":"08026622130"}]}],"NICCode3":"","NICCode3Desc":"","decProfessionalFatherName":"DESU NAGENDRA PRASAD"},"MCALinkedFormDetails":{"IntObjectFormat":"Siebel Hierarchical","MessageId":"1-SHIAQY","IntObjectName":"MCALinkedFormDetails","MessageType":"Integration Object","LinkedFormDetails":[]},"Approvedname":"","formAttachment":[{"attachmentLabel":"3eAdressProof","attachmentCategory":"Attachment","activityFileName":"_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg","activityFileSrcPath":"174820662","activityFileSrcType":"I","activityFileExt":"jpeg","activityFileSize":"112861","attachmentDMSId":"359563609","totalNoOfPages":"1","activityFileDate":"08/24/2023","publicDocument":"Y","activityComments":"174820662:3eAdressProof:Document added successfully.","folderName":"174820662","folderId":"174820662","version":"","addedBy":"Fo User"},{"attachmentLabel":"3eUtilityBills","attachmentCategory":"Attachment","activityFileName":"_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg","activityFileSrcPath":"174820662","activityFileSrcType":"I","activityFileExt":"jpeg","activityFileSize":"112861","attachmentDMSId":"359563657","totalNoOfPages":"1","activityFileDate":"08/24/2023","publicDocument":"Y","activityComments":"174820662:3eUtilityBills:Document added successfully.","folderName":"174820662","folderId":"174820662","version":"","addedBy":"Fo User"},{"attachmentLabel":"6bResidentialProof","attachmentCategory":"Attachment","activityFileName":"_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg","activityFileSrcPath":"174820662","activityFileSrcType":"I","activityFileExt":"jpeg","activityFileSize":"112861","attachmentDMSId":"359563898","totalNoOfPages":"1","activityFileDate":"08/24/2023","publicDocument":"Y","activityComments":"174820662:6bResidentialProof:Document added successfully.","folderName":"174820662","folderId":"174820662","version":"","addedBy":"Fo User"},{"attachmentLabel":"6bIdentityProof","attachmentCategory":"Attachment","activityFileName":"_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg","activityFileSrcPath":"174820662","activityFileSrcType":"I","activityFileExt":"jpeg","activityFileSize":"112861","attachmentDMSId":"359563965","totalNoOfPages":"1","activityFileDate":"08/24/2023","publicDocument":"Y","activityComments":"174820662:6bIdentityProof:Document added successfully.","folderName":"174820662","folderId":"174820662","version":"","addedBy":"Fo User"},{"attachmentLabel":"6bResidentialProof","attachmentCategory":"Attachment","activityFileName":"_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg","activityFileSrcPath":"174820662","activityFileSrcType":"I","activityFileExt":"jpeg","activityFileSize":"112861","attachmentDMSId":"359563998","totalNoOfPages":"1","activityFileDate":"08/24/2023","publicDocument":"Y","activityComments":"174820662:6bResidentialProof:Document added successfully.","folderName":"174820662","folderId":"174820662","version":"","addedBy":"Fo User"},{"attachmentLabel":"valuationCert10a","attachmentCategory":"Attachment","activityFileName":"_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg","activityFileSrcPath":"174820662","activityFileSrcType":"I","activityFileExt":"jpeg","activityFileSize":"112861","attachmentDMSId":"359564169","totalNoOfPages":"1","activityFileDate":"08/24/2023","publicDocument":"Y","activityComments":"174820662:valuationCert10a:Document added successfully.","folderName":"174820662","folderId":"174820662","version":"","addedBy":"Fo User"},{"attachmentLabel":"subscriberConsent","attachmentCategory":"Attachment","activityFileName":"_cf261114-b13f-4f7e-b7c2-1b2dbffd0b6a.jpeg","activityFileSrcPath":"174820662","activityFileSrcType":"I","activityFileExt":"jpeg","activityFileSize":"112861","attachmentDMSId":"359564216","totalNoOfPages":"1","activityFileDate":"08/24/2023","publicDocument":"Y","activityComments":"174820662:subscriberConsent:Document added successfully.","folderName":"174820662","folderId":"174820662","version":"","addedBy":"Fo User"}]}}

# %%
ky= []

for key in final_submit_2['requestBody'].keys():
    if key not in new_payload['requestBody']:
        ky.append(key)
for key in ky:
    if key in final_submit_2['requestBody']:
        del final_submit_2['requestBody'][key]

# %%
ky= []

for key in final_submit_2['requestBody']['formData'].keys():
    if key not in new_payload['requestBody']['formData']:
        ky.append(key)
for key in ky:
    if key in final_submit_2['requestBody']['formData']:
        del final_submit_2['requestBody']['formData'][key]

# %%
new_payload['requestBody'].keys()
# Out:
# dict_keys(['status', 'reason', 'integrationId', 'eventDate', 'lastUpdatedDate', 'CIN', 'formData', 'MCALinkedFormDetails', 'Approvedname', 'formAttachment'])

# %%
final_submit_2['requestBody']['formData']['particulatOfNotVaidDIN_DPIN']=nvd_details

# %%
final_submit_2['requestBody']['status']='Draft/Pending Submission'
final_submit_2['requestBody']['reason']=''
final_submit_2['requestBody']['eventDate']=''
final_submit_2['requestBody']['lastUpdatedDate']=''
final_submit_2['requestBody']['MCALinkedFormDetails']=f_details
final_submit_2['requestBody']['Approvedname']=''

# %%
refer_value="/content/forms/af/mca-aem-forms/form-fillip/fillip-main-form/form-fillip"
requestType="New Request"

# %%
metadata={'form': 'FiLLiP',
 'srn': ref_no,
 'documentType': 'Form',
 'module': 'FiLLiP',
 'userid': 'KASHVIJAIN19@GMAIL.COM',
 'applicationId': ref_no,
 'attachmentCategory': 'pdf',
 'integrationId': intid,
 'formDescription': 'FiLLiP',
 'formVersion': '01',
 'foldername': '174820662',
 'action': 'uploaddms'}

# %%
json.dumps(metadata)
# Out:
# '{"form": "FiLLiP", "srn": "1-10795589708", "documentType": "Form", "module": "FiLLiP", "userid": "KASHVIJAIN19@GMAIL.COM", "applicationId": "1-10795589708", "attachmentCategory": "pdf", "integrationId": "1-4YJEYBW", "formDescription": "FiLLiP", "formVersion": "01", "foldername": "174820662", "action": "uploaddms"}'

# %%
json.dumps(final_submit_2)
# Out:
# '{"requestBody": {"integrationId": "1-4YJEYBW", "CIN": null, "formData": {"formIntegrationId": "1-4YJEYBY", "isRegistered": "Y", "srn": "M28067253", "incorporationType": "New Incorporation", "cin": null, "proposedName": "INVITEFULFUSION LLP", "significanceProposedName": null, "vernacularLanguage": null, "isRegisteredPending": null, "particulars": null, "registeredAddress": {"addressI": "RVCE", "addressII": "Educational Institution", "country": "India", "pin": "560085", "area": "Banashankari III Stage", "city": "Bangalore South", "district": "Bangalore", "state": "Karnataka", "longitude": "73.859207", "latitude": "18.528851", "policeStation": "banashankari", "phone": null, "mobile": "9319421653", "fax": null, "email": "Sachuuuu1428@gmail.com", "registrarOfficeName": "Registrar of Companies, Karnataka"}, "mainIndustrialNICcode": "52291", "mainIndustrialDescriptionOfNIC": "Activities of travel agents and tour operators", "otherIndustrialNICcode": "79120", "otherIndustrialDescriptionOfNIC": "Tour operator activities", "NICCode3": "79110", "NICCode3Desc": "Travel agency activities", "numberOfDesignatedPartnersValidDIN_DPIN": "0", "numberOfDesignatedPartnersNotValidDIN_DPIN": "2", "individualValidDINorDPIN": "0", "individualNotValidDINorDPIN": "2", "nominiesValidDINorDPIN": "0", "nominiesNotValidDINorDPIN": "0", "numberOfPartnersOtherThanDesignatedPartnerValidDINorDPIN": "0", "numberOfPartnersOtherThanDesignatedPartnerNotValidDINorDPIN": "0", "individualOtherThanDesignatedPartnerValidDINorDPIN": "0", "individualOtherThanDesignatedPartnerNotValidDINorDPIN": "0", "nominiesOtherThanDesignatedPartnerValidDINorDPIN": "0", "nominiesOtherThanDesignatedPartnerNotValidDINorDPIN": "0", "totalNumberValidDesignatedPartners": "0", "totalNumberNotValidDesignatedPartners": "2", "monetaryValueOfContributionInFigures": "100000", "monetaryValueOfContributionInWords": "One Lakh", "panAreacode": "KAR", "panAOtype": "W", "panRangecode": "224", "panAONo": "93", "tanAreacode": "KAR", "tanAOtype": "WT", "tanRangecode": "182", "tanAONo": "3", "sourceofIncome": "Income from Business/profession ", "BusinessProfessionCode": "20", "DIN": "HQRPM8960H", "name": "DESU SAI MANIKANTA", "decProfessionalFatherName": "DESU NAGENDRA PRASAD", "relation": "Son", "profession": "Chartered Accountant in whole time practice", "practiceNumber": "263463", "regulatoryBody": "Institute of Company Secretaries of India", "associate_fellow": "Associate", "particulatOfNotVaidDIN_DPIN": [{"partnerFirstName": "SACHIN", "partnerMiddleName": "", "partnerSurname": "MADHESIYA", "partnerFatherFirstname": "RAJU", "partnerFatherMiddlename": "PRASAD", "partnerFatherSurname": "MADHESIYA", "partnerGender": "Male", "partnerDateofBirth": "12/14/1998", "partnerNationality": "India", "partnerIsResidentIndia": "Y", "isPanPass": "PAN", "panPassDetails": "HQRPM8960H", "partnerPlaceofBirthState": "Uttar Pradesh", "partnerPlaceofBirthDistrict": "Agra", "partnerIsCitizenofIndia": "Y", "OccupationType": "Private Employment", "descriptionOfOthers": "", "areaOfOccupation": "Private Employment", "otherAreaOfOccupation": "", "educationalQualification": "Bachelor\'s degree", "otherEducation": "", "mobileNo": "+919319421653", "emailid": "Sachuuuu1428@gmail.com", "durationStayedAtPresentAddressYears": "", "durationStayedAtPresentAddressMonth": "", "addressOfPreviousResidence": "", "proodOfIdentity": "Aadhaar", "identityProofNo": "798000043919", "residentialproof": "Bank Statement", "residentialProofNo": "7324123775", "numberOfSharesHeld": "", "paidSharesHeld": "", "formOfContribution": "Other than cash", "otherModeOfPayment": "CHEQUE", "monetaryValueOfContributionInFigures": "50000", "monetaryValueOfContributionInWords": " Fifty Thousand", "numberOfLLPpartner": "0", "numberOfcompanyDirector": "0", "permanentAddress": [{"addressI": "ward no 9 gandhi nagar", "addressII": "hariharapura", "country": "India", "pin": "272164", "area": "Hariharpur", "city": "Dhanghata", "district": "Sant Kabir Nagar", "state": "Uttar Pr ...

# %%
f9_srn
# Out:
# 'M28176668'

# %%
import requests

# Define the URL to send the POST request
url = "https://www.mca.gov.in/bin/mca-gov/generatePdf"


headers = {
    "Cookie": f"cookiesession1=678B2869D727DAE036D48B6E36133C84; session-token={session_token}",
}
multipart_data = MultipartEncoder(fields={
    'data':json.dumps(final_submit_2),
    'metadata': json.dumps(metadata),
    'refer': refer_value,
    'srn': f9_srn,
    'requestType': requestType
})
headers = {'Content-Type': multipart_data.content_type}

# Send the POST request
response = requests.post(url, data=multipart_data, headers=headers)


# Check if the request was successful
if response.status_code == 200:
    # Print the response content (PDF data)
    print(response.text)
else:
    print(f"Failed with status code {response.status_code}")
# Out:
# {"attachmentLabel":"FiLLiP","attachmentCategory":"Forms","activityFileName":"1-10795589708.pdf","activityFileSrcPath":"174820662","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"713246","attachmentDMSId":"360800521","totalNoOfPages":"23","activityFileDate":"08/29/2023","publicDocument":"Y","activityComments":"Generated PDF Stored Successfully","folderName":"174820662","folderId":"174820662","version":"","addedBy":"Fo User"}

# %%
f9_data={'requestBody': {'formData': {'LLPName': c_name1,
   'roAddrCity': 'Bangalore South',
   'roAddrCountry': 'India',
   'roAddrDistrict': '',
   'roAddrLatitude': '',
   'roAddrLine1': 'RVCE Educational Institution Banashankari III Stage Bangalore South 560085 Karnataka India',
   'roAddrLine2': '',
   'roAddrLocality': 'Banashankari III Stage',
   'roAddrLongitude': '',
   'roAddrPolice': '',
   'roAddrPincode': '560085',
   'roAddrState': 'Karnataka',
   'totalNoOfPartners': '0',
   'individuals': '0',
   'nomineesOfBodyCorporate': '0',
   'registrationNumber': '',
   'formIntegrationId': f9_formintid,
   'designatedPartnerDetails': []},
  'integrationId': f9_intid,
  'srn': f9_srn}}

# %%
f9_metadata={'form': 'LLP Form 9',
 'srn': f9_srn,
 'documentType': 'Form',
 'module': 'LLP Form 9',
 'userid': 'KASHVIJAIN19@GMAIL.COM',
 'applicationId': f9_rf,
 'attachmentCategory': 'pdf',
 'integrationId': f9_intid,
 'formDescription': 'LLP Form 9',
 'formVersion': '01',
 'foldername': '174820662',
 'action': 'uploaddms'}

# %%
f9_refer="/content/forms/af/mca-aem-forms/form-fillip/form-9/form-9"

# %%
import requests

# Define the URL to send the POST request
url = "https://www.mca.gov.in/bin/mca-gov/generatePdf"


headers = {
    "Cookie": f"cookiesession1=678B2869D727DAE036D48B6E36133C84; session-token={session_token}",
}
multipart_data = MultipartEncoder(fields={
    'data':json.dumps(f9_data),
    'metadata': json.dumps(f9_metadata),
    'refer': f9_refer,
    'srn': f9_srn,
    'requestType': requestType
})
headers = {'Content-Type': multipart_data.content_type}

# Send the POST request
response = requests.post(url, data=multipart_data, headers=headers)


# Check if the request was successful
if response.status_code == 200:
    
    # Print the response content (PDF data)
    print(response.text)
else:
    print(f"Failed with status code {response.status_code}")
# Out:
# {"attachmentLabel":"LLP Form 9","attachmentCategory":"Forms","activityFileName":"M28176668.pdf","activityFileSrcPath":"174820662","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"37784","attachmentDMSId":"360800524","totalNoOfPages":"2","activityFileDate":"08/29/2023","publicDocument":"Y","activityComments":"Generated PDF Stored Successfully","folderName":"174820662","folderId":"174820662","version":"","addedBy":"Fo User"}

# %%
f9_srn
# Out:
# 'M28176668'
