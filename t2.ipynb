# %%
from bs4 import BeautifulSoup
import json
import re

# %%
user_id = "rana123"
password = "Vivek@123"

# %%
import requests

# url = "https://ipindiaonline.gov.in//trademarkefiling/online/welcomeForm.aspx"
url = "https://ipindiaonline.gov.in///trademarkefiling/user/frmloginNew.aspx"

response = requests.get(url)

print(response.text)  # Print the response content
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" lang="en">
# <head>
#     <title>Intellectual Property India</title>
#     <meta http-equiv="x-ua-compatible" content="IE=11,10,9,8">
#
#
#
#     <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
#     <meta http-equiv="Content-Style-Type" content="text/css">
#     <meta http-equiv="Content-Script-Type" content="type">
#     <meta name="format-detection" content="telephone=no">
#     <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">
#
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.6/css/bootstrap.min.css">
#
#     <link media="all" href="../CSS/style.css" type="text/css" rel="stylesheet" />
#     <link media="all" href="../CSS/responsive.css" type="text/css" rel="stylesheet" />
#
#     <script src="../Scripts/SHA1.js" type="text/javascript"></script>
#
# ...

# %%
a=response.headers['Set-Cookie'].split(';')[0]

# %%
html_content=response.text

# %%
soup = BeautifulSoup(html_content, 'html.parser')
viewstate_input = soup.find('input', {'id': '__VIEWSTATE'})

if viewstate_input:
    viewstate_value = viewstate_input.get('value')
    print("VIEWSTATE value:", viewstate_value)
else:
    print("__VIEWSTATE input not found in the HTML")
# Out:
# VIEWSTATE value: 

# %%
from urllib.parse import quote
encoded_viewstate_value_string = quote(viewstate_value, safe='')

print("Encoded string:", encoded_viewstate_value_string)
# Out:
# Encoded string: FjEuYGKTVE7K9Mkqg9zNLz%2BcRbVzOix3tLw5897GKRssxayN666Zzkp8LLvTlFHIROl042ISfVn%2Bocxo%2BLP%2B8M59iScGphOshPzxoLRgwO0xXrtBtlh0FACxCJ6dZkA3ggbqX5t7xR%2FHRu6N0R58fFfPIhywl88l0N0QGd8nEoAYteysHsOaRgJYAPTZhmSX682z7Bnbw3tqr18p1EmhwKd%2BFXtS5VjuK5Z9hFaH1124vDONnG5EjHujIPr6QCyjt1uZnIwX0TKPMJN7SpR%2BE6CF9xGl99FyfGjtQCTM9YnhK%2Ba%2FlOsZ7XLV8kSOAJ%2F2eCGN%2BZcaoXzGuUhrCvtNdjNzAiylZ7w6uYa15KNsIpQ%3D

# %%
viewstateGEN_input = soup.find('input', {'id': '__VIEWSTATEGENERATOR'})

if viewstateGEN_input:
    viewstateGEN_value = viewstateGEN_input.get('value')
    print("VIEWSTATEGEN value:", viewstateGEN_value)
else:
    print("__VIEWSTATE input not found in the HTML")
# Out:
# VIEWSTATEGEN value: 137D2B9B

# %%
EVENTVALIDATION_input = soup.find('input', {'id': '__EVENTVALIDATION'})

if EVENTVALIDATION_input:
    EVENTVALIDATION_value = EVENTVALIDATION_input.get('value')
    print("EVENTVALIDATION value:", EVENTVALIDATION_value)
else:
    print("__VIEWSTATE input not found in the HTML")
# Out:
# EVENTVALIDATION value: 

# %%
from urllib.parse import quote
encoded_eventvalidation_value_string = quote(EVENTVALIDATION_value, safe='')

print("Encoded string:", encoded_eventvalidation_value_string)
# Out:
# Encoded string: %2FXJScuoW8aZhabrVW42i6ANF8CbsGepT%2FvwxnnNdd3afpCpSvHc%2BfwTrLsRUuImaJSNlRVJa2IQZJF8zcK8F6YW1PB4XOdASUGKjcbxzDrpEcMJdFrpEqLbCG0Y6iIWsvaU%2FRaLmGY27s82NuR0EMVi6xixgq%2Bzo3MSjlv%2BI7ISaVk%2F7CafScYFfcjkNrw5GF26CFx%2F3wj%2F1Ak4kZIkFxKtuWCjO9KpvZVzCQ9Xtvrt07tii%2FyTxjLObvdYXIzEKAa%2F2RvKfyNywG%2FV1qFc5jRNoR1ZR5sbpuXr%2BpwVvDdqN5So%2FVum%2BJpzE9Nvpb1AcyzYcCSFVQ6FpS2fISLL0zW%2FXQoudobtt5p7IePEVG%2Fg%3D

# %%
PREVIOUSPAGE_input = soup.find('input', {'id': '__PREVIOUSPAGE'})

if PREVIOUSPAGE_input:
    PREVIOUSPAGE_value = PREVIOUSPAGE_input.get('value')
    print("PREVIOUSPAGE value:", PREVIOUSPAGE_value)
else:
    print("__VIEWSTATE input not found in the HTML")
# Out:
# PREVIOUSPAGE value: DyDM6BKxjWaD_xdCbi4dHxeDtP7FqhnfVq0N8aYgqFH94VOfG_FAxJS-NRdFu3c_tDiHaLxOUO5H4-ntshP2hJ4HFRffJ-JzeHf8EY6ziG03kKAWq8paqoXwzqtrDH4F0

# %%
onclick_value = soup.find('input', {'id': 'LnkSubmitLogin'}).get('onclick')

# %%
seed_match = re.search(r'Validate\((\d+)\)', onclick_value)

# %%
seed = int(seed_match.group(1))
print("Extracted seed value:", seed)
# Out:
# Extracted seed value: 220039964

# %%
import hashlib

def str2rstr_utf8(s):
    return s.encode('utf-8')

def rstr_sha1(s):
    sha1 = hashlib.sha1()
    sha1.update(s)
    return sha1.digest()

def rstr2hex(input_bytes):
    return ''.join(format(byte, '02x') for byte in input_bytes)

def hex_sha1(s):
    return rstr2hex(rstr_sha1(str2rstr_utf8(s)))

def calculate_password_hash(password, seed):
    SHA1New = hex_sha1(password)
    finalpass = SHA1New + seed
    SHA1 = hex_sha1(finalpass)
    return SHA1

  # Replace this with the actual value of seed from your code

hashed_password = calculate_password_hash(password, str(seed))
# hashed_password = calculate_password_hash(password, "427215818")

print(hashed_password)
# Out:
# f241ad0930891003382a5fa025a13e4f7921de03

# %%
imges = soup.select('div img')

# %%
for i in imges:
    try:
        if i['id'] == "captchaimg":
            img_url = i['src']
            img_url = "https://ipindiaonline.gov.in/trademarkefiling/CaptchaGenerator/"+img_url.split('/')[2]
    except:
        continue

# %%
data_img={
    "__VIEWSTATE":viewstate_value,
    "__VIEWSTATEGENERATOR":viewstateGEN_value,
    
    
}

# %%
headers={"Cookie":a}
response = requests.get(img_url, stream=True)

if response.status_code == 200:
    # Replace with the desired file path to save the image
    image_path = "captcha_image2.jpg"

    with open(image_path, 'wb') as image_file:
        for chunk in response.iter_content(chunk_size=128):
            image_file.write(chunk)
            # print(response.content)

    print("CAPTCHA image saved as:", image_path)
else:
    print("Failed to fetch CAPTCHA image")
# Out:
# CAPTCHA image saved as: captcha_image2.jpg

# %%
headers = {
    # Your headers here
    "Cookie": a
}

response = requests.get(img_url, headers=headers)

if response.status_code == 200:
    with open("captcha_image.jpg", "wb") as image_file:
        image_file.write(response.content)
    print("Captcha image saved successfully.")
else:
    print("Failed to fetch captcha image.")
# Out:
# Captcha image saved successfully.

# %%
response.text
# Out:
# '����\x00\x10JFIF\x00\x01\x01\x01\x00`\x00`\x00\x00��\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\'9=82<.342��\x00C\x01\t\t\t\x0c\x0b\x0c\x18\r\r\x182!\x1c!22222222222222222222222222222222222222222222222222��\x00\x11\x08\x00#\x00�\x03\x01"\x00\x02\x11\x01\x03\x11\x01��\x00\x1f\x00\x00\x01\x05\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b��\x00�\x10\x00\x02\x01\x03\x03\x02\x04\x03\x05\x05\x04\x04\x00\x00\x01}\x01\x02\x03\x00\x04\x11\x05\x12!1A\x06\x13Qa\x07"q\x142���\x08#B��\x15R��$3br�\t\n\x16\x17\x18\x19\x1a%&\'()*456789:CDEFGHIJSTUVWXYZcdefghijstuvwxyz���������������������������������������������������������������������������\x00\x1f\x01\x00\x03\x01\x01\x01\x01\x01\x01\x01\x01\x01\x00\x00\x00\x00\x00\x00\x01\x02\x03\x04\x05\x06\x07\x08\t\n\x0b��\x00�\x11\x00\x02\x01\x02\x04\x04\x03\x04\x07\x05\x04\x04\x00\x01\x0
# ...

# %%
data1 = {
    "__LASTFOCUS": "",
    "__EVENTTARGET":"",
    "__EVENTARGUMENT":"",
    "__VIEWSTATE":viewstate_value,
    "__VIEWSTATEGENERATOR":"F8DFB1FA",
    "__VIEWSTATEENCRYPTED":"",
    "__PREVIOUSPAGE":PREVIOUSPAGE_value,
    "__EVENTVALIDATION":EVENTVALIDATION_value,
    "HFCertSrNo":"",
    "HFThumbPrint":"",
    "hdnSetPassword":hashed_password,
    "DDLLoginType":"0",
    "TBUserName":"rana123",
    "TBPassword":hashed_password,
    "txtCaptcha":"yo8tT",
    "LnkSubmitLogin":"Login"
    
    # ... (Add other form fields here)
}

# %%
a
# Out:
# 'ASP.NET_SessionId=x2dttzomqrc0i0zg2qzimtwv'

# %%
import httpx

url = "https://ipindiaonline.gov.in/trademarkefiling/user/frmLoginNew.aspx"
headers = {
    "Host": "ipindiaonline.gov.in",
    "Cookie": a
    # "Content-Type": "multipart/form-data; boundary=----WebKitFormBoundaryDmjNUnL8U90vfsgp"
    }

# multipart_data = """
# ... (Same multipart data as provided in the previous example)
# """

with httpx.Client() as client:
    response = client.post(url, headers=headers, data=data1)
    print(response.text)  # Print the response content
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" lang="en">
# <head>
#     <title>Intellectual Property India</title>
#     <meta http-equiv="x-ua-compatible" content="IE=11,10,9,8">
#
#
#
#     <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
#     <meta http-equiv="Content-Style-Type" content="text/css">
#     <meta http-equiv="Content-Script-Type" content="type">
#     <meta name="format-detection" content="telephone=no">
#     <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">
#
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.6/css/bootstrap.min.css">
#
#     <link media="all" href="../CSS/style.css" type="text/css" rel="stylesheet" />
#     <link media="all" href="../CSS/responsive.css" type="text/css" rel="stylesheet" />
#
#     <script src="../Scripts/SHA1.js" type="text/javascript"></script>
#
# ...

# %%
data1 = {
    "__LASTFOCUS": "",
    "__EVENTTARGET": "",
    "__EVENTARGUMENT": "",
    "__VIEWSTATE": "",
    "__VIEWSTATEGENERATOR": "137D2B9B",
    "__VIEWSTATEENCRYPTED": "",
    "__PREVIOUSPAGE": "DyDM6BKxjWaD_xdCbi4dHxeDtP7FqhnfVq0N8aYgqFH94VOfG_FAxJS-NRdFu3c_tDiHaLxOUO5H4-ntshP2hJ4HFRffJ-JzeHf8EY6ziG03kKAWq8paqoXwzqtrDH4F0",
    "__EVENTVALIDATION": "",
    "HFCertSrNo": "",
    "HFThumbPrint": "",
    "hdnSetPassword": "21083588d9421f48f4bbe9520b9dfd676fb51527",
    "DDLLoginType": "0",
    "TBUserName": "rana123",
    "TBPassword": "21083588d9421f48f4bbe9520b9dfd676fb51527",
    "txtCaptcha": "ue2VT",
    "LnkSubmitLogin": "Login"
    # ... (Add other form fields here)
}

# %%
import httpx

url = "https://ipindiaonline.gov.in/trademarkefiling/user/frmLoginNew.aspx"
headers = {
    "Host": "ipindiaonline.gov.in",
    "Cookie": "ASP.NET_SessionId=tud51vkspredkwlupgu5slup",
    # "Content-Type": "multipart/form-data; boundary=----WebKitFormBoundaryDmjNUnL8U90vfsgp"
    }

# multipart_data = """
# ... (Same multipart data as provided in the previous example)
# """

with httpx.Client() as client:
    response = client.post(url, headers=headers, data=data1)
    print(response.text)  # Print the response content
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" lang="en">
# <head>
#     <title>Intellectual Property India</title>
#     <meta http-equiv="x-ua-compatible" content="IE=11,10,9,8">
#
#
#
#     <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
#     <meta http-equiv="Content-Style-Type" content="text/css">
#     <meta http-equiv="Content-Script-Type" content="type">
#     <meta name="format-detection" content="telephone=no">
#     <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">
#
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.6/css/bootstrap.min.css">
#
#     <link media="all" href="../CSS/style.css" type="text/css" rel="stylesheet" />
#     <link media="all" href="../CSS/responsive.css" type="text/css" rel="stylesheet" />
#
#     <script src="../Scripts/SHA1.js" type="text/javascript"></script>
#
# ...

# %%
data={
    "__VIEWSTATE":viewstate_value,
    "__VIEWSTATEGENERATOR":"F8DFB1FA",
    "__VIEWSTATEENCRYPTED":""
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 data={
# ----> 2     "__VIEWSTATE":viewstate_value,
#       3     "__VIEWSTATEGENERATOR":"F8DFB1FA",
#       4     "__VIEWSTATEENCRYPTED":""
#       5 }
#
# NameError: name 'viewstate_value' is not defined

# %%
import requests

url = "https://ipindiaonline.gov.in/trademarkefiling/CaptchaGenerator/captcha.aspx?638273722548402461"
headers = {
    "Cookie": "ASP.NET_SessionId=00g41w2wxba1z2ue0ryv4tll",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.5790.171 Safari/537.36",
    "Referer": "https://ipindiaonline.gov.in/trademarkefiling/user/frmloginNew.aspx",
    "Accept": "image/avif,image/webp,image/apng,image/svg+xml,image/*,*/*;q=0.8",
    "Sec-Fetch-Site": "same-origin",
    "Sec-Fetch-Mode": "no-cors",
    "Sec-Fetch-Dest": "image",
    "Accept-Encoding": "gzip, deflate",
    "Accept-Language": "en-US,en;q=0.9"
}

response = requests.post(url, headers=headers,data=data)

# Save the image content to a file
if response.status_code == 200:
    with open("captcha_image.png", "wb") as image_file:
        image_file.write(response.content)
    print("Captcha image saved successfully.")
else:
    print("Failed to fetch captcha image.")
# Out:
# Captcha image saved successfully.

# %%
response.text
# Out:
# '\r\n\r\n<!DOCTYPE html>\r\n<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" lang="en">\r\n<head>\r\n    <title>Intellectual Property India</title>\r\n    <meta http-equiv="x-ua-compatible" content="IE=11,10,9,8">\r\n    \r\n\r\n    \r\n    <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\r\n    <meta http-equiv="Content-Style-Type" content="text/css">\r\n    <meta http-equiv="Content-Script-Type" content="type">\r\n    <meta name="format-detection" content="telephone=no">\r\n    <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">\r\n    \r\n    <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.6/css/bootstrap.min.css">\r\n\r\n    <link media="all" href="../CSS/style.css" type="text/css" rel="stylesheet" />\r\n    <link media="all" href="../CSS/responsive.css" type="text/css" rel="stylesheet" />\r\n\r\n    <script src="../Scripts/SHA1.js" type="text/javascript"></script>\r\n\r\n   
# ...

# %%
url="https://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js"
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '/*! jQuery v1.9.1 | (c) 2005, 2012 jQuery Foundation, Inc. | jquery.org/license\n//@ sourceMappingURL=jquery.min.map\n*/(function(e,t){var n,r,i=typeof t,o=e.document,a=e.location,s=e.jQuery,u=e.$,l={},c=[],p="1.9.1",f=c.concat,d=c.push,h=c.slice,g=c.indexOf,m=l.toString,y=l.hasOwnProperty,v=p.trim,b=function(e,t){return new b.fn.init(e,t,r)},x=/[+-]?(?:\\d*\\.|)\\d+(?:[eE][+-]?\\d+|)/.source,w=/\\S+/g,T=/^[\\s\\uFEFF\\xA0]+|[\\s\\uFEFF\\xA0]+$/g,N=/^(?:(<[\\w\\W]+>)[^>]*|#([\\w-]*))$/,C=/^<(\\w+)\\s*\\/?>(?:<\\/\\1>|)$/,k=/^[\\],:{}\\s]*$/,E=/(?:^|:|,)(?:\\s*\\[)+/g,S=/\\\\(?:["\\\\\\/bfnrt]|u[\\da-fA-F]{4})/g,A=/"[^"\\\\\\r\\n]*"|true|false|null|-?(?:\\d+\\.|)\\d+(?:[eE][+-]?\\d+|)/g,j=/^-ms-/,D=/-([\\da-z])/gi,L=function(e,t){return t.toUpperCase()},H=function(e){(o.addEventListener||"load"===e.type||"complete"===o.readyState)&&(q(),b.ready())},q=function(){o.addEventListener?(o.removeEventListener("DOMContentLoaded",H,!1),e.removeEventListener("load",H,!1)):(o.detachEvent("onrea
# ...

# %%
import requests
import json

url = "https://ipindiaonline.gov.in/trademarkefiling/user/frmloginNew.aspx"

headers = {
    # Your headers here
    # ...
    "Content-Type": "application/json",
    "Cookie": "ASP.NET_SessionId=r3ezegl1zwfp3zx2tu5zrbuh",  # Add the correct session ID here
}

json_data = {
    "__LASTFOCUS": "",
    "__EVENTTARGET": "",
    "__EVENTARGUMENT": "",
    "__VIEWSTATE": "",
    "__VIEWSTATEGENERATOR": "137D2B9B",
    "__VIEWSTATEENCRYPTED": "",
    "__PREVIOUSPAGE": "nEmPtbDHkfZBrn9N4UG5aK-FflVreZyubFoXiBFJtNn8Pfou6NlQXLd2KQRq7B2xo9-1q1YhMqwBkxnVaRLgcHj67h8KZo8Zu0hTW_JqHO9K5PrbjbFu1yuI27Fkuf4h0",
    "__EVENTVALIDATION": "",
    "HFCertSrNo": "",
    "HFThumbPrint": "",
    "hdnSetPassword": "5d517f80858a9a617c0e0cef4bd4052a71c65661",
    "DDLLoginType": "0",
    "TBUserName": "rana123",
    "TBPassword": "5d517f80858a9a617c0e0cef4bd4052a71c65661",
    "txtCaptcha": "Ry1i5",
    "LnkSubmitLogin": "Login"
}

response = requests.post(url, headers=headers, json=json_data)

print(response.status_code)
print(response.text)  # This will print the response content, which is usually HTML
# Out:
# 200
#
#
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" lang="en">
# <head>
#     <title>Intellectual Property India</title>
#     <meta http-equiv="x-ua-compatible" content="IE=11,10,9,8">
#
#
#
#     <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
#     <meta http-equiv="Content-Style-Type" content="text/css">
#     <meta http-equiv="Content-Script-Type" content="type">
#     <meta name="format-detection" content="telephone=no">
#     <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">
#
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.6/css/bootstrap.min.css">
#
#     <link media="all" href="../CSS/style.css" type="text/css" rel="stylesheet" />
#     <link media="all" href="../CSS/responsive.css" type="text/css" rel="stylesheet" />
#
#     <script src="../Scripts/SHA1.js" type="text/javascript"></script>
#
# ...

# %%
import requests
import json

# Step 1: Submit CAPTCHA to 2Captcha API
def solve_captcha(api_key, captcha_image_url):
    api_url = "http://2captcha.com/in.php"
    params = {
        "key": "93c63c2e0d32a9c7124025aa1e05afad",
        "method": "post",
        "json": "1",
        "numeric": "2",  # Specifies that the CAPTCHA is an image
        "min_len": "5",  # Minimum length of CAPTCHA
        "max_len": "5",  # Maximum length of CAPTCHA
        "file": captcha_image_url,
    }
    headers={
        "Cookie":a
    }

    response = requests.post(api_url,headers=headers, params=params)
    result = response.json()
    return result.get("request")

# Replace with your 2Captcha API key
api_key = "93c63c2e0d32a9c7124025aa1e05afad"

# URL to the CAPTCHA image
captcha_image_url = img_url

captcha_id = solve_captcha(api_key, captcha_image_url)

# Wait for a few seconds for the CAPTCHA to be solved
import time
time.sleep(15)

# Step 2: Incorporate CAPTCHA Solution into Request Data
captcha_solution = ""  # Replace with the actual CAPTCHA solution received from 2Captcha

url = "https://ipindiaonline.gov.in/trademarkefiling/user/frmloginNew.aspx"
headers = {
    # Your headerhere
    "Content-Type": "application/x-www-form-urlencoded",
    "Cookie": "ASP.NET_SessionId=p5r5w5ltp5rh5crqrimcr0uc",  # Add the correct session ID here
}

form_data = {
    "__LASTFOCUS": "",
    # ... (other form fields)
    "TBUserName": "rana123",
    "TBPassword": "9628726dcc627d509d3f19162074aaac5540d850",
    "txtCaptcha": captcha_solution,
    "LnkSubmitLogin": "Login"
}

response = requests.post(url, headers=headers, data=form_data)

print(response.status_code)
print(response.content)  # This will print the response content, which is usually HTML
# Out:
# 200
# ...

# %%
captcha_solution
# Out:
# ''

# %%
img_url
# Out:
# 'https://ipindiaonline.gov.in/trademarkefiling/CaptchaGenerator/captcha.aspx?638273971080444000'

# %%
import requests

API_KEY = '1a0c2ce3528cf7e17709ef6b22aaa305'
CREATE_TASK_URL = 'https://api.anti-captcha.com/createTask'
GET_TASK_RESULT_URL = 'https://api.anti-captcha.com/getTaskResult'

def solve_captcha(image_url):
    response = requests.get(image_url)
    
    if response.status_code == 200:
        image_data = response.content
        if len(image_data) >= 100:  # Ensure the image data size is at least 100 bytes
            create_task_data = {
                "clientKey": API_KEY,
                "task": {
                    "type": "ImageToTextTask",
                    "body": image_data,
                    "phrase": False,
                    "case": True,
                    "numeric": 0,
                    "math": False,
                    "minLength": 0,
                    "maxLength": 5
                }
            }
            
            response = requests.post(CREATE_TASK_URL, json=create_task_data)
            task_id = response.json().get("taskId")
            
            if task_id:
                while True:
                    task_result_data = {"clientKey": API_KEY, "taskId": task_id}
                    task_result_response = requests.post(GET_TASK_RESULT_URL, json=task_result_data)
                    if task_result_response.json().get("status") == "ready":
                        solved_captcha = task_result_response.json().get("solution").get("text")
                        return solved_captcha
            else:
                return None
    else:
        return None

# img_url = "URL_TO_CAPTCHA_IMAGE"  # Replace with your actual image URL
solved_captcha = solve_captcha(img_url)
print("Solved CAPTCHA:", solved_captcha)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[125], line 43
#      40         return None
#      42 # img_url = "URL_TO_CAPTCHA_IMAGE"  # Replace with your actual image URL
# ---> 43 solved_captcha = solve_captcha(img_url)
#      44 print("Solved CAPTCHA:", solved_captcha)
#
# Cell In[125], line 27, in solve_captcha(image_url)
#      12 if len(image_data) >= 100:  # Ensure the image data size is at least 100 bytes
#      13     create_task_data = {
#      14         "clientKey": API_KEY,
#      15         "task": {
#    (...)
#      24         }
#      25     }
# ---> 27     response = requests.post(CREATE_TASK_URL, json=create_task_data)
#      28     task_id = response.json().get("taskId")
#      30     if task_id:
#
# File ~/.local/lib/python3.10/site-packages/requests/api.py:116, in post(url, data, json, **kwargs)
# ...

# %%
captcha_id
# Out:
# 'ERROR_ZERO_BALANCE'

# %%
img_url
# Out:
# 'https://ipindiaonline.gov.in/trademarkefiling/CaptchaGenerator/captcha.aspx?638273971080444000'

# %%
import requests

API_KEY = '1a0c2ce3528cf7e17709ef6b22aaa305'
CREATE_TASK_URL = 'https://api.anti-captcha.com/createTask'
GET_TASK_RESULT_URL = 'https://api.anti-captcha.com/getTaskResult'

def solve_captcha_with_anticaptcha(image_data):
    create_task_data = {
        "clientKey": API_KEY,
        "task": {
            "type": "ImageToTextTask",
            "body": image_data,
            "phrase": False,
            "case": True,
            "numeric": 0,
            "math": False,
            "minLength": 0,
            "maxLength": 5
        }
    }
    
    response = requests.post(CREATE_TASK_URL, json=create_task_data)
    print(response.text)
    task_id = response.json().get("taskId")
    
    if task_id:
        while True:
            task_result_data = {"clientKey": API_KEY, "taskId": task_id}
            task_result_response = requests.post(GET_TASK_RESULT_URL, json=task_result_data)
            if task_result_response.json().get("status") == "ready":
                solved_captcha = task_result_response.json().get("solution").get("text")
                return solved_captcha
    else:
        return None

captcha_image_url = "https://ipindiaonline.gov.in/trademarkefiling/CaptchaGenerator/captcha.aspx?638273927482215758"
response = requests.get(captcha_image_url)
if response.status_code == 200:
    image_data = response.content
    if len(image_data) >= 100:  # Ensure the image data size is at least 100 bytes
        solved_captcha = solve_captcha_with_anticaptcha(image_data)
        print("Solved CAPTCHA:", solved_captcha)
    else:
        print("CAPTCHA image size is too small")
else:
    print("Failed to download CAPTCHA image")

# %%
import requests
from PIL import Image
from io import BytesIO

API_KEY = '1a0c2ce3528cf7e17709ef6b22aaa305'
CREATE_TASK_URL = 'https://api.anti-captcha.com/createTask'
GET_TASK_RESULT_URL = 'https://api.anti-captcha.com/getTaskResult'

def solve_captcha(image_path):
    create_task_data = {
        "clientKey": API_KEY,
        "task": {
            "type": "ImageToTextTask",
            "body": image_path,
            "phrase": False,
            "case": True,
            "numeric": 0,
            "math": False,
            "minLength": 0,
            "maxLength": 5
        }
    }

    response = requests.post(CREATE_TASK_URL, json=create_task_data)
    task_id = response.json().get("taskId")
    print(task_id)

    if task_id:
        while True:
            task_result_data = {"clientKey": API_KEY, "taskId": task_id}
            task_result_response = requests.post(GET_TASK_RESULT_URL, json=task_result_data)
            print(task_result_response)
            if task_result_response.json().get("status") == "ready":
                solved_captcha = task_result_response.json().get("solution").get("text")
                return solved_captcha
    else:
        return None

captcha_image_url = "https://ipindiaonline.gov.in/trademarkefiling/CaptchaGenerator/captcha.aspx?638273927482215758"

# Download and save the image locally
response = requests.get(captcha_image_url)
image_data = BytesIO(response.content)
image = Image.open(image_data)
image_path = "captcha.png"
image.save(image_path)

# Solve the CAPTCHA using 2Captcha
solved_captcha = solve_captcha(image_path)
print("Solved CAPTCHA:", solved_captcha)
# Out:
# None
# Solved CAPTCHA: None
