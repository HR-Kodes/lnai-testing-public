# %%
from bs4 import BeautifulSoup
import json
import re

# %%
user_id = "rana123"
password = "Vivek@123"

# %%
import requests

# url = "https://ipindiaonline.gov.in//trademarkefiling/online/welcomeForm.aspx"
url = "https://ipindiaonline.gov.in///trademarkefiling/user/frmloginNew.aspx"

response = requests.get(url)

print(response.text)  # Print the response content
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" lang="en">
# <head>
#     <title>Intellectual Property India</title>
#     <meta http-equiv="x-ua-compatible" content="IE=11,10,9,8">
#
#
#
#     <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
#     <meta http-equiv="Content-Style-Type" content="text/css">
#     <meta http-equiv="Content-Script-Type" content="type">
#     <meta name="format-detection" content="telephone=no">
#     <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">
#
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.6/css/bootstrap.min.css">
#
#     <link media="all" href="../CSS/style.css" type="text/css" rel="stylesheet" />
#     <link media="all" href="../CSS/responsive.css" type="text/css" rel="stylesheet" />
#
#     <script src="../Scripts/SHA1.js" type="text/javascript"></script>
#
#     <script src="../Scripts/signer.js" type="text/javascript"></script>
#
#
#     <script type="text/javascript" src="https://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js"></script>
#
#
#
#
#     <script type="text/javascript">
#         $(function () {
#
#             $('#TBUserName').keyup(function () {
#                 var yourInput = $(this).val();
#                 re = /['<>{\}]/gi;
#                 var isSplChar = re.test(yourInput);
#                 if (isSplChar) {
#                     var no_spl_char = yourInput.replace(/[`~!@#$%^&*()_|+\-=?;:'",.<>\{\}\[\]\\\/]/gi, '');
#                     $(this).val(no_spl_char);
#                 }
#             });
#         });
#     </script>
#
#     <script type="text/javascript">
#         $(document).ready(function () {
#             createCode();
#         });
#     </script>
#     <script type="text/javascript">
#         $(document).load(function () {
#             createCode();
#         });
#     </script>
#     <script type="text/javascript">
#         function clickButton(e, buttonid) {
#             var evt = e ? e : window.event;
#             var bt = document.getElementById(buttonid);
#             if (bt) {
#                 if (evt.keyCode == 13) {
#                     bt.click();
#                     return false;
#                 }
#             }
#         }
#
#     </script>
#     <script type="text/javascript">
#         $(document).ready(function () {
#             $('#TBPassword').bind('copy paste cut', function (e) {
#                 e.preventDefault(); //disable cut,copy,paste
#             });
#         });
#     </script>
#     <script type="text/javascript">
#         function OnChange(dropdown) {
#
#             var myindex = dropdown.selectedIndex;
#             var SelValue = dropdown.options[myindex].value;
#
#             if (SelValue == "0") {
#                 document.getElementById("TBPassword").disabled = false;
#
#             }
#             else {
#                 document.getElementById("TBPassword").disabled = true;
#
#             }
#         }
#
#         function NdemoSignAnyData() {
#             var dropdown = document.getElementById("DDLLoginType")
#             var myindex = dropdown.selectedIndex;
#             var SelValue = dropdown.options[myindex].value;
#             if (SelValue == "1") {
#                 var obj = GetCertificateInfo()
#                 if (obj) {
#                     document.getElementById("HFCertSrNo").value = obj.SerialNumber;
#                     document.getElementById("HFThumbPrint").value = obj.Thumbprint;
#                 }
#                 else {
#                     return false;
#                 }
#             }
#         }
#
#         function Validate(seed) {
#             if (document.getElementById("TBUserName").value == "") {
#                 document.getElementById("TBUserName").focus();
#                 if (document.getElementById("TBUserName").value == "") {
#                     alert("Please enter User Id");
#                     return false
#                 }
#
#                 else if (document.getElementById("TBPassword").value == "") {
#                     document.getElementById("TBPassword").value == " "
#                 }
#             return false
#         }
#         else {
#
#             var Pass = document.getElementById("TBPassword").value;
#                 document.getElementById("TBPassword").value = "";
#                 var finalpass;
#                 var SHA1New = hex_sha1(Pass);
#                 finalpass = SHA1New + seed;
#                 var SHA1 = hex_sha1(finalpass);
#                 document.getElementById("hdnSetPassword").value = SHA1;
#
#                 var k = document.getElementById("hdnSetPassword").value;
#                 document.getElementById("TBPassword").value = SHA1;
#             }
#         }
#         function Done(result) {
#             // Alert the boolean result returned from PageMethod
#             alert(result);
#         }
#
#     </script>
#
#     <script type="text/javascript">
#         function CaptchaAudio() {
#
#             $.ajax({
#                 type: "POST",
#
#                 url: '/trademarkefiling/user/frmLoginNew.aspx/GetCaptcha',
#
#                 data: '{}',
#                 contentType: "application/json; charset=utf-8",
#                 dataType: "json",
#                 success: OnSuccess,
#                 failure: function (response) {
#                     alert("failure" + response.d);
#                 }
#             });
#         }
#
#         function OnSuccess(response) {
#             var Array = response.d.split('')
#
#             $.each(Array, function (index, value) {
#                 var msg = new SpeechSynthesisUtterance(value);
#                 window.speechSynthesis.speak(msg);
#
#             })
#
#         }
#
#     </script>
#
#     <script type="text/javascript">
#         //function refreshcaptcha() {
#         //    $(document).load(function () {
#         //        createCode();
#         //    });
#         //}
#
#         $(function () {
#             $('#refresh').click(function () {
#                 createCode();
#             });
#         });
#     </script>
#
#     <style type="text/css">
#         ::-webkit-input-placeholder { /* Chrome */
#             color: #d8d0d0 !important;
#         }
#
#         :-ms-input-placeholder { /* IE 10+ */
#             color: #d8d0d0 !important;
#         }
#
#         ::-moz-placeholder { /* Firefox 19+ */
#             color: #d8d0d0 !important;
#             opacity: 1;
#         }
#
#         :-moz-placeholder { /* Firefox 4 - 18 */
#             color: #d8d0d0 !important;
#             opacity: 1;
#         }
#     </style>
#
# </head>
# <body>
#     <form name="Form1" method="post" action="./frmloginNew.aspx" id="Form1">
# <input type="hidden" name="__VIEWSTATE" id="__VIEWSTATE" value="" />
#
# <input type="hidden" name="__VIEWSTATEGENERATOR" id="__VIEWSTATEGENERATOR" value="137D2B9B" />
# <input type="hidden" name="__VIEWSTATEENCRYPTED" id="__VIEWSTATEENCRYPTED" value="" />
# <input type="hidden" name="__PREVIOUSPAGE" id="__PREVIOUSPAGE" value="DyDM6BKxjWaD_xdCbi4dHxeDtP7FqhnfVq0N8aYgqFH94VOfG_FAxJS-NRdFu3c_tDiHaLxOUO5H4-ntshP2hJ4HFRffJ-JzeHf8EY6ziG03kKAWq8paqoXwzqtrDH4F0" />
# <input type="hidden" name="__EVENTVALIDATION" id="__EVENTVALIDATION" value="" />
#
#
#
#
#         <div id="wrapper" class="patentsHome">
#             <div class="topStrip">
#                 <div class="container">
#                     <ul class="leftLinks">
#                         <li><a href="http://www.ipindia.nic.in/index.htm">Home</a> </li>
#                         <li><a href="http://www.ipindia.nic.in/about-us.htm">About Us</a> </li>
#                         <li><a href="http://www.ipindia.nic.in/whos-who-page.htm">Who's Who</a> </li>
#                         <li><a href="http://www.ipindia.nic.in/policy-pages.htm">Policy & Programs</a> </li>
#                         <li><a href="http://www.ipindia.nic.in/achievements-page.htm">Achievements</a> </li>
#                         <li><a href="https://ipindiaonline.gov.in/feedback">Feedback</a> </li>
#                         <li><a href="http://www.ipindia.nic.in/right-to-information.htm">RTI</a> </li>
#                         <li><a href="http://www.ipindia.nic.in/sitemap.htm">Sitemap</a> </li>
#                         <li><a href="http://www.ipindia.nic.in/contact-us.htm">Contact Us</a> </li>
#                     </ul>
#
#                 </div>
#             </div>
#         </div>
#         <div class="container">
#             <div id="header">
#                 <div class="logoBlock">
#                     <h1 id="logo"><a title="Intellectual Property India" href="http://www.ipindia.nic.in/index.htm">
#                         <img src="../Images/logoTrademark.png" class="img-responsive" alt="Intellectual Property India" /></a></h1>
#
#                     <div class="ipoLogo">
#                         <span class="subsiteName" style="font-size: 28px; color: #434343; font-weight: 600; padding-right: 60px; vertical-align: middle;">Trade Marks</span> <a href="http://www.ipindia.nic.in/index.htm">
#                             <img title="Intellectual Property India" src="../Images/images/Originals/ipo-logo.png" alt="Intellectual Property India" width="122" height="90"></a>
#
#                     </div>
#                 </div>
#             </div>
#
#             <nav class="clearfix">
#                 <ul id="nav">
#                     <li class="menu1" style="width: 1200px; height: 30px; margin-top: 0px;">
#                         <a class="navbar-brand" href="#"><b>Online Filing of Trade Mark Version 3.0</b></a>
#                     </li>
#
#                 </ul>
#
#             </nav>
#         </div>
#
#         <div id="content" class="innerContent">
#             <div class="container">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 <div class="contentArea">
#                     <div class="col-md-3">
#                         <input type="image" name="ImageButton2" id="ImageButton2" title="Links to Presenting Madrid System Online Services" src="../Images/logo_services.gif" onclick="javascript:WebForm_DoPostBackWithOptions(new WebForm_PostBackOptions(&quot;ImageButton2&quot;, &quot;&quot;, true, &quot;&quot;, &quot;frmInternationalBureauLink.aspx&quot;, false, false))" border="0" />
#                     </div>
#                     <div class="col-md-5">
#                         <div class="loginForm" style="height: 335px;">
#                             <div class="card" style="padding: 0px;"></div>
#                             <div class="card" style="padding-top: 10px; height: 330px; max-width: 380px;">
#
#                                 <div>
#                                     <input name="HFCertSrNo" type="hidden" id="HFCertSrNo" />
#                                     <input name="HFThumbPrint" type="hidden" id="HFThumbPrint" />
#                                     <input name="hdnSetPassword" type="hidden" id="hdnSetPassword" />
#                                 </div>
#                                 <div class="input-container" style="margin: 0 60px 15px;">
#                                     <span style="font-family: Verdana, Geneva, sans-serif; font-size: 14px; color: #003366;">&nbsp;Login With</span>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
#                             <select name="DDLLoginType" id="DDLLoginType" onchange="OnChange(this);">
# 	<option value="0">Password</option>
# 	<option value="1">Digital Signature</option>
#
# </select>
#                                 </div>
#                                 <div class="input-container" style="margin: 0 60px 5px;">
#
#                                     <input name="TBUserName" type="text" id="TBUserName" tabindex="1" autocomplete="off" PlaceHolder="User Name" onfocus="this.placeholder = &#39;&#39;" onblur="this.placeholder = &#39;User Name&#39;" />
#
#                                     <div class="bar"></div>
#                                 </div>
#                                 <div>
#                                     &nbsp;
#                                 </div>
#                                 <div class="input-container" style="margin: 0 60px 15px;">
#                                     <div id="TBPassword1">
#                                         <input name="TBPassword" type="password" id="TBPassword" tabindex="2" autocomplete="off" onpaste="return false" oncut="return false" ondelete="return false" PlaceHolder="Password" onfocus="this.placeholder = &#39;&#39;" onblur="this.placeholder = &#39;Password&#39;" />
#
#                                         <div class="bar"></div>
#                                     </div>
#                                 </div>
#                                 <div class="input-container" style="margin: 0 60px 5px;">
#
#                                     <div class="col-md-10">
#                                         <img id="captchaimg" src="../CaptchaGenerator/captcha.aspx?638271328672363967" height="30" width="200" border="0" />
#
#                                     </div>
#                                     <div class="col-md-2">
#                                         <input type="image" name="ImageButton1" id="ImageButton1" src="../Images/refress.png" border="0" style="width: 20px; height: 20px; margin-top: 5px; margin-bottom: 2px;" />
#                                     </div>
#
#                                 </div>
#                                 <div class="input-container" style="margin: 0 60px 5px;">
#
#                                     <input name="txtCaptcha" type="text" id="txtCaptcha" tabindex="3" placeHolder="Enter the code shown above" onfocus="this.placeholder = &#39;&#39;" onblur="this.placeholder = &#39;Enter the code shown above&#39;" />
#
#                                     <div class="bar"></div>
#                                 </div>
#
#                                 <div class="input-container" style="margin: 0 60px 5px;">
#                                      <img src="../Images/volume-24-512.png" height="30" width="30" title="Captcha Audio" alt="Captcha Audio" onclick="CaptchaAudio()" style="cursor: pointer; margin-left: 10px" />
#                                 </div>
#
#
#
#                                 <div class="buttons">
#                                     &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;<input type="submit" name="LnkSubmitLogin" value="Login" onclick="NdemoSignAnyData();javascript:Validate(450731544);WebForm_DoPostBackWithOptions(new WebForm_PostBackOptions(&quot;LnkSubmitLogin&quot;, &quot;&quot;, true, &quot;&quot;, &quot;&quot;, false, false))" id="LnkSubmitLogin" />
#                                 </div>
#                                 <div class="input-container">
#                                     <span style="font-family: Verdana, Geneva, sans-serif; font-weight: 400; font-size: 12px; color: #003366;"><a href="../user/How-To-Register.aspx">New User? Sign Up</a> | <a href="../user/frmForgotPassword.aspx">Forgot Password?</a></span>
#                                 </div>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="clearfix"></div>
#                     <div class="col-md-12">
#                         <center>
#                     <span style="font-family: Verdana, Geneva, sans-serif; font-weight: 500; font-size: 14px; color: #003366;"><a href="../UsefullDownloads/capicom.zip">Component(capicom.dll)</a> | <a href="../UsefullDownloads/DSCManual.pdf" target="_blank">Digital Signature Manual </a>| <a href="../UsefullDownloads/e-usermanual.pdf" target="_blank">e-filing User Manual</a> | <a href="../faqs/index.html" target="_blank">FAQs</a> | <a href="mailto:tmr-helpdesk@nic.in">Help Desk(tmr-helpdesk@nic.in)</a> |  <a href="../UsefullDownloads/Disclaimer%203%20.pdf" target="_blank">Disclaimer</a>|
#  <a href="../user/PrivacyPolicy.aspx" target="_blank">Privacy Policy</a> | <a href="../user/TermsandCondition.aspx" target="_blank">Terms & Condition</a><br />
#                           <a href="../Extras/FAQESign.aspx" target="_blank">ESign FAQs</a> | <a href="../UsefullDownloads/eMudhra_eSign_User_Guide.pdf" target="_blank">ESign User Guide</a> | <a href="https://app.e-mudhra.com/createNewUser.jsp?src=c44ead5fdecd48ecac24f" target="_blank">Web URL to procure esign for individual or Organization</a>
#                         | <a href="../Extras/RegistrationSteps.aspx" target="_blank">ESign Registration and Installation Details</a>
#                     </span>
#                 </center>
#                         <br />
#                         <p style="color: blue">Public Notice regarding lock down - <a href="../UsefullDownloads/PUBLIC_NOTICE_1.pdf" target="_blank" style="color: red">Public Notice 1</a> and <a href="../UsefullDownloads/PUBLIC_NOTICE_2.pdf" target="_blank" style="color: red">Public Notice 2</a></p>
#
#                         <p style="color: blue">
#                             Guidelines for using NTRP (Bharat Kosh) Payment Gateway  <a href="../UsefullDownloads/NTRP.pdf" target="_blank" style="color: red">Guide</a><br />
#                         </p>
#                         <p>
#                             Important! Users are requested to download and install the Digital Signature component from
#                     the under mentioned
#                  links prior to Registration/Signup
#                         </p>
#                         <p>
#                             Please note that the payment gateway is not available between 2300 HOURS and 0030 HOURS
#                     in the e-filing module due to bank reconciliation process.
#                         </p>
#                     </div>
#                 </div>
#             </div>
#         </div>
#
#         <div class="copyright" style="margin-top: -70px; position: fixed; bottom: 0px;">
#             <div class="container">
#                 <p>Content Owned, updated and maintained by Intellectual Property India, All Rights Reserved.</p>
#             </div>
#         </div>
#     </form>
#     <script type="text/javascript" src="../Scripts/impfunction.js"></script>
#     <script type="text/javascript">
#         createCode();
#         function createCode() {
#
#             var random;
#             var temp = "";
#             for (var i = 0; i < 5; i++) {
#                 temp += Math.round(Math.random() * 8);
#             }
#             //document.all.theImg.src = "JpegImage.aspx?code=" + temp;
#             $('#theImg').attr('src', "JpegImage.aspx?code=" + temp);
#             // document.getElementById("theImg").attributes("src", "JpegImage.aspx?code=" + temp);
#             // document.all.theImg.src = "JpegImage.aspx?code=" + temp;
#             $('#Hidden11').attr('value', temp);
#         }
#     </script>
# </body>
#
# </html>

# %%
response.headers
# Out:
# {'Cache-Control': 'no-cache, no-store,private, no-cache, no-store, pre-check=0, post-check=0, must-revalidate', 'Pragma': 'no-cache,no-cache', 'Content-Type': 'text/html; charset=utf-8', 'Expires': '-1', 'Server': 'Microsoft-IIS/10.0', 'x-frame-options': 'SAMEORIGIN', 'Set-Cookie': 'ASP.NET_SessionId=iz4n0j5b3fqjanibby3cnlmd; path=/; secure; HttpOnly; SameSite=Lax', 'X-Powered-By': 'ASP.NET', 'Date': 'Tue, 08 Aug 2023 17:37:46 GMT', 'Content-Length': '19704'}

# %%
a=response.headers['Set-Cookie'].split(';')[0]

# %%
a
# Out:
# 'ASP.NET_SessionId=iz4n0j5b3fqjanibby3cnlmd'

# %% [markdown]
# Sanket Code

# %%
# import requests
# from datetime import datetime

# # now = datetime.now()

# # current_time = now.strftime("%H:%M:%S")

# %%
# # url = "https://ipindiaonline.gov.in//trademarkefiling/online/welcomeForm.aspx"
# t={}
# for _ in range(20):
#     url = "https://ipindiaonline.gov.in///trademarkefiling/user/frmloginNew.aspx"
#     now = datetime.now()

#     response = requests.get(url)
#     soup = BeautifulSoup(response.content, 'html.parser')
#     current_time = now.strftime("%H:%M:%S")
#     imges = soup.select('div img')
#     for i in imges:
#         try:
#             if i['id'] == "captchaimg":
#                 img_url = i['src']
#                 t[current_time]=img_url.split('/')[2]
#         except:
#             continue

# %%
# t
# Out:
# {'22:53:16': 'captcha.aspx?638271321099248186',
#  '22:53:17': 'captcha.aspx?638271321108310665',
#  '22:53:18': 'captcha.aspx?638271321117529399',
#  '22:53:19': 'captcha.aspx?638271321127060651',
#  '22:53:20': 'captcha.aspx?638271321136123133',
#  '22:53:21': 'captcha.aspx?638271321146435620',
#  '22:53:22': 'captcha.aspx?638271321155654360',
#  '22:53:23': 'captcha.aspx?638271321171279340',
#  '22:53:24': 'captcha.aspx?638271321180029334',
#  '22:53:25': 'captcha.aspx?638271321189560568'}

# %%
# session_id_matches = re.findall(r'ASP\.NET_SessionId=([^;]+)', a)
# anti_xsrf_token_matches = re.findall(r'__AntiXsrfToken=([^;]+)', a)

# %%
# session_id = session_id_matches[0]
# anti_xsrf_token = anti_xsrf_token_matches[0]
# print("Session ID:", session_id)
# print("AntiXsrf Token:", anti_xsrf_token)
# Out:
# Session ID: jir4emcddeqsdosdtndv5tpx
# AntiXsrf Token: d52cb5304296406f99a9d1ea73d7569f

# %%
# cookie=f"ASP.NET_SessionId={session_id}; __AntiXsrfToken={anti_xsrf_token}"

# %%
response.headers
# Out:
# {'Cache-Control': 'no-cache, no-store,private, no-cache, no-store, pre-check=0, post-check=0, must-revalidate', 'Pragma': 'no-cache,no-cache', 'Content-Type': 'text/html; charset=utf-8', 'Expires': '-1', 'Server': 'Microsoft-IIS/10.0', 'x-frame-options': 'SAMEORIGIN', 'Set-Cookie': 'ASP.NET_SessionId=jir4emcddeqsdosdtndv5tpx; path=/; secure; HttpOnly; SameSite=Lax, ASP.NET_SessionId=jir4emcddeqsdosdtndv5tpx; path=/; secure; HttpOnly; SameSite=Lax, __AntiXsrfToken=d52cb5304296406f99a9d1ea73d7569f; path=/; secure; HttpOnly', 'X-Powered-By': 'ASP.NET', 'Date': 'Tue, 08 Aug 2023 11:18:05 GMT', 'Content-Length': '19718'}

# %%
html_content=response.text

# %%
soup = BeautifulSoup(html_content, 'html.parser')
viewstate_input = soup.find('input', {'id': '__VIEWSTATE'})

if viewstate_input:
    viewstate_value = viewstate_input.get('value')
    print("VIEWSTATE value:", viewstate_value)
else:
    print("__VIEWSTATE input not found in the HTML")
# Out:
# VIEWSTATE value: 

# %%
from urllib.parse import quote
encoded_viewstate_value_string = quote(viewstate_value, safe='')

print("Encoded string:", encoded_viewstate_value_string)
# Out:
# Encoded string: q3R6NsETiTw0kV9e7CmbYTevypBoLeZy%2FX0CJQBlSokG92dnUxcbDL6dnI2U3UjrV4eZbupK7KJn19FWc0di9t%2Bt0jAvJIPWOmZrmIOklICb%2BXUis79r0WmAUTfGcoKiV5uWNg7GfuuG%2BfcjtmYPrMLGJ1N9izhrJeaxu8dmo0ey6%2FeGg6AyCkeIKOu7yBCYD4FOb9N0RlABQPohXlyj0cFc13Flj2p0nKuDwUTzofYVhsl%2BgKCKOVGQ8tdabNs217Bht8l2bv5%2FMdz5%2FGe4Jio33TUWZN0xGmmP0dmOd38R67Y4cyKrENQoCnuWwe5gQIZqcu9RcgFCKkUrvARPf1hufcdxOuPZK%2B2CaxNm4Gs%3D

# %%
soup = BeautifulSoup(html_content, 'html.parser')
viewstateGEN_input = soup.find('input', {'id': '__VIEWSTATEGENERATOR'})

if viewstateGEN_input:
    viewstateGEN_value = viewstateGEN_input.get('value')
    print("VIEWSTATEGEN value:", viewstateGEN_value)
else:
    print("__VIEWSTATE input not found in the HTML")
# Out:
# VIEWSTATEGEN value: 137D2B9B

# %%
soup = BeautifulSoup(html_content, 'html.parser')
EVENTVALIDATION_input = soup.find('input', {'id': '__EVENTVALIDATION'})

if EVENTVALIDATION_input:
    EVENTVALIDATION_value = EVENTVALIDATION_input.get('value')
    print("EVENTVALIDATION value:", EVENTVALIDATION_value)
else:
    print("__VIEWSTATE input not found in the HTML")
# Out:
# EVENTVALIDATION value: 

# %%
from urllib.parse import quote
encoded_eventvalidation_value_string = quote(EVENTVALIDATION_value, safe='')

print("Encoded string:", encoded_eventvalidation_value_string)
# Out:
# Encoded string: V%2FjKS9SmFET6lKA5zi%2F9oYKq9RVmAyZ3HpkEEqtBhKhPaRoa1yQZ7LmqnVLhBSWC8CFfIBs49jGasRopY0iJcwcMXNXzVT7iie%2FzchjKyueaD%2BYSWfB7yzVHcu8AgHdXH9ALhkOs54yJnIGbYx4x1XzzZTIYi4IFHy3ZLsq%2BYuXfuhT3NZB0fxSVohuhckIskiH8eaMYS8LW7CEGouMIPd7CY5%2FFgKMf%2FJLl221CG4o5B%2F9NQBv6Fiy0IcqcQ%2Fqbeh7nv3XlvZaxmsxL9X2m%2BrxGtAlm%2FwZc31FtxGGIrzccrnKZJvDoge%2BTMvii4gdGb%2Fz%2BRz%2BoVoeQqyLkcba%2BbWmObFnwFy08UJOUxgGo7LI%3D

# %%
soup = BeautifulSoup(html_content, 'html.parser')
PREVIOUSPAGE_input = soup.find('input', {'id': '__PREVIOUSPAGE'})

if PREVIOUSPAGE_input:
    PREVIOUSPAGE_value = PREVIOUSPAGE_input.get('value')
    print("PREVIOUSPAGE value:", PREVIOUSPAGE_value)
else:
    print("__VIEWSTATE input not found in the HTML")
# Out:
# PREVIOUSPAGE value: DyDM6BKxjWaD_xdCbi4dHxeDtP7FqhnfVq0N8aYgqFH94VOfG_FAxJS-NRdFu3c_tDiHaLxOUO5H4-ntshP2hJ4HFRffJ-JzeHf8EY6ziG03kKAWq8paqoXwzqtrDH4F0

# %%
onclick_value = soup.find('input', {'id': 'LnkSubmitLogin'}).get('onclick')

# %%
seed_match = re.search(r'Validate\((\d+)\)', onclick_value)

# %%
seed = int(seed_match.group(1))
print("Extracted seed value:", seed)
# Out:
# Extracted seed value: 450731544

# %%
imges = soup.select('div img')

# %%
for i in imges:
    try:
        if i['id'] == "captchaimg":
            img_url = i['src']
            img_url = "https://ipindiaonline.gov.in/trademarkefiling/CaptchaGenerator/"+img_url.split('/')[2]
    except:
        continue

# %%
# captcha_img_src = img_tag.get('src')
    # Construct the complete URL for the CAPTCHA image
# base_url = "http://ipindiaonline.gov.in"
# captcha_img_url = f"{base_url}/{captcha_img_src}"

# Send a request to fetch the CAPTCHA image
headers={"Cookie":a}
response = requests.get(img_url, stream=True)

if response.status_code == 200:
    # Replace with the desired file path to save the image
    image_path = "captcha_image2.jpg"

    with open(image_path, 'wb') as image_file:
        for chunk in response.iter_content(chunk_size=128):
            image_file.write(chunk)

    print("CAPTCHA image saved as:", image_path)
else:
    print("Failed to fetch CAPTCHA image")
# Out:
# CAPTCHA image saved as: captcha_image2.jpg

# %%
response.headers
# Out:
# {'Cache-Control': 'no-cache, no-store,private, no-cache, no-store, pre-check=0, post-check=0, must-revalidate', 'Pragma': 'no-cache,no-cache', 'Content-Type': 'image/jpeg; charset=utf-8', 'Expires': '-1', 'Server': 'Microsoft-IIS/10.0', 'x-frame-options': 'SAMEORIGIN', 'Set-Cookie': 'ASP.NET_SessionId=1kyctbs0t2jxqa4xeddkpcy2; path=/; secure; HttpOnly; SameSite=Lax', 'X-Powered-By': 'ASP.NET', 'Date': 'Tue, 08 Aug 2023 17:40:28 GMT', 'Content-Length': '5231'}

# %%
b=response.headers['Set-Cookie'].split(';')[0]

# %%
b
# Out:
# 'ASP.NET_SessionId=1kyctbs0t2jxqa4xeddkpcy2'

# %%
import hashlib

def str2rstr_utf8(s):
    return s.encode('utf-8')

def rstr_sha1(s):
    sha1 = hashlib.sha1()
    sha1.update(s)
    return sha1.digest()

def rstr2hex(input_bytes):
    return ''.join(format(byte, '02x') for byte in input_bytes)

def hex_sha1(s):
    return rstr2hex(rstr_sha1(str2rstr_utf8(s)))

def calculate_password_hash(password, seed):
    SHA1New = hex_sha1(password)
    finalpass = SHA1New + seed
    SHA1 = hex_sha1(finalpass)
    return SHA1

  # Replace this with the actual value of seed from your code

hashed_password = calculate_password_hash(password, str(seed))
# hashed_password = calculate_password_hash(password, "427215818")

print(hashed_password)
# Out:
# 796d0953982d5057cc20e6f78ce9c62663e11833

# %%
# import requests

# # URL to send the POST request
# url = "https://ipindiaonline.gov.in/trademarkefiling/user/frmloginNew.aspx"

# # Headers for the request
# headers = {
#     "Host": "ipindiaonline.gov.in",
#     "Cookie": a_session_id,
#     "Cache-Control": "max-age=0",
#     "Sec-Ch-Ua": "",
#     "Sec-Ch-Ua-Mobile": "?0",
#     "Sec-Ch-Ua-Platform": "\"\"",
#     "Upgrade-Insecure-Requests": "1",
#     "Origin": "https://ipindiaonline.gov.in",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.5790.171 Safari/537.36",
#     "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
#     "Sec-Fetch-Site": "same-origin",
#     "Sec-Fetch-Mode": "navigate",
#     "Sec-Fetch-User": "?1",
#     "Sec-Fetch-Dest": "document",
#     "Referer": "https://ipindiaonline.gov.in/trademarkefiling/user/frmloginNew.aspx",
#     "Accept-Encoding": "gzip, deflate",
#     "Accept-Language": "en-US,en;q=0.9"
# }

# # Form data for the request
# data = {
#     "__LASTFOCUS": "",
#     "__EVENTTARGET":"",
#     "__EVENTARGUMENT":"",
#     "__VIEWSTATE":encoded_viewstate_value_string,
#     "__VIEWSTATEGENERATOR":viewstateGEN_value,
#     "__VIEWSTATEENCRYPTED":"",
#     "__PREVIOUSPAGE":PREVIOUSPAGE_value,
#     "__EVENTVALIDATION":encoded_eventvalidation_value_string,
#     "HFCertSrNo":"",
#     "HFThumbPrint":"",
#     "hdnSetPassword":hashed_password,
#     "DDLLoginType":"0",
#     "TBUserName":"rana123",
#     "TBPassword":hashed_password,
#     "txtCaptcha":"3T328",
#     "LnkSubmitLogin":"Login"
    
#     # ... (Add other form fields here)
# }

# response = requests.post(url, headers=headers, data=data)

# print(response.status_code)
# print(response.text)  # This will print the response content

# %%
data = {
    "__LASTFOCUS": "",
    "__EVENTTARGET":"",
    "__EVENTARGUMENT":"",
    "__VIEWSTATE":viewstate_value,
    "__VIEWSTATEGENERATOR":viewstateGEN_value,
    "__VIEWSTATEENCRYPTED":"",
    "__PREVIOUSPAGE":PREVIOUSPAGE_value,
    "__EVENTVALIDATION":EVENTVALIDATION_value,
    "HFCertSrNo":"",
    "HFThumbPrint":"",
    "hdnSetPassword":hashed_password,
    "DDLLoginType":"0",
    "TBUserName":"rana123",
    "TBPassword":hashed_password,
    "txtCaptcha":"rTU8P",
    "LnkSubmitLogin":"Login"
    
    # ... (Add other form fields here)
}

# %%
# import requests

# # URL to send the POST request
# url = "https://ipindiaonline.gov.in/trademarkefiling/user/frmloginNew.aspx"

# # Headers for the request
# headers = {
#     "Host": "ipindiaonline.gov.in",
#     "Cookie": "ASP.NET_SessionId=a5mk2nfm5yh2ll53svu3b4c2",
#     "Cache-Control": "max-age=0",
#     "Sec-Ch-Ua": "",
#     "Sec-Ch-Ua-Mobile": "?0",
#     "Sec-Ch-Ua-Platform": "\"\"",
#     "Upgrade-Insecure-Requests": "1",
#     "Origin": "https://ipindiaonline.gov.in",
#     "Content-Type": "application/x-www-form-urlencoded",
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.5790.171 Safari/537.36",
#     "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
#     "Sec-Fetch-Site": "same-origin",
#     "Sec-Fetch-Mode": "navigate",
#     "Sec-Fetch-User": "?1",
#     "Sec-Fetch-Dest": "document",
#     "Referer": "https://ipindiaonline.gov.in/trademarkefiling/user/frmloginNew.aspx",
#     "Accept-Encoding": "gzip, deflate",
#     "Accept-Language": "en-US,en;q=0.9"
# }

# # Form data for the request


# response = requests.post(url, headers=headers, data=data)

# print(response.status_code)
# print(response.text)  # This will print the response content

# %%
from requests_toolbelt.multipart.encoder import MultipartEncoder

# %%
import httpx

url = "https://ipindiaonline.gov.in/trademarkefiling/user/frmLoginNew.aspx"
headers = {
    "Host": "ipindiaonline.gov.in",
    "Cookie": b
    # "Content-Type": "multipart/form-data; boundary=----WebKitFormBoundaryDmjNUnL8U90vfsgp"
    }

# multipart_data = """
# ... (Same multipart data as provided in the previous example)
# """

with httpx.Client() as client:
    response = client.post(url, headers=headers, data=data)
    print(response.text)  # Print the response content
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" lang="en">
# <head>
#     <title>Intellectual Property India</title>
#     <meta http-equiv="x-ua-compatible" content="IE=11,10,9,8">
#
#
#
#     <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">
#     <meta http-equiv="Content-Style-Type" content="text/css">
#     <meta http-equiv="Content-Script-Type" content="type">
#     <meta name="format-detection" content="telephone=no">
#     <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=no">
#
#     <link rel="stylesheet" href="https://maxcdn.bootstrapcdn.com/bootstrap/3.3.6/css/bootstrap.min.css">
#
#     <link media="all" href="../CSS/style.css" type="text/css" rel="stylesheet" />
#     <link media="all" href="../CSS/responsive.css" type="text/css" rel="stylesheet" />
#
#     <script src="../Scripts/SHA1.js" type="text/javascript"></script>
#
#     <script src="../Scripts/signer.js" type="text/javascript"></script>
#
#
#     <script type="text/javascript" src="https://ajax.googleapis.com/ajax/libs/jquery/1.9.1/jquery.min.js"></script>
#
#
#
#
#     <script type="text/javascript">
#         $(function () {
#
#             $('#TBUserName').keyup(function () {
#                 var yourInput = $(this).val();
#                 re = /['<>{\}]/gi;
#                 var isSplChar = re.test(yourInput);
#                 if (isSplChar) {
#                     var no_spl_char = yourInput.replace(/[`~!@#$%^&*()_|+\-=?;:'",.<>\{\}\[\]\\\/]/gi, '');
#                     $(this).val(no_spl_char);
#                 }
#             });
#         });
#     </script>
#
#     <script type="text/javascript">
#         $(document).ready(function () {
#             createCode();
#         });
#     </script>
#     <script type="text/javascript">
#         $(document).load(function () {
#             createCode();
#         });
#     </script>
#     <script type="text/javascript">
#         function clickButton(e, buttonid) {
#             var evt = e ? e : window.event;
#             var bt = document.getElementById(buttonid);
#             if (bt) {
#                 if (evt.keyCode == 13) {
#                     bt.click();
#                     return false;
#                 }
#             }
#         }
#
#     </script>
#     <script type="text/javascript">
#         $(document).ready(function () {
#             $('#TBPassword').bind('copy paste cut', function (e) {
#                 e.preventDefault(); //disable cut,copy,paste
#             });
#         });
#     </script>
#     <script type="text/javascript">
#         function OnChange(dropdown) {
#
#             var myindex = dropdown.selectedIndex;
#             var SelValue = dropdown.options[myindex].value;
#
#             if (SelValue == "0") {
#                 document.getElementById("TBPassword").disabled = false;
#
#             }
#             else {
#                 document.getElementById("TBPassword").disabled = true;
#
#             }
#         }
#
#         function NdemoSignAnyData() {
#             var dropdown = document.getElementById("DDLLoginType")
#             var myindex = dropdown.selectedIndex;
#             var SelValue = dropdown.options[myindex].value;
#             if (SelValue == "1") {
#                 var obj = GetCertificateInfo()
#                 if (obj) {
#                     document.getElementById("HFCertSrNo").value = obj.SerialNumber;
#                     document.getElementById("HFThumbPrint").value = obj.Thumbprint;
#                 }
#                 else {
#                     return false;
#                 }
#             }
#         }
#
#         function Validate(seed) {
#             if (document.getElementById("TBUserName").value == "") {
#                 document.getElementById("TBUserName").focus();
#                 if (document.getElementById("TBUserName").value == "") {
#                     alert("Please enter User Id");
#                     return false
#                 }
#
#                 else if (document.getElementById("TBPassword").value == "") {
#                     document.getElementById("TBPassword").value == " "
#                 }
#             return false
#         }
#         else {
#
#             var Pass = document.getElementById("TBPassword").value;
#                 document.getElementById("TBPassword").value = "";
#                 var finalpass;
#                 var SHA1New = hex_sha1(Pass);
#                 finalpass = SHA1New + seed;
#                 var SHA1 = hex_sha1(finalpass);
#                 document.getElementById("hdnSetPassword").value = SHA1;
#
#                 var k = document.getElementById("hdnSetPassword").value;
#                 document.getElementById("TBPassword").value = SHA1;
#             }
#         }
#         function Done(result) {
#             // Alert the boolean result returned from PageMethod
#             alert(result);
#         }
#
#     </script>
#
#     <script type="text/javascript">
#         function CaptchaAudio() {
#
#             $.ajax({
#                 type: "POST",
#
#                 url: '/trademarkefiling/user/frmLoginNew.aspx/GetCaptcha',
#
#                 data: '{}',
#                 contentType: "application/json; charset=utf-8",
#                 dataType: "json",
#                 success: OnSuccess,
#                 failure: function (response) {
#                     alert("failure" + response.d);
#                 }
#             });
#         }
#
#         function OnSuccess(response) {
#             var Array = response.d.split('')
#
#             $.each(Array, function (index, value) {
#                 var msg = new SpeechSynthesisUtterance(value);
#                 window.speechSynthesis.speak(msg);
#
#             })
#
#         }
#
#     </script>
#
#     <script type="text/javascript">
#         //function refreshcaptcha() {
#         //    $(document).load(function () {
#         //        createCode();
#         //    });
#         //}
#
#         $(function () {
#             $('#refresh').click(function () {
#                 createCode();
#             });
#         });
#     </script>
#
#     <style type="text/css">
#         ::-webkit-input-placeholder { /* Chrome */
#             color: #d8d0d0 !important;
#         }
#
#         :-ms-input-placeholder { /* IE 10+ */
#             color: #d8d0d0 !important;
#         }
#
#         ::-moz-placeholder { /* Firefox 19+ */
#             color: #d8d0d0 !important;
#             opacity: 1;
#         }
#
#         :-moz-placeholder { /* Firefox 4 - 18 */
#             color: #d8d0d0 !important;
#             opacity: 1;
#         }
#     </style>
#
# </head>
# <body>
#     <form name="Form1" method="post" action="./frmLoginNew.aspx" id="Form1">
# <input type="hidden" name="__VIEWSTATE" id="__VIEWSTATE" value="" />
#
# <script type='text/javascript' language='Javascript'>alert('Invalid Login')</script>
# <input type="hidden" name="__VIEWSTATEGENERATOR" id="__VIEWSTATEGENERATOR" value="137D2B9B" />
# <input type="hidden" name="__VIEWSTATEENCRYPTED" id="__VIEWSTATEENCRYPTED" value="" />
# <input type="hidden" name="__PREVIOUSPAGE" id="__PREVIOUSPAGE" value="nEmPtbDHkfZBrn9N4UG5aK-FflVreZyubFoXiBFJtNn8Pfou6NlQXLd2KQRq7B2xo9-1q1YhMqwBkxnVaRLgcHj67h8KZo8Zu0hTW_JqHO9K5PrbjbFu1yuI27Fkuf4h0" />
# <input type="hidden" name="__EVENTVALIDATION" id="__EVENTVALIDATION" value="" />
#
#
#
#
#         <div id="wrapper" class="patentsHome">
#             <div class="topStrip">
#                 <div class="container">
#                     <ul class="leftLinks">
#                         <li><a href="http://www.ipindia.nic.in/index.htm">Home</a> </li>
#                         <li><a href="http://www.ipindia.nic.in/about-us.htm">About Us</a> </li>
#                         <li><a href="http://www.ipindia.nic.in/whos-who-page.htm">Who's Who</a> </li>
#                         <li><a href="http://www.ipindia.nic.in/policy-pages.htm">Policy & Programs</a> </li>
#                         <li><a href="http://www.ipindia.nic.in/achievements-page.htm">Achievements</a> </li>
#                         <li><a href="https://ipindiaonline.gov.in/feedback">Feedback</a> </li>
#                         <li><a href="http://www.ipindia.nic.in/right-to-information.htm">RTI</a> </li>
#                         <li><a href="http://www.ipindia.nic.in/sitemap.htm">Sitemap</a> </li>
#                         <li><a href="http://www.ipindia.nic.in/contact-us.htm">Contact Us</a> </li>
#                     </ul>
#
#                 </div>
#             </div>
#         </div>
#         <div class="container">
#             <div id="header">
#                 <div class="logoBlock">
#                     <h1 id="logo"><a title="Intellectual Property India" href="http://www.ipindia.nic.in/index.htm">
#                         <img src="../Images/logoTrademark.png" class="img-responsive" alt="Intellectual Property India" /></a></h1>
#
#                     <div class="ipoLogo">
#                         <span class="subsiteName" style="font-size: 28px; color: #434343; font-weight: 600; padding-right: 60px; vertical-align: middle;">Trade Marks</span> <a href="http://www.ipindia.nic.in/index.htm">
#                             <img title="Intellectual Property India" src="../Images/images/Originals/ipo-logo.png" alt="Intellectual Property India" width="122" height="90"></a>
#
#                     </div>
#                 </div>
#             </div>
#
#             <nav class="clearfix">
#                 <ul id="nav">
#                     <li class="menu1" style="width: 1200px; height: 30px; margin-top: 0px;">
#                         <a class="navbar-brand" href="#"><b>Online Filing of Trade Mark Version 3.0</b></a>
#                     </li>
#
#                 </ul>
#
#             </nav>
#         </div>
#
#         <div id="content" class="innerContent">
#             <div class="container">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                 <div class="contentArea">
#                     <div class="col-md-3">
#                         <input type="image" name="ImageButton2" id="ImageButton2" title="Links to Presenting Madrid System Online Services" src="../Images/logo_services.gif" onclick="javascript:WebForm_DoPostBackWithOptions(new WebForm_PostBackOptions(&quot;ImageButton2&quot;, &quot;&quot;, true, &quot;&quot;, &quot;frmInternationalBureauLink.aspx&quot;, false, false))" border="0" />
#                     </div>
#                     <div class="col-md-5">
#                         <div class="loginForm" style="height: 335px;">
#                             <div class="card" style="padding: 0px;"></div>
#                             <div class="card" style="padding-top: 10px; height: 330px; max-width: 380px;">
#
#                                 <div>
#                                     <input name="HFCertSrNo" type="hidden" id="HFCertSrNo" />
#                                     <input name="HFThumbPrint" type="hidden" id="HFThumbPrint" />
#                                     <input name="hdnSetPassword" type="hidden" id="hdnSetPassword" value="796d0953982d5057cc20e6f78ce9c62663e11833" />
#                                 </div>
#                                 <div class="input-container" style="margin: 0 60px 15px;">
#                                     <span style="font-family: Verdana, Geneva, sans-serif; font-size: 14px; color: #003366;">&nbsp;Login With</span>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
#                             <select name="DDLLoginType" id="DDLLoginType" onchange="OnChange(this);">
# 	<option selected="selected" value="0">Password</option>
# 	<option value="1">Digital Signature</option>
#
# </select>
#                                 </div>
#                                 <div class="input-container" style="margin: 0 60px 5px;">
#
#                                     <input name="TBUserName" type="text" value="rana123" id="TBUserName" tabindex="1" autocomplete="off" PlaceHolder="User Name" onfocus="this.placeholder = &#39;&#39;" onblur="this.placeholder = &#39;User Name&#39;" />
#
#                                     <div class="bar"></div>
#                                 </div>
#                                 <div>
#                                     &nbsp;
#                                 </div>
#                                 <div class="input-container" style="margin: 0 60px 15px;">
#                                     <div id="TBPassword1">
#                                         <input name="TBPassword" type="password" id="TBPassword" tabindex="2" autocomplete="off" onpaste="return false" oncut="return false" ondelete="return false" PlaceHolder="Password" onfocus="this.placeholder = &#39;&#39;" onblur="this.placeholder = &#39;Password&#39;" />
#
#                                         <div class="bar"></div>
#                                     </div>
#                                 </div>
#                                 <div class="input-container" style="margin: 0 60px 5px;">
#
#                                     <div class="col-md-10">
#                                         <img id="captchaimg" src="../CaptchaGenerator/captcha.aspx?638271328672363967" height="30" width="200" border="0" />
#
#                                     </div>
#                                     <div class="col-md-2">
#                                         <input type="image" name="ImageButton1" id="ImageButton1" src="../Images/refress.png" border="0" style="width: 20px; height: 20px; margin-top: 5px; margin-bottom: 2px;" />
#                                     </div>
#
#                                 </div>
#                                 <div class="input-container" style="margin: 0 60px 5px;">
#
#                                     <input name="txtCaptcha" type="text" id="txtCaptcha" tabindex="3" placeHolder="Enter the code shown above" onfocus="this.placeholder = &#39;&#39;" onblur="this.placeholder = &#39;Enter the code shown above&#39;" />
#
#                                     <div class="bar"></div>
#                                 </div>
#
#                                 <div class="input-container" style="margin: 0 60px 5px;">
#                                      <img src="../Images/volume-24-512.png" height="30" width="30" title="Captcha Audio" alt="Captcha Audio" onclick="CaptchaAudio()" style="cursor: pointer; margin-left: 10px" />
#                                 </div>
#
#
#
#                                 <div class="buttons">
#                                     &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp;<input type="submit" name="LnkSubmitLogin" value="Login" onclick="NdemoSignAnyData();javascript:Validate(450731544);WebForm_DoPostBackWithOptions(new WebForm_PostBackOptions(&quot;LnkSubmitLogin&quot;, &quot;&quot;, true, &quot;&quot;, &quot;&quot;, false, false))" id="LnkSubmitLogin" />
#                                 </div>
#                                 <div class="input-container">
#                                     <span style="font-family: Verdana, Geneva, sans-serif; font-weight: 400; font-size: 12px; color: #003366;"><a href="../user/How-To-Register.aspx">New User? Sign Up</a> | <a href="../user/frmForgotPassword.aspx">Forgot Password?</a></span>
#                                 </div>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="clearfix"></div>
#                     <div class="col-md-12">
#                         <center>
#                     <span style="font-family: Verdana, Geneva, sans-serif; font-weight: 500; font-size: 14px; color: #003366;"><a href="../UsefullDownloads/capicom.zip">Component(capicom.dll)</a> | <a href="../UsefullDownloads/DSCManual.pdf" target="_blank">Digital Signature Manual </a>| <a href="../UsefullDownloads/e-usermanual.pdf" target="_blank">e-filing User Manual</a> | <a href="../faqs/index.html" target="_blank">FAQs</a> | <a href="mailto:tmr-helpdesk@nic.in">Help Desk(tmr-helpdesk@nic.in)</a> |  <a href="../UsefullDownloads/Disclaimer%203%20.pdf" target="_blank">Disclaimer</a>|
#  <a href="../user/PrivacyPolicy.aspx" target="_blank">Privacy Policy</a> | <a href="../user/TermsandCondition.aspx" target="_blank">Terms & Condition</a><br />
#                           <a href="../Extras/FAQESign.aspx" target="_blank">ESign FAQs</a> | <a href="../UsefullDownloads/eMudhra_eSign_User_Guide.pdf" target="_blank">ESign User Guide</a> | <a href="https://app.e-mudhra.com/createNewUser.jsp?src=c44ead5fdecd48ecac24f" target="_blank">Web URL to procure esign for individual or Organization</a>
#                         | <a href="../Extras/RegistrationSteps.aspx" target="_blank">ESign Registration and Installation Details</a>
#                     </span>
#                 </center>
#                         <br />
#                         <p style="color: blue">Public Notice regarding lock down - <a href="../UsefullDownloads/PUBLIC_NOTICE_1.pdf" target="_blank" style="color: red">Public Notice 1</a> and <a href="../UsefullDownloads/PUBLIC_NOTICE_2.pdf" target="_blank" style="color: red">Public Notice 2</a></p>
#
#                         <p style="color: blue">
#                             Guidelines for using NTRP (Bharat Kosh) Payment Gateway  <a href="../UsefullDownloads/NTRP.pdf" target="_blank" style="color: red">Guide</a><br />
#                         </p>
#                         <p>
#                             Important! Users are requested to download and install the Digital Signature component from
#                     the under mentioned
#                  links prior to Registration/Signup
#                         </p>
#                         <p>
#                             Please note that the payment gateway is not available between 2300 HOURS and 0030 HOURS
#                     in the e-filing module due to bank reconciliation process.
#                         </p>
#                     </div>
#                 </div>
#             </div>
#         </div>
#
#         <div class="copyright" style="margin-top: -70px; position: fixed; bottom: 0px;">
#             <div class="container">
#                 <p>Content Owned, updated and maintained by Intellectual Property India, All Rights Reserved.</p>
#             </div>
#         </div>
#     </form>
#     <script type="text/javascript" src="../Scripts/impfunction.js"></script>
#     <script type="text/javascript">
#         createCode();
#         function createCode() {
#
#             var random;
#             var temp = "";
#             for (var i = 0; i < 5; i++) {
#                 temp += Math.round(Math.random() * 8);
#             }
#             //document.all.theImg.src = "JpegImage.aspx?code=" + temp;
#             $('#theImg').attr('src', "JpegImage.aspx?code=" + temp);
#             // document.getElementById("theImg").attributes("src", "JpegImage.aspx?code=" + temp);
#             // document.all.theImg.src = "JpegImage.aspx?code=" + temp;
#             $('#Hidden11').attr('value', temp);
#         }
#     </script>
# </body>
#
# </html>

# %%
response.headers
# Out:
# Headers({'cache-control': 'no-cache, no-store,private, no-cache, no-store, pre-check=0, post-check=0, must-revalidate', 'pragma': 'no-cache,no-cache', 'content-type': 'text/html; charset=utf-8', 'expires': '-1', 'server': 'Microsoft-IIS/10.0', 'x-frame-options': 'SAMEORIGIN', 'x-powered-by': 'ASP.NET', 'date': 'Tue, 08 Aug 2023 11:06:43 GMT', 'content-length': '19898'})

# %%
# from PIL import Image
# import pytesseract

# # Open the image using Pillow
# image_path = "captcha_image2.jpg"  # Replace with the actual image path
# img = Image.open(image_path)

# # Perform OCR using Tesseract
# text = pytesseract.image_to_string(img)

# # Print the extracted text
# print("Extracted Text:")
# print(text)
# Out:
# Extracted Text:

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=220x35>

# %%
# import re
# import cv2 
# import numpy as np
# import pytesseract
# from pytesseract import Output
# from matplotlib import pyplot as plt

# %%
# # get grayscale image
# def get_grayscale(image):
#     return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# # noise removal
# def remove_noise(image):
#     return cv2.medianBlur(image,5)
 
# #thresholding
# def thresholding(image):
#     return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

# #dilation
# def dilate(image):
#     kernel = np.ones((5,5),np.uint8)
#     return cv2.dilate(image, kernel, iterations = 1)
    
# #erosion
# def erode(image):
#     kernel = np.ones((5,5),np.uint8)
#     return cv2.erode(image, kernel, iterations = 1)

# #opening - erosion followed by dilation
# def opening(image):
#     kernel = np.ones((5,5),np.uint8)
#     return cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)

# #canny edge detection
# def canny(image):
#     return cv2.Canny(image, 100, 200)

# #skew correction
# def deskew(image):
#     coords = np.column_stack(np.where(image > 0))
#     angle = cv2.minAreaRect(coords)[-1]
#     if angle < -45:
#         angle = -(90 + angle)
#     else:
#         angle = -angle
#     (h, w) = image.shape[:2]
#     center = (w // 2, h // 2)
#     M = cv2.getRotationMatrix2D(center, angle, 1.0)
#     rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
#     return rotated

# #template matching
# def match_template(image, template):
#     return cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED)

# %%
# # Plot original image

# image = cv2.imread('captcha_image2.jpg')
# b,g,r = cv2.split(image)
# rgb_img = cv2.merge([r,g,b])
# plt.imshow(rgb_img)
# plt.title('AUREBESH ORIGINAL IMAGE')
# plt.show()

# %%
# gray = get_grayscale(image)
# thresh = thresholding(gray)
# opening = opening(gray)
# canny = canny(gray)
# images = {'gray': gray, 
#           'thresh': thresh, 
#           'opening': opening, 
#           'canny': canny}

# %%
# fig = plt.figure(figsize=(13,13))
# ax = []

# rows = 2
# columns = 2
# keys = list(images.keys())
# for i in range(rows*columns):
#     ax.append( fig.add_subplot(rows, columns, i+1) )
#     ax[-1].set_title('AUREBESH - ' + keys[i]) 
#     plt.imshow(images[keys[i]], cmap='gray')

# %%
# Get OCR output using Pytesseract

custom_config = r'--oem 3 --psm 6'
print('-----------------------------------------')
print('TESSERACT OUTPUT --> ORIGINAL IMAGE')
print('-----------------------------------------')
print(pytesseract.image_to_string(image, config=custom_config))
print('\n-----------------------------------------')
print('TESSERACT OUTPUT --> THRESHOLDED IMAGE')
print('-----------------------------------------')
print(pytesseract.image_to_string(image, config=custom_config))
print('\n-----------------------------------------')
print('TESSERACT OUTPUT --> OPENED IMAGE')
print('-----------------------------------------')
print(pytesseract.image_to_string(image, config=custom_config))
print('\n-----------------------------------------')
print('TESSERACT OUTPUT --> CANNY EDGE IMAGE')
print('-----------------------------------------')
print(pytesseract.image_to_string(image, config=custom_config))
# Out:
# -----------------------------------------
# TESSERACT OUTPUT --> ORIGINAL IMAGE
# -----------------------------------------
# mo MGGab* |.
#
#
# -----------------------------------------
# TESSERACT OUTPUT --> THRESHOLDED IMAGE
# -----------------------------------------
# mo MGGab* |.
#
#
# -----------------------------------------
# TESSERACT OUTPUT --> OPENED IMAGE
# -----------------------------------------
# mo MGGab* |.
#
#
# -----------------------------------------
# TESSERACT OUTPUT --> CANNY EDGE IMAGE
# -----------------------------------------
# mo MGGab* |.
