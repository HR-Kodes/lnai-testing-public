# %%
import requests
api_key='AIzaSyBajyG1anQx_af3zP1A6Ozsn6DtYaBBaZk'
# address='SHOP NO. 4, SY NO. 70/3, ADARSH GROUP,BEGUR KOPPA ROAD, NEAR GREENCITY LAYOUT,BANGALORE'
# address='SY.NO.20/2, PLOT-22, GR. FLOOR,MARKAND GALI NO.1,AMBA NAGAR,Limbayat,Gujarat'
address="RACHANA GALAXY Pole star co workspace 3rd floor, 21st main road Marenahalli vijay nagar Bangalore -560040"
# address='BMSCE,BULL TEMPLE ROAD,BANGALORE,560019'
# latlng='12.9410122,77.5655258'
params={
    'key':api_key,
    'address':address,
    # 'latlng':latlng
}
    
base_url='https://maps.googleapis.com/maps/api/geocode/json?'
response=requests.get(base_url,params=params).json()
response.keys()
if response['status']=='OK':
    geometry=response['results'][0]['geometry']
    lat=geometry['location']['lat']
    lon=geometry['location']['lng']
print(lat,lon)
# Out:
# 12.9683547 77.5333101

# %%
response['results']
# Out:
# [{'address_components': [{'long_name': 'Bull Temple Road',
#     'short_name': 'Bull Temple Rd',
#     'types': ['route']},
#    {'long_name': 'Basavanagudi',
#     'short_name': 'Basavanagudi',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Bengaluru',
#     'short_name': 'Bengaluru',
#     'types': ['locality', 'political']},
#    {'long_name': 'Bengaluru Urban',
#     'short_name': 'Bengaluru Urban',
#     'types': ['administrative_area_level_3', 'political']},
#    {'long_name': 'Bangalore Division',
#     'short_name': 'Bangalore Division',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'Karnataka',
#     'short_name': 'KA',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'India',
#     'short_name': 'IN',
#     'types': ['country', 'political']},
#    {'long_name': '560019', 'short_name': '560019', 'types': ['postal_code']}],
# ...

# %%
api_key='AIzaSyBajyG1anQx_af3zP1A6Ozsn6DtYaBBaZk'
# address='BMS College of Engineering,Bull temple road,bAsavangudi,bangalore'
latlng='12.9410122, 77.5655258'
params1={
    'key':api_key,
    # 'address':address,
    'latlng':latlng
}

# %%
base_url='https://maps.googleapis.com/maps/api/geocode/json?'
response=requests.get(base_url,params=params1).json()
response['plus_code']
response['results']
# Out:
# [{'address_components': [{'long_name': 'WHR8+954',
#     'short_name': 'WHR8+954',
#     'types': ['plus_code']},
#    {'long_name': 'Basavanagudi',
#     'short_name': 'Basavanagudi',
#     'types': ['political', 'sublocality', 'sublocality_level_1']},
#    {'long_name': 'Bengaluru',
#     'short_name': 'Bengaluru',
#     'types': ['locality', 'political']},
#    {'long_name': 'Bengaluru Urban',
#     'short_name': 'Bengaluru Urban',
#     'types': ['administrative_area_level_3', 'political']},
#    {'long_name': 'Bangalore Division',
#     'short_name': 'Bangalore Division',
#     'types': ['administrative_area_level_2', 'political']},
#    {'long_name': 'Karnataka',
#     'short_name': 'KA',
#     'types': ['administrative_area_level_1', 'political']},
#    {'long_name': 'India',
#     'short_name': 'IN',
#     'types': ['country', 'political']},
#    {'long_name': '560019', 'short_name': '560019', 'types': ['postal_code']}],
# ...

# %%
https://api.indiacitys.com/api/v2/reverse-geocode?lat=<19.0121554>&lng=<72.8266225>
