# %%
import json

inp = {'spiceBpartaddress':{'line1': 'C/O Shobha H 33  1st MAIN',
  'line2': 'MARENAHALLI',
  'pincode': '560040',
  'addressType': 'Correspondance Address', #don't change
  'coutry': 'India',
  'area': '',  #will be updated with array resulted from the pin code
  'city': '',
  'district': '',
  'state_ut': '',
  'mobile': '7975735563',
  'companymailid': 'ranumahimewada@gmail.com'},
'formIntId':'1-4GNQQ2T',
'refNo':'1-9714466168',
'IntId':'1-4GNQQ2G',
'userId':'BIPULSINGH6690@GMAIL.COM',
'pan':"DKJPA2449M",

'Dir_w_DIN':{
  'din':"08092541",
  'designation':'Director',
  'category':'Promoter',
  'chairman':'',
  'director':"Executive director",
  'Number of equity shares':'5000'
  },
'Dir_wt_DIN':{
  'pan_data_' :{
    "pan": "COFPM2679A",
    "fName": "RANU",
    "midName": "",
    "surName": "MEWADA",
    "dob": "14/11/1990",
    "fullName": "RANUMEWADA"
},
  'fathers_first_name':'Karan',
  'fathers_middle_name':'Singh',
  'fathers_surname':'Mewada',
  'gender':'Female',
  'Nationality':'Indian',
  'Place_of_Birth':'Bangalore',
  'Occupation_type':'Private Employment',
  'Educational_qualification':'Master degree',
  'designation':'Director',
  'category':'Promoter',
  'director':'Executive Director',
  'chairman':'',
  'Mobile_no':'7975735563',
  'email':'ranumahimewada@gmail.com',
  'Number of equity shares':'5000',
  'permanent_add':{
    'line1':'asdsd',
    'line2':'asdda',
    'country':'India',
    'pincode':'560040'
  },
  'present_add':{
    'line1':'ads',
    'line2':'ads',
    'country':'India',
    'pincode':'560040',
    'duration_of_stay_years':'4',
    'duration_of_stay_months':'0'
  },
  'id_proof_type':'Aadhar Card',
  'id_proof_no':'773418462481',
  'residential_proof_type':'Bank Statement',
  'residential_proof_number':'188089555',
  'proof_of_identity':'',   #file_path
  'proof_of_address':''     #file_path

    
}}

inp = json.dumps(inp)
loaded_r = json.loads(inp)

# %%
def up(dict1:dict,dict2:dict):
    i = dict1.keys()
    j = dict2.keys()
    common_keys = filter(lambda x: x in i, j)
    tmp_dict = dict2.copy()
    # keys_not_in_dict2 = [key for key in dict1 if key not in dict2]
    keys_not_in_dict1 = [key for key in dict2 if key not in dict1]
    print(keys_not_in_dict1)
    # print(common_keys)
    for x in common_keys:
        # print(x)
        if type(dict1[x]) is dict:
            tmp_dict[x] = up(dict1[x],dict2[x])
        elif type(dict1[x]) is list and dict1[x]:
            for a in range(len(dict1[x])):
                tmp_dict[x][a] = up(dict1[x][a],dict2[x][a])
                # print(dict1[x][a],'\n',dict2[x][a])
        elif type(dict1[x]) is str and dict1[x]:
            tmp_dict[x] = dict1[x]
    return tmp_dict

# %%
loaded_r
# Out:
# {'spiceBpartaddress': {'line1': 'C/O Shobha H 33  1st MAIN',
#   'line2': 'MARENAHALLI',
#   'pincode': '560040',
#   'addressType': 'Correspondance Address',
#   'coutry': 'India',
#   'area': '',
#   'city': '',
#   'district': '',
#   'state_ut': '',
#   'mobile': '7975735563',
#   'companymailid': 'ranumahimewada@gmail.com'},
#  'formIntId': '1-4GNQQ2T',
#  'refNo': '1-9714466168',
#  'IntId': '1-4GNQQ2G',
#  'userId': 'BIPULSINGH6690@GMAIL.COM',
#  'pan': 'DKJPA2449M',
#  'Dir_w_DIN': {'din': '08092541',
#   'designation': 'Director',
#   'category': 'Promoter',
#   'chairman': '',
#   'director': 'Executive director',
#   'Number of equity shares': '5000'},
#  'Dir_wt_DIN': {'pan_data_': {'pan': 'COFPM2679A',
#    'fName': 'RANU',
#    'midName': '',
#    'surName': 'MEWADA',
#    'dob': '14/11/1990',
#    'fullName': 'RANUMEWADA'},
#   'fathers_first_name': 'Karan',
#   'fathers_middle_name': 'Singh',
#   'fathers_surname': 'Mewada',
#   'gender': 'Female',
# ...

# %%
import requests
import json
from requests_toolbelt.multipart.encoder import MultipartEncoder

url = "https://www.mca.gov.in/bin/mca/login"

headers = {
    "Origin": "www.mca.gov.in",
    "Content-Length": "231",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.5672.127 Safari/537.36",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Accept": "*/*",
    "X-Requested-With": "XMLHttpRequest",
    "Sec-Ch-Ua-Platform": "Windows"
}

# data = "data=Ut8pBOc0RSM6iYqffqN1orWH0Ee6A57QEKGmyHa5KnuzzybQ%2BjY2pMJIsLZw9DznTxfJeWvJFEcqsU2aZC33AC2nYaU60TNo8VjomCHN2dDSdHEC2enwIeEWCNR42vj7gfXFsvEwLfoO25%2BUKeho6%2B3l%2FkhEucDAzA4XeVNg0dhlBlgG95nyBiwYk3XhQoJtHSgqcb%2FI8MCyxN9h1unz%2Fw%3D%3D"
# data="data=Ut8pBOc0RSM6iYqffqN1oiyj9WvJGiJEVVlWEbrO16gkiUbYKGssebXlM%2Bcc1l6%2FKdM23DNeW8llstTdFVei6y9xEMOwz%2B9knilQCQO4A3hoGElJda82FpprBAEPkWo06fv8DKFy5OviHO14m2H3cvh0AOMj6KoZqODUvX6ZGHFHSu8p9yr2NmQsefa0pSN8hMhE3wtHhCdRiTJASCWjBw%3D%3D"
data="data=Ut8pBOc0RSM6iYqffqN1os8UC0wHR0dnkdWUh91bTVvbkOR1FwhDJFzabaerMcr6%2FKsnM50rkp32gFLlPIvLY2azrsy%2BFmeaecxebsQ2rMsFc5GCTglQP0xS6U9zJnDCSQK5SaWWU2%2BV26jpyqkyoIPo7tUlyt5PC9nL7eZxgxzDrAaL8RcGdMXXFiDj8jrOxbVTSdw3ix2lmz8kj1AbBw%3D%3D"
response = requests.post(url, headers=headers, data=data)
set_cookie_value = response.headers.get('Set-Cookie')
start_index = set_cookie_value.find("session-token=") + len("session-token=")
end_index = set_cookie_value.find(";", start_index)
session_token = set_cookie_value[start_index:end_index]

# %%
#change the values of 1st page here
payload1=r'''{"requestBody":{"formData":{"aoaEntrenched":"N","Havingsharecapital":"Having Share Capital","totalAuthorizedShareCapital":"200000","totalClassifiedAuthorizedShareCapital":"100000","totalSubscribedShareCapital":"100000","totalUnclassifiedAuthorizedShareCapital":"100000","equitynumberofClasses":"1","preferencenumberofClasses":"0","regaddresscountry":"India","NonIndividualCountWithoutDIN":"0","SpicePartBINDVSubscribersHavingDin":[{"INDVSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"INDVSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}]}],"SpicePartBINDVSubscribersNotHavingDin":[{"SpicePartBINDVsubscribersPermAddress":{"addressType":"Permanent Address"},"SpicePartBINDVsubscribersPresAddress":{"addressType":"Present Address"},"INDVSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"INDVSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}]}],"SpicePartBSubscribersHavingDin":[{"SubscriberType":"Subscriber CUM Director DIN","category":"Individual First subscribers cum Directors","SpicePartBSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"SpicePartBSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}],"SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"SpicePartBSubscribersNotHavingDin":[{"category":"Individual First subscribers cum Directors","SubscriberType":"Subscriber CUM Director No DIN","SpicePartBSubscribersPermAddress":{"addressType":"Permanent Address"},"SpicePartBSubscribersPresAddress":{"addressType":"Present Address"},"SpicePartBSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"SpicePartBSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}],"SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"SpicePartBDirectorsHavingDin":[{"category":"Directors","SubscriberType":"Directors Having DIN","SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"SpicePartBDirectorsNotHavingDin":[{"category":"Directors","SubscriberType":"Directors Not Having DIN","SpicePartBSubscribersPermAddress":{"addressType":"Permanent Address"},"SpicePartBSubscribersPresAddress":{"addressType":"Present Address"},"SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"formIntegrationId":"1-4C351SZ","SpicePartBShares":[{"classShare":"1","authorizedcapitalsharenumber":"10000","subscribedcapitalsharenumber":"10000","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"100000","subscribedcapitaltotalamount":"100000","sharecategory":"Equity Share"}],"spicePartBNonINDVSubscribers":[]},"status":"Draft/Pending Submission","formDescription":"For Spice+PartB","formName":"SPICE + Part B","formVersion":"01","userId":"BIPULKUMARSINGH6690@GMAIL.COM","integrationId":"1-4C351PA","referenceNumber":"1-9437997790","formAttachment":[],"operation":"Save","action":"savesubmit","formIntegrationId":"1-4C351SZ","srn":""}}'''
payload1_json=json.loads(payload1)

# %%
payload1_json
# Out:
# {'requestBody': {'formData': {'aoaEntrenched': 'N',
#    'Havingsharecapital': 'Having Share Capital',
#    'totalAuthorizedShareCapital': '200000',
#    'totalClassifiedAuthorizedShareCapital': '100000',
#    'totalSubscribedShareCapital': '100000',
#    'totalUnclassifiedAuthorizedShareCapital': '100000',
#    'equitynumberofClasses': '1',
#    'preferencenumberofClasses': '0',
#    'regaddresscountry': 'India',
#    'NonIndividualCountWithoutDIN': '0',
#    'SpicePartBINDVSubscribersHavingDin': [{'INDVSubscribersEquityShares': [{'sharecategory': 'Equity Share'}],
#      'INDVSubscribersPreferenceShares': [{'sharecategory': 'Preference Share'}]}],
#    'SpicePartBINDVSubscribersNotHavingDin': [{'SpicePartBINDVsubscribersPermAddress': {'addressType': 'Permanent Address'},
#      'SpicePartBINDVsubscribersPresAddress': {'addressType': 'Present Address'},
#      'INDVSubscribersEquityShares': [{'sharecategory': 'Equity Share'}],
# ...

# %%
payload1_json['requestBody']['formData']['SpicePartBShares']
# Out:
# [{'classShare': '1',
#   'authorizedcapitalsharenumber': '10000',
#   'subscribedcapitalsharenumber': '10000',
#   'authorizedcapitalnominalamountpershare': '10',
#   'subscribedcapitalnominalamountpershare': '10',
#   'authorizedcapitaltotalamount': '100000',
#   'subscribedcapitaltotalamount': '100000',
#   'sharecategory': 'Equity Share'}]

# %%
payload1_json['requestBody']['formData']['SpicePartBShares'][0]['authorizedcapitalsharenumber']
# Out:
# '10000'

# %%
payload1_json['requestBody']['formData']['SpicePartBShares'][0]['subscribedcapitalsharenumber']
payload1_json['requestBody']['formData']['SpicePartBShares'][0]['authorizedcapitalnominalamountpershare']
payload1_json['requestBody']['formData']['SpicePartBShares'][0]['subscribedcapitalnominalamountpershare']=''
payload1_json['requestBody']['formData']['SpicePartBShares'][0]['authorizedcapitaltotalamount']
payload1_json['requestBody']['formData']['SpicePartBShares'][0]['authorizedcapitalsharenumber']
payload1_json['requestBody']['formData']['SpicePartBShares'][0]['authorizedcapitaltotalamount']=''
payload1_json['requestBody']['formData']['SpicePartBShares'][0]['subscribedcapitaltotalamount']=''
payload1_json['requestBody']['formData']['Havingsharecapital']=''

payload1_json['requestBody']['referenceNumber']=refNo
payload1_json['requestBody']['formData']['formIntegrationId']=formIntId
payload1_json['requestBody']['formIntegrationId']=formIntId
payload1_json['requestBody']['integrationId']='IntId'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 10
#       7 payload1_json['requestBody']['formData']['SpicePartBShares'][0]['subscribedcapitaltotalamount']=''
#       8 payload1_json['requestBody']['formData']['Havingsharecapital']=''
# ---> 10 payload1_json['requestBody']['referenceNumber']=refNo
#      11 payload1_json['requestBody']['formData']['formIntegrationId']=formIntId
#      12 payload1_json['requestBody']['formIntegrationId']=formIntId
#
# NameError: name 'refNo' is not defined

# %%
payload1_json=json.dumps(payload1_json)

# %%
payload1_json
# Out:
# '{"requestBody": {"formData": {"aoaEntrenched": "N", "Havingsharecapital": "", "totalAuthorizedShareCapital": "200000", "totalClassifiedAuthorizedShareCapital": "100000", "totalSubscribedShareCapital": "100000", "totalUnclassifiedAuthorizedShareCapital": "100000", "equitynumberofClasses": "1", "preferencenumberofClasses": "0", "regaddresscountry": "India", "NonIndividualCountWithoutDIN": "0", "SpicePartBINDVSubscribersHavingDin": [{"INDVSubscribersEquityShares": [{"sharecategory": "Equity Share"}], "INDVSubscribersPreferenceShares": [{"sharecategory": "Preference Share"}]}], "SpicePartBINDVSubscribersNotHavingDin": [{"SpicePartBINDVsubscribersPermAddress": {"addressType": "Permanent Address"}, "SpicePartBINDVsubscribersPresAddress": {"addressType": "Present Address"}, "INDVSubscribersEquityShares": [{"sharecategory": "Equity Share"}], "INDVSubscribersPreferenceShares": [{"sharecategory": "Preference Share"}]}], "SpicePartBSubscribersHavingDin": [{"SubscriberType": "Subscriber CUM Dir
# ...

# %%
#page 1 save
url = "https://www.mca.gov.in/bin/mca-gov/SpicePartB_SAVESUBMIT"

headers = {
    "Cookie": f"cookiesession1=678B28695C218253C321286001478935; alertPopup=true; session-token=e{session_token}; deviceId=volakx5sla",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0",
    "Accept": "*/*",
    "Accept-Language": "en-US,en;q=0.5",
    "Accept-Encoding": "gzip, deflate",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html",
    "X-Requested-With": "XMLHttpRequest",
    "Content-Type": "multipart/form-data",
    "Content-Length": "3692",
    "Origin": "https://www.mca.gov.in",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "Te": "trailers"
}


multipart_data = MultipartEncoder(fields={
    'data': (payload1_json),
    'action': 'savesubmit',
    'operation': 'Save',
    'serveAction': 'saveForm',
    'referenceNumber': '',
    'formId': ''
})

headers['Content-Type'] = multipart_data.content_type
response = requests.post(url, headers=headers, data=multipart_data)

print(response.text)
# Out:
# {
# 		"error": "",
# 		"message": "Data Added Successfully",
#
# 		"data":	{
# 			"referenceNumber":"1-9739885569",
# 			"srn": "",
# 			"dateTime":"",
#                     "integrationId":"1-4H2VJSX",
#                     "srnStatus":"Draft/Pending Submission",
#                      "formIntegrationId":"1-4H2VJSZ"
# 			}
# }

# %%
def form_save(url,headers,payload):
    multipart_data = MultipartEncoder(fields={
		'data': (payload),
		'action': 'savesubmit',
		'operation': 'Save',
		'serveAction': 'saveForm',
		'referenceNumber': '',
		'formId': ''
	})
    headers['Content-Type'] = multipart_data.content_type
    return requests.post(url, headers=headers, data=multipart_data)

# %%
url = "https://www.mca.gov.in/bin/mca-gov/SpicePartB_SAVESUBMIT"

headers = {
    "Cookie": f"cookiesession1=678B28695C218253C321286001478935; alertPopup=true; session-token=e{session_token}; deviceId=volakx5sla",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0",
    "Accept": "*/*",
    "Accept-Language": "en-US,en;q=0.5",
    "Accept-Encoding": "gzip, deflate",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html",
    "X-Requested-With": "XMLHttpRequest",
    "Content-Type": "multipart/form-data",
    "Content-Length": "3692",
    "Origin": "https://www.mca.gov.in",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "Te": "trailers"
}

rp =form_save(url,headers,payload1_json)
print(rp.text)
# Out:
# {
# 		"error": "",
# 		"message": "Data Added Successfully",
#
# 		"data":	{
# 			"referenceNumber":"1-9739887540",
# 			"srn": "",
# 			"dateTime":"",
#                     "integrationId":"1-4H2VLBO",
#                     "srnStatus":"Draft/Pending Submission",
#                      "formIntegrationId":"1-4H2VLD4"
# 			}
# }

# %%
refNo_=json.loads(response.text)['data']['referenceNumber']
IntId_=json.loads(response.text)['data']['integrationId']
FormIntId=json.loads(response.text)['data']['formIntegrationId']

# %%
#page 1 next
url = 'https://www.mca.gov.in/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer.af.dermis'
headers = {
    'Cookie': f"cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}",
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': 'text/plain, */*; q=0.01',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'X-Requested-With': 'XMLHttpRequest',
    'Csrf-Token': 'undefined',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}

payload = {
    'functionToExecute': 'invokeFDMOperation',
    'formDataModelId': '/content/dam/formsanddocuments-fdm/mca-aem-forms/spice-part-b/spice-b-prefill',
    'input': '{"Model0":{"requestBody":{"userId":"","referenceNumber":'+f"{refNo_}"+',"srn":""}}}',
    'operationName': 'POST /spicepartb/services/getSRNDetails/1.0.0',
    'guideNodePath': '/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer/rootPanel/items/panel_437033673/items/panel_651281723_copy_1876865449/items/mca_button_copy_33766249'
}

response = requests.post(url, headers=headers, data=payload)

print(response.text)
print(response.status_code)
# Out:
# {"error":"","message":"Data Fetched Successfully","integrationId":"1-4H2VJSX","formIntegrationId":"1-4H2VJSZ","data":{"status":"Draft/Pending Submission","formData":{"formIntegrationId":"1-4H2VJSZ","numberOfArticles":"","aoaEntrenched":"N","Havingsharecapital":"","totalSubscribedShareCapital":"100000","totalUnclassifiedAuthorizedShareCapital":"100000","totalClassifiedAuthorizedShareCapital":"100000","totalAuthorizedShareCapital":"200000","equitynumberofClasses":"1","preferencenumberofClasses":"0","maxnumofMembers":"","maxNumofMembersExcludingProposedemp":"","numOfMembers":"","numOfMembersExcludingProposedEmp":"","regaddressline1":"","regaddressline2":"","regaddresscity":"","regaddressstate_ut":"","regaddressarea":"","regaddresspincode":"","regaddressdistrict":"","regaddresscountry":"India","regaddresscountryCode":"","regaddressfax":"","regaddresscompanymailid":"","regaddressphone":"","regaddresslatitude":"","regaddresslongitude":"","rocName":"","corresAddrSameRegAddr":"","SubsrciberD
# ...

# %%
#page 2 pin code

import requests

url = 'https://www.mca.gov.in/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer.af.dermis'
headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': 'text/plain, */*; q=0.01',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'X-Requested-With': 'XMLHttpRequest',
    'Csrf-Token': 'undefined',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}

payload = {
    'functionToExecute': 'invokeFDMOperation',
    'formDataModelId': '/content/dam/formsanddocuments-fdm/mca-aem-forms/spice-part-b/pincode',
    'input': '{"pinCode":560040}',
    'operationName': 'GET /common/service/lookup/pindetails/1.0.0',
    'guideNodePath': '/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer/rootPanel/items/panel_2001397683/items/panel_1902152287/items/guidetextbox_copy_11_762323347'
}

response = requests.post(url, headers=headers, data=payload)

print(response.text)
print(response.status_code)
# Out:
# {"data":[{"Area":"Chandra Lay Out","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"},{"Area":"Vijayanagar East","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"},{"Area":"Vijayanagar (Bangalore)","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"}],"error":"","message":"Data fetched Successfully"}
# 200

# %%
a=json.loads(response.text)['data']
area=[i['Area'] for i in a]
state=a[0]['State']

# %%
#page 2 arealocality

import requests

url = 'https://www.mca.gov.in/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer.af.dermis'
headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': 'text/plain, */*; q=0.01',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'X-Requested-With': 'XMLHttpRequest',
    'Csrf-Token': 'undefined',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}

payload = {
    'functionToExecute': 'invokeFDMOperation',
    'formDataModelId': '/content/dam/formsanddocuments-fdm/mca-aem-forms/spice-part-b/newroclist',
    'input': '{"Type":"MCA_ROC_LIST","Name":'+f"'{state}'"+'}',
    'operationName': 'GET /common/service/lookup/form15/val/1.0.0',
    'guideNodePath': '/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer/rootPanel/items/panel_2001397683/items/panel_1902152287/items/panel_1966601478/items/guidenumericbox_6907'
}

response = requests.post(url, headers=headers, data=payload)

print(response.text)
print(response.status_code)
# Out:
# {"data":[{"name":"Registrar of Companies, Karnataka"}],"error":"","message":"Data fetched Successfully"}
# 200

# %%
#Name of the office of the Registrar of Companies in which the proposed company is to be registered
reg=json.loads(response.text)['data'][0]['name']

# %%
file_path = r"C:\Users\golup\Downloads\MODEL QUESTIONS 3 Answers.pdf"

# %%
#payload to retrieve folder name
import urllib.parse

formData ="%7b%22requestBody%22%3a%7b%22userId%22%3a%22BIPULKUMARSINGH6690@GMAIL.COM%22%2c%22referenceNumber%22%3a%221-9713920310%22%2c%22srn%22%3a%22%22%2c%22action%22%3a%22SpiceplusAViewForm%22%7d%7d"
# Manually parse the data
decoded_data = urllib.parse.unquote_plus(formData,encoding='utf-8')
data_start = decoded_data.find('{')

data_end = decoded_data.rfind('}') + 1
data_str = decoded_data[data_start:data_end]
data = eval(data_str)
data
data['requestBody']['userId']=userId
data['referenceNumber']=refNo_
data['referenceNumber']=refNo_

# %%
data
# Out:
# {'requestBody': {'userId': 'BIPULSINGH6690@GMAIL.COM',
#   'referenceNumber': '1-9713920310',
#   'srn': '',
#   'action': 'SpiceplusAViewForm'},
#  'referenceNumber': '1-9739885569'}

# %%
encoded_data = urllib.parse.quote_plus(json.dumps(data), encoding='utf-8').replace('%20', '').replace('%28','(').replace('%29',')').replace('+%','%')

# %%
#to get folder id and stuff
import requests

url = 'https://www.mca.gov.in/bin/mca-gov/spiceGetData'

headers = {
    'Host': 'www.mca.gov.in',
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    'Accept': '*/*',
    'Csrf-Token': 'undefined',
    'X-Requested-With': 'XMLHttpRequest',
    'Origin': 'https://www.mca.gov.in',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.199 Safari/537.36',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Dest': 'empty',
    'Accept-Encoding': 'gzip, deflate',
    'Accept-Language': 'en-US,en;q=0.9'
}


payload=f"data={encoded_data}"
response = requests.post(url, headers=headers, data=payload)
response.text
# Out:
# '{"error":"","message":"Data Fetched Successfully","data":{"integrationId":"1-4GNF0VQ","status":"Submitted","reason":"","formData":{"formIntegrationId":"1-4GNF0WW","companyType":"New Company (Others)","CIN":"","companyClass":"Private","companyCategory":"Company limited by shares","companySubCategory":"Non-government company","NICCode1":"98200","Description1":"Undifferentiated service-producing activities of private households for own use","NICCode2":"","Description2":"","NICCode3":"","Description3":"","proposedName1":"HGCGHCFC PRIVATE LIMITED","proposedName2":"","proposedNameRating1":"","proposedNameRating2":""},"formAttachment":[{"attachmentLabel":"Spice+ Part A","attachmentCategory":"Forms","activityFileName":"1-9713920310.pdf","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"26646","attachmentDMSId":"347832456","totalNoOfPages":"2","activityFileDate":"07/08/2023 02:07:26","publicDocument":"Y","activityComments":"Generated PDF Stored Successfully","folderId":"1
# ...

# %%
json.loads(response.text)
# Out:
# {'error': '',
#  'message': 'Data Fetched Successfully',
#  'data': {'integrationId': '1-4GNF0VQ',
#   'status': 'Submitted',
#   'reason': '',
#   'formData': {'formIntegrationId': '1-4GNF0WW',
#    'companyType': 'New Company (Others)',
#    'CIN': '',
#    'companyClass': 'Private',
#    'companyCategory': 'Company limited by shares',
#    'companySubCategory': 'Non-government company',
#    'NICCode1': '98200',
#    'Description1': 'Undifferentiated service-producing activities of private households for own use',
#    'NICCode2': '',
#    'Description2': '',
#    'NICCode3': '',
#    'Description3': '',
#    'proposedName1': 'HGCGHCFC PRIVATE LIMITED',
#    'proposedName2': '',
#    'proposedNameRating1': '',
#    'proposedNameRating2': ''},
#   'formAttachment': [{'attachmentLabel': 'Spice+ Part A',
#     'attachmentCategory': 'Forms',
#     'activityFileName': '1-9713920310.pdf',
#     'activityFileSrcType': 'I',
#     'activityFileExt': 'pdf',
# ...

# %%
# refNo__=json.loads(response.text)['data'][]
IntId_=json.loads(response.text)['data']['integrationId']
FormIntId=json.loads(response.text)['data']['formData']['formIntegrationId']

# %%
folder1=json.loads(response.text)['data']['formAttachment'][0]

# %%
folder2=json.loads(response.text)['data']['formAttachment'][1]

# %%
#page 2 attachment 1
import requests

url = 'https://www.mca.gov.in/bin/mca/dms/addservice'
# file_path = '/path/to/your/file.pdf'
# session_token = 'your_session_token'

# Set the headers
headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Csrf-Token': 'undefined',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}

# Open the file in binary mode
with open(file_path, 'rb') as file:
    # Create the multipart form-data payload
    payload = {
        'file': ('a.pdf', file, 'application/pdf'),
        'folder': '',
        'filemetadata': '{"form":"SPICE + Part B","srn":"","documentType":"Attachment","module":"SPICE + Part B","userid":"SPICE + Part B","applicationId":"","attachmentCategory":"pdf","attachmentLabel":"SpiceBproofAddress"}'
    }

    # Send the POST request
    response = requests.post(url, headers=headers, files=payload)

# Check the response
if response.status_code == 200:
    print('File uploaded successfully')
else:
    print('Failed to upload the file')
# Out:
# File uploaded successfully

# %%
def form_save_file(url,headers,label,file_path):
    with open(file_path,'rb') as file:
        payload = {
        'file': ('a.pdf', file, 'application/pdf'),
        'folder': '',
        'filemetadata': '{"form":"SPICE + Part B","srn":"","documentType":"Attachment","module":"SPICE + Part B","userid":"SPICE + Part B","applicationId":"","attachmentCategory":"pdf","attachmentLabel":'+f'{label}'+'}'
    }
    
    return requests.post(url,headers=headers,files=payload)

# %%
url = 'https://www.mca.gov.in/bin/mca/dms/addservice'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Csrf-Token': 'undefined',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}
response = form_save_file(url,headers,"SpiceBproofAddress",file_path)
if response.status_code == 200:
    print('File uploaded successfully')
else:
    print('Failed to upload the file')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[268], line 15
#       1 url = 'https://www.mca.gov.in/bin/mca/dms/addservice'
#       3 headers = {
#       4     'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
#       5     'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
#    (...)
#      13     'Te': 'trailers'
#      14 }
# ---> 15 response = form_save_file(url,headers,"SpiceBproofAddress",file_path)
#      16 if response.status_code == 200:
#      17     print('File uploaded successfully')
#
# Cell In[267], line 9, in form_save_file(url, headers, label, file_path)
#       2 with open(file_path,'rb') as file:
#       3     payload = {
#       4     'file': ('a.pdf', file, 'application/pdf'),
#       5     'folder': '',
# ...

# %%
json.loads(response.text)
# Out:
# {'attachmentLabel': 'SpiceBproofAddress',
#  'attachmentCategory': 'Attachment',
#  'activityFileName': 'a.pdf',
#  'activityFileSrcPath': '171274212',
#  'activityFileSrcType': 'I',
#  'activityFileExt': 'pdf',
#  'activityFileSize': '2200170',
#  'attachmentDMSId': '347931491',
#  'totalNoOfPages': '21',
#  'activityFileDate': '07/08/2023',
#  'publicDocument': 'Y',
#  'activityComments': '171274212:SpiceBproofAddress:Document added successfully.',
#  'folderName': '',
#  'folderId': '171274212',
#  'version': '',
#  'addedBy': 'Fo User'}

# %%
att_resp1=r'''{"attachmentLabel":"SpiceBproofAddress","attachmentCategory":"Attachment","activityFileName":"a.pdf","activityFileSrcPath":"171273086","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"2200170","attachmentDMSId":"347923889","totalNoOfPages":"21","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171273086:SpiceBproofAddress:Document added successfully.","folderName":"","folderId":"171273086","version":"","addedBy":"Fo User"}'''

# %%
att_resp1=json.loads(response.text)

# %%
#page 2 attachment 2
import requests

url = 'https://www.mca.gov.in/bin/mca/dms/addservice'
# file_path = '/path/to/your/file.pdf'
# session_token = 'your_session_token'

# Set the headers
headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Csrf-Token': 'undefined',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}

# Open the file in binary mode
with open(file_path, 'rb') as file:
    # Create the multipart form-data payload
    payload = {
        'file': ('AA290623000151T_RC13062023.pdf', file, 'application/pdf'),
        'folder': '',
        'filemetadata': '{"form":"SPICE + Part B","srn":"","documentType":"Attachment","module":"SPICE + Part B","userid":"SPICE + Part B","applicationId":"","attachmentCategory":"pdf","attachmentLabel":"SpiceBcopyUtility"}'
    }

    # Send the POST request
    response = requests.post(url, headers=headers, files=payload)

# Check the response
if response.status_code == 200:
    print('File uploaded successfully')
else:
    print('Failed to upload the file')
# Out:
# File uploaded successfully

# %%
response.text
# Out:
# '{"attachmentLabel":"SpiceBcopyUtility","attachmentCategory":"Attachment","activityFileName":"AA290623000151T_RC13062023.pdf","activityFileSrcPath":"171274212","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"2200170","attachmentDMSId":"347931520","totalNoOfPages":"21","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171274212:SpiceBcopyUtility:Document added successfully.","folderName":"","folderId":"171274212","version":"","addedBy":"Fo User"}'

# %%
# att_resp2=r'''{"attachmentLabel":"SpiceBcopyUtility","attachmentCategory":"Attachment","activityFileName":"AA290623000151T_RC13062023.pdf","activityFileSrcPath":"171273086","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"2200170","attachmentDMSId":"347923903","totalNoOfPages":"21","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171273086:SpiceBcopyUtility:Document added successfully.","folderName":"","folderId":"171273086","version":"","addedBy":"Fo User"}'''
att_resp2=json.loads(response.text)

# %%
payload2=r'''{"requestBody":{"formData":{"aoaEntrenched":"N","Havingsharecapital":"Having Share Capital","totalAuthorizedShareCapital":"113000","totalClassifiedAuthorizedShareCapital":"13000","totalSubscribedShareCapital":"2000","totalUnclassifiedAuthorizedShareCapital":"100000","equitynumberofClasses":"2","preferencenumberofClasses":"2","SpicePartBAddress":[{"line1":"asdad","line2":"asdada","pincode":"560019","addressType":"Correspondance Address","coutry":"India","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state_ut":"Karnataka","mobile":"2313131312","companymailid":"asda@gmail.com"}],"regaddressline1":"asdad","regaddressline2":"asdada","regaddresspincode":"560019","regaddresscountry":"India","regaddresscity":"Bangalore South","regaddressdistrict":"Bangalore","regaddressstate_ut":"Karnataka","regaddresscompanymailid":"asda@gmail.com","regaddressarea":"Gaviopuram Extension","corresAddrSameRegAddr":"N","rocName":"Registrar of Companies, Karnataka","NonIndividualCountWithoutDIN":"0","SpicePartBINDVSubscribersHavingDin":[{"INDVSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"INDVSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}]}],"SpicePartBINDVSubscribersNotHavingDin":[{"SpicePartBINDVsubscribersPermAddress":{"addressType":"Permanent Address"},"SpicePartBINDVsubscribersPresAddress":{"addressType":"Present Address"},"INDVSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"INDVSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}]}],"SpicePartBSubscribersHavingDin":[{"SubscriberType":"Subscriber CUM Director DIN","category":"Individual First subscribers cum Directors","SpicePartBSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"SpicePartBSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}],"SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"SpicePartBSubscribersNotHavingDin":[{"category":"Individual First subscribers cum Directors","SubscriberType":"Subscriber CUM Director No DIN","SpicePartBSubscribersPermAddress":{"addressType":"Permanent Address"},"SpicePartBSubscribersPresAddress":{"addressType":"Present Address"},"SpicePartBSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"SpicePartBSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}],"SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"SpicePartBDirectorsHavingDin":[{"category":"Directors","SubscriberType":"Directors Having DIN","SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"SpicePartBDirectorsNotHavingDin":[{"category":"Directors","SubscriberType":"Directors Not Having DIN","SpicePartBSubscribersPermAddress":{"addressType":"Permanent Address"},"SpicePartBSubscribersPresAddress":{"addressType":"Present Address"},"SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"formIntegrationId":"1-4CXKS24","SpicePartBShares":[{"sharecategory":"Preference Share","classShare":"12","authorizedcapitalsharenumber":"100","subscribedcapitalsharenumber":"0","authorizedcapitalnominalamountpershare":"100","subscribedcapitalnominalamountpershare":"100","authorizedcapitaltotalamount":"10000"},{"sharecategory":"Preference Share","classShare":"13","authorizedcapitalsharenumber":"100","subscribedcapitalsharenumber":"0","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"1000"},{"classShare":"1","authorizedcapitalsharenumber":"100","subscribedcapitalsharenumber":"100","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"1000","subscribedcapitaltotalamount":"1000","sharecategory":"Equity Share"},{"classShare":"2","authorizedcapitalsharenumber":"100","subscribedcapitalsharenumber":"100","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"1000","subscribedcapitaltotalamount":"1000","sharecategory":"Equity Share"}],"spicePartBNonINDVSubscribers":[]},"status":"Draft/Pending Submission","formDescription":"For Spice+PartB","formName":"SPICE + Part B","formVersion":"01","userId":"BIPULKUMARSINGH6690@GMAIL.COM","integrationId":"1-4CXKS21","referenceNumber":"1-9489120265","formAttachment":[{"attachmentLabel":"SpiceBproofAddress","attachmentCategory":"Attachment","activityFileName":"1AA290623000151T_RC13062023.pdf","activityFileSrcPath":"170638497","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"81873","attachmentDMSId":"345253894","totalNoOfPages":"3","activityFileDate":"06/26/2023","publicDocument":"Y","activityComments":"170638497:SpiceBproofAddress:Document added successfully.","folderName":"tbU5W44287200571","folderId":"170638497","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBcopyUtility","attachmentCategory":"Attachment","activityFileName":"NIC-2004_detail_19jan2009.pdf","activityFileSrcPath":"170638497","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"386212","attachmentDMSId":"345253994","totalNoOfPages":"58","activityFileDate":"06/26/2023","publicDocument":"Y","activityComments":"170638497:SpiceBcopyUtility:Document added successfully.","folderName":"170638497","folderId":"170638497","version":"","addedBy":"Fo User"}],"operation":"Save","action":"savesubmit","formId":"","formIntegrationId":"1-4CXKS24","srn":""}}'''
payload2_json=json.loads(payload2)

# %%
payload2_json['requestBody']['formData'].update(json.loads(payload1_json)['requestBody']['formData'])

# %%
payload2_json
# Out:
# {'requestBody': {'formData': {'aoaEntrenched': 'N',
#    'Havingsharecapital': '',
#    'totalAuthorizedShareCapital': '200000',
#    'totalClassifiedAuthorizedShareCapital': '100000',
#    'totalSubscribedShareCapital': '100000',
#    'totalUnclassifiedAuthorizedShareCapital': '100000',
#    'equitynumberofClasses': '1',
#    'preferencenumberofClasses': '0',
#    'SpicePartBAddress': [{'line1': 'asdad',
#      'line2': 'asdada',
#      'pincode': '560019',
#      'addressType': 'Correspondance Address',
#      'coutry': 'India',
#      'area': 'Gaviopuram Extension',
#      'city': 'Bangalore South',
#      'district': 'Bangalore',
#      'state_ut': 'Karnataka',
#      'mobile': '2313131312',
#      'companymailid': 'asda@gmail.com'}],
#    'regaddressline1': 'asdad',
#    'regaddressline2': 'asdada',
#    'regaddresspincode': '560019',
#    'regaddresscountry': 'India',
#    'regaddresscity': 'Bangalore South',
#    'regaddressdistrict': 'Bangalore',
# ...

# %%
spiceBpartaddress=payload2_json['requestBody']['formData']['SpicePartBAddress']
spiceBpartaddress[0]=spiceBpartaddress_

spiceBpartaddress[0]['area']=area[2]  #have to put this in json,or make a code to automate the selection

# %%
for x,a in enumerate(payload2_json['requestBody']['formAttachment']):
    if a['attachmentLabel']=='SpiceBproofAddress':
        payload2_json['requestBody']['formAttachment'][x]=att_resp1
    elif a['attachmentLabel']=='SpiceBcopyUtility':
        payload2_json['requestBody']['formAttachment'][x]=att_resp2

# %%
payload2_json['requestBody']['formData']['regaddressline1']=spiceBpartaddress_['line1']
payload2_json['requestBody']['formData']['regaddressline2']=spiceBpartaddress_['line2']
payload2_json['requestBody']['formData']['regaddresspincode']=spiceBpartaddress_['pincode']
payload2_json['requestBody']['formData']['regaddressarea']=spiceBpartaddress_['area']
payload2_json['requestBody']['formData']['regaddresscompanymailid']=spiceBpartaddress_['companymailid']

# %%
payload2_json
# Out:
# {'requestBody': {'formData': {'aoaEntrenched': 'N',
#    'Havingsharecapital': '',
#    'totalAuthorizedShareCapital': '200000',
#    'totalClassifiedAuthorizedShareCapital': '100000',
#    'totalSubscribedShareCapital': '100000',
#    'totalUnclassifiedAuthorizedShareCapital': '100000',
#    'equitynumberofClasses': '1',
#    'preferencenumberofClasses': '0',
#    'SpicePartBAddress': [{'line1': 'C/O Shobha H 33  1st MAIN',
#      'line2': 'MARENAHALLI',
#      'pincode': '560040',
#      'addressType': 'Correspondance Address',
#      'coutry': 'India',
#      'area': 'Vijayanagar (Bangalore)',
#      'city': '',
#      'district': '',
#      'state_ut': '',
#      'mobile': '7975735563',
#      'companymailid': 'ranumahimewada@gmail.com'}],
#    'regaddressline1': 'C/O Shobha H 33  1st MAIN',
#    'regaddressline2': 'MARENAHALLI',
#    'regaddresspincode': '560040',
#    'regaddresscountry': 'India',
#    'regaddresscity': 'Bangalore South',
# ...

# %%
payload2_json=json.dumps(payload2_json)

# %%
#page 2 save
url = 'https://www.mca.gov.in/bin/mca-gov/SpicePartB_SAVESUBMIT'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Content-Type': 'multipart/form-data; boundary=---------------------------385063496230279602103212072529',
    'Content-Length': '5202',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}


multipart_data = MultipartEncoder(fields={
    'data': (payload2_json),
    'action': 'savesubmit',
    'operation': 'Save',
    'serveAction': 'saveForm',
    'referenceNumber': '',
    'formId': ''
})

headers['Content-Type'] = multipart_data.content_type
response = requests.post(url, headers=headers, data=multipart_data)

print(response.text)
# Out:
# {
# 		"error": "",
# 		"message": "Data Added Successfully",
#
# 		"data":	{
# 			"referenceNumber":"1-9489120265",
# 			"srn": "",
# 			"dateTime":"",
#                     "integrationId":"1-4CXKS21",
#                     "srnStatus":"Draft/Pending Submission",
#                      "formIntegrationId":""
# 			}
# }

# %%
payload3=r'''{"requestBody":{"formData":{"aoaEntrenched":"N","Havingsharecapital":"Having Share Capital","totalAuthorizedShareCapital":"100000","totalClassifiedAuthorizedShareCapital":"100000","totalSubscribedShareCapital":"100000","totalUnclassifiedAuthorizedShareCapital":"0","equitynumberofClasses":"1","preferencenumberofClasses":"0","numOfMembers":"2","regaddressline1":"ad","regaddressline2":"asda","regaddresspincode":"560040","regaddresscountry":"India","regaddresscity":"Bangalore North","regaddressdistrict":"Bangalore","regaddressstate_ut":"Karnataka","regaddresscompanymailid":"fa@gma.com","regaddressarea":"Vijayanagar (Bangalore)","corresAddrSameRegAddr":"Y","regaddresslongitude":"11","regaddresslatitude":"11","rocName":"Registrar of Companies, Karnataka","SubsrciberDINCount":"1","SubsrciberCountWithoutDIN":"1","NonIndividualCountWithoutDIN":"0","DirectorSubscriberDINCount":"1","DirectorSubscriberWithoutDINCount":"1","DirectorDINCount":"1","DirectorCountWithoutDINCount":"1","SpicePartBINDVSubscribersHavingDin":[{"INDVSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"INDVSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}]}],"SpicePartBINDVSubscribersNotHavingDin":[{"SpicePartBINDVsubscribersPermAddress":{"addressType":"Permanent Address"},"SpicePartBINDVsubscribersPresAddress":{"addressType":"Present Address"},"INDVSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"INDVSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}]}],"SpicePartBSubscribersHavingDin":[{"SubscriberType":"Subscriber CUM Director DIN","category":"Individual First subscribers cum Directors","SpicePartBSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"SpicePartBSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}],"SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"SpicePartBSubscribersNotHavingDin":[{"category":"Individual First subscribers cum Directors","SubscriberType":"Subscriber CUM Director No DIN","SpicePartBSubscribersPermAddress":{"addressType":"Permanent Address"},"SpicePartBSubscribersPresAddress":{"addressType":"Present Address"},"SpicePartBSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"SpicePartBSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}],"SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"SpicePartBDirectorsHavingDin":[{"category":"Directors","SubscriberType":"Directors Having DIN","SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"SpicePartBDirectorsNotHavingDin":[{"category":"Directors","SubscriberType":"Directors Not Having DIN","SpicePartBSubscribersPermAddress":{"addressType":"Permanent Address"},"SpicePartBSubscribersPresAddress":{"addressType":"Present Address"},"SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"formIntegrationId":"1-4GNQQ2T","SpicePartBShares":[{"classShare":"1","authorizedcapitalsharenumber":"10000","subscribedcapitalsharenumber":"10000","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"100000","subscribedcapitaltotalamount":"100000","sharecategory":"Equity Share"}],"spicePartBNonINDVSubscribers":[]},"status":"Draft/Pending Submission","formDescription":"For Spice+PartB","formName":"SPICE + Part B","formVersion":"01","userId":"BIPULKUMARSINGH6690@GMAIL.COM","integrationId":"1-4GNQQ2G","referenceNumber":"1-9714466168","operation":"SaveDelete","formId":"","formIntegrationId":"1-4GNQQ2T","srn":"","action":"savesubmit"}}'''

# %%
payload3_json=json.loads(payload3)

# %%
def update_dict_recursive(target_dict, source_dict):
    for key, value in source_dict.items():
        if isinstance(value, dict) and key in target_dict:
            update_dict_recursive(target_dict[key], value)
        else:
            target_dict[key] = value

update_dict_recursive(payload3_json, json.loads(payload2_json))
payload3_json
# Out:
# {'requestBody': {'formData': {'aoaEntrenched': 'N',
#    'Havingsharecapital': '',
#    'totalAuthorizedShareCapital': '200000',
#    'totalClassifiedAuthorizedShareCapital': '100000',
#    'totalSubscribedShareCapital': '100000',
#    'totalUnclassifiedAuthorizedShareCapital': '100000',
#    'equitynumberofClasses': '1',
#    'preferencenumberofClasses': '0',
#    'numOfMembers': '2',
#    'regaddressline1': 'C/O Shobha H 33  1st MAIN',
#    'regaddressline2': 'MARENAHALLI',
#    'regaddresspincode': '560040',
#    'regaddresscountry': 'India',
#    'regaddresscity': 'Bangalore South',
#    'regaddressdistrict': 'Bangalore',
#    'regaddressstate_ut': 'Karnataka',
#    'regaddresscompanymailid': 'ranumahimewada@gmail.com',
#    'regaddressarea': 'Vijayanagar (Bangalore)',
#    'corresAddrSameRegAddr': 'N',
#    'regaddresslongitude': '11',
#    'regaddresslatitude': '11',
#    'rocName': 'Registrar of Companies, Karnataka',
#    'SubsrciberDINCount': '1',
# ...

# %%
payload3_json=json.dumps(payload3_json)

# %%
#page 2 save
url = 'https://www.mca.gov.in/bin/mca-gov/SpicePartB_SAVESUBMIT'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Content-Type': 'multipart/form-data; boundary=---------------------------385063496230279602103212072529',
    'Content-Length': '5202',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}


multipart_data = MultipartEncoder(fields={
    'data': (payload3_json),
    'action': 'savesubmit',
    'operation': 'Save',
    'serveAction': 'saveForm',
    'referenceNumber': '',
    'formId': ''
})

headers['Content-Type'] = multipart_data.content_type
response = requests.post(url, headers=headers, data=multipart_data)

print(response.text)
# Out:
# {
# 		"error": "",
# 		"message": "Data Added Successfully",
#
# 		"data":	{
# 			"referenceNumber":"1-9489120265",
# 			"srn": "",
# 			"dateTime":"",
#                     "integrationId":"1-4CXKS21",
#                     "srnStatus":"Draft/Pending Submission",
#                      "formIntegrationId":""
# 			}
# }

# %%
#dir with din
import requests

url = 'https://www.mca.gov.in/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer.af.dermis'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.199 Safari/537.36',
    'Accept': 'text/plain, */*; q=0.01',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Dest': 'empty',
    'Accept-Encoding': 'gzip, deflate',
    'Accept-Language': 'en-US,en;q=0.9'
}

data = {
    'functionToExecute': 'invokeFDMOperation',
    'formDataModelId': '/content/dam/formsanddocuments-fdm/mca-aem-forms/spice-part-b/dindetails',
    # 'input': '{"Model0":{"ID":"08092541"}}',
    'input': f'{{"Model0": {{"ID": "{Dir_w_DIN["din"]}"}}}}',

    
    'operationName': 'POST /MDS/service/director/1.0.0',
    'guideNodePath': '/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer/rootPanel/items/panel_351137353/items/panel_2146734853/items/panel/items/guidenumericbox'
}

response = requests.post(url, headers=headers, data=data)

print(response.text)
# Out:
# {"message":"Data Fetched Successfully","data":{"directorData":[{"DIN":"08092541","directorDisqualified":"N","disqualificationRemovalDate":"","firstName":"SHOBHA","middleName":"","lastName":"HANUMAPPA","status":"Approved","DINSurrenderDate":"","educationalQualification":"","birthPlace":"","drivingLicenseNumber":"","mobileNumber":"+919964266665","city":"Bangalore North","directorDeathDate":"","votersIdNumber":"","durationofStay":"","fathersFirstName":"HANUMAPPA","authorizedRepType":"","district":"Bangalore","membershipNumber":"","pincode":"560040","nationality":"India","disqualificationSection":"","gender":"Female","DINAllocationDate":"03/21/2018","occupationType":"","area":"Vijayanagar (Bangalore)","KMPFlag":"","othersEducationalQualification":"","disqualificationDate":"","disqualificationReason":"","verificationStatus":"","OPCFlag":"","sameAddressFlag":"","fathersLastName":".","DOB":"10/08/1979","addressLine2":"MARENAHALLI VIJAYANAGAR","addressLine1":"NO 33/1 1ST MAIN ROAD","addressT
# ...

# %%
dir_with_din_details=json.loads(response.text)['data']['directorData'][0]

# %%
payload4=r'''{"requestBody":{"formData":{"aoaEntrenched":"N","Havingsharecapital":"Having Share Capital","totalAuthorizedShareCapital":"100000","totalClassifiedAuthorizedShareCapital":"100000","totalSubscribedShareCapital":"100000","totalUnclassifiedAuthorizedShareCapital":"0","equitynumberofClasses":"1","preferencenumberofClasses":"0","numOfMembers":"2","SpicePartBAddress":[{"line1":"asdada","line2":"dawsdad","pincode":"560040","addressType":"Correspondance Address","coutry":"India","area":"Vijayanagar (Bangalore)","city":"Bangalore North","district":"Bangalore","state_ut":"Karnataka","mobile":"9898989891","companymailid":"ada@faf.com"}],"regaddressline1":"asdada","regaddressline2":"dawsdad","regaddresspincode":"560040","regaddresscountry":"India","regaddresscity":"Bangalore North","regaddressdistrict":"Bangalore","regaddressstate_ut":"Karnataka","regaddresscompanymailid":"ada@faf.com","regaddressarea":"Vijayanagar (Bangalore)","corresAddrSameRegAddr":"Y","regaddresslongitude":"12","regaddresslatitude":"12","rocName":"Registrar of Companies, Karnataka","SubsrciberDINCount":"1","SubsrciberCountWithoutDIN":"1","NonIndividualCountWithoutDIN":"0","DirectorSubscriberDINCount":"1","DirectorSubscriberWithoutDINCount":"1","DirectorDINCount":"1","DirectorCountWithoutDINCount":"1","spicePartBNonINDVSubscribers":[],"formIntegrationId":"1-4GT5934","SpicePartBShares":[{"classShare":"1","authorizedcapitalsharenumber":"10000","subscribedcapitalsharenumber":"10000","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"100000","subscribedcapitaltotalamount":"100000","sharecategory":"Equity Share"}],"SpicePartBINDVSubscribers":[],"SpicePartBSubscribers":[{"SubscriberType":"Subscriber CUM Director DIN","din":"08092541","name":"SHOBHA  HANUMAPPA","nationality":"India","firstName":"","category":"Individual First subscribers cum Directors","Surname":"HANUMAPPA","designation":"Director","directorCategory":"Promoter","whetherNonED":"Executive director","emailid":"shobhah888@gmail.com","totalSubscribedShareCapital":"50000","equitynumofclasses":"1","DirectorInterestedEntitiescount":"0","SpicePartBSubsDeclaration":[],"inc9DeclarationFlag1":"N","SpicePartBSubscribersShares":[{"sharecategory":"Equity Share","classShare":"1","subscribedcapitalsharenumber":"5000","subscribedcapitalnominalamountpershare":"10","subscribedcapitaltotalamount":"50000"}],"pan":"","identityProofNumber":""}]},"status":"Draft/Pending Submission","formDescription":"For Spice+PartB","formName":"SPICE + Part B","formVersion":"01","userId":"BIPULKUMARSINGH6690@GMAIL.COM","integrationId":"1-4GT5931","referenceNumber":"1-9723542077","formAttachment":[{"attachmentLabel":"SpiceBproofAddress","attachmentCategory":"Attachment","activityFileName":"14691f19733dbc38843295f5b4e8fc5e3.jpg","activityFileSrcPath":"171265592","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"244314","attachmentDMSId":"347890979","totalNoOfPages":"1","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171265592:SpiceBproofAddress:Document added successfully.","folderName":"tm6tE1011929468910","folderId":"171265592","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBcopyUtility","attachmentCategory":"Attachment","activityFileName":"download (1).jpg","activityFileSrcPath":"171265592","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"22585","attachmentDMSId":"347891022","totalNoOfPages":"1","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171265592:SpiceBcopyUtility:Document added successfully.","folderName":"171265592","folderId":"171265592","version":"","addedBy":"Fo User"}],"operation":"Save","action":"savesubmit","formId":"","formIntegrationId":"1-4GT5934","srn":""}}'''

# %%
payload4_json=json.loads(payload4)

# %%
update_dict_recursive(payload4_json, json.loads(payload3_json))
# payload4_json

# %%
# payload4_json['requestBody']['formData']['SpicePartBSubscribers'][0]['name']=dir_with_din_details['name']
# payload4_json['requestBody']['formData']['SpicePartBSubscribers'][0]['']

payload4_json['requestBody']['formData']['SpicePartBSubscribers'][0]['directorCategory']=Dir_w_DIN['category']
payload4_json['requestBody']['formData']['SpicePartBSubscribers'][0]['designation']=Dir_w_DIN['designation']
payload4_json['requestBody']['formData']['SpicePartBSubscribers'][0]['whetherNonED']=Dir_w_DIN['director']
payload4_json['requestBody']['formData']['SpicePartBSubscribers'][0]['SpicePartBSubscribersShares'][0]['subscribedcapitalsharenumber']=Dir_w_DIN['Number of equity shares']

# %%
payload4_json
# Out:
# {'requestBody': {'formData': {'aoaEntrenched': 'N',
#    'Havingsharecapital': '',
#    'totalAuthorizedShareCapital': '200000',
#    'totalClassifiedAuthorizedShareCapital': '100000',
#    'totalSubscribedShareCapital': '100000',
#    'totalUnclassifiedAuthorizedShareCapital': '100000',
#    'equitynumberofClasses': '1',
#    'preferencenumberofClasses': '0',
#    'numOfMembers': '2',
#    'SpicePartBAddress': [{'line1': 'C/O Shobha H 33  1st MAIN',
#      'line2': 'MARENAHALLI',
#      'pincode': '560040',
#      'addressType': 'Correspondance Address',
#      'coutry': 'India',
#      'area': 'Vijayanagar (Bangalore)',
#      'city': '',
#      'district': '',
#      'state_ut': '',
#      'mobile': '7975735563',
#      'companymailid': 'ranumahimewada@gmail.com'}],
#    'regaddressline1': 'C/O Shobha H 33  1st MAIN',
#    'regaddressline2': 'MARENAHALLI',
#    'regaddresspincode': '560040',
#    'regaddresscountry': 'India',
#    'regaddresscity': 'Bangalore South',
# ...

# %%
payload4_json
# Out:
# '{"requestBody": {"formData": {"aoaEntrenched": "N", "Havingsharecapital": "", "totalAuthorizedShareCapital": "200000", "totalClassifiedAuthorizedShareCapital": "100000", "totalSubscribedShareCapital": "100000", "totalUnclassifiedAuthorizedShareCapital": "100000", "equitynumberofClasses": "1", "preferencenumberofClasses": "0", "numOfMembers": "2", "SpicePartBAddress": [{"line1": "C/O Shobha H 33  1st MAIN", "line2": "MARENAHALLI", "pincode": "560040", "addressType": "Correspondance Address", "coutry": "India", "area": "Vijayanagar (Bangalore)", "city": "", "district": "", "state_ut": "", "mobile": "7975735563", "companymailid": "ranumahimewada@gmail.com"}], "regaddressline1": "C/O Shobha H 33  1st MAIN", "regaddressline2": "MARENAHALLI", "regaddresspincode": "560040", "regaddresscountry": "India", "regaddresscity": "Bangalore South", "regaddressdistrict": "Bangalore", "regaddressstate_ut": "Karnataka", "regaddresscompanymailid": "ranumahimewada@gmail.com", "regaddressarea": "Vijayana
# ...

# %%
payload4_json=json.dumps(payload4_json)

# %%
#dir_with_din save
url = 'https://www.mca.gov.in/bin/mca-gov/SpicePartB_SAVESUBMIT'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Content-Type': 'multipart/form-data; boundary=---------------------------385063496230279602103212072529',
    'Content-Length': '5202',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}


multipart_data = MultipartEncoder(fields={
    'data': (payload4_json),
    'action': 'savesubmit',
    'operation': 'Save',
    'serveAction': 'saveForm',
    'referenceNumber': '',
    'formId': ''
})

headers['Content-Type'] = multipart_data.content_type
response = requests.post(url, headers=headers, data=multipart_data)

print(response.text)
# Out:
# {
# 		"error": "",
# 		"message": "Data Added Successfully",
#
# 		"data":	{
# 			"referenceNumber":"1-9489120265",
# 			"srn": "",
# 			"dateTime":"",
#                     "integrationId":"1-4CXKS21",
#                     "srnStatus":"Draft/Pending Submission",
#                      "formIntegrationId":""
# 			}
# }

# %%
import requests
from requests_toolbelt.multipart.encoder import MultipartEncoder

url = 'https://www.mca.gov.in/bin/commongetapi'
# session_token = 'your_session_token'

# Set the headers
headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}; sessionID=e084ac64-956a-4795-bc39-310fef37cfe9; deviceId=volakx5sla',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'Csrf-Token': 'undefined',
    'Content-Type': 'multipart/form-data; boundary=---------------------------3958746645966091053487563336',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}

# Define the payload as a multipart form-data
payload = MultipartEncoder(
    fields={
        'data': '{"id":'+F"{Dir_wt_DIN['pan_data_']['pan']}"+'}',
        'endpointID': 'dinprefill'
    }
    # boundary='---------------------------3958746645966091053487563336'
)

# Set the headers with the appropriate content-type
headers['Content-Type'] = payload.content_type

# Send the POST request
response = requests.post(url, headers=headers, data=payload)

# Check the response
if response.status_code == 200:
    print('Request successful!')
    print('Response:', response.text)
else:
    print('Request failed. Status code:', response.status_code)
# Out:
# Request successful!
# Response: {"resCode":200,"resStr":"{\n                    \"error\":\"Error\"\n                    }"}

# %%
import urllib.parse

pan_data = Dir_wt_DIN['pan_data_']

pan_data_encoded1 = urllib.parse.quote(json.dumps(pan_data)).replace('%20','').replace('/','%2F')

print('Encoded PAN data:', pan_data_encoded1)
# Out:
# Encoded PAN data: %7B%22pan%22%3A%22COFPM2679A%22%2C%22fName%22%3A%22RANU%22%2C%22midName%22%3A%22%22%2C%22surName%22%3A%22MEWADA%22%2C%22dob%22%3A%2214%2F11%2F1990%22%2C%22fullName%22%3A%22RANUMEWADA%22%7D

# %%
#VALIDATE PAN DATA
url = 'https://www.mca.gov.in/bin/cbdtPanValidate'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'X-Requested-With': 'XMLHttpRequest',
    'Csrf-Token': 'undefined',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}
data=f'panData={pan_data_encoded1}'
response = requests.post(url, headers=headers, data=data)

# Check the response
if response.status_code == 200:
    print('Request successful!')
    print('Response:', response.text)
else:
    print('Request failed. Status code:', response.status_code)
# Out:
# Request successful!
# Response: {"resCode":200,"resStr":"{\"status\":\"true\"}"}

# %%
#DIR_WT_DIN PINCODE
#permanent address
import requests

url = "https://www.mca.gov.in/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer.af.dermis"
headers = {
    "Cookie": "cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token=eyJhbGciOiJIUzUxMiJ9..sDBdpiVVuWp7NDihEOVHSIHW0cVSkZFj54s_0R94NKUSCZQJJr_QISd26Sns-AZNF1kSxxYVoRh8BupApZ132Q; sessionID=e084ac64-956a-4795-bc39-310fef37cfe9; deviceId=volakx5sla",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0",
    "Accept": "text/plain, */*; q=0.01",
    "Accept-Language": "en-US,en;q=0.5",
    "Accept-Encoding": "gzip, deflate",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest",
    "Csrf-Token": "undefined",
    "Origin": "https://www.mca.gov.in",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "Te": "trailers"
}

data = {
    "functionToExecute": "invokeFDMOperation",
    "formDataModelId": "/content/dam/formsanddocuments-fdm/mca-aem-forms/spice-part-b/pincode",
    # "input": '{"pinCode":"560004"}',
    'input': f'{{"pinCode": "{Dir_wt_DIN["permanent_add"]["pincode"]}"}}',
    "operationName": "GET /common/service/lookup/pindetails/1.0.0",
    "guideNodePath": "/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer/rootPanel/items/panel_434252747/items/panel_334769435/items/panel_copy/items/panel/items/guidetextbox_copy_11_1268838373"
}

try:
    response = requests.post(url, headers=headers, data=data)
    response.raise_for_status()
    
    print("Request successful!")
    print("Response:", response.text)
except requests.exceptions.RequestException as e:
    print("Request failed:", str(e))
# Out:
# Request successful!
# Response: {"data":[{"Area":"Chandra Lay Out","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"},{"Area":"Vijayanagar East","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"},{"Area":"Vijayanagar (Bangalore)","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"}],"error":"","message":"Data fetched Successfully"}

# %%
b=json.loads(response.text)['data']
area=[i['Area'] for i in b]
state=b[0]['State']

# %%
#DIR_WT_DIN PINCODE
#present address (only if present residential address is not same as permanent residential address)


url = "https://www.mca.gov.in/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer.af.dermis"
headers = {
    "Cookie": "cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token=eyJhbGciOiJIUzUxMiJ9..sDBdpiVVuWp7NDihEOVHSIHW0cVSkZFj54s_0R94NKUSCZQJJr_QISd26Sns-AZNF1kSxxYVoRh8BupApZ132Q; sessionID=e084ac64-956a-4795-bc39-310fef37cfe9; deviceId=volakx5sla",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0",
    "Accept": "text/plain, */*; q=0.01",
    "Accept-Language": "en-US,en;q=0.5",
    "Accept-Encoding": "gzip, deflate",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest",
    "Csrf-Token": "undefined",
    "Origin": "https://www.mca.gov.in",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "Te": "trailers"
}

data = {
    "functionToExecute": "invokeFDMOperation",
    "formDataModelId": "/content/dam/formsanddocuments-fdm/mca-aem-forms/spice-part-b/pincode",
    # "input": '{"pinCode":"560004"}',
    'input': f'{{"pinCode": "{Dir_wt_DIN["permanent_add"]["pincode"]}"}}',
    "operationName": "GET /common/service/lookup/pindetails/1.0.0",
    "guideNodePath": "/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer/rootPanel/items/panel_434252747/items/panel_334769435/items/panel_copy_copy/items/panel/items/guidetextbox_copy_11_1268838373"
}

try:
    response = requests.post(url, headers=headers, data=data)
    response.raise_for_status()
    
    print("Request successful!")
    print("Response:", response.text)
except requests.exceptions.RequestException as e:
    print("Request failed:", str(e))
# Out:
# Request successful!
# Response: {"data":[{"Area":"Chandra Lay Out","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"},{"Area":"Vijayanagar East","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"},{"Area":"Vijayanagar (Bangalore)","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"}],"error":"","message":"Data fetched Successfully"}

# %%
c=json.loads(response.text)['data']
area=[i['Area'] for i in c]
state=c[0]['State']

# %%
#dir_wt_din attachment 1

#have to change the file name


url = 'https://www.mca.gov.in/bin/mca/dms/addservice'
# file_path = '/path/to/your/file.pdf'
# session_token = 'your_session_token'

# Set the headers
headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Csrf-Token': 'undefined',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}

# Open the file in binary mode
with open(file_path, 'rb') as file:
    # Create the multipart form-data payload
    payload = {
        'file': ('AA290623000151T_RC13062023.pdf', file, 'application/pdf'),
        'folder': '',
        'filemetadata': '{"form":"SPICE + Part B","srn":"","documentType":"Attachment","module":"SPICE + Part B","userid":"SPICE + Part B","applicationId":"","attachmentCategory":"pdf","attachmentLabel":"SpiceBidentityPro7B"}'
    }

    # Send the POST request
    response = requests.post(url, headers=headers, files=payload)

# Check the response
if response.status_code == 200:
    print('File uploaded successfully')
else:
    print('Failed to upload the file')
# Out:
# File uploaded successfully

# %%
response.text
# Out:
# '{"attachmentLabel":"SpiceBidentityPro7B","attachmentCategory":"Attachment","activityFileName":"AA290623000151T_RC13062023.pdf","activityFileSrcPath":"171274212","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"2200170","attachmentDMSId":"347931812","totalNoOfPages":"21","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171274212:SpiceBidentityPro7B:Document added successfully.","folderName":"","folderId":"171274212","version":"","addedBy":"Fo User"}'

# %%
att_resp3=json.loads(response.text)

# %%
#dir_wt_din attachment 2

#have to change the file name
import requests

url = 'https://www.mca.gov.in/bin/mca/dms/addservice'
# file_path = '/path/to/your/file.pdf'
# session_token = 'your_session_token'

# Set the headers
headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Csrf-Token': 'undefined',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}

# Open the file in binary mode
with open(file_path, 'rb') as file:
    # Create the multipart form-data payload
    payload = {
        'file': ('AA290623000151T_RC13062023.pdf', file, 'application/pdf'),
        'folder': '',
        'filemetadata': '{"form":"SPICE + Part B","srn":"","documentType":"Attachment","module":"SPICE + Part B","userid":"SPICE + Part B","applicationId":"","attachmentCategory":"pdf","attachmentLabel":"SpiceBProofOfResi7B"}'
    }

    # Send the POST request
    response = requests.post(url, headers=headers, files=payload)

# Check the response
if response.status_code == 200:
    print('File uploaded successfully')
else:
    print('Failed to upload the file')
# Out:
# File uploaded successfully

# %%
response.text
# Out:
# '{"attachmentLabel":"SpiceBProofOfResi7B","attachmentCategory":"Attachment","activityFileName":"AA290623000151T_RC13062023.pdf","activityFileSrcPath":"171274212","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"2200170","attachmentDMSId":"347931871","totalNoOfPages":"21","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171274212:SpiceBProofOfResi7B:Document added successfully.","folderName":"","folderId":"171274212","version":"","addedBy":"Fo User"}'

# %%
att_resp4=json.loads(response.text)

# %%
payload5=r'''{"requestBody":{"formData":{"aoaEntrenched":"N","Havingsharecapital":"Having Share Capital","totalAuthorizedShareCapital":"100000","totalClassifiedAuthorizedShareCapital":"100000","totalSubscribedShareCapital":"100000","totalUnclassifiedAuthorizedShareCapital":"0","equitynumberofClasses":"1","preferencenumberofClasses":"0","numOfMembers":"2","SpicePartBAddress":[{"line1":"asdada","line2":"dawsdad","pincode":"560040","addressType":"Correspondance Address","coutry":"India","area":"Vijayanagar (Bangalore)","city":"Bangalore North","district":"Bangalore","state_ut":"Karnataka","mobile":"9898989891","companymailid":"ada@faf.com"}],"regaddressline1":"asdada","regaddressline2":"dawsdad","regaddresspincode":"560040","regaddresscountry":"India","regaddresscity":"Bangalore North","regaddressdistrict":"Bangalore","regaddressstate_ut":"Karnataka","regaddresscompanymailid":"ada@faf.com","regaddressarea":"Vijayanagar (Bangalore)","corresAddrSameRegAddr":"Y","regaddresslongitude":"12","regaddresslatitude":"12","rocName":"Registrar of Companies, Karnataka","SubsrciberDINCount":"1","SubsrciberCountWithoutDIN":"1","NonIndividualCountWithoutDIN":"0","DirectorSubscriberDINCount":"1","DirectorSubscriberWithoutDINCount":"1","DirectorDINCount":"1","DirectorCountWithoutDINCount":"1","spicePartBNonINDVSubscribers":[],"formIntegrationId":"1-4GT5934","SpicePartBShares":[{"classShare":"1","authorizedcapitalsharenumber":"10000","subscribedcapitalsharenumber":"10000","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"100000","subscribedcapitaltotalamount":"100000","sharecategory":"Equity Share"}],"SpicePartBINDVSubscribers":[],"SpicePartBSubscribers":[{"SubscriberType":"Subscriber CUM Director DIN","din":"08092541","name":"SHOBHA  HANUMAPPA","nationality":"India","firstName":"SHOBHA","category":"Individual First subscribers cum Directors","Surname":"HANUMAPPA","designation":"Director","directorCategory":"Promoter","whetherNonED":"Executive director","emailid":"shobhah888@gmail.com","totalSubscribedShareCapital":"50000","equitynumofclasses":"1","DirectorInterestedEntitiescount":"0","SpicePartBSubsDeclaration":[],"inc9DeclarationFlag1":"N","SpicePartBSubscribersShares":[{"sharecategory":"Equity Share","classShare":"1","subscribedcapitalsharenumber":"5000","subscribedcapitalnominalamountpershare":"10","subscribedcapitaltotalamount":"50000"}],"pan":"","identityProofNumber":""},{"category":"Individual First subscribers cum Directors","SubscriberType":"Subscriber CUM Director No DIN","firstName":"Pratik","Surname":"Agarwal","fatherFirstName":"asds","fatherMiddleName":"ada","fatherSurName":"adsa","gender":"Male","dateOfBirth":"7/9/2000","nationality":"India","placeofBirth":"Koderma","citizenOfIndia":"Y","residentOfIndia":"Y","occupationType":"Private Employment","educationalQualificationothers":"Master degree","pan":"DKJPA2449M","designation":"Director","directorCategory":"Promoter","whetherNonED":"Executive director","MobileNo":"0121212121212","emailid":"f@gmail.com","ResidenseCorespondenceFlag":"N","identityProofDocument":"Aadhar Card","identityProofNumber":"212121212121212","residentialProofDocument":"Bank Statement","residentialProofNumber":"21212121221212","Attachment1":{"fileAttachment":"DKJPA2449M_debb0c0c9_0a4e_4ebe_9578_348213020dc1.jpg"},"Attachment2":{"fileAttachment":"DKJPA2449M_81aee76d_7931_4998_ab52_f3df205125d4 (2).jpg"},"totalSubscribedShareCapital":"50000","equitynumofclasses":"1","DirectorInterestedEntitiescount":"0","SpicePartBSubsDeclaration":[],"inc9DeclarationFlag1":"N","din":"","SpicePartBSubscribersShares":[{"sharecategory":"Equity Share","classShare":"1","subscribedcapitalsharenumber":"5000","subscribedcapitalnominalamountpershare":"10","subscribedcapitaltotalamount":"50000"}],"SpicePartBSubscribersAddress":[{"addressType":"Permanent Address","line1":"asdad","line2":"dasdasd","country":"India","pincode":"560019","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state_ut":"Karnataka"},{"addressType":"Present Address","line1":"asdsad","line2":"dad","country":"India","pincode":"560019","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state_ut":"Karnataka","yearresidenseduration":" 4"}]}]},"status":"Draft/Pending Submission","formDescription":"For Spice+PartB","formName":"SPICE + Part B","formVersion":"01","userId":"BIPULKUMARSINGH6690@GMAIL.COM","integrationId":"1-4GT5931","referenceNumber":"1-9723542077","operation":"Save","action":"savesubmit","formId":"","formIntegrationId":"1-4GT5934","srn":"","formAttachment":[{"attachmentLabel":"SpiceBproofAddress","attachmentCategory":"Attachment","activityFileName":"14691f19733dbc38843295f5b4e8fc5e3.jpg","activityFileSrcPath":"171265592","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"244314","attachmentDMSId":"347890979","totalNoOfPages":"1","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171265592:SpiceBproofAddress:Document added successfully.","folderName":"tm6tE1011929468910","folderId":"171265592","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBcopyUtility","attachmentCategory":"Attachment","activityFileName":"download (1).jpg","activityFileSrcPath":"171265592","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"22585","attachmentDMSId":"347891022","totalNoOfPages":"1","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171265592:SpiceBcopyUtility:Document added successfully.","folderName":"171265592","folderId":"171265592","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBidentityPro7B","attachmentCategory":"Attachment","activityFileName":"DKJPA2449M_debb0c0c9_0a4e_4ebe_9578_348213020dc1.jpg","activityFileSrcPath":"171265592","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"106323","attachmentDMSId":"347926914","totalNoOfPages":"1","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171265592:SpiceBidentityPro7B:Document added successfully.","folderName":"171265592","folderId":"171265592","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBProofOfResi7B","attachmentCategory":"Attachment","activityFileName":"DKJPA2449M_81aee76d_7931_4998_ab52_f3df205125d4 (2).jpg","activityFileSrcPath":"171265592","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"73451","attachmentDMSId":"347927158","totalNoOfPages":"1","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171265592:SpiceBProofOfResi7B:Document added successfully.","folderName":"171265592","folderId":"171265592","version":"","addedBy":"Fo User"}]}}'''
payload5_json=json.loads(payload5)

# %%
payload5_json
# Out:
# {'requestBody': {'formData': {'aoaEntrenched': 'N',
#    'Havingsharecapital': 'Having Share Capital',
#    'totalAuthorizedShareCapital': '100000',
#    'totalClassifiedAuthorizedShareCapital': '100000',
#    'totalSubscribedShareCapital': '100000',
#    'totalUnclassifiedAuthorizedShareCapital': '0',
#    'equitynumberofClasses': '1',
#    'preferencenumberofClasses': '0',
#    'numOfMembers': '2',
#    'SpicePartBAddress': [{'line1': 'asdada',
#      'line2': 'dawsdad',
#      'pincode': '560040',
#      'addressType': 'Correspondance Address',
#      'coutry': 'India',
#      'area': 'Vijayanagar (Bangalore)',
#      'city': 'Bangalore North',
#      'district': 'Bangalore',
#      'state_ut': 'Karnataka',
#      'mobile': '9898989891',
#      'companymailid': 'ada@faf.com'}],
#    'regaddressline1': 'asdada',
#    'regaddressline2': 'dawsdad',
#    'regaddresspincode': '560040',
#    'regaddresscountry': 'India',
#    'regaddresscity': 'Bangalore North',
# ...

# %%
def update_dict_recursive(target_dict, source_dict):
    for key, value in source_dict.items():
        if isinstance(value, dict) and key in target_dict:
            update_dict_recursive(target_dict[key], value)
        elif key in target_dict:
            target_dict[key] = value

update_dict_recursive(payload5_json['requestBody']['formData'], json.loads(payload4_json)['requestBody']['formData'])

# %%
for x, a in enumerate(payload5_json['requestBody']['formAttachment']):
    if a['attachmentLabel'] == 'SpiceBproofAddress':
        a.update(att_resp1)
    elif a['attachmentLabel'] == 'SpiceBcopyUtility':
        a.update(att_resp2)
    elif a['attachmentLabel'] == 'SpiceBidentityPro7B':
        a.update(att_resp3)
    elif a['attachmentLabel'] == 'SpiceBProofOfResi7B':
        a.update(att_resp4)

# %%
# for x,a in enumerate(payload5_json['requestBody']['formAttachment']):
#     if a['attachmentLabel']=='SpiceBproofAddress':
#         payload2_json['requestBody']['formAttachment'][x]=att_resp1
#     elif a['attachmentLabel']=='SpiceBcopyUtility':
#         payload2_json['requestBody']['formAttachment'][x]=att_resp2
#     elif a['attachmentLabel']=='SpiceBidentityPro7B':
#         payload5_json['requestBody']['formAttachment'][x]=att_resp3
#     elif a['attachmentLabel']=='SpiceBProofOfResi7B':
#         payload5_json['requestBody']['formAttachment'][x]=att_resp4

# %%
payload5_json['requestBody']
# Out:
# {'formData': {'aoaEntrenched': 'N',
#   'Havingsharecapital': '',
#   'totalAuthorizedShareCapital': '200000',
#   'totalClassifiedAuthorizedShareCapital': '100000',
#   'totalSubscribedShareCapital': '100000',
#   'totalUnclassifiedAuthorizedShareCapital': '100000',
#   'equitynumberofClasses': '1',
#   'preferencenumberofClasses': '0',
#   'numOfMembers': '2',
#   'SpicePartBAddress': [{'line1': 'C/O Shobha H 33  1st MAIN',
#     'line2': 'MARENAHALLI',
#     'pincode': '560040',
#     'addressType': 'Correspondance Address',
#     'coutry': 'India',
#     'area': 'Vijayanagar (Bangalore)',
#     'city': '',
#     'district': '',
#     'state_ut': '',
#     'mobile': '7975735563',
#     'companymailid': 'ranumahimewada@gmail.com'}],
#   'regaddressline1': 'C/O Shobha H 33  1st MAIN',
#   'regaddressline2': 'MARENAHALLI',
#   'regaddresspincode': '560040',
#   'regaddresscountry': 'India',
#   'regaddresscity': 'Bangalore South',
#   'regaddressdistrict': 'Bangalore',
# ...

# %%
payload5_json=json.dumps(payload5_json)

# %%
#dir_wt_din save
url = 'https://www.mca.gov.in/bin/mca-gov/SpicePartB_SAVESUBMIT'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Content-Type': 'multipart/form-data; boundary=---------------------------385063496230279602103212072529',
    'Content-Length': '5202',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}


multipart_data = MultipartEncoder(fields={
    'data': (payload5_json),
    'action': 'savesubmit',
    'operation': 'Save',
    'serveAction': 'saveForm',
    'referenceNumber': '',
    'formId': ''
})

headers['Content-Type'] = multipart_data.content_type
response = requests.post(url, headers=headers, data=multipart_data)

print(response.text)

# %%
payload6=r'''{"requestBody":{"formData":{"aoaEntrenched":"N","Havingsharecapital":"Having Share Capital","totalAuthorizedShareCapital":"100000","totalClassifiedAuthorizedShareCapital":"100000","totalSubscribedShareCapital":"100000","totalUnclassifiedAuthorizedShareCapital":"0","equitynumberofClasses":"1","preferencenumberofClasses":"0","numOfMembers":"2","SpicePartBAddress":[{"line1":"asdada","line2":"dawsdad","pincode":"560040","addressType":"Correspondance Address","coutry":"India","area":"Vijayanagar (Bangalore)","city":"Bangalore North","district":"Bangalore","state_ut":"Karnataka","mobile":"9898989891","companymailid":"ada@faf.com"}],"regaddressline1":"asdada","regaddressline2":"dawsdad","regaddresspincode":"560040","regaddresscountry":"India","regaddresscity":"Bangalore North","regaddressdistrict":"Bangalore","regaddressstate_ut":"Karnataka","regaddresscompanymailid":"ada@faf.com","regaddressarea":"Vijayanagar (Bangalore)","corresAddrSameRegAddr":"Y","regaddresslongitude":"12","regaddresslatitude":"12","rocName":"Registrar of Companies, Karnataka","SubsrciberDINCount":"1","SubsrciberCountWithoutDIN":"1","NonIndividualCountWithoutDIN":"0","DirectorSubscriberDINCount":"1","DirectorSubscriberWithoutDINCount":"1","DirectorDINCount":"1","DirectorCountWithoutDINCount":"1","opcDetails":{"stampDuty":{"state_ut":"Karnataka","stampDutyElectronicallyPaid":"Yes","stampDutyToBePaidDetails":{"amountForm":20,"amountMOA":1000,"amountAOA":1000}}},"formIntegrationId":"1-4GT5934","SpicePartBShares":[{"classShare":"1","authorizedcapitalsharenumber":"10000","subscribedcapitalsharenumber":"10000","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"100000","subscribedcapitaltotalamount":"100000","sharecategory":"Equity Share"}],"spicePartBNonINDVSubscribers":[],"SpicePartBINDVSubscribers":[],"SpicePartBSubscribers":[{"SubscriberType":"Subscriber CUM Director DIN","din":"08092541","name":"SHOBHA  HANUMAPPA","nationality":"India","firstName":"SHOBHA","category":"Individual First subscribers cum Directors","Surname":"HANUMAPPA","designation":"Director","directorCategory":"Promoter","whetherNonED":"Executive director","emailid":"shobhah888@gmail.com","totalSubscribedShareCapital":"50000","equitynumofclasses":"1","DirectorInterestedEntitiescount":"0","SpicePartBSubsDeclaration":[],"inc9DeclarationFlag1":"N","SpicePartBSubscribersShares":[{"sharecategory":"Equity Share","classShare":"1","subscribedcapitalsharenumber":"5000","subscribedcapitalnominalamountpershare":"10","subscribedcapitaltotalamount":"50000"}],"pan":"","identityProofNumber":""},{"category":"Individual First subscribers cum Directors","SubscriberType":"Subscriber CUM Director No DIN","firstName":"Pratik","Surname":"Agarwal","fatherFirstName":"asds","fatherMiddleName":"ada","fatherSurName":"adsa","gender":"Male","dateOfBirth":"7/9/2000","nationality":"India","placeofBirth":"Koderma","citizenOfIndia":"Y","residentOfIndia":"Y","occupationType":"Private Employment","educationalQualificationothers":"Master degree","pan":"DKJPA2449M","designation":"Director","directorCategory":"Promoter","whetherNonED":"Executive director","MobileNo":"0121212121212","emailid":"f@gmail.com","ResidenseCorespondenceFlag":"N","identityProofDocument":"Aadhar Card","identityProofNumber":"212121212121212","residentialProofDocument":"Bank Statement","residentialProofNumber":"21212121221212","Attachment1":{"fileAttachment":"DKJPA2449M_debb0c0c9_0a4e_4ebe_9578_348213020dc1.jpg"},"Attachment2":{"fileAttachment":"DKJPA2449M_81aee76d_7931_4998_ab52_f3df205125d4 (2).jpg"},"totalSubscribedShareCapital":"50000","equitynumofclasses":"1","DirectorInterestedEntitiescount":"0","SpicePartBSubsDeclaration":[],"inc9DeclarationFlag1":"N","SpicePartBSubscribersShares":[{"sharecategory":"Equity Share","classShare":"1","subscribedcapitalsharenumber":"5000","subscribedcapitalnominalamountpershare":"10","subscribedcapitaltotalamount":"50000"}],"din":"","SpicePartBSubscribersAddress":[{"addressType":"Permanent Address","line1":"asdad","line2":"dasdasd","country":"India","pincode":"560019","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state_ut":"Karnataka"},{"addressType":"Present Address","line1":"asdsad","line2":"dad","country":"India","pincode":"560019","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state_ut":"Karnataka","yearresidenseduration":" 4"}]}],"formAttachment":[{"attachmentLabel":"SpiceBproofAddress","attachmentCategory":"Attachment","activityFileName":"14691f19733dbc38843295f5b4e8fc5e3.jpg","activityFileSrcPath":"171265592","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"244314","attachmentDMSId":"347890979","totalNoOfPages":"1","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171265592:SpiceBproofAddress:Document added successfully.","folderName":"tm6tE1011929468910","folderId":"171265592","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBcopyUtility","attachmentCategory":"Attachment","activityFileName":"download (1).jpg","activityFileSrcPath":"171265592","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"22585","attachmentDMSId":"347891022","totalNoOfPages":"1","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171265592:SpiceBcopyUtility:Document added successfully.","folderName":"171265592","folderId":"171265592","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBidentityPro7B","attachmentCategory":"Attachment","activityFileName":"DKJPA2449M_debb0c0c9_0a4e_4ebe_9578_348213020dc1.jpg","activityFileSrcPath":"171265592","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"106323","attachmentDMSId":"347926914","totalNoOfPages":"1","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171265592:SpiceBidentityPro7B:Document added successfully.","folderName":"171265592","folderId":"171265592","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBProofOfResi7B","attachmentCategory":"Attachment","activityFileName":"DKJPA2449M_81aee76d_7931_4998_ab52_f3df205125d4 (2).jpg","activityFileSrcPath":"171265592","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"73451","attachmentDMSId":"347927158","totalNoOfPages":"1","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171265592:SpiceBProofOfResi7B:Document added successfully.","folderName":"171265592","folderId":"171265592","version":"","addedBy":"Fo User"}]},"status":"Draft/Pending Submission","formDescription":"For Spice+PartB","formName":"SPICE + Part B","formVersion":"01","userId":"BIPULKUMARSINGH6690@GMAIL.COM","integrationId":"1-4GT5931","referenceNumber":"","formAttachment":[{"attachmentLabel":"SpiceBproofAddress","attachmentCategory":"Attachment","activityFileName":"14691f19733dbc38843295f5b4e8fc5e3.jpg","activityFileSrcPath":"171265592","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"244314","attachmentDMSId":"347890979","totalNoOfPages":"1","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171265592:SpiceBproofAddress:Document added successfully.","folderName":"tm6tE1011929468910","folderId":"171265592","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBcopyUtility","attachmentCategory":"Attachment","activityFileName":"download (1).jpg","activityFileSrcPath":"171265592","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"22585","attachmentDMSId":"347891022","totalNoOfPages":"1","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171265592:SpiceBcopyUtility:Document added successfully.","folderName":"171265592","folderId":"171265592","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBidentityPro7B","attachmentCategory":"Attachment","activityFileName":"DKJPA2449M_debb0c0c9_0a4e_4ebe_9578_348213020dc1.jpg","activityFileSrcPath":"171265592","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"106323","attachmentDMSId":"347926914","totalNoOfPages":"1","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171265592:SpiceBidentityPro7B:Document added successfully.","folderName":"171265592","folderId":"171265592","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBProofOfResi7B","attachmentCategory":"Attachment","activityFileName":"DKJPA2449M_81aee76d_7931_4998_ab52_f3df205125d4 (2).jpg","activityFileSrcPath":"171265592","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"73451","attachmentDMSId":"347927158","totalNoOfPages":"1","activityFileDate":"07/08/2023","publicDocument":"Y","activityComments":"171265592:SpiceBProofOfResi7B:Document added successfully.","folderName":"171265592","folderId":"171265592","version":"","addedBy":"Fo User"}],"operation":"Save","action":"savesubmit","srn":"","formIntegrationId":"1-4GT5934","formId":""}}'''

# %%
url = "https://www.mca.gov.in/bin/mca-gov/SpicePartB_SAVESUBMIT"
headers = {
    "Host": "www.mca.gov.in",
    "Cookie": "cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token=eyJhbGciOiJIUzUxMiJ9..sDBdpiVVuWp7NDihEOVHSIHW0cVSkZFj54s_0R94NKUSCZQJJr_QISd26Sns-AZNF1kSxxYVoRh8BupApZ132Q; sessionID=e084ac64-956a-4795-bc39-310fef37cfe9; deviceId=volakx5sla",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0",
    "Accept": "*/*",
    "Accept-Language": "en-US,en;q=0.5",
    "Accept-Encoding": "gzip, deflate",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html",
    "X-Requested-With": "XMLHttpRequest",
    "Content-Type": "multipart/form-data; boundary=---------------------------414149160577139445205473741",
    "Origin": "https://www.mca.gov.in",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "Te": "trailers"
}

multipart_data = MultipartEncoder(fields={
    'data': (payload3_json),
    'action': 'savesubmit',
    'operation': 'Save',
    'serveAction': 'saveForm',
    'referenceNumber': '',
    'formId': ''
})

headers['Content-Type'] = multipart_data.content_type
response = requests.post(url, headers=headers, data=multipart_data)

print(response.text)
# Out:
# {
#
#                     "Error" : "Technical Error Occurred",
#                     "Message": "Error invoking service 'EAI Siebel Adapter', method 'Synchronize' at step 'Insert SR'.(SBL-BPR-00162)\n--\nMethod 'SetFieldValue' of business component 'MCA SpiceB Subscribers' (integration component 'MCASpiceBSubscribers') for record with search specification '[DIN] IS NULL AND [PAN] = \"DKJPA2449M\" AND [Identity Proof No] = \"456640096331\"' returned the following error:\"The value entered in field Gender of buscomp MCA SpiceB Subscribers does not match any value in the bounded pick list PickList Gender.(SBL-DAT-00225)\"(SBL-EAI-04451)"
#
#                     }

# %%
payload4=r'''{"requestBody":{"formData":{"aoaEntrenched":"N","Havingsharecapital":"Having Share Capital","totalAuthorizedShareCapital":"113000","totalClassifiedAuthorizedShareCapital":"13000","totalSubscribedShareCapital":"2000","totalUnclassifiedAuthorizedShareCapital":"100000","equitynumberofClasses":"2","preferencenumberofClasses":"2","numOfMembers":"2","SpicePartBAddress":[{"line1":"asdad","line2":"asdada","pincode":"560019","addressType":"Correspondance Address","coutry":"India","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state_ut":"Karnataka","mobile":"2313131312","companymailid":"asda@gmail.com"}],"regaddressline1":"asdad","regaddressline2":"asdada","regaddresspincode":"560019","regaddresscountry":"India","regaddresscity":"Bangalore South","regaddressdistrict":"Bangalore","regaddressstate_ut":"Karnataka","regaddresscompanymailid":"asda@gmail.com","regaddressarea":"Gaviopuram Extension","corresAddrSameRegAddr":"Y","regaddresslongitude":"11","regaddresslatitude":"21","rocName":"Registrar of Companies, Karnataka","SubsrciberDINCount":"0","SubsrciberCountWithoutDIN":"2","NonIndividualCountWithoutDIN":"0","DirectorSubscriberDINCount":"0","DirectorSubscriberWithoutDINCount":"2","DirectorDINCount":"0","DirectorCountWithoutDINCount":"2","spicePartBNonINDVSubscribers":[],"formIntegrationId":"1-4CXKS24","SpicePartBShares":[{"sharecategory":"Preference Share","classShare":"12","authorizedcapitalsharenumber":"100","subscribedcapitalsharenumber":"0","authorizedcapitalnominalamountpershare":"100","subscribedcapitalnominalamountpershare":"100","authorizedcapitaltotalamount":"10000"},{"sharecategory":"Preference Share","classShare":"13","authorizedcapitalsharenumber":"100","subscribedcapitalsharenumber":"0","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"1000"},{"classShare":"1","authorizedcapitalsharenumber":"100","subscribedcapitalsharenumber":"100","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"1000","subscribedcapitaltotalamount":"1000","sharecategory":"Equity Share"},{"classShare":"2","authorizedcapitalsharenumber":"100","subscribedcapitalsharenumber":"100","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"1000","subscribedcapitaltotalamount":"1000","sharecategory":"Equity Share"}],"SpicePartBINDVSubscribers":[],"SpicePartBSubscribers":[{"category":"Individual First subscribers cum Directors","SubscriberType":"Subscriber CUM Director No DIN","firstName":"Pratik","Surname":"Agarwal","fatherFirstName":"Dilip ","fatherMiddleName":"Kumar","fatherSurName":"Agarwal","gender":"Male","dateOfBirth":"7/9/2000","nationality":"India","placeofBirth":"Jhumri Telaiya","citizenOfIndia":"Y","residentOfIndia":"Y","occupationType":"Student","educationalQualificationothers":"Bachelor's degree","pan":"DKJPA2449M","designation":"Director","directorCategory":"Professional","whetherChairman":"Chairman","whetherNonED":"Executive director","MobileNo":"+916200104066","emailid":"golupratik001@gmail.com","ResidenseCorespondenceFlag":"Y","identityProofDocument":"Aadhar Card","identityProofNumber":"323123123123131","residentialProofDocument":"Mobile bill","residentialProofNumber":"1231231231231313133333333","Attachment1":{"fileAttachment":"DKJPA2449M_Brown Modern Minimalist Graphic Designer Resume (1).pdf"},"Attachment2":{"fileAttachment":"DKJPA2449M_MODEL QUESTIONS 2 Answers.pdf"},"totalSubscribedShareCapital":"1000","equitynumofclasses":"1","preferencenumofclasses":"1","SpicePartBSubsDeclaration":[],"inc9DeclarationFlag1":"N","din":"","SpicePartBSubscribersShares":[{"sharecategory":"Preference Share","classShare":"12","subscribedcapitalsharenumber":"0","subscribedcapitalnominalamountpershare":"100"},{"sharecategory":"Equity Share","classShare":"1","subscribedcapitalsharenumber":"100","subscribedcapitalnominalamountpershare":"10","subscribedcapitaltotalamount":"1000"}],"SpicePartBSubscribersAddress":[{"addressType":"Permanent Address","line1":"asdasda","line2":"asdasd","country":"India","pincode":"560019","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state_ut":"Karnataka"},{"addressType":"Present Address","line1":"asdasda","line2":"asdasd","country":"India","pincode":"560019","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state_ut":"Karnataka","yearresidenseduration":" 2","monthresidenseduration":" 3"}]}]},"status":"Draft/Pending Submission","formDescription":"For Spice+PartB","formName":"SPICE + Part B","formVersion":"01","userId":"BIPULKUMARSINGH6690@GMAIL.COM","integrationId":"1-4CXKS21","referenceNumber":"1-9489120265","formattachList":"[{\"attachmentLabel\":\"SpiceBproofAddress\",\"attachmentCategory\":\"Attachment\",\"activityFileName\":\"1AA290623000151T_RC13062023.pdf\",\"activityFileSrcType\":\"I\",\"activityFileExt\":\"pdf\",\"activityFileSize\":\"81873\",\"attachmentDMSId\":\"345253894\",\"totalNoOfPages\":\"3\",\"activityFileDate\":\"06/26/2023 12:31:16\",\"publicDocument\":\"Y\",\"activityComments\":\"170638497:SpiceBproofAddress:Document added successfully.\",\"versionNo\":\"0\",\"folderName\":\"tbU5W44287200571\",\"addedBy\":\"Fo User\",\"formName\":\"\",\"folderId\":\"170638497\"},{\"attachmentLabel\":\"SpiceBcopyUtility\",\"attachmentCategory\":\"Attachment\",\"activityFileName\":\"NIC-2004_detail_19jan2009.pdf\",\"activityFileSrcType\":\"I\",\"activityFileExt\":\"pdf\",\"activityFileSize\":\"386212\",\"attachmentDMSId\":\"345253994\",\"totalNoOfPages\":\"58\",\"activityFileDate\":\"06/26/2023 12:31:16\",\"publicDocument\":\"Y\",\"activityComments\":\"170638497:SpiceBcopyUtility:Document added successfully.\",\"versionNo\":\"0\",\"folderName\":\"170638497\",\"addedBy\":\"Fo User\",\"formName\":\"\",\"folderId\":\"170638497\"}]","operation":"Save","action":"savesubmit","formId":"","formIntegrationId":"1-4CXKS24","srn":"","formAttachment":[{"attachmentLabel":"SpiceBproofAddress","attachmentCategory":"Attachment","activityFileName":"1AA290623000151T_RC13062023.pdf","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"81873","attachmentDMSId":"345253894","totalNoOfPages":"3","activityFileDate":"06/26/2023 12:31:16","publicDocument":"Y","activityComments":"170638497:SpiceBproofAddress:Document added successfully.","versionNo":"0","folderName":"tbU5W44287200571","addedBy":"Fo User","formName":"","folderId":"170638497"},{"attachmentLabel":"SpiceBcopyUtility","attachmentCategory":"Attachment","activityFileName":"NIC-2004_detail_19jan2009.pdf","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"386212","attachmentDMSId":"345253994","totalNoOfPages":"58","activityFileDate":"06/26/2023 12:31:16","publicDocument":"Y","activityComments":"170638497:SpiceBcopyUtility:Document added successfully.","versionNo":"0","folderName":"170638497","addedBy":"Fo User","formName":"","folderId":"170638497"},{"attachmentLabel":"SpiceBproofAddress","attachmentCategory":"Attachment","activityFileName":"1Brown Modern Minimalist Graphic Designer Resume.pdf","activityFileSrcPath":"170638497","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"1816056","attachmentDMSId":"345261677","totalNoOfPages":"1","activityFileDate":"06/26/2023","publicDocument":"Y","activityComments":"170638497:SpiceBproofAddress:Document added successfully.","folderName":"170638497","folderId":"170638497","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBcopyUtility","attachmentCategory":"Attachment","activityFileName":"AA290623000151T_RC13062023.pdf","activityFileSrcPath":"170638497","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"81873","attachmentDMSId":"345261757","totalNoOfPages":"3","activityFileDate":"06/26/2023","publicDocument":"Y","activityComments":"170638497:SpiceBcopyUtility:Document added successfully.","folderName":"170638497","folderId":"170638497","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBidentityPro7B","attachmentCategory":"Attachment","activityFileName":"DKJPA2449M_Brown Modern Minimalist Graphic Designer Resume (1).pdf","activityFileSrcPath":"170638497","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"1770282","attachmentDMSId":"345343595","totalNoOfPages":"1","activityFileDate":"06/26/2023","publicDocument":"Y","activityComments":"170638497:SpiceBidentityPro7B:Document added successfully.","folderName":"170638497","folderId":"170638497","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBProofOfResi7B","attachmentCategory":"Attachment","activityFileName":"DKJPA2449M_MODEL QUESTIONS 2 Answers.pdf","activityFileSrcPath":"170638497","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"855637","attachmentDMSId":"345344143","totalNoOfPages":"15","activityFileDate":"06/26/2023","publicDocument":"Y","activityComments":"170638497:SpiceBProofOfResi7B:Document added successfully.","folderName":"170638497","folderId":"170638497","version":"","addedBy":"Fo User"}]}}'''

# %%
payload4_json=json.loads(payload4)

# %%
payload4_json['requestBody']
# Out:
# {'formData': {'aoaEntrenched': 'N',
#   'Havingsharecapital': 'Having Share Capital',
#   'totalAuthorizedShareCapital': '113000',
#   'totalClassifiedAuthorizedShareCapital': '13000',
#   'totalSubscribedShareCapital': '2000',
#   'totalUnclassifiedAuthorizedShareCapital': '100000',
#   'equitynumberofClasses': '2',
#   'preferencenumberofClasses': '2',
#   'numOfMembers': '2',
#   'SpicePartBAddress': [{'line1': 'asdad',
#     'line2': 'asdada',
#     'pincode': '560019',
#     'addressType': 'Correspondance Address',
#     'coutry': 'India',
#     'area': 'Gaviopuram Extension',
#     'city': 'Bangalore South',
#     'district': 'Bangalore',
#     'state_ut': 'Karnataka',
#     'mobile': '2313131312',
#     'companymailid': 'asda@gmail.com'}],
#   'regaddressline1': 'asdad',
#   'regaddressline2': 'asdada',
#   'regaddresspincode': '560019',
#   'regaddresscountry': 'India',
#   'regaddresscity': 'Bangalore South',
#   'regaddressdistrict': 'Bangalore',
# ...

# %%
payload5='''{"requestBody":{"formData":{"aoaEntrenched":"N","Havingsharecapital":"Having Share Capital","totalAuthorizedShareCapital":"500000","totalClassifiedAuthorizedShareCapital":"500000","totalSubscribedShareCapital":"100000","totalUnclassifiedAuthorizedShareCapital":"0","equitynumberofClasses":"1","preferencenumberofClasses":"0","numOfMembers":"2","SpicePartBAddress":[{"line1":"ASsdd","line2":"dasdsada","pincode":"560019","addressType":"Correspondance Address","coutry":"India","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state_ut":"Karnataka","mobile":"1312313131","companymailid":"ada@gmail.com"}],"regaddresscountry":"India","corresAddrSameRegAddr":"N","rocName":"Registrar of Companies, Karnataka","SubsrciberDINCount":"0","SubsrciberCountWithoutDIN":"2","NonIndividualCountWithoutDIN":"0","DirectorSubscriberDINCount":"0","DirectorSubscriberWithoutDINCount":"2","DirectorDINCount":"0","DirectorCountWithoutDINCount":"2","spicePartBNonINDVSubscribers":[],"formIntegrationId":"1-4D3JT78","SpicePartBShares":[{"classShare":"1","authorizedcapitalsharenumber":"50000","subscribedcapitalsharenumber":"10000","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"500000","subscribedcapitaltotalamount":"100000","sharecategory":"Equity Share"}],"SpicePartBINDVSubscribers":[],"SpicePartBSubscribers":[{"category":"Individual First subscribers cum Directors","SubscriberType":"Subscriber CUM Director No DIN","firstName":"Pratik ","Surname":"Agarwal","fatherFirstName":"Dilip ","fatherMiddleName":"Kumar","fatherSurName":"Agarwal","gender":"Male","dateOfBirth":"7/9/2000","nationality":"India","placeofBirth":"jhumri telaiya","citizenOfIndia":"Y","residentOfIndia":"Y","occupationType":"Student","educationalQualificationothers":"Bachelor's degree","pan":"DKJPA2449M","designation":"Director","directorCategory":"Promoter","whetherNonED":"Executive director","MobileNo":"06200104066","emailid":"agarwalpratik69@gmail.com","ResidenseCorespondenceFlag":"Y","identityProofDocument":"Aadhar Card","identityProofNumber":"456640096331","residentialProofDocument":"Mobile bill","residentialProofNumber":"1323333333333333333333333","Attachment1":{"fileAttachment":"DKJPA2449M_AA290623000151T_RC13062023.pdf"},"Attachment2":{"fileAttachment":"DKJPA2449M_AA290623000151T_RC13062023.pdf"},"totalSubscribedShareCapital":"75000","equitynumofclasses":"1","DirectorInterestedEntitiescount":"0","SpicePartBSubsDeclaration":[],"inc9DeclarationFlag1":"N","din":"","SpicePartBSubscribersShares":[{"sharecategory":"Equity Share","classShare":"1","subscribedcapitalsharenumber":"7500","subscribedcapitalnominalamountpershare":"10","subscribedcapitaltotalamount":"75000"}],"SpicePartBSubscribersAddress":[{"addressType":"Permanent Address","line1":"adsad","line2":"adad","country":"India","pincode":"560019","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state_ut":"Karnataka"},{"addressType":"Present Address","line1":"adsad","line2":"adad","country":"India","pincode":"560019","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state_ut":"Karnataka","yearresidenseduration":" 2","monthresidenseduration":" 3"}]}]},"status":"Draft/Pending Submission","formDescription":"For Spice+PartB","formName":"SPICE + Part B","formVersion":"01","userId":"BIPULKUMARSINGH6690@GMAIL.COM","integrationId":"1-4D3JT75","referenceNumber":"1-9499152785","operation":"Save","action":"savesubmit","formId":"","formIntegrationId":"1-4D3JT78","srn":"","formAttachment":[{"attachmentLabel":"SpiceBproofAddress","attachmentCategory":"Attachment","activityFileName":"1AA290623000151T_RC13062023.pdf","activityFileSrcPath":"170690894","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"81873","attachmentDMSId":"345457827","totalNoOfPages":"3","activityFileDate":"06/26/2023","publicDocument":"Y","activityComments":"170690894:SpiceBproofAddress:Document added successfully.","folderName":"eR3wf57739036546","folderId":"170690894","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBcopyUtility","attachmentCategory":"Attachment","activityFileName":"AA290623000151T_RC13062023.pdf","activityFileSrcPath":"170690894","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"81873","attachmentDMSId":"345457861","totalNoOfPages":"3","activityFileDate":"06/26/2023","publicDocument":"Y","activityComments":"170690894:SpiceBcopyUtility:Document added successfully.","folderName":"170690894","folderId":"170690894","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBidentityPro7B","attachmentCategory":"Attachment","activityFileName":"DKJPA2449M_AA290623000151T_RC13062023.pdf","activityFileSrcPath":"170690894","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"81873","attachmentDMSId":"345459939","totalNoOfPages":"3","activityFileDate":"06/26/2023","publicDocument":"Y","activityComments":"170690894:SpiceBidentityPro7B:Document added successfully.","folderName":"170690894","folderId":"170690894","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBProofOfResi7B","attachmentCategory":"Attachment","activityFileName":"DKJPA2449M_AA290623000151T_RC13062023.pdf","activityFileSrcPath":"170690894","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"81873","attachmentDMSId":"345459971","totalNoOfPages":"3","activityFileDate":"06/26/2023","publicDocument":"Y","activityComments":"170690894:SpiceBProofOfResi7B:Document added successfully.","folderName":"170690894","folderId":"170690894","version":"","addedBy":"Fo User"}]}}'''

# %%
payload5_json=json.loads(payload5)

# %%
payload5_json['requestBody']['formData']
# Out:
# {'aoaEntrenched': 'N',
#  'Havingsharecapital': 'Having Share Capital',
#  'totalAuthorizedShareCapital': '500000',
#  'totalClassifiedAuthorizedShareCapital': '500000',
#  'totalSubscribedShareCapital': '100000',
#  'totalUnclassifiedAuthorizedShareCapital': '0',
#  'equitynumberofClasses': '1',
#  'preferencenumberofClasses': '0',
#  'numOfMembers': '2',
#  'SpicePartBAddress': [{'line1': 'ASsdd',
#    'line2': 'dasdsada',
#    'pincode': '560019',
#    'addressType': 'Correspondance Address',
#    'coutry': 'India',
#    'area': 'Gaviopuram Extension',
#    'city': 'Bangalore South',
#    'district': 'Bangalore',
#    'state_ut': 'Karnataka',
#    'mobile': '1312313131',
#    'companymailid': 'ada@gmail.com'}],
#  'regaddresscountry': 'India',
#  'corresAddrSameRegAddr': 'N',
#  'rocName': 'Registrar of Companies, Karnataka',
#  'SubsrciberDINCount': '0',
#  'SubsrciberCountWithoutDIN': '2',
#  'NonIndividualCountWithoutDIN': '0',
#  'DirectorSubscriberDINCount': '0',
# ...

# %%
#ao code trial
import requests

url = "https://www.mca.gov.in/bin/fillip/fillipAoCode"
params = {
    "AO_NO": "2",
    "AO_CODE": "TKAR",
    "RANGE_CODE": "182",
    "AO_TYPE": "WT"
}

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/115.0",
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "Accept-Language": "en-US,en;q=0.5",
    "Accept-Encoding": "gzip, deflate",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html",
    "X-Requested-With": "XMLHttpRequest",
    "Cookie": "cookiesession1=678B28691F6518167EE395808C55BE5E; alertPopup=true; deviceId=czl2bunr1i; session-token=eyJhbGciOiJIUzUxMiJ9..d7ltRvsQM6ow6h_dgDQVK_2PBjYKXjFCdvwSdQdS-gjEC3dbzg4C8nJCEL0Q-GLThXvHX0syIAFi3cq7iWT4Bw; sessionID=c9e5e54e-11f9-4a74-bcd3-a44e970180ac",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin"
}

response = requests.get(url, params=params, headers=headers)

# Check if the request was successful (status code 200)
if response.status_code == 200:
    # Access the response content (JSON, text, etc.)
    response_data = response.json()  # Assuming the response is in JSON format
    print(response_data)
else:
    print("Request failed with status code:", response.status_code)
# Out:
# {'resCode': 200, 'resStr': '{\n        \t\t\n        \t\t"message":"Data fetched Successfully",\n        \t\t"data":{"is_valid":1}\n        \t}'}

# %%
response.links
# Out:
# {}
