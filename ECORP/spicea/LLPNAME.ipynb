# %%
# %run names.py

keywords = 'technology medical equipments creation '
description = 'technology medical equipments creation'

business_names = fetch_business_names(keywords, description)

# %%
business_names
# Out:
# ['DIGINS LLP',
#  'DATIONS LLP',
#  'MACHING LLP',
#  'TECHINE LLP',
#  'PATIVE LLP',
#  'BIOENTS LLP',
#  'SCIENTS LLP',
#  'MEDICIAL LLP',
#  'SCIENE LLP',
#  'ORICS LLP',
#  'MORAGE LLP',
#  'MEDICIA LLP',
#  'TECHNIIC LLP',
#  'MEDYGRIC LLP',
#  'TECHNOLO LLP',
#  'PERIAL LLP',
#  'SOCIAN LLP',
#  'CORPMENT LLP',
#  'ORIGITAL LLP',
#  'SCIENCESS LLP',
#  'ANATION LLP',
#  'PANATURE LLP',
#  'TENETICS LLP',
#  'ANTER LLP',
#  'ELECTROL LLP',
#  'SCIENTAL LLP',
#  'SYNATURE LLP',
#  'REMEDIA LLP',
#  'DENTIVE LLP',
#  'INTERS LLP',
#  'BACKET LLP',
#  'SCIENET LLP',
#  'TECHYSIC LLP',
#  'HEALINIC LLP',
#  'PATIC LLP',
#  'BION LLP',
#  'PEERIAN LLP',
#  'TECHANIC LLP',
#  'SEXYMENT LLP',
#  'ANTISM LLP',
#  'ARTIME LLP',
#  'INVENTAL LLP',
#  'SOCIALA LLP',
#  'TECHINO LLP',
#  'MEDICMECH LLP',
#  'PROGUE LLP',
#  'PEERCE LLP',
#  'COMPUTERY LLP',
#  'CLIXLIFE LLP',
#  'BIOTICAL LLP',
#  'TECHEMIC LLP',
#  'INTIALS LLP',
#  'DESIGNAL LLP',
#  'HEALLIFE LLP',
#  'MEDICPORT LLP',
#  'APPTRICS LLP',
#  'AERONICS LLP',
#  'PRACTION LLP',
#  'STURE LLP',
#  'THERAPHY LLP',
#  'SILITY LLP',
#  'FINANCY LLP',
#  'TECHNIICS LLP',
#  'TECHEMEN LLP',
#  'MASTICS LLP',
#  'CHRHIFE LLP',
#  'DIGIOUS LLP',
#  'CRATICS LLP',
#  'ASYSTEM LLP',
#  'DATASY LLP',
#  'MEDTENT LLP',
#  'MEDITAL LLP',
#  'PRACTICS LLP',
#  'TECHSIST LLP',
#  'MENTIVE LLP',
#  'SCIETAL LLP',
#  'EDUCATIC LLP',
#  'GRAPYLUX LLP',
#  'MEDICIAN LLP',
#  'CHACHINE LLP',
#  'MEDICLAB LLP',
#  'ELITECH LLP',
#  'TECHTECH LLP',
#  'NTECHNOLOGY LLP',
#  'TECHNOLGY LLP',
#  'GTECHNOLOGY LLP',
#  'BIPMENT LLP',
#  'BITRONICS LLP',
#  'GCREATION LLP',
#  'TECHRONIC LLP',
#  'TUROLOGY LLP',
#  'MASTECH LLP',
#  'CHROLOGY LLP',
#  'ELETRICS LLP',
#  'MOTECH LLP',
#  'TECHROLOGY LLP',
#  'CNOLOGY LLP',
#  'BIOMATIC LLP',
#  'DOBOTICS LLP',
#  'EXOMEDICAL LLP',
#  'MMEDICAL LLP',
#  'TECHN LLP',
#  'KARMATIC LLP',
#  'HEROLOGY LLP',
#  'TECHNOLOGYGY LLP',
#  'TTECHNOLOGY LLP',
#  'ENTECH LLP',
#  'RCREATION LLP',
#  'TECHNICK LLP',
#  'COMPUTERY LLP',
#  'GAMEDICINE LLP',
#  'CCREATION LLP',
#  'INTECH LLP',
#  'OUTICS LLP',
#  'METAMEDICAL LLP',
#  'TECHNIST LLP',
#  'TECHATION LLP',
#  'NANOLOGY LLP',
#  'VRTRONICS LLP',
#  'CHROLOGY LLP',
#  'VETECH LLP',
#  'TECHSIGHT LLP',
#  'TECHIP LLP',
#  'METRONICS LLP',
#  'TECHR LLP',
#  'NNOLOGY LLP',
#  'BIOMATOR LLP',
#  'NMEDICAL LLP',
#  'NITRONICS LLP',
#  'NEWGENICS LLP',
#  'MEDICALA LLP',
#  'TECHSCOPY LLP',
#  'RAMEDICINE LLP',
#  'BIOMEDICS LLP',
#  'ONCOLOGY LLP',
#  'TECHG LLP',
#  'BIOTIICS LLP',
#  'TECHP LLP',
#  'TECHD LLP',
#  'MEDICINET LLP',
#  'OPTOMEDIC LLP',
#  'TECHB LLP',
#  'RUPTECH LLP',
#  'CYBERAPY LLP',
#  'QTECHNIC LLP',
#  'TECHPUTER LLP',
#  'MEDICALTY LLP',
#  'TELETRIC LLP',
#  'COMPUTIC LLP',
#  'CMEDICAL LLP',
#  'SCIENTIV LLP',
#  'GMEDICAL LLP',
#  'ACTRONICS LLP',
#  'GAMEDICAL LLP',
#  'SCIENICS LLP',
#  'TECHNISTRY LLP',
#  'TECHNICS LLP',
#  'TECTRONICS LLP',
#  'OEQUIPMENTS LLP',
#  'HEALTLAB LLP',
#  'MEDICLAB LLP',
#  'FORMSCAL LLP',
#  'EDUCATIC LLP',
#  'SOCIALA LLP',
#  'CARDRY LLP',
#  'TECHINE LLP',
#  'TECHPUTE LLP',
#  'TECHWIRE LLP',
#  'SCIENCH LLP',
#  'TECHANIC LLP',
#  'ACTICS LLP',
#  'MEDICALB LLP',
#  'MONOMIC LLP',
#  'TECHAND LLP',
#  'TECHNOST LLP',
#  'TECHNOLOG LLP',
#  'MEDICMARY LLP',
#  'TECHMENT LLP',
#  'TECHSIGHT LLP',
#  'TECHNEWS LLP',
#  'TECHINO LLP',
#  'PLASTROL LLP',
#  'CURRICAL LLP',
#  'PHYSIONS LLP',
#  'TECHSPOT LLP',
#  'HELISTIC LLP',
#  'DIGIN LLP',
#  'TECHNOVA LLP',
#  'DIGIES LLP',
#  'HISTRY LLP',
#  'SOCIALSE LLP',
#  'STRIALS LLP',
#  'TECHN LLP',
#  'SOCIAN LLP',
#  'MEDICALN LLP',
#  'HEALE LLP',
#  'ANTIVE LLP',
#  'HEATION LLP',
#  'MEDICALE LLP',
#  'ACTORY LLP',
#  'ASTRICS LLP',
#  'TECHRHINE LLP',
#  'INTIVE LLP',
#  'PREMEDIA LLP',
#  'TECHT LLP',
#  'TECHANITY LLP',
#  'TECHNOB LLP',
#  'MINIC LLP',
#  'GENION LLP',
#  'TECHBOOK LLP',
#  'TECHPOINT LLP',
#  'SOCIALAB LLP',
#  'DEVICESS LLP',
#  'SCIENTA LLP',
#  'TECHILD LLP',
#  'ARTINGS LLP',
#  'NONRY LLP',
#  'PRINVENT LLP',
#  'TECHCAPE LLP',
#  'PEDAGON LLP',
#  'TECHMENTS LLP',
#  'SCIENTIVE LLP',
#  'TECHANDS LLP',
#  'MINICAL LLP',
#  'TECHNOLD LLP',
#  'TECHZONE LLP',
#  'MILITIC LLP',
#  'MEDICALT LLP',
#  'TECHCARE LLP',
#  'HISTICS LLP',
#  'TECHENOR LLP',
#  'DIGITARY LLP',
#  'BIONS LLP',
#  'MILITAL LLP',
#  'SCIENTS LLP',
#  'MEDICMART LLP',
#  'PATIC LLP',
#  'TECHHOME LLP',
#  'PHYSICINE LLP',
#  'TECHG LLP']

# %%
c_name='MEDTECH FORALL LLP'

# %%
import requests
import json
from requests_toolbelt.multipart.encoder import MultipartEncoder

url = "https://www.mca.gov.in/bin/mca/login"
# url = "https://130.59.142.2/bin/mca/login"


headers = {
    "Origin": "www.mca.gov.in",
    "Content-Length": "231",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.5672.127 Safari/537.36",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Accept": "*/*",
    "X-Requested-With": "XMLHttpRequest",
    "Sec-Ch-Ua-Platform": "Windows"
}

data = "data=Ut8pBOc0RSM6iYqffqN1orWH0Ee6A57QEKGmyHa5KnuzzybQ%2BjY2pMJIsLZw9DznTxfJeWvJFEcqsU2aZC33AC2nYaU60TNo8VjomCHN2dDSdHEC2enwIeEWCNR42vj7gfXFsvEwLfoO25%2BUKeho6%2B3l%2FkhEucDAzA4XeVNg0dhlBlgG95nyBiwYk3XhQoJtHSgqcb%2FI8MCyxN9h1unz%2Fw%3D%3D"

response = requests.post(url, headers=headers, data=data)
# print(response.status_code)


set_cookie_value = response.headers.get('Set-Cookie')

start_index = set_cookie_value.find("session-token=") + len("session-token=")
end_index = set_cookie_value.find(";", start_index)
session_token = set_cookie_value[start_index:end_index]

# %%
payload4=r'''{"requestBody":{"formData":{"purpose":"New Incorporation","proposedname1":"ZIZZAGGGGG LLP","formIntegrationId":"1686922988308_FOUSER","NICcode1":"98200","NICCode1Desc":"Undifferentiated service-producing activities of private households for own use","NICcode2":"98100","NICCode2Desc":"Undifferentiated goods-producing activities of private households for own use","NICcode3":"","NICCode3Desc":"","formAttachment":[]},"formDescription":"RUN LLP","formName":"RUN LLP","formVersion":"1.1","userId":"BIPULKUMARSINGH6690@GMAIL.COM","integrationId":"1686922988308_FOUSER","status":"Draft/Pending Submission"}}'''
payload4_json=json.loads(payload4)
payload4_json['requestBody']['formData']['proposedname1']=c_name
payload4_json=json.dumps(payload4_json)

# %%
import requests

url = "https://www.mca.gov.in/bin/mca-gov/RunLLPSaveSubmit"

headers = {
    "Host": "www.mca.gov.in",
    "Cookie": f"cookiesession1=678B28695C218253C321286001478935; alertPopup=true; session-token={session_token}",
    "Sec-Ch-Ua-Mobile": "?0",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.110 Safari/537.36",
    "Content-Type": "multipart/form-data; boundary=----WebKitFormBoundary0AN6dHNNjREqqUBN",
    "Accept": "*/*",
    "Csrf-Token": "undefined",
    "X-Requested-With": "XMLHttpRequest",
    "Sec-Ch-Ua-Platform": "",
    "Origin": "https://www.mca.gov.in",
    "Sec-Fetch-Site": "same-origin",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Dest": "empty",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/run-llp.html",
    "Accept-Encoding": "gzip, deflate",
    "Accept-Language": "en-US,en;q=0.9"
}

multipart_data = MultipartEncoder(fields={
    'data': (None, payload4_json),
    'action': (None, 'savesubmit'),
    'operation': (None, 'Submit'),
    'serveAction': (None, 'validateform')
})

headers['Content-Type'] = multipart_data.content_type

response = requests.post(url, headers=headers, data=multipart_data)
print(response.status_code)
print(response.text)
# Out:
# 200
# {"message":"","error":"","data":{"referenceNumber":"1-9894974630","dateTime":"","integrationId":"1-4JN7NAE","formIntegrationId":"1-4JN7NDS","srnStatus":"Draft/Pending Submission","formType":"","srn":""},"validationResponse":{"submissionRestricted":false,"validationresposeBody":[{"proposedName1":"MEDTECH FORALL LLP","alertDescription":"Please note that the proposed name is similar to the name of an existing Company / LLP WELLNESS FORALL LLP as per Section 15(2), Limited Liability Partnership Act, 2008. Please attach No Objection Certificate (NOC), if applicable","alertCategory":"WM_1","alertType":"Info"},{"proposedName1":"MEDTECH FORALL LLP","alertDescription":"Proposed name MEDTECH FORALL LLP is similar to the name of struck off company MEDTECH HEALTHCARE PRIVATE LIMITED and not allowed for twenty years from the date of such striking off. Please check the name and change the proposed name, if applicable.","alertCategory":"WM_3","alertType":"Info"},{"alertType":"","alertDescription":"","alertCategory":""},{"alertType":"","alertDescription":"","alertCategory":""},{"alertType":"","alertDescription":"","alertCategory":""},{"alertType":"","alertDescription":"","alertCategory":""},{"alertType":"","alertDescription":"","alertCategory":""},{"alertType":"","alertDescription":"","alertCategory":""},{"alertType":"","alertDescription":"","alertCategory":""},{"alertType":"","alertDescription":"","alertCategory":""}]},"alertInfo":[],"alertWarn":[],"alertError":[],"errorTab":[{"proposedName1":"MEDTECH FORALL LLP","alertDescription":"Please note that the proposed name is similar to the name of an existing Company / LLP WELLNESS FORALL LLP as per Section 15(2), Limited Liability Partnership Act, 2008. Please attach No Objection Certificate (NOC), if applicable","alertCategory":"WM_1","alertType":"Info"},{"proposedName1":"MEDTECH FORALL LLP","alertDescription":"Proposed name MEDTECH FORALL LLP is similar to the name of struck off company MEDTECH HEALTHCARE PRIVATE LIMITED and not allowed for twenty years from the date of such striking off. Please check the name and change the proposed name, if applicable.","alertCategory":"WM_3","alertType":"Info"}],"supportDataTab":[[{"companyOldName":"","acntType":"LLP","companyLlpNumber":"AAR-7466","companyStatus":"Active","score":119.46112,"companyName":"WELLNESS FORALL LLP"},{"companyOldName":"","acntType":"Company","companyLlpNumber":"U15400MP2015PTC033634","companyStatus":"Active","score":117.54845,"companyName":"FORALL FOODS PRIVATE LIMITED"},{"companyOldName":"","acntType":"Company","companyLlpNumber":"U18129DL2023PTC411403","companyStatus":"Active","score":117.54845,"companyName":"SUSHKAM FORALL PRIVATE LIMITED"}],[{"companyOldName":"","acntType":"Company","companyLlpNumber":"U33110DL1995PTC070308","companyStatus":"Struck off","score":85.76187,"companyName":"MEDTECH HEALTHCARE PRIVATE LIMITED"},{"companyOldName":"","acntType":"Company","companyLlpNumber":"U99999MH1988PTC048099","companyStatus":"Struck off","score":85.76187,"companyName":"MED-TECH EQUIPMENTS PRIVATE LIMITED"},{"companyOldName":"","acntType":"Company","companyLlpNumber":"U17290TZ2014PTC020507","companyStatus":"Struck off","score":85.76187,"companyName":"SKL MEDTECH PRIVATE LIMITED"},{"companyOldName":"","acntType":"Company","companyLlpNumber":"U33300TN2016PTC113172","companyStatus":"Struck off","score":85.76187,"companyName":"VRIKSHA MEDTECH PRIVATE LIMITED"},{"companyOldName":"","acntType":"Company","companyLlpNumber":"U72200AS2011PTC010774","companyStatus":"Struck off","score":85.76187,"companyName":"MEDTECH SOLUTIONS PRIVATE LIMITED"},{"companyOldName":"","acntType":"Company","companyLlpNumber":"U74900PN2013PTC145905","companyStatus":"Struck off","score":85.76187,"companyName":"INTRAXIS MEDTECH PRIVATE LIMITED"},{"companyOldName":"","acntType":"Company","companyLlpNumber":"U24239DL2000PTC107926","companyStatus":"Struck off","score":85.76187,"companyName":"CREATIVE MEDTECH PRIVATE LIMITED"},{"companyOldName":"","acntType":"Company","c ...

# %%
import requests
import urllib.parse
import json

def check_alert_descriptions(business_names):
    url = "https://www.mca.gov.in/bin/mca-gov/RunLLPSaveSubmit"

    headers = {
        "Host": "www.mca.gov.in",
        "Cookie": f"cookiesession1=678B28695C218253C321286001478935; alertPopup=true; session-token={session_token}",
        "Sec-Ch-Ua-Mobile": "?0",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.110 Safari/537.36",
        "Content-Type": "multipart/form-data; boundary=----WebKitFormBoundary0AN6dHNNjREqqUBN",
        "Accept": "*/*",
        "Csrf-Token": "undefined",
        "X-Requested-With": "XMLHttpRequest",
        "Sec-Ch-Ua-Platform": "",
        "Origin": "https://www.mca.gov.in",
        "Sec-Fetch-Site": "same-origin",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Dest": "empty",
        "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/run-llp.html",
        "Accept-Encoding": "gzip, deflate",
        "Accept-Language": "en-US,en;q=0.9"
    }

    empty_alert_names = []
    
    multipart_data = MultipartEncoder(fields={
        'data': (None, payload4_json),
        'action': (None, 'savesubmit'),
        'operation': (None, 'Submit'),
        'serveAction': (None, 'validateform')
    })

    headers['Content-Type'] = multipart_data.content_type

    def has_empty_alert(name):
        multipart_data.fields['data'] = (None, name)

        response = requests.post(url, headers=headers, data=multipart_data)
        result = response.json()
        alert_list = result['validationResponse']['validationresposeBody']
        all_empty = all(not item['alertDescription'] for item in alert_list)
		
        return all_empty

    # Iterate through the business_names and check for empty alert descriptions
    for name in business_names:
        if has_empty_alert(name):
            print(name)
            empty_alert_names.append(name)
        else:
            print()
    return empty_alert_names

# %%
# business_names = ["DECORPLANNER LLP", "PLANNINGPROS LLP", "EVENTENSEMBLE LLP", "EVENTATION LLP"]

empty_alert_names = check_alert_descriptions(business_names)
print(empty_alert_names)
# Out:
# ---------------------------------------------------------------------------
# BadStatusLine                             Traceback (most recent call last)
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\http\client.py:306, in HTTPResponse._read_status(self)
#     305     if status < 100 or status > 999:
# --> 306         raise BadStatusLine(line)
#     307 except ValueError:
#
# BadStatusLine: HTTP/1.1   0 Init
#
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     785     e = ProtocolError("Connection aborted.", e)
# --> 787 retries = retries.increment(
#     788     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     789 )
#     790 retries.sleep()
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\util\retry.py:550, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     549 if read is False or not self._is_method_retryable(method):
# --> 550     raise six.reraise(type(error), error, _stacktrace)
#     551 elif read is not None:
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\packages\six.py:769, in reraise(tp, value, tb)
#     768 if value.__traceback__ is not tb:
# --> 769     raise value.with_traceback(tb)
#     770 raise value
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:703, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     702 # Make the request on the httplib connection object.
# --> 703 httplib_response = self._make_request(
#     704     conn,
#     705     method,
#     706     url,
#     707     timeout=timeout_obj,
#     708     body=body,
#     709     headers=headers,
#     710     chunked=chunked,
#     711 )
#     713 # If we're going to release the connection in ``finally:``, then
#     714 # the response doesn't need to know about the connection. Otherwise
#     715 # it will also try to release it and we'll have a double-release
#     716 # mess.
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:449, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     445         except BaseException as e:
#     446             # Remove the TypeError from the exception chain in
#     447             # Python 3 (including for exceptions like SystemExit).
#     448             # Otherwise it looks like a bug in the code.
# --> 449             six.raise_from(e, None)
#     450 except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# File <string>:3, in raise_from(value, from_value)
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\site-packages\urllib3\connectionpool.py:444, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     443 try:
# --> 444     httplib_response = conn.getresponse()
#     445 except BaseException as e:
#     446     # Remove the TypeError from the exception chain in
#     447     # Python 3 (including for exceptions like SystemExit).
#     448     # Otherwise it looks like a bug in the code.
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\http\client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\http\client.py:306, in HTTPResponse._read_status(self)
#     305     if status < 100 or status > 999:
# --> 306         raise BadStatusLine(line)
#     307 except ValueError:
#
# ProtocolError: ('Connection aborted.', BadStatusLine('HTTP/1.1   0 Init\r\n'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[16], line 3
#       1 # business_names = ["DECORPLANNER LLP", "PLANNINGPROS LLP", "EVENTENSEMBLE LLP", "EVENTATION LLP"]
# ----> 3 empty_alert_names = check_alert_descriptions(business_names)
#       4 print(empty_alert_names)
#
# Cell In[15], line 50, in check_alert_descriptions(business_names)
#      48 # Iterate through the business_names and check for empty alert descriptions
#      49 for name in business_names:
# ---> 50     if has_empty_alert(name):
#      51         print(name)
#      52         empty_alert_names.append(name)
#
# Cell In[15], line 41, in check_alert_descriptions.<locals>.has_empty_alert(name)
#      38 def has_empty_alert(name):
#      39     multipart_data.fields['data'] = (None, name)
# ---> 41     response = requests.post(url, headers=headers, data=multipart_data)
#      42     result = response.json()
#      43     alert_list = result['validationResponse']['validationresposeBody']
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)
#     112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\golup\AppData\Local\Programs\Python\Python311\Lib\site-packages\requests\adapters.py:501, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#    (...)
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
# --> 501     raise ConnectionError(err, request=request)
#     503 except MaxRetryError as e:
#     504     if isinstance(e.reason, ConnectTimeoutError):
#     505         # TODO: Remove this in 3.0.0: see #2811
#
# ConnectionError: ('Connection aborted.', BadStatusLine('HTTP/1.1   0 Init\r\n'))

# %%
def check_alert_descriptions(name, name_list, session_token):
    url = "https://www.mca.gov.in/bin/mca-gov/RunLLPSaveSubmit"
    headers = {
        "Host": "www.mca.gov.in",
        "Cookie": f"cookiesession1=678B28695C218253C321286001478935; alertPopup=true; session-token={session_token}",
        "Sec-Ch-Ua-Mobile": "?0",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.110 Safari/537.36",
        "Content-Type": "multipart/form-data; boundary=----WebKitFormBoundary0AN6dHNNjREqqUBN",
        "Accept": "*/*",
        "Csrf-Token": "undefined",
        "X-Requested-With": "XMLHttpRequest",
        "Sec-Ch-Ua-Platform": "",
        "Origin": "https://www.mca.gov.in",
        "Sec-Fetch-Site": "same-origin",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Dest": "empty",
        "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/run-llp.html",
        "Accept-Encoding": "gzip, deflate",
        "Accept-Language": "en-US,en;q=0.9"
    }
    empty_alert_names = []

    def has_empty_alert(name):
        # payload4_json = json.dumps({"llpType": "LLP", "defaultValues": {}, "proposedLLPName": name})
            
        multipart_data = MultipartEncoder(fields={
            'data': (None, payload4_json),
            'action': (None, 'savesubmit'),
            'operation': (None, 'Submit'),
            'serveAction': (None, 'validateform')
        })

        headers['Content-Type'] = multipart_data.content_type

        response = requests.post(url, headers=headers, data=multipart_data)
        result = response.json()
        alert_list = result['validationResponse']['validationresposeBody']
        all_empty = all(not item['alertDescription'] for item in alert_list)
        
        return all_empty

    # Iterate through the business_names and check for empty alert descriptions
    for name in business_names:
        if has_empty_alert(name):
            print(name)
            empty_alert_names.append(name)
        else:
            print()

    return empty_alert_names

# Example usage
# business_names = ["Business1", "Business2"]
business_names = ["DECORPLANNER LLP", "PLANNINGPROS LLP", "EVENTENSEMBLE LLP", "EVENTATION LLP"]
empty_alert_names = check_alert_descriptions(c_name, business_names, session_token)
print(empty_alert_names)
# check_alert_descriptions(business_names)
# Out:
# []

# %%
import requests
from requests_toolbelt import MultipartEncoder
import urllib.parse
import json

def check_alert_descriptions(business_names):
    url = "https://www.mca.gov.in/bin/mca-gov/RunLLPSaveSubmit"

    headers = {
        "Host": "www.mca.gov.in",
        "Cookie": f"cookiesession1=678B28695C218253C321286001478935; alertPopup=true; session-token={session_token}",
        "Sec-Ch-Ua-Mobile": "?0",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.110 Safari/537.36",
        "Content-Type": "multipart/form-data; boundary=----WebKitFormBoundary0AN6dHNNjREqqUBN",
        "Accept": "*/*",
        "Csrf-Token": "undefined",
        "X-Requested-With": "XMLHttpRequest",
        "Sec-Ch-Ua-Platform": "",
        "Origin": "https://www.mca.gov.in",
        "Sec-Fetch-Site": "same-origin",
        "Sec-Fetch-Mode": "cors",
        "Sec-Fetch-Dest": "empty",
        "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/llp-e-filling/run-llp.html",
        "Accept-Encoding": "gzip, deflate",
        "Accept-Language": "en-US,en;q=0.9"
    }

    empty_alert_names = []

    def has_empty_alert(name):
        payload4_json = json.loads(r'''{"requestBody":{"formData":{"purpose":"New Incorporation","proposedname1":"ZIZZAGGGGG LLP","formIntegrationId":"1686922988308_FOUSER","NICcode1":"98200","NICCode1Desc":"Undifferentiated service-producing activities of private households for own use","NICcode2":"98100","NICCode2Desc":"Undifferentiated goods-producing activities of private households for own use","NICcode3":"","NICCode3Desc":"","formAttachment":[]},"formDescription":"RUN LLP","formName":"RUN LLP","formVersion":"1.1","userId":"BIPULKUMARSINGH6690@GMAIL.COM","integrationId":"1686922988308_FOUSER","status":"Draft/Pending Submission"}}''')

        payload4_json['requestBody']['formData']['proposedname1'] = name
        payload4_json = json.dumps(payload4_json)

        multipart_data = MultipartEncoder(fields={
            'data': (None, payload4_json),
            'action': (None, 'savesubmit'),
            'operation': (None, 'Submit'),
            'serveAction': (None, 'validateform')
        })

        headers['Content-Type'] = multipart_data.content_type

        try:
            response = requests.post(url, headers=headers, data=multipart_data)
            result = response.json()
            alert_list = result['validationResponse']['validationresposeBody']
            all_empty = all(not item['alertDescription'] for item in alert_list)
            return all_empty
        except (requests.RequestException, ValueError) as e:
            print(f"Error occurred for name: {name}. Error message: {str(e)}")
            return False

    # Iterate through the business_names and check for empty alert descriptions
    for name in business_names:
        if has_empty_alert(name):
            print(name)
            empty_alert_names.append(name)
        else:
            print()

    return empty_alert_names

# Example usage
# business_names = ["Business1", "Business2"]
# business_names = ["DECORPLANNER LLP", "PLANNINGPROS LLP", "EVENTENSEMBLE LLP", "EVENTATION LLP"]
# business_names=['CULTURE CATERER LLP', 'PARTY POINTE LLP', 'THEME PLANNER LLP', 'EXCELLENT EVENT LLP', 'EVENT FROSTING LLP', 'MAGIC PLANNER LLP', 'GLITTER GURU LLP', 'FEST EVENT LLP', 'EVENT SIZZLE LLP', 'ESPRESSO EVENT LLP', 'EDIBLE DESIGN LLP', 'UPBEAT CATERING LLP', 'MANGEMENT MINDSET LLP', 'TOP FESTIVITIES LLP', 'CUPID PARTY LLP', 'CATERED UP LLP', 'THE EVENTLYST LLP', 'FRINGE CATERER LLP', 'TASTY EVENTS LLP', 'ELEGANT PLANNER LLP', 'SEEDLING EVENTI LLP', 'GALA VENUE LLP', 'DAZZLING DECORATOR LLP', 'BELLY BUFFET LLP', 'FEAST BUDDY LLP', 'CATERING HUB LLP', 'MIDNIGHT DECOR LLP', 'DECORATE TOGETHER LLP', 'LUXE CATER LLP', 'DINING DESIGNER LLP', 'PARTIES UNLIMITED LLP', 'EVENTLY DONE LLP', 'EVENT GENIUS LLP', 'FLORAL GALA LLP', 'PEASY CATER LLP', 'HOSTING ASSIST LLP', 'CATERER HQ LLP', 'CATERING BLOOM LLP', 'BALLROOM DESIGN LLP', 'WRAPPED&CATERED LLP', 'EVENTFUL MGMT LLP', 'BEST EVENT LLP', 'PEOPLE CATER LLP', 'SUCCESS MENU LLP', 'FESTIVE FIRM LLP', 'AURA CATERWORKS LLP', 'CHIC CATERING LLP', 'NETWORK PLANNER LLP', 'SCHEME PLANNER LLP', 'MODEL EVENT LLP', 'ALLURE AFFAIRS LLP', 'HOST CRAFT LLP', 'MOOD MAVENS LLP', 'EVENTFUL EVENTS LLP', 'EVENTIDE SOLUTIONS LLP', 'PICNIC PARTNER LLP', 'FETE MAKERS LLP', 'PICNIC CO LLP', 'MARQUEE MASTER LLP', 'SOIREE SCAPE LLP', 'VENUE WISH LLP', 'FANCY FLAVORS LLP', 'CELEBRATION CREATORS LLP', 'GALLERIA CATERING LLP', 'PARTY PLANNERZ LLP', 'DECOR DIVAS LLP', 'RELAXING GATHERINGS LLP', 'BANQUET BOSS LLP', 'FESTIVE NEST LLP', 'EVENTO HIVE LLP', 'SUBSET EVENTS LLP', 'MARKETABLE MENU LLP', 'VENUE MIX LLP', 'SMART PLANNERS LLP', 'CELEBRATE FEST LLP', 'GATHERINGS GALORE LLP', 'CELEBRATE PLUS LLP', 'PRESENT PERFECTION LLP', 'PARTY SAVVY LLP', 'CELEBRATE SOLUTIONS LLP', 'ACTION ARRANGE LLP', 'JOYFUL FESTIVITIES LLP', 'CELEBRATE CO LLP', 'SPECTACULAR AFFAIR LLP', 'CHIC DESIGNS LLP', 'THEMED HAVEN LLP', 'MY FEST LLP', 'SASSY SUPPLIES LLP', 'LUCRATIVE LUNCHES LLP', 'CATERED CREATIONS LLP', 'OCCASIONAL OASIS LLP', 'SPECTACULAR STAGING LLP', 'HORIZON GALA LLP', 'PLAN CRAFTERS LLP', 'PARTY EXPERT LLP', 'PICNIC PERFECT LLP', 'CULINARY WAVE LLP', 'ELEGANT EXPERIENCE LLP', 'GRACEFUL EVENTFUL LLP', 'TASTY TERRA LLP', 'EVENTFUL PLANNING LLP', 'EAT MEETING LLP', 'ARENA ARTISAN LLP', 'ACTIV EVENTO LLP', 'DECORATE MIX LLP', 'THE EVENTY LLP', 'CATERED AFFAIR LLP', 'THE CATERER LLP', 'ELITE PLANNING LLP', 'CHAPTER MANAGEMENT LLP', 'ELEGANT FESTIVITIES LLP', 'THE GALA LLP', 'CATERED MANN LLP', 'PARTY PLANNER LLP', 'BANQUET BRIDGE LLP', 'CEILING EVENT LLP', 'ELEGANT EVENTS LLP', 'OCCASION OASIS LLP', 'DELUXE DECOR LLP', 'BOLD BANQUET LLP', 'SCENE CATERING LLP', 'EATAND PLAN LLP', 'EVENT MIXER LLP', 'DECOR DELUXE LLP', 'GLITZ PLANNER LLP', 'PREMIER PLANNERS LLP', 'EVENTIFY CREW LLP', 'EVENT MANAGER LLP', 'EVENTFUL AFFAIR LLP', 'EXPERT GATHER LLP', 'HOSTING MAGIC LLP', 'ELA CATERING LLP', 'XMAS GALA LLP', 'PLANNER SCAPE LLP', 'PLANNER GURU LLP', 'OCCASION ORGANIZER LLP', 'SEIZE CATERING LLP', 'CATERING HUB LLP', 'CONSCIOUS CATERER LLP', 'OCCASIONS CREW LLP', 'MEAL MAVEN LLP', 'DECORATIONS LAB LLP', 'PLAN TAILOR LLP', 'SACRED PLANNER LLP', 'EVENTING UP LLP', 'CATERER ZONE LLP', 'MANAGE ACE LLP', 'PRIME PLANNING LLP', 'PUBLIC FUNCTION LLP', 'MOSAIC MANAGE LLP']


check_alert_descriptions(business_names)
# Out:
# MEDYGRIC LLP
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SEXYMENT LLP
#
#
#
#
#
#
#
#
#
# CLIXLIFE LLP
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# GRAPYLUX LLP
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Error occurred for name: GAMEDICINE LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Read timed out. (read timeout=None)
#
#
#
#
# METAMEDICAL LLP
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Error occurred for name: CARDRY LLP. Error message: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
#
#
# Error occurred for name: TECHWIRE LLP. Error message: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#
# Error occurred for name: SCIENCH LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA5610>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHANIC LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA41D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: ACTICS LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA75D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: MEDICALB LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA54D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: MONOMIC LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA4190>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHAND LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA6C50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHNOST LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA5790>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHNOLOG LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7D50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: MEDICMARY LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA6650>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHMENT LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA62D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHSIGHT LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA4C90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHNEWS LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7010>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHINO LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA72D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: PLASTROL LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7150>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: CURRICAL LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7A90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: PHYSIONS LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA6450>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHSPOT LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA59D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: HELISTIC LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA6AD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: DIGIN LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7950>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHNOVA LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA6510>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: DIGIES LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA4C50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: HISTRY LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA51D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: SOCIALSE LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA5350>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: STRIALS LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA68D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHN LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA6090>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: SOCIAN LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA5650>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: MEDICALN LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA4F10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: HEALE LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA74D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: ANTIVE LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7B50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: HEATION LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA4E50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: MEDICALE LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA5590>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: ACTORY LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA4090>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: ASTRICS LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7490>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHRHINE LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA6710>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: INTIVE LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7290>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: PREMEDIA LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA5290>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHT LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA4490>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHANITY LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA5E10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHNOB LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA6950>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: MINIC LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA4310>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: GENION LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA4DD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHBOOK LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7B10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHPOINT LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA68D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: SOCIALAB LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA4D90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: DEVICESS LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA6AD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: SCIENTA LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA74D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHILD LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA60D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: ARTINGS LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA6510>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: NONRY LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA4910>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: PRINVENT LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7750>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHCAPE LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA4610>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: PEDAGON LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA6550>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHMENTS LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7010>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: SCIENTIVE LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA58D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHANDS LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA4E10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: MINICAL LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7C50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHNOLD LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA68D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHZONE LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA6390>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: MILITIC LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA4A90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: MEDICALT LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA5A50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHCARE LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA6A90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: HISTICS LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7B90>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHENOR LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7B10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: DIGITARY LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA4B10>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: BIONS LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7050>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: MILITAL LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7BD0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: SCIENTS LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7290>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: MEDICMART LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA4310>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: PATIC LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA5250>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHHOME LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7350>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: PHYSICINE LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA7ED0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
#
# Error occurred for name: TECHG LLP. Error message: HTTPSConnectionPool(host='www.mca.gov.in', port=443): Max retries exceeded with url: /bin/mca-gov/RunLLPSaveSubmit (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x0000024C51CA4090>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed'))
# ['MEDYGRIC LLP',
#  'SEXYMENT LLP',
#  'CLIXLIFE LLP',
#  'GRAPYLUX LLP',
#  'METAMEDICAL LLP']
