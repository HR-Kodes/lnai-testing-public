# %%
# %run names.py

keywords = 'TECHNOLOGY HEALTHCARE MEDICAL EQUIPMENT ADVCANCED'
description = 'TECHNOLOGY HEALTHCARE MEDICAL EQUIPMENT ADVCANCED'

business_names = fetch_business_names(keywords, description)
print(business_names)
# Out:
# ['MEDICALE PRIVATE LIMITED', 'MODMEDIC PRIVATE LIMITED', 'NEWMEDIC PRIVATE LIMITED', 'TECGEAR PRIVATE LIMITED', 'BIONAL PRIVATE LIMITED', 'CURRIC PRIVATE LIMITED', 'TECHANDS PRIVATE LIMITED', 'PANATIC PRIVATE LIMITED', 'MICAL PRIVATE LIMITED', 'TECHAND PRIVATE LIMITED', 'DOCGENIC PRIVATE LIMITED', 'METABLE PRIVATE LIMITED', 'AGENIC PRIVATE LIMITED', 'CONDER PRIVATE LIMITED', 'SANITAL PRIVATE LIMITED', 'TECHCARE PRIVATE LIMITED', 'SANITIC PRIVATE LIMITED', 'QUALIST PRIVATE LIMITED', 'MEDICIAL PRIVATE LIMITED', 'MINGENIC PRIVATE LIMITED', 'MEDZONE PRIVATE LIMITED', 'CAREMIC PRIVATE LIMITED', 'MEDVINE PRIVATE LIMITED', 'THEMICAL PRIVATE LIMITED', 'MEDPLATE PRIVATE LIMITED', 'BIONRY PRIVATE LIMITED', 'CONDERST PRIVATE LIMITED', 'SANICINE PRIVATE LIMITED', 'GENERGY PRIVATE LIMITED', 'DEVITAX PRIVATE LIMITED', 'ACTIONIC PRIVATE LIMITED', 'DRUGFORT PRIVATE LIMITED', 'BIOANATE PRIVATE LIMITED', 'SCIENCED PRIVATE LIMITED', 'LOGYSTER PRIVATE LIMITED', 'MEDISTIC PRIVATE LIMITED', 'TECHARMA PRIVATE LIMITED', 'MEDICMECH PRIVATE LIMITED', 'DISTICS PRIVATE LIMITED', 'VITARY PRIVATE LIMITED', 'MEDENT PRIVATE LIMITED', 'PREMICAL PRIVATE LIMITED', 'MILITY PRIVATE LIMITED', 'MILITAL PRIVATE LIMITED', 'HEALHAND PRIVATE LIMITED', 'VITAR PRIVATE LIMITED', 'TECHCAPE PRIVATE LIMITED', 'MAINERGY PRIVATE LIMITED', 'HELINIC PRIVATE LIMITED', 'SOCIALAB PRIVATE LIMITED', 'MASTRY PRIVATE LIMITED', 'HISTIC PRIVATE LIMITED', 'CLINITE PRIVATE LIMITED', 'TECHIC PRIVATE LIMITED', 'MEDICIAN PRIVATE LIMITED', 'MEDHEALTH PRIVATE LIMITED', 'SANITURE PRIVATE LIMITED', 'RETAL PRIVATE LIMITED', 'BIOMATIC PRIVATE LIMITED', 'HUMANICS PRIVATE LIMITED', 'SANITE PRIVATE LIMITED', 'INTERIAN PRIVATE LIMITED', 'ACTIC PRIVATE LIMITED', 'HELINICAL PRIVATE LIMITED', 'HEALTHLY PRIVATE LIMITED', 'HEALLIFE PRIVATE LIMITED', 'PHYSICITY PRIVATE LIMITED', 'SANICS PRIVATE LIMITED', 'REMEDIC PRIVATE LIMITED', 'HEALITIC PRIVATE LIMITED', 'MEDTENT PRIVATE LIMITED', 'SANIST PRIVATE LIMITED', 'DRUGFORM PRIVATE LIMITED', 'MEDPLACE PRIVATE LIMITED', 'TECHANIC PRIVATE LIMITED', 'DOCTORIE PRIVATE LIMITED', 'MINIC PRIVATE LIMITED', 'TECHINE PRIVATE LIMITED', 'CORDER PRIVATE LIMITED', 'SOCIAN PRIVATE LIMITED', 'LOGYSTER PRIVATE LIMITED', 'MEDICALSE PRIVATE LIMITED', 'GENMEDIC PRIVATE LIMITED', 'MINGKEY PRIVATE LIMITED', 'ENETIC PRIVATE LIMITED', 'ACTIONAL PRIVATE LIMITED', 'THEMICAL PRIVATE LIMITED', 'MINIC PRIVATE LIMITED', 'NEWGENIC PRIVATE LIMITED', 'CAREGEAR PRIVATE LIMITED', 'SALLINIC PRIVATE LIMITED', 'DOCTORY PRIVATE LIMITED', 'BION PRIVATE LIMITED', 'ADVFEVER PRIVATE LIMITED', 'TECGEAR PRIVATE LIMITED', 'MEDIPROP PRIVATE LIMITED', 'MEDICITY PRIVATE LIMITED', 'PREMEDIC PRIVATE LIMITED', 'MONETICS PRIVATE LIMITED', 'ADVCAL PRIVATE LIMITED', 'DOCGENIC PRIVATE LIMITED', 'BOTGENE PRIVATE LIMITED', 'SYNTIVE PRIVATE LIMITED', 'MEDBION PRIVATE LIMITED', 'DEVITARY PRIVATE LIMITED', 'CHRONICS PRIVATE LIMITED', 'DIGIOUS PRIVATE LIMITED', 'DICAL PRIVATE LIMITED', 'MEDICACY PRIVATE LIMITED', 'PHYSION PRIVATE LIMITED', 'DISTICS PRIVATE LIMITED', 'UNEMEDIC PRIVATE LIMITED', 'MEDICPORT PRIVATE LIMITED', 'GENMENT PRIVATE LIMITED', 'HISTIC PRIVATE LIMITED', 'VIOLOGY PRIVATE LIMITED', 'MEDICALE PRIVATE LIMITED', 'SANATION PRIVATE LIMITED', 'MOTORY PRIVATE LIMITED', 'MILITE PRIVATE LIMITED', 'MEDICLAB PRIVATE LIMITED', 'ADHOME PRIVATE LIMITED', 'PANTIVE PRIVATE LIMITED', 'ENETICS PRIVATE LIMITED', 'MILITY PRIVATE LIMITED', 'ADVCARE PRIVATE LIMITED', 'TECHAND PRIVATE LIMITED', 'DRUGFOOT PRIVATE LIMITED', 'DENIC PRIVATE LIMITED', 'NEWGENICS PRIVATE LIMITED', 'MEDICPLE6 PRIVATE LIMITED', 'DENICS PRIVATE LIMITED', 'MEDICATIC PRIVATE LIMITED', 'DOCNETIC PRIVATE LIMITED', 'DOCGEAR PRIVATE LIMITED', 'DRUGFORT PRIVATE LIMITED', 'PHYSISH PRIVATE LIMITED', 'MASTRY PRIVATE LIMITED', 'NEWMEDIC PRIVATE LIMITED', 'COLOGIC PRIVATE LIMITED', 'DEVITAL PRIVATE LIMITED', 'HUMANIC PRIVATE LIMITED', 'STRYCARE PRIVATE LIMITED', 'DENTER PRIVATE LIMITED', 'DIGITARY PRIVATE LIMITED', 'SOCIALA PRIVATE LIMITED', 'VITARY PRIVATE LIMITE ...

# %%
business_names
# Out:
# ['MEDICALE PRIVATE LIMITED',
#  'MODMEDIC PRIVATE LIMITED',
#  'NEWMEDIC PRIVATE LIMITED',
#  'TECGEAR PRIVATE LIMITED',
#  'BIONAL PRIVATE LIMITED',
#  'CURRIC PRIVATE LIMITED',
#  'TECHANDS PRIVATE LIMITED',
#  'PANATIC PRIVATE LIMITED',
#  'MICAL PRIVATE LIMITED',
#  'TECHAND PRIVATE LIMITED',
#  'DOCGENIC PRIVATE LIMITED',
#  'METABLE PRIVATE LIMITED',
#  'AGENIC PRIVATE LIMITED',
#  'CONDER PRIVATE LIMITED',
#  'SANITAL PRIVATE LIMITED',
#  'TECHCARE PRIVATE LIMITED',
#  'SANITIC PRIVATE LIMITED',
#  'QUALIST PRIVATE LIMITED',
#  'MEDICIAL PRIVATE LIMITED',
#  'MINGENIC PRIVATE LIMITED',
#  'MEDZONE PRIVATE LIMITED',
#  'CAREMIC PRIVATE LIMITED',
#  'MEDVINE PRIVATE LIMITED',
#  'THEMICAL PRIVATE LIMITED',
#  'MEDPLATE PRIVATE LIMITED',
#  'BIONRY PRIVATE LIMITED',
#  'CONDERST PRIVATE LIMITED',
#  'SANICINE PRIVATE LIMITED',
#  'GENERGY PRIVATE LIMITED',
#  'DEVITAX PRIVATE LIMITED',
#  'ACTIONIC PRIVATE LIMITED',
#  'DRUGFORT PRIVATE LIMITED',
#  'BIOANATE PRIVATE LIMITED',
#  'SCIENCED PRIVATE LIMITED',
#  'LOGYSTER PRIVATE LIMITED',
#  'MEDISTIC PRIVATE LIMITED',
#  'TECHARMA PRIVATE LIMITED',
#  'MEDICMECH PRIVATE LIMITED',
#  'DISTICS PRIVATE LIMITED',
#  'VITARY PRIVATE LIMITED',
#  'MEDENT PRIVATE LIMITED',
#  'PREMICAL PRIVATE LIMITED',
#  'MILITY PRIVATE LIMITED',
#  'MILITAL PRIVATE LIMITED',
#  'HEALHAND PRIVATE LIMITED',
#  'VITAR PRIVATE LIMITED',
#  'TECHCAPE PRIVATE LIMITED',
#  'MAINERGY PRIVATE LIMITED',
#  'HELINIC PRIVATE LIMITED',
#  'SOCIALAB PRIVATE LIMITED',
#  'MASTRY PRIVATE LIMITED',
#  'HISTIC PRIVATE LIMITED',
#  'CLINITE PRIVATE LIMITED',
#  'TECHIC PRIVATE LIMITED',
#  'MEDICIAN PRIVATE LIMITED',
#  'MEDHEALTH PRIVATE LIMITED',
#  'SANITURE PRIVATE LIMITED',
#  'RETAL PRIVATE LIMITED',
#  'BIOMATIC PRIVATE LIMITED',
#  'HUMANICS PRIVATE LIMITED',
#  'SANITE PRIVATE LIMITED',
#  'INTERIAN PRIVATE LIMITED',
#  'ACTIC PRIVATE LIMITED',
#  'HELINICAL PRIVATE LIMITED',
#  'HEALTHLY PRIVATE LIMITED',
#  'HEALLIFE PRIVATE LIMITED',
#  'PHYSICITY PRIVATE LIMITED',
#  'SANICS PRIVATE LIMITED',
#  'REMEDIC PRIVATE LIMITED',
#  'HEALITIC PRIVATE LIMITED',
#  'MEDTENT PRIVATE LIMITED',
#  'SANIST PRIVATE LIMITED',
#  'DRUGFORM PRIVATE LIMITED',
#  'MEDPLACE PRIVATE LIMITED',
#  'TECHANIC PRIVATE LIMITED',
#  'DOCTORIE PRIVATE LIMITED',
#  'MINIC PRIVATE LIMITED',
#  'TECHINE PRIVATE LIMITED',
#  'CORDER PRIVATE LIMITED',
#  'SOCIAN PRIVATE LIMITED',
#  'LOGYSTER PRIVATE LIMITED',
#  'MEDICALSE PRIVATE LIMITED',
#  'GENMEDIC PRIVATE LIMITED',
#  'MINGKEY PRIVATE LIMITED',
#  'ENETIC PRIVATE LIMITED',
#  'ACTIONAL PRIVATE LIMITED',
#  'THEMICAL PRIVATE LIMITED',
#  'MINIC PRIVATE LIMITED',
#  'NEWGENIC PRIVATE LIMITED',
#  'CAREGEAR PRIVATE LIMITED',
#  'SALLINIC PRIVATE LIMITED',
#  'DOCTORY PRIVATE LIMITED',
#  'BION PRIVATE LIMITED',
#  'ADVFEVER PRIVATE LIMITED',
#  'TECGEAR PRIVATE LIMITED',
#  'MEDIPROP PRIVATE LIMITED',
#  'MEDICITY PRIVATE LIMITED',
#  'PREMEDIC PRIVATE LIMITED',
#  'MONETICS PRIVATE LIMITED',
#  'ADVCAL PRIVATE LIMITED',
#  'DOCGENIC PRIVATE LIMITED',
#  'BOTGENE PRIVATE LIMITED',
#  'SYNTIVE PRIVATE LIMITED',
#  'MEDBION PRIVATE LIMITED',
#  'DEVITARY PRIVATE LIMITED',
#  'CHRONICS PRIVATE LIMITED',
#  'DIGIOUS PRIVATE LIMITED',
#  'DICAL PRIVATE LIMITED',
#  'MEDICACY PRIVATE LIMITED',
#  'PHYSION PRIVATE LIMITED',
#  'DISTICS PRIVATE LIMITED',
#  'UNEMEDIC PRIVATE LIMITED',
#  'MEDICPORT PRIVATE LIMITED',
#  'GENMENT PRIVATE LIMITED',
#  'HISTIC PRIVATE LIMITED',
#  'VIOLOGY PRIVATE LIMITED',
#  'MEDICALE PRIVATE LIMITED',
#  'SANATION PRIVATE LIMITED',
#  'MOTORY PRIVATE LIMITED',
#  'MILITE PRIVATE LIMITED',
#  'MEDICLAB PRIVATE LIMITED',
#  'ADHOME PRIVATE LIMITED',
#  'PANTIVE PRIVATE LIMITED',
#  'ENETICS PRIVATE LIMITED',
#  'MILITY PRIVATE LIMITED',
#  'ADVCARE PRIVATE LIMITED',
#  'TECHAND PRIVATE LIMITED',
#  'DRUGFOOT PRIVATE LIMITED',
#  'DENIC PRIVATE LIMITED',
#  'NEWGENICS PRIVATE LIMITED',
#  'MEDICPLE6 PRIVATE LIMITED',
#  'DENICS PRIVATE LIMITED',
#  'MEDICATIC PRIVATE LIMITED',
#  'DOCNETIC PRIVATE LIMITED',
#  'DOCGEAR PRIVATE LIMITED',
#  'DRUGFORT PRIVATE LIMITED',
#  'PHYSISH PRIVATE LIMITED',
#  'MASTRY PRIVATE LIMITED',
#  'NEWMEDIC PRIVATE LIMITED',
#  'COLOGIC PRIVATE LIMITED',
#  'DEVITAL PRIVATE LIMITED',
#  'HUMANIC PRIVATE LIMITED',
#  'STRYCARE PRIVATE LIMITED',
#  'DENTER PRIVATE LIMITED',
#  'DIGITARY PRIVATE LIMITED',
#  'SOCIALA PRIVATE LIMITED',
#  'VITARY PRIVATE LIMITED',
#  'BIOTICAL PRIVATE LIMITED',
#  'BIONOMIC PRIVATE LIMITED',
#  'TECHIC PRIVATE LIMITED',
#  'RELINIC PRIVATE LIMITED',
#  'HEALINIC PRIVATE LIMITED',
#  'PHYGIENT PRIVATE LIMITED',
#  'QMINIC PRIVATE LIMITED',
#  'ADVMEDICAL PRIVATE LIMITED',
#  'MOTORIAN PRIVATE LIMITED',
#  'DYNERGY PRIVATE LIMITED',
#  'ADVSTORY PRIVATE LIMITED',
#  'BICYIELD PRIVATE LIMITED',
#  'ADVNET PRIVATE LIMITED',
#  'MEDICT PRIVATE LIMITED',
#  'PATIVE PRIVATE LIMITED',
#  'PHARGE PRIVATE LIMITED',
#  'SANITIC PRIVATE LIMITED',
#  'MEDICALE PRIVATE LIMITED',
#  'TECHSIDE PRIVATE LIMITED',
#  'MONOMICK PRIVATE LIMITED',
#  'PSYCHONE PRIVATE LIMITED',
#  'HUMANIC PRIVATE LIMITED',
#  'MACEUTIC PRIVATE LIMITED',
#  'DIGIOUS PRIVATE LIMITED',
#  'EDUCATIX PRIVATE LIMITED',
#  'INTERY PRIVATE LIMITED',
#  'SCIENTAL PRIVATE LIMITED',
#  'UNIC PRIVATE LIMITED',
#  'TECHCARE PRIVATE LIMITED',
#  'TECHONEY PRIVATE LIMITED',
#  'MEDICIAN PRIVATE LIMITED',
#  'VIOLOGIC PRIVATE LIMITED',
#  'PHYSIICAL PRIVATE LIMITED',
#  'SCITY PRIVATE LIMITED',
#  'DELINIC PRIVATE LIMITED',
#  'CURANCE PRIVATE LIMITED',
#  'MICAL PRIVATE LIMITED',
#  'MEDICONT PRIVATE LIMITED',
#  'SANIC PRIVATE LIMITED',
#  'SCAL PRIVATE LIMITED',
#  'DOCGEAR PRIVATE LIMITED',
#  'PHYSIST PRIVATE LIMITED',
#  'TECHWIRE PRIVATE LIMITED',
#  'FINIC PRIVATE LIMITED',
#  'MONOMIC PRIVATE LIMITED',
#  'VITARY PRIVATE LIMITED',
#  'TECHFEVER PRIVATE LIMITED',
#  'TECHNOLF PRIVATE LIMITED',
#  'SILICINE PRIVATE LIMITED',
#  'INTERSE PRIVATE LIMITED',
#  'ONERGY PRIVATE LIMITED',
#  'CONDER PRIVATE LIMITED',
#  'FASTCITY PRIVATE LIMITED',
#  'CAREGEAR PRIVATE LIMITED',
#  'LIFESTY PRIVATE LIMITED',
#  'HISTIC PRIVATE LIMITED',
#  'DOCGENIC PRIVATE LIMITED',
#  'SUPERSE PRIVATE LIMITED',
#  'TECHEMIC PRIVATE LIMITED',
#  'PATIC PRIVATE LIMITED',
#  'TECHCITY PRIVATE LIMITED',
#  'MEDICONSE PRIVATE LIMITED',
#  'MEDCORD PRIVATE LIMITED',
#  'QUALIST PRIVATE LIMITED',
#  'CASTERY PRIVATE LIMITED',
#  'SCIENTERY PRIVATE LIMITED',
#  'CAREGAL PRIVATE LIMITED',
#  'MOTIONIC PRIVATE LIMITED',
#  'GEATION PRIVATE LIMITED',
#  'SANIMAL PRIVATE LIMITED',
#  'MONERGY PRIVATE LIMITED',
#  'MEDICIAL PRIVATE LIMITED',
#  'TECHE PRIVATE LIMITED',
#  'FRINVENT PRIVATE LIMITED',
#  'MEDMEDIC PRIVATE LIMITED',
#  'MODMEDIC PRIVATE LIMITED',
#  'SOCIAN PRIVATE LIMITED',
#  'RELATICS PRIVATE LIMITED',
#  'TECHNOLD PRIVATE LIMITED',
#  'TECHANIC PRIVATE LIMITED',
#  'DEMEDIC PRIVATE LIMITED',
#  'CAPIENT PRIVATE LIMITED',
#  'AGENIC PRIVATE LIMITED',
#  'GREENNEL PRIVATE LIMITED',
#  'RESCENT PRIVATE LIMITED',
#  'RELINIC PRIVATE LIMITED',
#  'CLINIX PRIVATE LIMITED',
#  'SCIENCED PRIVATE LIMITED',
#  'COLOGY PRIVATE LIMITED',
#  'RETAL PRIVATE LIMITED',
#  'THENTIVE PRIVATE LIMITED',
#  'MEDICALSE PRIVATE LIMITED',
#  'PHYSICINE PRIVATE LIMITED']

# %%
c_name='MEDTECH FORALL PRIVATE LIMITED'

# %%
import requests
import json
url = "https://www.mca.gov.in/bin/mca/login"

headers = {
    "Origin": "www.mca.gov.in",
    "Content-Length": "231",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.5672.127 Safari/537.36",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Accept": "*/*",
    "X-Requested-With": "XMLHttpRequest",
    "Sec-Ch-Ua-Platform": "Windows"
}

data = "data=Ut8pBOc0RSM6iYqffqN1orWH0Ee6A57QEKGmyHa5KnuzzybQ%2BjY2pMJIsLZw9DznTxfJeWvJFEcqsU2aZC33AC2nYaU60TNo8VjomCHN2dDSdHEC2enwIeEWCNR42vj7gfXFsvEwLfoO25%2BUKeho6%2B3l%2FkhEucDAzA4XeVNg0dhlBlgG95nyBiwYk3XhQoJtHSgqcb%2FI8MCyxN9h1unz%2Fw%3D%3D"

response = requests.post(url, headers=headers, data=data)



set_cookie_value = response.headers.get('Set-Cookie')

start_index = set_cookie_value.find("session-token=") + len("session-token=")
end_index = set_cookie_value.find(";", start_index)
session_token = set_cookie_value[start_index:end_index]

# %%
import urllib.parse

formData = "%7B%22formData%22%3A%7B%22companyType%22%3A%22New+Company+(Others)%22%2C%22companyClass%22%3A%22Private%22%2C%22companyCategory%22%3A%22Company+limited+by+shares%22%2C%22companySubCategory%22%3A%22Non-government+company%22%2C%22proposedName1%22%3A%22DUMBMET+PRIVATE+LIMITED%22%2C%22NICCode1%22%3A%2298200%22%2C%22Description1%22%3A%22Undifferentiated+service-producing+activities+of+private+households+for+own+use%22%2C%22NICCode2%22%3A%2298100%22%2C%22Description2%22%3A%22Undifferentiated+goods-producing+activities+of+private+households+for+own+use%22%2C%22formIntegrationId%22%3A%221%22%2C%22continueFlag%22%3A%22N%22%2C%22LLPIN%22%3A%22%22%2C%22NICCode3%22%3A%22%22%2C%22Description3%22%3A%22%22%2C%22proposedName2%22%3A%22%22%7D%2C%22formDescription%22%3A%22SPICE+PART+A%22%2C%22formName%22%3A%22Spice%2B+Part+A%22%2C%22formVersion%22%3A%221%22%2C%22userId%22%3A%22BIPULKUMARSINGH6690%40GMAIL.COM%22%2C%22integrationId%22%3A%221%22%2C%22prefill%22%3A%22false%22%2C%22status%22%3A%22Draft%2FPending+Submission%22%2C%22operation%22%3A%22Save%22%2C%22referenceNumber%22%3A%22%22%2C%22srn%22%3A%22%22%2C%22formId%22%3A%22%22%2C%22Approvedname%22%3A%22%22%2C%22serveAction%22%3A%22autocheck%22%7D"

# Manually parse the data
decoded_data = urllib.parse.unquote_plus(formData,encoding='utf-8')
data_start = decoded_data.find('{')

data_end = decoded_data.rfind('}') + 1
data_str = decoded_data[data_start:data_end]
data = eval(data_str)
data['formData']['proposedName1']=c_name
encoded_data = urllib.parse.quote_plus(json.dumps(data), encoding='utf-8').replace('%20', '').replace('%28','(').replace('%29',')').replace('+%','%')

# %%
import requests

url = "https://www.mca.gov.in/bin/mca-gov/newSpiceA"

headers = {
    "Host": "www.mca.gov.in",
    "Cookie": f"cookiesession1=678B28695C218253C321286001478935; alertPopup=true; session-token={session_token}; deviceId=1uytaas0tlbi",
    "Content-Length": "1208",
    "Sec-Ch-Ua": "",
    "Sec-Ch-Ua-Mobile": "?0",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.91 Safari/537.36",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Accept": "*/*",
    "Csrf-Token": "undefined",
    "X-Requested-With": "XMLHttpRequestmcamca",
    "Sec-Ch-Ua-Platform": "\"\"",
    "Origin": "https://www.mca.gov.in",
    "Sec-Fetch-Site": "same-origin",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Dest": "empty",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/spice.html",
    "Accept-Encoding": "gzip, deflate",
    "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.8"
}


payload=f"formData={encoded_data}"
response = requests.post(url, headers=headers, data=payload)
response.text
# Out:
# '{"message":"Auto check Completed","data":{"SRN":"","ReferenceNumber":"1-9897667288","SubmittedDate":"","integrationId":"1-4JOTCYG","formIntegrationId":"1-4JOTCYI","srnStatus":"","formType":"","srNumber":""},"validationResponse":{"submissionRestricted":"false","validationresposeBody":[{"proposedName1":"MEDTECH FORALL PRIVATE LIMITED","alertCategory":"foWMUC0217","alertDescription":"","alertType":"Info"},{"proposedName1":"MEDTECH FORALL PRIVATE LIMITED","alertType":"Info","alertCategory":"WM_UC02_1","alertDescription":"Please note that the proposed name is similar to the name of an existing Company / LLP WELLNESS FORALL LLP as per Rule 8(1) / 8A(1)(d) of Companies (Incorporation) Rules,2014. Please attach No Objection Certificate (NOC), if applicable"},{"proposedName1":"MEDTECH FORALL PRIVATE LIMITED","alertType":"Info","alertCategory":"WM_UC02_11","alertDescription":"Proposed name may be similar to registered trademark and may not be allowed as per rule 8A(1)(b) of Companies (Incorporation) Rules, 2014. Please attach the No Objection Certificate, if applicable"},{"alertType":"","alertDescription":"","alertCategory":""},{"alertType":"","alertDescription":"","alertCategory":""},{"alertType":"","alertDescription":"","alertCategory":""},{"alertType":"","alertDescription":"","alertCategory":""},{"alertType":"","alertDescription":"","alertCategory":""}]},"alertInfo":[],"alertWarn":[],"alertError":[],"errorTab":[{"proposedName1":"MEDTECH FORALL PRIVATE LIMITED","alertCategory":"foWMUC0217","alertDescription":"","alertType":"Info"},{"proposedName1":"MEDTECH FORALL PRIVATE LIMITED","alertType":"Info","alertCategory":"WM_UC02_1","alertDescription":"Please note that the proposed name is similar to the name of an existing Company / LLP WELLNESS FORALL LLP as per Rule 8(1) / 8A(1)(d) of Companies (Incorporation) Rules,2014. Please attach No Objection Certificate (NOC), if applicable"},{"proposedName1":"MEDTECH FORALL PRIVATE LIMITED","alertType":"Info","alertCategory":"WM_UC02_11","alertDescription":"Proposed name may be similar to registered trademark and may not be allowed as per rule 8A(1)(b) of Companies (Incorporation) Rules, 2014. Please attach the No Objection Certificate, if applicable"}],"supportDataTab":[[{"companyLlpNumber":"AAR-7466","score":121.58563,"companyOldName":"","companyName":"WELLNESS FORALL LLP","companyStatus":"Active"},{"companyLlpNumber":"U15400MP2015PTC033634","score":117.54845,"companyOldName":"","companyName":"FORALL FOODS PRIVATE LIMITED","companyStatus":"Active"},{"companyLlpNumber":"U18129DL2023PTC411403","score":117.54845,"companyOldName":"","companyName":"SUSHKAM FORALL PRIVATE LIMITED","companyStatus":"Active"}]],"supportDataTrademark":[[{"TradeMarkName":"MEDTECH","ApplicationStatus":"Registered","ProprietorName":"MEDTECH GLOBAL LTD","Class":"35","ProprietorAddress":"LEVEL 2, 99, COVENTRY STREET, SOUTH MELBOURNE, AUSTRALIA","ApplicationNo":"2112831"},{"TradeMarkName":"medtech","ApplicationStatus":"Registered","ProprietorName":"MEDTECH GLOBAL LTD","Class":"16","ProprietorAddress":"LEVEL 2, 99, COVENTRY STREET, SOUTH MELBOURNE, AUSTRALIA","ApplicationNo":"1923829"},{"TradeMarkName":"medtech","ApplicationStatus":"Registered","ProprietorName":"MEDTECH GLOBAL LTD","Class":"9","ProprietorAddress":"LEVEL 2, 99, COVENTRY STREET, SOUTH MELBOURNE, AUSTRALIA","ApplicationNo":"1923828"},{"TradeMarkName":"medtech","ApplicationStatus":"Registered","ProprietorName":"MEDTECH GLOBAL LTD","Class":"44","ProprietorAddress":"LEVEL 2, 99, COVENTRY STREET, SOUTH MELBOURNE, AUSTRALIA","ApplicationNo":"1923831"},{"TradeMarkName":"medtech","ApplicationStatus":"Registered","ProprietorName":"MEDTECH GLOBAL LTD","Class":"38","ProprietorAddress":"LEVEL 2, 99, COVENTRY STREET, SOUTH MELBOURNE, AUSTRALIA","ApplicationNo":"1923830"},{"TradeMarkName":"MED-TECH","ApplicationStatus":"Registered","ProprietorName":"MEDTECH LIFE PRIVATE LIMITED","Class":"10","ProprietorAddress":"B6,BYCULLA SERVICE INDUSTRIAL ESTATE, SUSSEX ROAD, D.K.MARG, BYCU ...

# %%
response_dict=json.loads(response.text)
formIntegrationId=response_dict['data']['formIntegrationId']
integrationId=response_dict['data']['integrationId']
ReferenceNumber=response_dict['data']['ReferenceNumber']
payload4=r'''{"requestBody":{"formData":{"companyType":"New Company (Others)","companyClass":"Private","companyCategory":"Company limited by shares","companySubCategory":"Non-government company","proposedName1":"DBMBETTNNBBTXX PRIVATE LIMITED","NICCode1":"98200","Description1":"Undifferentiated service-producing activities of private households for own use","NICCode2":"98100","Description2":"Undifferentiated goods-producing activities of private households for own use","formIntegrationId":"1-48JSN72","continueFlag":"Y","LLPIN":"","NICCode3":"","Description3":"","proposedName2":""},"formDescription":"SPICE PART A","formName":"Spice+ Part A","formVersion":"1","userId":"BIPULKUMARSINGH6690@GMAIL.COM","integrationId":"1-48JSN70","referenceNumber":"1-9224203987","prefill":"false","status":"Draft/Pending Submission","operation":"","srn":"","formId":"","Approvedname":"","formAttachment":[]}}'''
payload4_json=json.loads(payload4)
payload4_json['requestBody']['integrationId']=integrationId
payload4_json['requestBody']['formData']['formIntegrationId']=formIntegrationId
payload4_json['requestBody']['formData']['proposedName1']=c_name
payload4_json['requestBody']['approvedName']=c_name
payload4_json['requestBody']['referenceNumber']=ReferenceNumber
payload4_json=json.dumps(payload4_json)

# %%
autocheckdata='''%7B%22reason%22%3A%22%22%2C%22approvalDate%22%3A%22%22%2C%22purpose%22%3A%22Default%22%2C%22accountType%22%3A%22%22%2C%22prefill%22%3A%22false%22%2C%22integrationId%22%3A%221-48JUPCJ%22%2C%22mcaRSUBFlag%22%3A%22N%22%2C%22expiryDate%22%3A%22%22%2C%22lastUpdatedDate%22%3A%22%22%2C%22MCAFillingDate%22%3A%2206%2F09%2F2023%22%2C%22approvedName%22%3A%22BHOLU+PRIVATE+LIMITED%22%2C%22formData%22%3A%7B%22companyType%22%3A%22New+Company+(Others)%22%2C%22NICCode2%22%3A%2252291%22%2C%22NICCode1%22%3A%2279120%22%2C%22CIN%22%3A%22%22%2C%22companyCategory%22%3A%22Company+limited+by+shares%22%2C%22proposedNameRating1%22%3A%22%22%2C%22proposedNameRating2%22%3A%22%22%2C%22Description2%22%3A%22Activities+of+travel+agents+and+tour+operators%22%2C%22Description1%22%3A%22Tour+operator+activities%22%2C%22companyClass%22%3A%22Private%22%2C%22formIntegrationId%22%3A%221-48JUPCL%22%2C%22companySubCategory%22%3A%22Non-government+company%22%2C%22proposedName1%22%3A%22GOTURN+PRIVATE+LIMITED%22%2C%22continueFlag%22%3A%22N%22%2C%22LLPIN%22%3A%22%22%2C%22NICCode3%22%3A%22%22%2C%22Description3%22%3A%22%22%2C%22proposedName2%22%3A%22%22%7D%2C%22status%22%3A%22Draft%2FPending+Submission%22%2C%22eventDate%22%3A%22%22%2C%22formDescription%22%3A%22SPICE+PART+A%22%2C%22formName%22%3A%22Spice%2B+Part+A%22%2C%22formVersion%22%3A%221%22%2C%22userId%22%3A%22BIPULKUMARSINGH6690%40GMAIL.COM%22%2C%22referenceNumber%22%3A%221-9224203987%22%2C%22operation%22%3A%22Save%22%2C%22srn%22%3A%22%22%2C%22formId%22%3A%22%22%2C%22Approvedname%22%3A%22%22%2C%22serveAction%22%3A%22autocheck%22%7D'''

decoded_data = urllib.parse.unquote_plus(autocheckdata,encoding='utf-8')
data_start = decoded_data.find('{')

data_end = decoded_data.rfind('}') + 1
data_str = decoded_data[data_start:data_end]
data = eval(data_str)
data['Approvedname']=c_name
data['formData']['proposedName1']=c_name
encoded_data = urllib.parse.quote_plus(json.dumps(data), encoding='utf-8').replace('%20', '').replace('%28','(').replace('%29',')').replace('+%','%')

# %%
url = 'https://www.mca.gov.in/bin/mca-gov/newSpiceA'
headers = {
	'Host': 'www.mca.gov.in',
	'Cookie': f"cookiesession1=678B28695C218253C321286001478935; alertPopup=true; session-token={session_token}",
	'Sec-Ch-Ua': '',
	'Sec-Ch-Ua-Mobile': '?0',
	'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.110 Safari/537.36',
	'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
	'Accept': '*/*',
	'Csrf-Token': 'undefined',
	'X-Requested-With': 'XMLHttpRequest',
	'Sec-Ch-Ua-Platform': '',
	'Origin': 'https://www.mca.gov.in',
	'Sec-Fetch-Site': 'same-origin',
	'Sec-Fetch-Mode': 'cors',
	'Sec-Fetch-Dest': 'empty',
	'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/spice.html?applicationHistory=eyJzcm4iOiIiLCJyZWZlcmVuY2UiOiIxLTkyMjQyMDM5ODciLCJwdXJwb3NlIjoiRGVmYXVsdCJ9',
	'Accept-Encoding': 'gzip, deflate',
	'Accept-Language': 'en-US,en;q=0.9'

}
data['Approvedname'] = c_name   
data['formData']['proposedName1'] = c_name

# %%
# import requests
# import json
# import urllib.parse

# def check_alert_descriptions(names):
#     url = 'https://www.mca.gov.in/bin/mca-gov/newSpiceA'
#     headers = {
#         # Your headers here
#     }
    
#     for name in names:
#         encoded_data = urllib.parse.quote_plus(json.dumps(data), encoding='utf-8').replace('%20', '').replace('%28','(').replace('%29',')').replace('+%','%')
#         payload_data = f"formData={encoded_data}"
#         response = requests.post(url, headers=headers, data=payload_data)
        
#         try:
#             result = response.json()
#             alert_list = result['validationResponse']['validationresposeBody']
#             all_empty = all(not item['alertDescription'] for item in alert_list)

#             if all_empty:
#                 return response.text

#         except json.JSONDecodeError as e:
#             print(f"JSONDecodeError occurred: {str(e)}")
#             print(f"Response text: {response.text}")

#     return None

# # Example usage
# name_list = ['ZZZ PRIVATE LIMITED', 'ZZZZ PRIVATE LIMITED', 'ZZLL PRIVATE LIMITED']  # Replace with your array of names
# response_text = check_alert_descriptions(name_list)
# print(response_text)

# %%
len(business_names)
# Out:
# 240

# %%
# business_names=['Foralltechnologies private limited','Technologoiesforall private limited','Foralltechnologies solutions private limited','Foralltechnologies sciences private limited','Foralltechnologies health private limited','Foralltechnologies wellness private limited','Foralltechnologies biomedical private limited','Foralltechnologies clinical private limited','Foralltechnologies medicinal private limited','Technologoiesforall solutions private limited','Technologoiesforall sciences private limited','Technologoiesforall health private limited','Technologoiesforall wellness private limited','Technologoiesforall biomedical private limited','Technologoiesforall clinical private limited','Technologoiesforall medicinal private limited','Forall technologies private limited','Technologoies forall private limited','Forall technologies solutions private limited','Forall technologies sciences private limited','Forall technologies health private limited','Forall technologies wellness private limited','Forall technologies biomedical private limited','Forall technologies clinical private limited','Forall technologies medicinal private limited','Technologoies forall solutions private limited','Technologoies forall sciences private limited','Technologoies forall health private limited','Technologoies forall wellness private limited','Technologoies forall biomedical private limited','Technologoies forall clinical private limited','Technologoies forall medicinal private limited']

# %%
import requests
import urllib.parse
import json

def check_alert_descriptions(c_name, name_list, session_token):
    url = 'https://www.mca.gov.in/bin/mca-gov/newSpiceA'
    headers = {
        'Host': 'www.mca.gov.in',
        'Cookie': f"cookiesession1=678B28695C218253C321286001478935; alertPopup=true; session-token={session_token}",
        'Sec-Ch-Ua': '',
        'Sec-Ch-Ua-Mobile': '?0',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.110 Safari/537.36',
        'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'Accept': '*/*',
        'Csrf-Token': 'undefined',
        'X-Requested-With': 'XMLHttpRequest',
        'Sec-Ch-Ua-Platform': '',
        'Origin': 'https://www.mca.gov.in',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Dest': 'empty',
        'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/spice.html?applicationHistory=eyJzcm4iOiIiLCJyZWZlcmVuY2UiOiIxLTkyMjQyMDM5ODciLCJwdXJwb3NlIjoiRGVmYXVsdCJ9',
        'Accept-Encoding': 'gzip, deflate',
        'Accept-Language': 'en-US,en;q=0.9'
    }

    empty_alert_names = []

    data['Approvedname']=c_name
    data['formData']['proposedName1']=c_name

    import requests
import urllib.parse
import json

def check_alert_descriptions(c_name, name_list, session_token):
    url = 'https://www.mca.gov.in/bin/mca-gov/newSpiceA'
    headers = {
        'Host': 'www.mca.gov.in',
        'Cookie': f"cookiesession1=678B28695C218253C321286001478935; alertPopup=true; session-token={session_token}",
        'Sec-Ch-Ua': '',
        'Sec-Ch-Ua-Mobile': '?0',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.110 Safari/537.36',
        'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'Accept': '*/*',
        'Csrf-Token': 'undefined',
        'X-Requested-With': 'XMLHttpRequest',
        'Sec-Ch-Ua-Platform': '',
        'Origin': 'https://www.mca.gov.in',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Dest': 'empty',
        'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/spice.html?applicationHistory=eyJzcm4iOiIiLCJyZWZlcmVuY2UiOiIxLTkyMjQyMDM5ODciLCJwdXJwb3NlIjoiRGVmYXVsdCJ9',
        'Accept-Encoding': 'gzip, deflate',
        'Accept-Language': 'en-US,en;q=0.9'
    }

    empty_alert_names = []

    data['Approvedname']=c_name
    data['formData']['proposedName1']=c_name

    def has_empty_alert(name):
        data['Approvedname'] = name
        data['formData']['proposedName1'] = name

        encoded_data = urllib.parse.quote_plus(json.dumps(data), encoding='utf-8').replace('%20', '').replace('%28','(').replace('%29',')').replace('+%','%')
        payload_data = f"formData={encoded_data}"
        response = requests.post(url, headers=headers, data=payload_data)
        try:
            result = response.json()
        except json.JSONDecodeError as e:
            print(f"Error decoding JSON response: {e}")
            return False
        
        alert_list = result['validationResponse']['validationresposeBody']
        all_empty = all(not item['alertDescription'] for item in alert_list)
        return all_empty

    try:
        if has_empty_alert(c_name):
            empty_alert_names.append(c_name)
        else:
            for name in name_list:
                if has_empty_alert(name):
                    print(name)
                    empty_alert_names.append(name)
    except requests.RequestException as e:
        print(f"Request error: {e}")
    
    return empty_alert_names
6
empty_alert_names = check_alert_descriptions(c_name, business_names, session_token)
print(empty_alert_names)
# Out:
# DOCGENIC PRIVATE LIMITED
# CONDERST PRIVATE LIMITED
# DRUGFORT PRIVATE LIMITED
# DISTICS PRIVATE LIMITED
# PREMICAL PRIVATE LIMITED
# HELINICAL PRIVATE LIMITED
# DRUGFORM PRIVATE LIMITED
# ADVFEVER PRIVATE LIMITED
# DOCGENIC PRIVATE LIMITED
# DISTICS PRIVATE LIMITED
# ADVCARE PRIVATE LIMITED
# DRUGFOOT PRIVATE LIMITED
# DOCNETIC PRIVATE LIMITED
# DRUGFORT PRIVATE LIMITED
# PHYGIENT PRIVATE LIMITED
# ADVMEDICAL PRIVATE LIMITED
# ADVSTORY PRIVATE LIMITED
# EDUCATIX PRIVATE LIMITED
# PHYSIICAL PRIVATE LIMITED
# TECHFEVER PRIVATE LIMITED
# TECHNOLF PRIVATE LIMITED
# Request error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
# ['DOCGENIC PRIVATE LIMITED', 'CONDERST PRIVATE LIMITED', 'DRUGFORT PRIVATE LIMITED', 'DISTICS PRIVATE LIMITED', 'PREMICAL PRIVATE LIMITED', 'HELINICAL PRIVATE LIMITED', 'DRUGFORM PRIVATE LIMITED', 'ADVFEVER PRIVATE LIMITED', 'DOCGENIC PRIVATE LIMITED', 'DISTICS PRIVATE LIMITED', 'ADVCARE PRIVATE LIMITED', 'DRUGFOOT PRIVATE LIMITED', 'DOCNETIC PRIVATE LIMITED', 'DRUGFORT PRIVATE LIMITED', 'PHYGIENT PRIVATE LIMITED', 'ADVMEDICAL PRIVATE LIMITED', 'ADVSTORY PRIVATE LIMITED', 'EDUCATIX PRIVATE LIMITED', 'PHYSIICAL PRIVATE LIMITED', 'TECHFEVER PRIVATE LIMITED', 'TECHNOLF PRIVATE LIMITED']

# %%
empty_alert_names
# Out:
# ['COMMEDIC PRIVATE LIMITED',
#  'INTERAND PRIVATE LIMITED',
#  'DOCGENIC PRIVATE LIMITED',
#  'SURGENIC PRIVATE LIMITED',
#  'DISCIENT PRIVATE LIMITED',
#  'DOCNETIC PRIVATE LIMITED',
#  'ACTIICAL PRIVATE LIMITED',
#  'ADVDOME PRIVATE LIMITED',
#  'MEDENTAL PRIVATE LIMITED',
#  'RELATORY PRIVATE LIMITED',
#  'ADVCARE PRIVATE LIMITED',
#  'ADVMEDICAL PRIVATE LIMITED',
#  'ADVCAFE PRIVATE LIMITED',
#  'MEDICASE PRIVATE LIMITED',
#  'ADVFEVER PRIVATE LIMITED',
#  'DRUGFORE PRIVATE LIMITED',
#  'EDUCATIX PRIVATE LIMITED',
#  'PODIATRIC PRIVATE LIMITED',
#  'TECHNOLOH PRIVATE LIMITED']

# %%
from requests_toolbelt.multipart.encoder import MultipartEncoder
import requests

url = "https://www.mca.gov.in/bin/mca-gov/SpiceSaveSubmit"

headers = {
    "Host": "www.mca.gov.in",
    "Cookie": f"cookiesession1=678B28695C218253C321286001478935; alertPopup=true; session-token={session_token}; deviceId=1uytaas0tlbi",
    "Sec-Ch-Ua-Mobile": "?0",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.91 Safari/537.36",
    "Content-Type": "multipart/form-data; boundary=----WebKitFormBoundary0DRTY0BWFJSpDAkt",
    "Accept": "*/*",
    "X-Requested-With": "XMLHttpRequest",
    "Sec-Ch-Ua-Platform": "\"Windows\"",
    "Origin": "https://www.mca.gov.in",
    "Sec-Fetch-Site": "same-origin",
    # "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Dest": "empty",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/spice.html?applicationHistory=eyJzcm4iOiIiLCJyZWZlcmVuY2UiOiIxLTkxOTQ4NjA5NjYiLCJwdXJwb3NlIjoiRGVmYXVsdCJ9",
    "Accept-Encoding": "gzip, deflate",
    "Accept-Language": "en-GB,en-US;q=0.9,en;q=0.9"
}

# data = '''{"requestBody":{"reason":"","approvalDate":"","purpose":"Default","accountType":"","prefill":"false","integrationId":"1-48K61NT","mcaRSUBFlag":"N","expiryDate":"","lastUpdatedDate":"","MCAFillingDate":"06/09/2023","approvedName":"ZIGZAG PRIVATE LIMITED","formData":{"companyType":"New Company (Others)","NICCode2":"98100","NICCode1":"98200","CIN":"","companyCategory":"Company limited by shares","proposedNameRating1":"","proposedNameRating2":"","Description2":"Undifferentiated goods-producing activities of private households for own use","Description1":"Undifferentiated service-producing activities of private households for own use","companyClass":"Private","formIntegrationId":"1-48K61NV","companySubCategory":"Non-government company","proposedName1":"ZIGZAG PRIVATE LIMITED","continueFlag":"Y","LLPIN":"","NICCode3":"","Description3":"","proposedName2":""},"status":"Draft/Pending Submission","eventDate":"","formDescription":"SPICE PART A","formName":"Spice+ Part A","formVersion":"1","userId":"BIPULKUMARSINGH6690@GMAIL.COM","referenceNumber":"1-9224733161","operation":"","srn":"","formId":"","Approvedname":"","formAttachment":[]}}'''

multipart_data = MultipartEncoder(fields={
    'data': (None, payload4_json),
    'action': (None, 'savesubmit'),
    'operation': (None, 'Submit'),
    'serveAction': (None, 'submitform')
})

headers['Content-Type'] = multipart_data.content_type

response = requests.post(url, headers=headers, data=multipart_data)
print(response.status_code)
print(response.text)
# Out:
# 200
# {"error":"","message":"Data Added Successfully","data":{"SRN":"","SRNStatus":"Submitted","formType":"NSTP","integrationId":"1-4A1NYIF","ReferenceNumber":"1-9314588535","SubmittedDate":"06/16/2023 18:36:43","formIntegrationId":"1-4A1NYIH","MCASpiceBForm":{"subscriberMemorandum":"LEGAL NITI PRIVATE LIMITED","shareCapital":"Having Share Capital"},"ReferenceNumberPartB":"1-9315186695"}}

# %%
def print_characters(start_char, end_char):
    # Convert start and end characters to their ASCII values
    start_ord = ord(start_char)
    end_ord = ord(end_char)

    # Create an empty array to store the characters
    characters = []

    # Iterate over the ASCII values and convert them back to characters
    for char_ord in range(start_ord, end_ord + 1):
        char = chr(char_ord)
        characters.append(char)

    # Print the resulting array of characters|
    print(characters)


# Test the function
start = input("Enter the start characters: ")
end = input("Enter the end characters: ")

# Ensure the start and end inputs have the same length
if len(start) == len(end):
    print_characters(start, end)
else:
    print("Error: Start and end inputs should have the same length.")
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j', 'k', 'l', 'm']

# %%
payload=r'''{"requestBody":{"userId":"BIPULKUMARSINGH6690@GMAIL.COM","referenceNumber":"1-9713920310","srn":"","action":"SpiceplusAViewForm"}}'''

# %%
#to get folder id and stuff
import requests
from requests_toolbelt.multipart.encoder import MultipartEncoder

url = 'https://www.mca.gov.in/bin/mca-gov/spiceGetData'

headers = {
    'Host': 'www.mca.gov.in',
    'Cookie': 'cookiesession1=678B28695C218253C321286001478935; alertPopup=true; session-token=eyJhbGciOiJIUzUxMiJ9..V_U1rbJwawUZegqIPhTfJ-1nBpU5pCeBUht66L_iOejOCpmiIZqMAtynfgXZxS1WV58sJ2g3l7Yw-YMkOphsVQ; sessionID=58770fcc-cb83-406a-afc3-391a933aae75; deviceId=dzde8fggrkl',
    'Content-Type': 'multipart/form-data; boundary=----WebKitFormBoundaryCzELCG2dAxL2APPw',
    'Accept': '*/*',
    'Csrf-Token': 'undefined',
    'X-Requested-With': 'XMLHttpRequest',
    'Origin': 'https://www.mca.gov.in',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.199 Safari/537.36',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Dest': 'empty',
    'Accept-Encoding': 'gzip, deflate',
    'Accept-Language': 'en-US,en;q=0.9'
}

multipart_data = MultipartEncoder(fields={
    'data': payload
})

# Set the headers with the appropriate content-type
# headers['Content-Type'] = payload.content_type

# Send the POST request
response = requests.post(url, headers=headers, data=multipart_data)

# Check the response
if response.status_code == 200:
    print('Request successful!')
    print('Response:', response.text)
else:
    print('Request failed. Status code:', response.status_code)
# Out:
# Request failed. Status code: 403

# %%
import urllib.parse

formData ="%7b%22requestBody%22%3a%7b%22userId%22%3a%22BIPULKUMARSINGH6690@GMAIL.COM%22%2c%22referenceNumber%22%3a%221-9713920310%22%2c%22srn%22%3a%22%22%2c%22action%22%3a%22SpiceplusAViewForm%22%7d%7d"
# Manually parse the data
decoded_data = urllib.parse.unquote_plus(formData,encoding='utf-8')
data_start = decoded_data.find('{')

data_end = decoded_data.rfind('}') + 1
data_str = decoded_data[data_start:data_end]
data = eval(data_str)
# data['formData']['proposedName1']=c_name
encoded_data = urllib.parse.quote_plus(json.dumps(data), encoding='utf-8').replace('%20', '').replace('%28','(').replace('%29',')').replace('+%','%')

# %%
encoded_data
# Out:
# '%7B%22requestBody%22%3A%7B%22userId%22%3A%22BIPULKUMARSINGH6690%40GMAIL.COM%22%2C%22referenceNumber%22%3A%221-9713920310%22%2C%22srn%22%3A%22%22%2C%22action%22%3A%22SpiceplusAViewForm%22%7D%7D'

# %%
import requests

url = 'https://www.mca.gov.in/bin/mca-gov/spiceGetData'

headers = {
    'Host': 'www.mca.gov.in',
    'Cookie': 'cookiesession1=678B28695C218253C321286001478935; alertPopup=true; session-token=eyJhbGciOiJIUzUxMiJ9..V_U1rbJwawUZegqIPhTfJ-1nBpU5pCeBUht66L_iOejOCpmiIZqMAtynfgXZxS1WV58sJ2g3l7Yw-YMkOphsVQ; sessionID=58770fcc-cb83-406a-afc3-391a933aae75; deviceId=dzde8fggrkl',
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    'Accept': '*/*',
    'Csrf-Token': 'undefined',
    'X-Requested-With': 'XMLHttpRequest',
    'Origin': 'https://www.mca.gov.in',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.199 Safari/537.36',
    'Sec-Fetch-Site': 'same-origin',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Dest': 'empty',
    'Accept-Encoding': 'gzip, deflate',
    'Accept-Language': 'en-US,en;q=0.9'
}


payload=f"data={encoded_data}"
response = requests.post(url, headers=headers, data=payload)
response.text
# Out:
# '{"error":"","message":"Data Fetched Successfully","data":{"integrationId":"1-4GNF0VQ","status":"Submitted","reason":"","formData":{"formIntegrationId":"1-4GNF0WW","companyType":"New Company (Others)","CIN":"","companyClass":"Private","companyCategory":"Company limited by shares","companySubCategory":"Non-government company","NICCode1":"98200","Description1":"Undifferentiated service-producing activities of private households for own use","NICCode2":"","Description2":"","NICCode3":"","Description3":"","proposedName1":"HGCGHCFC PRIVATE LIMITED","proposedName2":"","proposedNameRating1":"","proposedNameRating2":""},"formAttachment":[{"attachmentLabel":"Spice+ Part A","attachmentCategory":"Forms","activityFileName":"1-9713920310.pdf","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"26646","attachmentDMSId":"347832456","totalNoOfPages":"2","activityFileDate":"07/08/2023 02:07:26","publicDocument":"Y","activityComments":"Generated PDF Stored Successfully","folderId":"171251262","folderName":"InZmR590399349705","addedBy":"Fo User","version":"0"},{"attachmentLabel":"Spice+ Part A","attachmentCategory":"Forms","activityFileName":"1-9713920310.pdf","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"26646","attachmentDMSId":"347832454","totalNoOfPages":"2","activityFileDate":"07/08/2023 02:07:23","publicDocument":"Y","activityComments":"Generated PDF Stored Successfully","folderId":"171251261","folderName":"InZmR590399349705","addedBy":"Fo User","version":"0"}],"accountType":"","expiryDate":"","approvedName":"HGCGHCFC PRIVATE LIMITED","eventDate":"","lastUpdatedDate":"","MCAFillingDate":"07/08/2023","purpose":"Default","approvalDate":"","mcaRSUBFlag":"N"}}'
