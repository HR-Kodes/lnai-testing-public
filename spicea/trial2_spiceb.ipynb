# %%
import json
import json

with open('data.json') as f:
   inp = json.load(f)

# %%
from datetime import datetime

# %%
inp
# Out:
# {'spiceBpartaddress': [{'line1': 'C/O H N CHAMPA,#17 ',
#    'line2': 'Basaveswara HBC LYT.',
#    'pincode': '560040',
#    'addressType': 'Correspondance Address',
#    'coutry': 'India',
#    'area': 'Chandra Lay Out',
#    'city': 'Bangalore North',
#    'district': 'Bangalore',
#    'state_ut': 'Karnataka',
#    'mobile': '9108042546',
#    'companymailid': 'ananyamadhav23@gmail.com'}],
#  'corresaddressameasregaddress': 'Y',
#  'lat': '12.9680',
#  'long': '77.5305',
#  'roc': 'Registrar of Companies, Karnataka',
#  'formIntId': '1-4IF12OS',
#  'refNo': '1-9431091455',
#  'IntId': '1-4PZC9ZF',
#  'userId': 'BIPULKUMARSINGH6690@GMAIL.COM',
#  'pan': 'DLQPR2890H',
#  'Dir_w_din_count': '1',
#  'Dir_wt_din_count': '1',
#  'Dir_w_DIN': [{'SubscriberType': 'Subscriber CUM Director DIN',
#    'din': '08553753',
#    'name': '',
#    'nationality': '',
#    'firstName': '',
#    'middleName': '',
#    'category': 'Individual First subscribers cum Directors',
#    'Surname': '',
# ...

# %%
srn='1-10501882963'

# %%
def up(dict1:dict,dict2:dict):
    i = dict1.keys()
    j = dict2.keys()
    common_keys = filter(lambda x: x in i, j)
    tmp_dict = dict2.copy()
    # keys_not_in_dict2 = [key for key in dict1 if key not in dict2]
    keys_not_in_dict2 = [key for key in dict1 if key not in dict2]
    # print(keys_not_in_dict1)
    # print(common_keys)
    for x in common_keys:
        # print(x)
        if type(dict1[x]) is dict:
            tmp_dict[x] = up(dict1[x],dict2[x])
        elif type(dict1[x]) is list and dict1[x]:
            for a in range(len(dict1[x])):
                tmp_dict[x][a] = up(dict1[x][a],dict2[x][a])
                # print(dict1[x][a],'\n',dict2[x][a])
        elif type(dict1[x]) is str and dict1[x]:
            # print(x)
            tmp_dict[x] = dict1[x]
        elif dict1[x] == '':
            # print(x)
            tmp_dict[x] = dict1[x]
    for x in keys_not_in_dict2:
        tmp_dict[x] = dict1[x]
    return tmp_dict

# %%
import requests
import json
from requests_toolbelt.multipart.encoder import MultipartEncoder

url = "https://www.mca.gov.in/bin/mca/login"
# url='https://e109148.dscb.akamaiedge.net./23.41.4.72'

headers = {
    "Origin": "www.mca.gov.in",
    "Content-Length": "231",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/113.0.5672.127 Safari/537.36",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Accept": "*/*",
    "X-Requested-With": "XMLHttpRequest",
    "Sec-Ch-Ua-Platform": "Windows"
}
data="data=Ut8pBOc0RSM6iYqffqN1orWH0Ee6A57QEKGmyHa5KnuzzybQ%2BjY2pMJIsLZw9DznTxfJeWvJFEcqsU2aZC33AC2nYaU60TNo8VjomCHN2dDSdHEC2enwIeEWCNR42vj7gfXFsvEwLfoO25%2BUKeho68x7N0qx56oyIAoVHQsAH1VP5mEoz%2FgNjOF8O12Av4DsLLckO7DUNCnmr%2FYByWESRw%3D%3D"
# data="data=Ut8pBOc0RSM6iYqffqN1oiyj9WvJGiJEVVlWEbrO16gkiUbYKGssebXlM%2Bcc1l6%2FlYt9nd52E%2F6cRHxAhy9plsPqVlTm%2BlnUYYrPt1WD3ffWRYE89JPWwGsKmmXvLHUmWvHhyaU92uRNpQhiodcazD9wyNQT%2FRjmh%2BH7H3vXG3T9TXgFBv0JbIVMm2J%2B4iA%2BcmMG7k2a4%2BkLGnUsqK4W8w%3D%3D"
response = requests.post(url, headers=headers, data=data)
set_cookie_value = response.headers.get('Set-Cookie')
start_index = set_cookie_value.find("session-token=") + len("session-token=")
end_index = set_cookie_value.find(";", start_index)
session_token = set_cookie_value[start_index:end_index]

# %%
session_token
# Out:
# 'eyJhbGciOiJIUzUxMiJ9..xjKTSkA-Bag5ABWoAFWrkK0gV1EurygNRfOjS9bzTIPpV5OzBcFx-eO7q5i75j7sCxUnNRBCcIx4hslGFunwaA'

# %%
url = 'https://www.mca.gov.in/bin/spiceDashboard'
params = {'srn': f'{srn}'}
headers = {
    'Cookie': 'cookiesession1=678B2869A3F37E351C741CDEA2BC2CAE; alertPopup=true; session-token=eyJhbGciOiJIUzUxMiJ9..iWqz4A95_KnZpPNGR5UE1DpwcaPt3taMQFX0nFGvEbHEiW7ubNlQ0Tglvo-qaP6ScRJGWt292IwJj-s-_I61Dg; sessionID=c4f8c54d-7846-489c-8f2b-20358c0597a3; deviceId=bak4bebjs1m',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64; rv:109.0) Gecko/20100101 Firefox/115.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'X-Requested-With': 'XMLHttpRequest',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}

try:
    response = requests.get(url, params=params, headers=headers)
    response.raise_for_status()  # Check if the request was successful
    print("Response:")
    print(response.text)  # Print the response content if needed
except requests.exceptions.RequestException as e:
    print(f"Error: {e}")
# Out:
# Response:
# {"message":"Data fetched Successfully","error":"","linkedForms":[{"integrationId":"1-4TOJSR7","primaryParentSRId":"No Match Row Id","referenceNumber":"1-10501882963","formName":"Spice+ Part A","srnNumber":"","action":{"type":"14-AUG-23","status":""},"parentServiceRequestId":"","updated":"2023-08-14T19:10:22.000+05:30","status":"Submitted","approvalDate":""},{"integrationId":"1-4U2W7N7","spiceBDirectorDeclaration":{"membershipNumber":"","certificateofPracticeNumber":"","associate_Fellow":"","practiceNumber_declaration":"","LegalProffesion":"","dropdown2":"","membershipNumber_declaration":""},"primaryParentSRId":"No Match Row Id","referenceNumber":"1-10525976755","formName":"SPICE + Part B","srnNumber":"","parentServiceRequestId":"1-4TOJSR7","updated":"2023-08-14T19:14:34.000+05:30","status":"Draft/Pending Submission"}]}

# %%
a=json.loads(response.text)['linkedForms']

# %%
ref_no=json.loads(response.text)['linkedForms'][1]['referenceNumber']

# %%
#page 1 next
url = 'https://www.mca.gov.in/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer.af.dermis'
headers = {
    'Cookie': f'cookiesession1=678B2869A3F37E351C741CDEA2BC2CAE; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': 'text/plain, */*; q=0.01',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    # 'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'X-Requested-With': 'XMLHttpRequest',
    'Csrf-Token': 'undefined',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}

payload = {
    'functionToExecute': 'invokeFDMOperation',
    'formDataModelId': '/content/dam/formsanddocuments-fdm/mca-aem-forms/spice-part-b/spice-b-prefill',
    'input': f'{{"Model0": {{"requestBody": {{"userId": "", "referenceNumber": "{ref_no}", "srn": ""}}}}}}',

    'operationName': 'POST /spicepartb/services/getSRNDetails/1.0.0',
    # 'guideNodePath': '/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer/rootPanel/items/panel_437033673/items/panel_651281723_copy_1876865449/items/mca_button_copy_33766249'
    'guideNodePath': '/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer/rootPanel/items/panel_2001397683/items/panel_651281723/items/mca_button_copy_33766249'

}

response = requests.post(url, headers=headers, data=payload)

print(response.text)
print(response.status_code)
# Out:
# {"error":"","message":"Data Fetched Successfully","integrationId":"1-4U2W7N7","formIntegrationId":"1-4U2W7NA","data":{"status":"Draft/Pending Submission","formData":{"formIntegrationId":"1-4U2W7NA","numberOfArticles":"","aoaEntrenched":"N","Havingsharecapital":"","totalSubscribedShareCapital":"100000","totalUnclassifiedAuthorizedShareCapital":"100000","totalClassifiedAuthorizedShareCapital":"100000","totalAuthorizedShareCapital":"200000","equitynumberofClasses":"1","preferencenumberofClasses":"0","maxnumofMembers":"","maxNumofMembersExcludingProposedemp":"","numOfMembers":"2","numOfMembersExcludingProposedEmp":"","regaddressline1":"C/O H N CHAMPA,#17","regaddressline2":"Basaveswara HBC LYT.","regaddresscity":"Bangalore North","regaddressstate_ut":"Karnataka","regaddressarea":"Chandra Lay Out","regaddresspincode":"560040","regaddressdistrict":"Bangalore","regaddresscountry":"India","regaddresscountryCode":"","regaddressfax":"","regaddresscompanymailid":"ananyamadhav23@gmail.com","rega
# ...

# %%
intid=json.loads(response.text)['integrationId']
formIntId=json.loads(response.text)['formIntegrationId']

# %%
payload1=r'''{"requestBody":{"formData":{"aoaEntrenched":"N","Havingsharecapital":"Having Share Capital","totalAuthorizedShareCapital":"200000","totalClassifiedAuthorizedShareCapital":"100000","totalSubscribedShareCapital":"100000","totalUnclassifiedAuthorizedShareCapital":"100000","equitynumberofClasses":"1","preferencenumberofClasses":"0","regaddresscountry":"India","NonIndividualCountWithoutDIN":"0","SpicePartBINDVSubscribersHavingDin":[{"INDVSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"INDVSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}]}],"SpicePartBINDVSubscribersNotHavingDin":[{"SpicePartBINDVsubscribersPermAddress":{"addressType":"Permanent Address"},"SpicePartBINDVsubscribersPresAddress":{"addressType":"Present Address"},"INDVSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"INDVSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}]}],"SpicePartBSubscribersHavingDin":[{"SubscriberType":"Subscriber CUM Director DIN","category":"Individual First subscribers cum Directors","SpicePartBSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"SpicePartBSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}],"SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"SpicePartBSubscribersNotHavingDin":[{"category":"Individual First subscribers cum Directors","SubscriberType":"Subscriber CUM Director No DIN","SpicePartBSubscribersPermAddress":{"addressType":"Permanent Address"},"SpicePartBSubscribersPresAddress":{"addressType":"Present Address"},"SpicePartBSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"SpicePartBSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}],"SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"SpicePartBDirectorsHavingDin":[{"category":"Directors","SubscriberType":"Directors Having DIN","SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"SpicePartBDirectorsNotHavingDin":[{"category":"Directors","SubscriberType":"Directors Not Having DIN","SpicePartBSubscribersPermAddress":{"addressType":"Permanent Address"},"SpicePartBSubscribersPresAddress":{"addressType":"Present Address"},"SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"formIntegrationId":"1-4C351SZ","SpicePartBShares":[{"classShare":"1","authorizedcapitalsharenumber":"10000","subscribedcapitalsharenumber":"10000","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"100000","subscribedcapitaltotalamount":"100000","sharecategory":"Equity Share"}],"spicePartBNonINDVSubscribers":[]},"status":"Draft/Pending Submission","formDescription":"For Spice+PartB","formName":"SPICE + Part B","formVersion":"01","userId":"BIPULKUMARSINGH6690@GMAIL.COM","integrationId":"1-4C351PA","referenceNumber":"1-9437997790","formAttachment":[],"operation":"Save","action":"savesubmit","formIntegrationId":"1-4C351SZ","srn":""}}'''
payload1_json=json.loads(payload1)

# %%
# payload1_json['requestBody']['status']="Resubmission Required"

# %%
payload1_json['requestBody']['formData']['SpicePartBShares'][0]['subscribedcapitalsharenumber']='10000'
payload1_json['requestBody']['formData']['SpicePartBShares'][0]['authorizedcapitalnominalamountpershare']='10'
payload1_json['requestBody']['formData']['SpicePartBShares'][0]['authorizedcapitaltotalamount']
payload1_json['requestBody']['formData']['SpicePartBShares'][0]['authorizedcapitalsharenumber']='10000'
payload1_json['requestBody']['formData']['SpicePartBShares'][0]['authorizedcapitaltotalamount']=''
payload1_json['requestBody']['formData']['SpicePartBShares'][0]['subscribedcapitaltotalamount']=''
payload1_json['requestBody']['formData']['Havingsharecapital']=''
payload1_json['requestBody']['userId']=inp['userId']
payload1_json['requestBody']['referenceNumber']=ref_no
payload1_json['requestBody']['formData']['formIntegrationId']=formIntId
payload1_json['requestBody']['formIntegrationId']=formIntId
payload1_json['requestBody']['integrationId']=intid
payload1_json=json.dumps(payload1_json)

# %%
payload1_json
# Out:
# '{"requestBody": {"formData": {"aoaEntrenched": "N", "Havingsharecapital": "", "totalAuthorizedShareCapital": "200000", "totalClassifiedAuthorizedShareCapital": "100000", "totalSubscribedShareCapital": "100000", "totalUnclassifiedAuthorizedShareCapital": "100000", "equitynumberofClasses": "1", "preferencenumberofClasses": "0", "regaddresscountry": "India", "NonIndividualCountWithoutDIN": "0", "SpicePartBINDVSubscribersHavingDin": [{"INDVSubscribersEquityShares": [{"sharecategory": "Equity Share"}], "INDVSubscribersPreferenceShares": [{"sharecategory": "Preference Share"}]}], "SpicePartBINDVSubscribersNotHavingDin": [{"SpicePartBINDVsubscribersPermAddress": {"addressType": "Permanent Address"}, "SpicePartBINDVsubscribersPresAddress": {"addressType": "Present Address"}, "INDVSubscribersEquityShares": [{"sharecategory": "Equity Share"}], "INDVSubscribersPreferenceShares": [{"sharecategory": "Preference Share"}]}], "SpicePartBSubscribersHavingDin": [{"SubscriberType": "Subscriber CUM Dir
# ...

# %% [markdown]
# IF RESUBMIT

# %%
# #to resubmit
# import requests

# # Request headers and payload data
# headers = {
#     "Host": "www.mca.gov.in",
#     "Cookie": f"cookiesession1=678B2869D727DAE036D48B6E36133C84; session-token={session_token}",
#     "Content-Length": "62",
#     "Sec-Ch-Ua": "",
#     "Sec-Ch-Ua-Mobile": "?0",
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.5790.110 Safari/537.36",
#     "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
#     "Accept": "*/*",
#     "Csrf-Token": "undefined",
#     "X-Requested-With": "XMLHttpRequest",
#     "Sec-Ch-Ua-Platform": "",
#     "Origin": "https://www.mca.gov.in",
#     "Sec-Fetch-Site": "same-origin",
#     "Sec-Fetch-Mode": "cors",
#     "Sec-Fetch-Dest": "empty",
#     "Referer": "https://www.mca.gov.in/content/mca/global/spicedashboard.html?applicationHistory=eyJzcm4iOiJBQTMwODM0NTUiLCJyZWZlcmVuY2UiOiIxLTk0Mzc5NjU4MDYiLCJwdXJwb3NlIjoiRGVmYXVsdCIsInByb3Bvc2VkTmFtZSI6IkZBSFRFQ0hOT0xPR0lFUyBQUklWQVRFIExJTUlURUQifQ%3D%3D",
#     "Accept-Encoding": "gzip, deflate",
#     "Accept-Language": "en-US,en;q=0.9"
# }

# payload = "requestType=discard&referenceNumber=1-9954521492&srn=AA3083455"

# # Make the POST request
# url = "https://www.mca.gov.in/bin/spiceDashboard"
# response = requests.post(url, headers=headers, data=payload)

# # Print the response status and content
# print(f"Status Code: {response.status_code}")
# print("Response Content:")
# print(response.text)

# %%
import requests

# Request headers and payload data
headers = {
    "Host": "www.mca.gov.in",
    "Cookie": f"cookiesession1=678B2869D727DAE036D48B6E36133C84; session-token={session_token}",
    "Content-Length": "579",
    "Sec-Ch-Ua": "",
    "Sec-Ch-Ua-Mobile": "?0",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.5790.110 Safari/537.36",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Accept": "text/plain, */*; q=0.01",
    "Csrf-Token": "undefined",
    "X-Requested-With": "XMLHttpRequest",
    "Sec-Ch-Ua-Platform": "",
    "Origin": "https://www.mca.gov.in",
    "Sec-Fetch-Site": "same-origin",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Dest": "empty",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html?applicationHistory=eyJzcm4iOiJBQTMwODM0NTUiLCJyZWZlcmVuY2UiOiIxLTk5NTQ1MjE0OTIiLCJwdXJwb3NlIjoiIn0=",
    "Accept-Encoding": "gzip, deflate",
    "Accept-Language": "en-US,en;q=0.9"
}

payload = 'functionToExecute=invokeFDMOperation&formDataModelId=%2Fcontent%2Fdam%2Fformsanddocuments-fdm%2Fmca-aem-forms%2Fspice-part-b%2Fspice-b-prefill&input=%7B%22Model0%22%3A%7B%22requestBody%22%3A%7B%22userId%22%3A%22%22%2C%22referenceNumber%22%3A%221-9954521492%22%2C%22srn%22%3A%22%22%7D%7D%7D&operationName=POST+%2Fspicepartb%2Fservices%2FgetSRNDetails%2F1.0.0&guideNodePath=%2Fcontent%2Fforms%2Faf%2Fmca-aem-forms%2Fspice-part-b%2Fspice-plus-part-b%2Fjcr%3Acontent%2FguideContainer%2FrootPanel%2Fitems%2Fpanel_2001397683%2Fitems%2Fpanel_651281723%2Fitems%2Fmca_button_copy_33766249'

# Make the POST request
url = "https://www.mca.gov.in/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer.af.dermis"
response = requests.post(url, headers=headers, data=payload)

# Print the response status and content
print(f"Status Code: {response.status_code}")
print("Response Content:")
print(response.text)
# Out:
# Status Code: 200
# Response Content:
# ...

# %%
session_token
# Out:
# 'eyJhbGciOiJIUzUxMiJ9..xjKTSkA-Bag5ABWoAFWrkK0gV1EurygNRfOjS9bzTIPpV5OzBcFx-eO7q5i75j7sCxUnNRBCcIx4hslGFunwaA'

# %%
#page 1 save
url = "https://www.mca.gov.in/bin/mca-gov/SpicePartB_SAVESUBMIT"

headers = {
    "Cookie": f"cookiesession1=678B28691F6518167EE395808C55BE5E; alertPopup=true; session-token=e{session_token}",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0",
    "Accept": "*/*",
    "Accept-Language": "en-US,en;q=0.5",
    "Accept-Encoding": "gzip, deflate",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html",
    "X-Requested-With": "XMLHttpRequest",
    "Content-Type": "multipart/form-data",
    "Content-Length": "3692",
    "Origin": "https://www.mca.gov.in",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "Te": "trailers"
}


multipart_data = MultipartEncoder(fields={
    'data': (payload1_json),
    'action': 'savesubmit',
    'operation': 'Save',
    'serveAction': 'saveForm',
    'referenceNumber': '',
    'formId': ''
})

headers['Content-Type'] = multipart_data.content_type
response = requests.post(url, headers=headers, data=multipart_data)

print(response.text)

# %%
json.dumps(payload1_json)
# Out:
# '"{\\"requestBody\\": {\\"formData\\": {\\"aoaEntrenched\\": \\"N\\", \\"Havingsharecapital\\": \\"\\", \\"totalAuthorizedShareCapital\\": \\"200000\\", \\"totalClassifiedAuthorizedShareCapital\\": \\"100000\\", \\"totalSubscribedShareCapital\\": \\"100000\\", \\"totalUnclassifiedAuthorizedShareCapital\\": \\"100000\\", \\"equitynumberofClasses\\": \\"1\\", \\"preferencenumberofClasses\\": \\"0\\", \\"regaddresscountry\\": \\"India\\", \\"NonIndividualCountWithoutDIN\\": \\"0\\", \\"SpicePartBINDVSubscribersHavingDin\\": [{\\"INDVSubscribersEquityShares\\": [{\\"sharecategory\\": \\"Equity Share\\"}], \\"INDVSubscribersPreferenceShares\\": [{\\"sharecategory\\": \\"Preference Share\\"}]}], \\"SpicePartBINDVSubscribersNotHavingDin\\": [{\\"SpicePartBINDVsubscribersPermAddress\\": {\\"addressType\\": \\"Permanent Address\\"}, \\"SpicePartBINDVsubscribersPresAddress\\": {\\"addressType\\": \\"Present Address\\"}, \\"INDVSubscribersEquityShares\\": [{\\"sharecategory\\": \\"Equity Share\
# ...

# %%
#page 2 pin code

import requests

url = 'https://www.mca.gov.in/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer.af.dermis'
headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': 'text/plain, */*; q=0.01',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'X-Requested-With': 'XMLHttpRequest',
    'Csrf-Token': 'undefined',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}

pincode=inp['spiceBpartaddress'][0]['pincode']
payload = {
    'functionToExecute': 'invokeFDMOperation',
    'formDataModelId': '/content/dam/formsanddocuments-fdm/mca-aem-forms/spice-part-b/pincode',
    'input': f'{{"pinCode":"{pincode}"}}',
    'operationName': 'GET /common/service/lookup/pindetails/1.0.0',
    'guideNodePath': '/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer/rootPanel/items/panel_2001397683/items/panel_1902152287/items/guidetextbox_copy_11_762323347'
}

response = requests.post(url, headers=headers, data=payload)

print(response.text)
print(response.status_code)
# Out:
# {"data":[{"Area":"Chandra Lay Out","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"},{"Area":"Vijayanagar East","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"},{"Area":"Vijayanagar (Bangalore)","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"}],"error":"","message":"Data fetched Successfully"}
# 200

# %%
a=json.loads(response.text)['data']
area=[i['Area'] for i in a]
state=a[0]['State']
city=a[0]['city']
district=a[0]['District']
state=a[0]['State']

# %%
#page 2 arealocality
url = 'https://www.mca.gov.in/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer.af.dermis'
headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': 'text/plain, */*; q=0.01',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'X-Requested-With': 'XMLHttpRequest',
    'Csrf-Token': 'undefined',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}

payload = {
    'functionToExecute': 'invokeFDMOperation',
    'formDataModelId': '/content/dam/formsanddocuments-fdm/mca-aem-forms/spice-part-b/newroclist',
    'input': '{"Type":"MCA_ROC_LIST","Name":'+f"'{state}'"+'}',
    'operationName': 'GET /common/service/lookup/form15/val/1.0.0',
    'guideNodePath': '/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer/rootPanel/items/panel_2001397683/items/panel_1902152287/items/panel_1966601478/items/guidenumericbox_6907'
}

response = requests.post(url, headers=headers, data=payload)

print(response.text)
print(response.status_code)
# Out:
# {"data":[{"name":"Registrar of Companies, Karnataka"}],"error":"","message":"Data fetched Successfully"}
# 200

# %%
#Name of the office of the Registrar of Companies in which the proposed company is to be registered
reg=json.loads(response.text)['data'][0]['name']

# %%
#spicepartbaddressproof
file_path = r"/home/pratik/Downloads/1.pdf"
file_name1="1.pdf"

# %%
def form_save_file(url,headers,label,file_path,file_name):
    with open(file_path,'rb') as file:
        payload = {
        'file': (file_name, file, 'application/pdf'),
        'folder': '',
        'filemetadata': '{"form":"SPICE + Part B","srn":"","documentType":"Attachment","module":"SPICE + Part B","userid":"SPICE + Part B","applicationId":"","attachmentCategory":"pdf","attachmentLabel":'+f'{label}'+'}'
    }
    
        return requests.post(url,headers=headers,files=payload)

# %%
url = 'https://www.mca.gov.in/bin/mca/dms/addservice'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Csrf-Token': 'undefined',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}
response = form_save_file(url,headers,"SpiceBproofAddress",file_path,f'1{file_name1}')
if response.status_code == 200:
    print('File uploaded successfully')
else:
    print('Failed to upload the file')
# Out:
# File uploaded successfully

# %%
att_resp1=json.loads(response.text)

# %%
#spicepartBulilitycopy
file_path = r"/home/pratik/Downloads/a1.jpeg"
file_name2="a1.jpeg"

# %%
url = 'https://www.mca.gov.in/bin/mca/dms/addservice'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Csrf-Token': 'undefined',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}
response = form_save_file(url,headers,"SpiceBcopyUtility",file_path,file_name2)
if response.status_code == 200:
    print('File uploaded successfully')
else:
    print('Failed to upload the file')
# Out:
# File uploaded successfully

# %%
att_resp2=json.loads(response.text)

# %%
payload2=r'''{"requestBody":{"formData":{"aoaEntrenched":"N","Havingsharecapital":"Having Share Capital","totalAuthorizedShareCapital":"113000","totalClassifiedAuthorizedShareCapital":"13000","totalSubscribedShareCapital":"2000","totalUnclassifiedAuthorizedShareCapital":"100000","equitynumberofClasses":"2","preferencenumberofClasses":"2","SpicePartBAddress":[{"line1":"asdad","line2":"asdada","pincode":"560019","addressType":"Correspondance Address","coutry":"India","area":"Gaviopuram Extension","city":"Bangalore South","district":"Bangalore","state_ut":"Karnataka","mobile":"2313131312","companymailid":"asda@gmail.com"}],"regaddressline1":"asdad","regaddressline2":"asdada","regaddresspincode":"560019","regaddresscountry":"India","regaddresscity":"Bangalore South","regaddressdistrict":"Bangalore","regaddressstate_ut":"Karnataka","regaddresscompanymailid":"asda@gmail.com","regaddressarea":"Gaviopuram Extension","corresAddrSameRegAddr":"N","rocName":"Registrar of Companies, Karnataka","NonIndividualCountWithoutDIN":"0","SpicePartBINDVSubscribersHavingDin":[{"INDVSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"INDVSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}]}],"SpicePartBINDVSubscribersNotHavingDin":[{"SpicePartBINDVsubscribersPermAddress":{"addressType":"Permanent Address"},"SpicePartBINDVsubscribersPresAddress":{"addressType":"Present Address"},"INDVSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"INDVSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}]}],"SpicePartBSubscribersHavingDin":[{"SubscriberType":"Subscriber CUM Director DIN","category":"Individual First subscribers cum Directors","SpicePartBSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"SpicePartBSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}],"SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"SpicePartBSubscribersNotHavingDin":[{"category":"Individual First subscribers cum Directors","SubscriberType":"Subscriber CUM Director No DIN","SpicePartBSubscribersPermAddress":{"addressType":"Permanent Address"},"SpicePartBSubscribersPresAddress":{"addressType":"Present Address"},"SpicePartBSubscribersEquityShares":[{"sharecategory":"Equity Share"}],"SpicePartBSubscribersPreferenceShares":[{"sharecategory":"Preference Share"}],"SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"SpicePartBDirectorsHavingDin":[{"category":"Directors","SubscriberType":"Directors Having DIN","SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"SpicePartBDirectorsNotHavingDin":[{"category":"Directors","SubscriberType":"Directors Not Having DIN","SpicePartBSubscribersPermAddress":{"addressType":"Permanent Address"},"SpicePartBSubscribersPresAddress":{"addressType":"Present Address"},"SpicePartBSubsDeclaration":[{"shareholdingPercentage":"0"}]}],"formIntegrationId":"1-4CXKS24","SpicePartBShares":[{"sharecategory":"Preference Share","classShare":"12","authorizedcapitalsharenumber":"100","subscribedcapitalsharenumber":"0","authorizedcapitalnominalamountpershare":"100","subscribedcapitalnominalamountpershare":"100","authorizedcapitaltotalamount":"10000"},{"sharecategory":"Preference Share","classShare":"13","authorizedcapitalsharenumber":"100","subscribedcapitalsharenumber":"0","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"1000"},{"classShare":"1","authorizedcapitalsharenumber":"100","subscribedcapitalsharenumber":"100","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"1000","subscribedcapitaltotalamount":"1000","sharecategory":"Equity Share"},{"classShare":"2","authorizedcapitalsharenumber":"100","subscribedcapitalsharenumber":"100","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"1000","subscribedcapitaltotalamount":"1000","sharecategory":"Equity Share"}],"spicePartBNonINDVSubscribers":[]},"status":"Draft/Pending Submission","formDescription":"For Spice+PartB","formName":"SPICE + Part B","formVersion":"01","userId":"BIPULKUMARSINGH6690@GMAIL.COM","integrationId":"1-4CXKS21","referenceNumber":"1-9489120265","formAttachment":[{"attachmentLabel":"SpiceBproofAddress","attachmentCategory":"Attachment","activityFileName":"1AA290623000151T_RC13062023.pdf","activityFileSrcPath":"170638497","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"81873","attachmentDMSId":"345253894","totalNoOfPages":"3","activityFileDate":"06/26/2023","publicDocument":"Y","activityComments":"170638497:SpiceBproofAddress:Document added successfully.","folderName":"tbU5W44287200571","folderId":"170638497","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBcopyUtility","attachmentCategory":"Attachment","activityFileName":"NIC-2004_detail_19jan2009.pdf","activityFileSrcPath":"170638497","activityFileSrcType":"I","activityFileExt":"pdf","activityFileSize":"386212","attachmentDMSId":"345253994","totalNoOfPages":"58","activityFileDate":"06/26/2023","publicDocument":"Y","activityComments":"170638497:SpiceBcopyUtility:Document added successfully.","folderName":"170638497","folderId":"170638497","version":"","addedBy":"Fo User"}],"operation":"Save","action":"savesubmit","formId":"","formIntegrationId":"1-4CXKS24","srn":""}}'''
payload2_json=json.loads(payload2)

# %%
payload2_json=up(json.loads(payload1_json),payload2_json)

# %%
payload2_json
# Out:
# {'requestBody': {'formData': {'aoaEntrenched': 'N',
#    'Havingsharecapital': '',
#    'totalAuthorizedShareCapital': '200000',
#    'totalClassifiedAuthorizedShareCapital': '100000',
#    'totalSubscribedShareCapital': '100000',
#    'totalUnclassifiedAuthorizedShareCapital': '100000',
#    'equitynumberofClasses': '1',
#    'preferencenumberofClasses': '0',
#    'SpicePartBAddress': [{'line1': 'asdad',
#      'line2': 'asdada',
#      'pincode': '560019',
#      'addressType': 'Correspondance Address',
#      'coutry': 'India',
#      'area': 'Gaviopuram Extension',
#      'city': 'Bangalore South',
#      'district': 'Bangalore',
#      'state_ut': 'Karnataka',
#      'mobile': '2313131312',
#      'companymailid': 'asda@gmail.com'}],
#    'regaddressline1': 'asdad',
#    'regaddressline2': 'asdada',
#    'regaddresspincode': '560019',
#    'regaddresscountry': 'India',
#    'regaddresscity': 'Bangalore South',
#    'regaddressdistrict': 'Bangalore',
# ...

# %%
payload2_json['requestBody']['formData']['SpicePartBAddress']
# Out:
# [{'line1': 'asdad',
#   'line2': 'asdada',
#   'pincode': '560019',
#   'addressType': 'Correspondance Address',
#   'coutry': 'India',
#   'area': 'Gaviopuram Extension',
#   'city': 'Bangalore South',
#   'district': 'Bangalore',
#   'state_ut': 'Karnataka',
#   'mobile': '2313131312',
#   'companymailid': 'asda@gmail.com'}]

# %%
spiceBpartaddress=''

# %%
payload2_json['requestBody']['formData']['SpicePartBAddress']=inp['spiceBpartaddress']

# %%
payload2_json['requestBody']['formData']['SpicePartBAddress'][0]
# Out:
# {'line1': 'C/O H N CHAMPA,#17 ',
#  'line2': 'Basaveswara HBC LYT.',
#  'pincode': '560040',
#  'addressType': 'Correspondance Address',
#  'coutry': 'India',
#  'area': 'Chandra Lay Out',
#  'city': 'Bangalore North',
#  'district': 'Bangalore',
#  'state_ut': 'Karnataka',
#  'mobile': '9108042546',
#  'companymailid': 'ananyamadhav23@gmail.com'}

# %%
for x,a in enumerate(payload2_json['requestBody']['formAttachment']):
    if a['attachmentLabel']=='SpiceBproofAddress':
        payload2_json['requestBody']['formAttachment'][x]=att_resp1
    elif a['attachmentLabel']=='SpiceBcopyUtility':
        payload2_json['requestBody']['formAttachment'][x]=att_resp2

# %%
payload2_json['requestBody']['formData']['SpicePartBShares']=inp['SpicePartBshares']

# %%
payload2_json['requestBody']['formData']['regaddressline1']=inp['spiceBpartaddress'][0]['line1']
payload2_json['requestBody']['formData']['regaddressline2']=inp['spiceBpartaddress'][0]['line2']
payload2_json['requestBody']['formData']['regaddresspincode']=inp['spiceBpartaddress'][0]['pincode']
payload2_json['requestBody']['formData']['regaddressarea']=inp['spiceBpartaddress'][0]['area']
payload2_json['requestBody']['formData']['regaddresscompanymailid']=inp['spiceBpartaddress'][0]['companymailid']
payload2_json['requestBody']['formData']['regaddresslatitude']=inp['lat']
payload2_json['requestBody']['formData']['regaddresslongitude']=inp['long']

# %%
payload2_json['requestBody']['formData']['corresAddrSameRegAddr']=inp['corresaddressameasregaddress']

# %%
payload2_json
# Out:
# {'requestBody': {'formData': {'aoaEntrenched': 'N',
#    'Havingsharecapital': '',
#    'totalAuthorizedShareCapital': '200000',
#    'totalClassifiedAuthorizedShareCapital': '100000',
#    'totalSubscribedShareCapital': '100000',
#    'totalUnclassifiedAuthorizedShareCapital': '100000',
#    'equitynumberofClasses': '1',
#    'preferencenumberofClasses': '0',
#    'SpicePartBAddress': [{'line1': 'C/O H N CHAMPA,#17 ',
#      'line2': 'Basaveswara HBC LYT.',
#      'pincode': '560040',
#      'addressType': 'Correspondance Address',
#      'coutry': 'India',
#      'area': 'Chandra Lay Out',
#      'city': 'Bangalore North',
#      'district': 'Bangalore',
#      'state_ut': 'Karnataka',
#      'mobile': '9108042546',
#      'companymailid': 'ananyamadhav23@gmail.com'}],
#    'regaddressline1': 'C/O H N CHAMPA,#17 ',
#    'regaddressline2': 'Basaveswara HBC LYT.',
#    'regaddresspincode': '560040',
#    'regaddresscountry': 'India',
#    'regaddresscity': 'Bangalore South',
# ...

# %%
payload2_json=json.dumps(payload2_json)

# %%
#page 2 save
url = 'https://www.mca.gov.in/bin/mca-gov/SpicePartB_SAVESUBMIT'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Content-Type': 'multipart/form-data',
    'Content-Length': '5202',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}


multipart_data = MultipartEncoder(fields={
    'data': (payload2_json),
    'action': 'savesubmit',
    'operation': 'Save',
    'serveAction': 'saveForm',
    'referenceNumber': '',
    'formId': ''
})

headers['Content-Type'] = multipart_data.content_type
response = requests.post(url, headers=headers, data=multipart_data)

print(response.text)

# %%
w_ct=inp['Dir_w_din_count']
wt_ct=inp["Dir_wt_din_count"]

# %%
payload2_json=json.loads(payload2_json)
(payload2_json)['requestBody']['formData']['SubsrciberDINCount']=w_ct
(payload2_json)['requestBody']['formData']['SubsrciberCountWithoutDIN']=wt_ct
(payload2_json)['requestBody']['formData']['NonIndividualCountWithoutDIN']="0"
(payload2_json)['requestBody']['formData']['DirectorSubscriberDINCount']=w_ct
(payload2_json)['requestBody']['formData']['DirectorSubscriberWithoutDINCount']=wt_ct
(payload2_json)['requestBody']['formData']['DirectorDINCount']=w_ct
(payload2_json)['requestBody']['formData']['DirectorCountWithoutDINCount']=wt_ct

# %%
payload2_json=json.dumps(payload2_json)

# %%
url = 'https://www.mca.gov.in/bin/mca-gov/SpicePartB_SAVESUBMIT'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Content-Type': 'multipart/form-data',
    'Content-Length': '5202',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}


multipart_data = MultipartEncoder(fields={
    'data': (payload2_json),
    'action': 'savesubmit',
    'operation': 'Save',
    'serveAction': 'saveForm',
    'referenceNumber': '',
    'formId': ''
})

headers['Content-Type'] = multipart_data.content_type
response = requests.post(url, headers=headers, data=multipart_data)

print(response.text)

# %%
if int(w_ct)>0:
    url = 'https://www.mca.gov.in/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer.af.dermis'

    headers = {
        'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
        'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.5735.199 Safari/537.36',
        'Accept': 'text/plain, */*; q=0.01',
        'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
        'X-Requested-With': 'XMLHttpRequest',
        'Origin': 'https://www.mca.gov.in',
        'Sec-Fetch-Site': 'same-origin',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Dest': 'empty',
        'Accept-Encoding': 'gzip, deflate',
        'Accept-Language': 'en-US,en;q=0.9'
    }
    din=inp['Dir_w_DIN'][0]['din']
    data = {
        'functionToExecute': 'invokeFDMOperation',
        'formDataModelId': '/content/dam/formsanddocuments-fdm/mca-aem-forms/spice-part-b/dindetails',
        # 'input': '{"Model0":{"ID":"08092541"}}',
        'input': f'{{"Model0": {{"ID": "{din}"}}}}',

        
        'operationName': 'POST /MDS/service/director/1.0.0',
        'guideNodePath': '/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer/rootPanel/items/panel_351137353/items/panel_2146734853/items/panel/items/guidenumericbox'
    }

    response = requests.post(url, headers=headers, data=data)

    print(response.text)
# Out:
# {"message":"Data Fetched Successfully","data":{"directorData":[{"DIN":"08553753","directorDisqualified":"N","disqualificationRemovalDate":"","firstName":"HONNENAHALLY","middleName":"NINGAPPA","lastName":"SUMA","status":"Approved","DINSurrenderDate":"","educationalQualification":"DOCT","birthPlace":"Hassan","drivingLicenseNumber":"","mobileNumber":"+919448394974","city":"Bangalore North","directorDeathDate":"","votersIdNumber":"","durationofStay":"","fathersFirstName":"HONNENAHALLY","authorizedRepType":"","district":"Bangalore","membershipNumber":"","pincode":"560020","nationality":"India","disqualificationSection":"","gender":"Female","DINAllocationDate":"09/03/2019","occupationType":"","area":"Chandra Lay Out","KMPFlag":"","othersEducationalQualification":"","disqualificationDate":"","disqualificationReason":"","verificationStatus":"","OPCFlag":"","sameAddressFlag":"","fathersLastName":"NINGAPPA","DOB":"08/21/1966","addressLine2":"Kumara Park West","addressLine1":"#17,3rd Cross,4th 
# ...

# %%
payload2_json=json.loads(payload2_json)

# %%
dir_with_din_details=json.loads(response.text)['data']['directorData'][0]
# dir_with_din_details

# %%
inp['Dir_w_DIN'][0]['name']=dir_with_din_details['firstName']+' '+dir_with_din_details['middleName']+' '+dir_with_din_details['lastName']
inp['Dir_w_DIN'][0]['nationality']=dir_with_din_details['nationality']
inp['Dir_w_DIN'][0]['firstName']=dir_with_din_details['firstName']
inp['Dir_w_DIN'][0]['middleName']=dir_with_din_details['middleName']
inp['Dir_w_DIN'][0]['Surname']=dir_with_din_details['lastName']
inp['Dir_w_DIN'][0]['emailid']=dir_with_din_details['emailAddress']

# %%
payload2_json['requestBody']['formData']['SpicePartBSubscribers']=inp['Dir_w_DIN']
payload2_json['requestBody']['formData']["numOfMembers"]= int(w_ct) + int(wt_ct)

# %%
#dir_w_din save
url = 'https://www.mca.gov.in/bin/mca-gov/SpicePartB_SAVESUBMIT'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Content-Type': 'multipart/form-data',
    'Content-Length': '5202',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}


multipart_data = MultipartEncoder(fields={
    'data': (json.dumps(payload2_json)),
    'action': 'savesubmit',
    'operation': 'Save',
    'serveAction': 'saveForm',
    'referenceNumber': '',
    'formId': ''
})

headers['Content-Type'] = multipart_data.content_type
response = requests.post(url, headers=headers, data=multipart_data)

print(response.text)

# %%
import urllib.parse
formatted_date = datetime.strptime(inp['Dir_wt_DIN1'][0]['dateOfBirth'], '%m/%d/%Y').strftime('%d/%m/%Y')

pan_data={'pan': inp['Dir_wt_DIN1'][0]['pan'],
 'fName': inp['Dir_wt_DIN1'][0]['firstName'],
 'midName': inp['Dir_wt_DIN1'][0]['MiddleName'],
 'surName': inp['Dir_wt_DIN1'][0]['Surname'],
 'dob': formatted_date,
 'fullName': inp['Dir_wt_DIN1'][0]['firstName']+inp['Dir_wt_DIN1'][0]['MiddleName']+inp['Dir_wt_DIN1'][0]['Surname']}
# pan_data = inp['Dir_wt_DIN'][0]['pan_data_']

pan_data_encoded1 = urllib.parse.quote(json.dumps(pan_data)).replace('%20','').replace('/','%2F')

print('Encoded PAN data:', pan_data_encoded1)
# Out:
# Encoded PAN data: %7B%22pan%22%3A%22DKJPA2449M%22%2C%22fName%22%3A%22Pratik%22%2C%22midName%22%3A%22%22%2C%22surName%22%3A%22Agarwal%22%2C%22dob%22%3A%2209%2F07%2F2000%22%2C%22fullName%22%3A%22PratikAgarwal%22%7D

# %%
pan_data
# Out:
# {'pan': 'DKJPA2449M',
#  'fName': 'Pratik',
#  'midName': '',
#  'surName': 'Agarwal',
#  'dob': '09/07/2000',
#  'fullName': 'PratikAgarwal'}

# %%
if int(wt_ct)>0:

    url = 'https://www.mca.gov.in/bin/commongetapi'
    # session_token = 'your_session_token'

    # Set the headers
    headers = {
        'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
        'Accept': '*/*',
        'Accept-Language': 'en-US,en;q=0.5',
        'Accept-Encoding': 'gzip, deflate',
        'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
        'Csrf-Token': 'undefined',
        'Content-Type': 'multipart/form-data',
        'Origin': 'https://www.mca.gov.in',
        'Sec-Fetch-Dest': 'empty',
        'Sec-Fetch-Mode': 'cors',
        'Sec-Fetch-Site': 'same-origin',
        'Te': 'trailers'
    }
    pandata1=inp['Dir_wt_DIN'][0]['pan_data_']
    # Define the payload as a multipart form-data
    payload = MultipartEncoder(
        fields={
            'data': '{"id":'+F"{pandata1['pan']}"+'}',
            'endpointID': 'dinprefill'
        }
        # boundary='---------------------------3958746645966091053487563336'
    )

    # Set the headers with the appropriate content-type
    headers['Content-Type'] = payload.content_type

    # Send the POST request
    response = requests.post(url, headers=headers, data=payload)

    # Check the response
    if response.status_code == 200:
        print('Request successful!')
        print('Response:', response.text)
    else:
        print('Request failed. Status code:', response.status_code)
        
        

#VALIDATE PAN DATA
url = 'https://www.mca.gov.in/bin/cbdtPanValidate'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'X-Requested-With': 'XMLHttpRequest',
    'Csrf-Token': 'undefined',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}
data=f'panData={pan_data_encoded1}'
response = requests.post(url, headers=headers, data=data)

# Check the response
if response.status_code == 200:
    print('Request successful!')
    print('Response:', response.text)
else:
    print('Request failed. Status code:', response.status_code)
# Out:
# Request successful!
# Response: {"resCode":200,"resStr":"{\n              \"error\": \"\",\n               \"message\": \"Data fetched Successfully\",\n              \"data\" : {\"membershipNumber\":null,\"residentOfIndia\":\"Y\",\"firstName\":\"ANANYA\",\"lastName\":\"MADHAV\",\"fatherFirstName\":\"MADHAVA\",\"fatherLastName\":\".\",\"DINStatus\":\"Approved\",\"DIN\":10278315,\"middleName\":null,\"fatherMiddleName\":null,\"dateOfBirth\":\"23-DEC-1998\",\"PAN\":\"EEUPM6910R\"}\n                       }"}
# Request successful!
# Response: {"resCode":200,"resStr":"{\"status\":\"true\"}"}

# %%
url = "https://www.mca.gov.in/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer.af.dermis"
headers = {
    "Cookie": "cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token=eyJhbGciOiJIUzUxMiJ9..sDBdpiVVuWp7NDihEOVHSIHW0cVSkZFj54s_0R94NKUSCZQJJr_QISd26Sns-AZNF1kSxxYVoRh8BupApZ132Q; sessionID=e084ac64-956a-4795-bc39-310fef37cfe9; deviceId=volakx5sla",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0",
    "Accept": "text/plain, */*; q=0.01",
    "Accept-Language": "en-US,en;q=0.5",
    "Accept-Encoding": "gzip, deflate",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest",
    "Csrf-Token": "undefined",
    "Origin": "https://www.mca.gov.in",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "Te": "trailers"
}

data = {
    "functionToExecute": "invokeFDMOperation",
    "formDataModelId": "/content/dam/formsanddocuments-fdm/mca-aem-forms/spice-part-b/pincode",
    # "input": '{"pinCode":"560004"}',
    'input': f'{{"pinCode": "{inp["Dir_wt_DIN"][0]["permanent_add"]["pincode"]}"}}',
    "operationName": "GET /common/service/lookup/pindetails/1.0.0",
    "guideNodePath": "/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer/rootPanel/items/panel_434252747/items/panel_334769435/items/panel_copy/items/panel/items/guidetextbox_copy_11_1268838373"
}

try:
    response = requests.post(url, headers=headers, data=data)
    response.raise_for_status()
    
    print("Request successful!")
    print("Response:", response.text)
except requests.exceptions.RequestException as e:
    print("Request failed:", str(e))
# Out:
# Request successful!
# Response: {"data":[{"Area":"Chandra Lay Out","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"},{"Area":"Vijayanagar East","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"},{"Area":"Vijayanagar (Bangalore)","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"}],"error":"","message":"Data fetched Successfully"}

# %%
b=json.loads(response.text)['data']
area=[i['Area'] for i in b]
state=b[0]['State']

# %%
url = "https://www.mca.gov.in/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer.af.dermis"
headers = {
    "Cookie": "cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token=eyJhbGciOiJIUzUxMiJ9..sDBdpiVVuWp7NDihEOVHSIHW0cVSkZFj54s_0R94NKUSCZQJJr_QISd26Sns-AZNF1kSxxYVoRh8BupApZ132Q; sessionID=e084ac64-956a-4795-bc39-310fef37cfe9; deviceId=volakx5sla",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0",
    "Accept": "text/plain, */*; q=0.01",
    "Accept-Language": "en-US,en;q=0.5",
    "Accept-Encoding": "gzip, deflate",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "X-Requested-With": "XMLHttpRequest",
    "Csrf-Token": "undefined",
    "Origin": "https://www.mca.gov.in",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "Te": "trailers"
}

data = {
    "functionToExecute": "invokeFDMOperation",
    "formDataModelId": "/content/dam/formsanddocuments-fdm/mca-aem-forms/spice-part-b/pincode",
    # "input": '{"pinCode":"560004"}',
    'input': f'{{"pinCode": "{inp["Dir_wt_DIN"][0]["permanent_add"]["pincode"]}"}}',
    "operationName": "GET /common/service/lookup/pindetails/1.0.0",
    "guideNodePath": "/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b/jcr:content/guideContainer/rootPanel/items/panel_434252747/items/panel_334769435/items/panel_copy_copy/items/panel/items/guidetextbox_copy_11_1268838373"
}

try:
    response = requests.post(url, headers=headers, data=data)
    response.raise_for_status()
    
    print("Request successful!")
    print("Response:", response.text)
except requests.exceptions.RequestException as e:
    print("Request failed:", str(e))
# Out:
# Request successful!
# Response: {"data":[{"Area":"Chandra Lay Out","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"},{"Area":"Vijayanagar East","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"},{"Area":"Vijayanagar (Bangalore)","Pin":560040,"city":"Bangalore North","State":"Karnataka","Country":"India","District":"Bangalore"}],"error":"","message":"Data fetched Successfully"}

# %%
c=json.loads(response.text)['data']
area=[i['Area'] for i in c]
state=c[0]['State']

# %%
url = 'https://www.mca.gov.in/bin/mca/dms/addservice'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Csrf-Token': 'undefined',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}
response = form_save_file(url,headers,"SpiceBidentityPro7B",file_path,file_name2)
if response.status_code == 200:
    print('File uploaded successfully')
else:
    print('Failed to upload the file')
# Out:
# File uploaded successfully

# %%
att_resp3=json.loads(response.text)

# %%
# url = 'https://www.mca.gov.in/bin/mca/dms/addservice'
# file_path = '/home/pratik/Downloads/Ananya_Aadhar.jpg'
# file_name3=f"{inp['Dir_wt_DIN'][0]['pan_data_']['pan']}_Ananya_Aadhar.jpg"
# # session_token = 'your_session_token'

# # Set the headers
# headers = {
#     'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
#     'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
#     'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
#     'X-Requested-With': 'XMLHttpRequest',
#     'Csrf-Token': 'undefined',
#     'Origin': 'https://www.mca.gov.in',
#     'Sec-Fetch-Dest': 'empty',
#     'Sec-Fetch-Mode': 'cors',
#     'Sec-Fetch-Site': 'same-origin',
#     'Te': 'trailers'
# }

# # Open the file in binary mode
# with open(file_path, 'rb') as file:
#     # Create the multipart form-data payload
#     payload = {
#         'file': (file_name3, file, 'application/pdf'),
#         'folder': '',
#         'filemetadata': '{"form":"SPICE + Part B","srn":"","documentType":"Attachment","module":"SPICE + Part B","userid":"SPICE + Part B","applicationId":"","attachmentCategory":"pdf","attachmentLabel":"SpiceBidentityPro7B"}'
#     }

#     # Send the POST request
#     response = requests.post(url, headers=headers, files=payload)

# # Check the response
# if response.status_code == 200:
#     print('File uploaded successfully')
# else:
#     print('Failed to upload the file')

# %%
att_resp3=json.loads(response.text)

# %%
url = 'https://www.mca.gov.in/bin/mca/dms/addservice'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Csrf-Token': 'undefined',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}
response = form_save_file(url,headers,"SpiceBProofOfResi7B",file_path,file_name2)
if response.status_code == 200:
    print('File uploaded successfully')
else:
    print('Failed to upload the file')
# Out:
# File uploaded successfully

# %%
response.text
# Out:
# '{"attachmentLabel":"SpiceBProofOfResi7B","attachmentCategory":"Attachment","activityFileName":"a1.jpeg","activityFileSrcPath":"175237094","activityFileSrcType":"I","activityFileExt":"jpeg","activityFileSize":"59471","attachmentDMSId":"356031206","totalNoOfPages":"1","activityFileDate":"08/14/2023","publicDocument":"Y","activityComments":"175237094:SpiceBProofOfResi7B:Document added successfully.","folderName":"","folderId":"175237094","version":"","addedBy":"Fo User"}'

# %%
# url = 'https://www.mca.gov.in/bin/mca/dms/addservice'
# file_path = '/home/pratik/Downloads/Ananya_electrical_bill.jpg'
# file_name4=f"{inp['Dir_wt_DIN'][0]['pan_data_']['pan']}_Ananya_electrical_bill.jpg"

# # Set the headers
# headers = {
#     'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
#     'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
#     'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
#     'X-Requested-With': 'XMLHttpRequest',
#     'Csrf-Token': 'undefined',
#     'Origin': 'https://www.mca.gov.in',
#     'Sec-Fetch-Dest': 'empty',
#     'Sec-Fetch-Mode': 'cors',
#     'Sec-Fetch-Site': 'same-origin',
#     'Te': 'trailers'
# }

# # Open the file in binary mode
# with open(file_path, 'rb') as file:
#     # Create the multipart form-data payload
#     payload = {
#         'file': (file_name4, file, 'application/pdf'),
#         'folder': '',
#         'filemetadata': '{"form":"SPICE + Part B","srn":"","documentType":"Attachment","module":"SPICE + Part B","userid":"SPICE + Part B","applicationId":"","attachmentCategory":"pdf","attachmentLabel":"SpiceBProofOfResi7B"}'
#     }

#     # Send the POST request
#     response = requests.post(url, headers=headers, files=payload)

# # Check the response
# if response.status_code == 200:
#     print('File uploaded successfully')
# else:
#     print('Failed to upload the file')

# %%
att_resp3
# Out:
# {'attachmentLabel': 'SpiceBidentityPro7B',
#  'attachmentCategory': 'Attachment',
#  'activityFileName': 'a1.jpeg',
#  'activityFileSrcPath': '175237094',
#  'activityFileSrcType': 'I',
#  'activityFileExt': 'jpeg',
#  'activityFileSize': '59471',
#  'attachmentDMSId': '356031197',
#  'totalNoOfPages': '1',
#  'activityFileDate': '08/14/2023',
#  'publicDocument': 'Y',
#  'activityComments': '175237094:SpiceBidentityPro7B:Document added successfully.',
#  'folderName': '',
#  'folderId': '175237094',
#  'version': '',
#  'addedBy': 'Fo User'}

# %%
att_resp4=json.loads(response.text)

# %%
payload2_json['requestBody']['formData']['SpicePartBSubscribers']
# Out:
# [{'SubscriberType': 'Subscriber CUM Director DIN',
#   'din': '08553753',
#   'name': 'HONNENAHALLY NINGAPPA SUMA',
#   'nationality': 'India',
#   'firstName': 'HONNENAHALLY',
#   'middleName': 'NINGAPPA',
#   'category': 'Individual First subscribers cum Directors',
#   'Surname': 'SUMA',
#   'designation': 'Director',
#   'directorCategory': 'Promoter',
#   'whetherNonED': 'Executive director',
#   'emailid': 'hnsuma@yahoo.co.in',
#   'totalSubscribedShareCapital': '30000',
#   'equitynumofclasses': '1',
#   'DirectorInterestedEntitiescount': '0',
#   'SpicePartBSubsDeclaration': [],
#   'inc9DeclarationFlag1': 'N',
#   'SpicePartBSubscribersShares': [{'sharecategory': 'Equity Share',
#     'classShare': '1',
#     'subscribedcapitalsharenumber': '3000',
#     'subscribedcapitalnominalamountpershare': '10',
#     'subscribedcapitaltotalamount': '30000'}],
#   'pan': '',
#   'identityProofNumber': ''},
#  {'SubscriberType': 'Subscriber CUM Director No DIN',
# ...

# %%
payload3_json=(payload2_json)

# %%
payload3_json['requestBody']['formAttachment']=[]
payload3_json['requestBody']['formAttachment'].append(att_resp1)
payload3_json['requestBody']['formAttachment'].append(att_resp2)
payload3_json['requestBody']['formAttachment'].append(att_resp3)
payload3_json['requestBody']['formAttachment'].append(att_resp4)

# %%
payload3_json
# Out:
# {'requestBody': {'formData': {'aoaEntrenched': 'N',
#    'Havingsharecapital': '',
#    'totalAuthorizedShareCapital': '200000',
#    'totalClassifiedAuthorizedShareCapital': '100000',
#    'totalSubscribedShareCapital': '100000',
#    'totalUnclassifiedAuthorizedShareCapital': '100000',
#    'equitynumberofClasses': '1',
#    'preferencenumberofClasses': '0',
#    'SpicePartBAddress': [{'line1': 'C/O H N CHAMPA,#17 ',
#      'line2': 'Basaveswara HBC LYT.',
#      'pincode': '560040',
#      'addressType': 'Correspondance Address',
#      'coutry': 'India',
#      'area': 'Chandra Lay Out',
#      'city': 'Bangalore North',
#      'district': 'Bangalore',
#      'state_ut': 'Karnataka',
#      'mobile': '9108042546',
#      'companymailid': 'ananyamadhav23@gmail.com'}],
#    'regaddressline1': 'C/O H N CHAMPA,#17 ',
#    'regaddressline2': 'Basaveswara HBC LYT.',
#    'regaddresspincode': '560040',
#    'regaddresscountry': 'India',
#    'regaddresscity': 'Bangalore South',
# ...

# %%
payload3_json['requestBody']['formData']['numOfMembers']='2'
payload3_json['requestBody']['formData']['SpicePartBSubscribers'].append(inp['Dir_wt_DIN1'][0])

# %%
payload3_json['requestBody']['formData'].pop('SpicePartBINDVSubscribersHavingDin',None)
payload3_json['requestBody']['formData'].pop('SpicePartBINDVSubscribersNotHavingDin',None)
payload3_json['requestBody']['formData'].pop('SpicePartBSubscribersHavingDin',None)
payload3_json['requestBody']['formData'].pop('SpicePartBSubscribersNotHavingDin',None)
payload3_json['requestBody']['formData'].pop('SpicePartBDirectorsHavingDin',None)
payload3_json['requestBody']['formData'].pop('SpicePartBDirectorsNotHavingDin',None)

# %%
payload3_json['requestBody']['formData']['SpicePartBINDVSubscribers']=[]

# %%
payload3_json
# Out:
# {'requestBody': {'formData': {'aoaEntrenched': 'N',
#    'Havingsharecapital': '',
#    'totalAuthorizedShareCapital': '200000',
#    'totalClassifiedAuthorizedShareCapital': '100000',
#    'totalSubscribedShareCapital': '100000',
#    'totalUnclassifiedAuthorizedShareCapital': '100000',
#    'equitynumberofClasses': '1',
#    'preferencenumberofClasses': '0',
#    'SpicePartBAddress': [{'line1': 'C/O H N CHAMPA,#17 ',
#      'line2': 'Basaveswara HBC LYT.',
#      'pincode': '560040',
#      'addressType': 'Correspondance Address',
#      'coutry': 'India',
#      'area': 'Chandra Lay Out',
#      'city': 'Bangalore North',
#      'district': 'Bangalore',
#      'state_ut': 'Karnataka',
#      'mobile': '9108042546',
#      'companymailid': 'ananyamadhav23@gmail.com'}],
#    'regaddressline1': 'C/O H N CHAMPA,#17 ',
#    'regaddressline2': 'Basaveswara HBC LYT.',
#    'regaddresspincode': '560040',
#    'regaddresscountry': 'India',
#    'regaddresscity': 'Bangalore South',
# ...

# %%
payload3_json['requestBody']['formData']['SpicePartBSubscribers']
# Out:
# [{'SubscriberType': 'Subscriber CUM Director DIN',
#   'din': '08553753',
#   'name': 'HONNENAHALLY NINGAPPA SUMA',
#   'nationality': 'India',
#   'firstName': 'HONNENAHALLY',
#   'middleName': 'NINGAPPA',
#   'category': 'Individual First subscribers cum Directors',
#   'Surname': 'SUMA',
#   'designation': 'Director',
#   'directorCategory': 'Promoter',
#   'whetherNonED': 'Executive director',
#   'emailid': 'hnsuma@yahoo.co.in',
#   'totalSubscribedShareCapital': '30000',
#   'equitynumofclasses': '1',
#   'DirectorInterestedEntitiescount': '0',
#   'SpicePartBSubsDeclaration': [],
#   'inc9DeclarationFlag1': 'N',
#   'SpicePartBSubscribersShares': [{'sharecategory': 'Equity Share',
#     'classShare': '1',
#     'subscribedcapitalsharenumber': '3000',
#     'subscribedcapitalnominalamountpershare': '10',
#     'subscribedcapitaltotalamount': '30000'}],
#   'pan': '',
#   'identityProofNumber': ''},
#  {'SubscriberType': 'Subscriber CUM Director No DIN',
# ...

# %%
# for x,i in enumerate(payload3_json['requestBody']['formData']['SpicePartBSubscribers']):
#     if i['SubscriberType']=="Subscriber CUM Director No DIN":
#         for j in inp['Dir_wt_DIN1']:
#             # print(j)
#             payload3_json['requestBody']['formData']['SpicePartBSubscribers'][x]=up(j,i)

# %%
#dir_wt_din save
url = 'https://www.mca.gov.in/bin/mca-gov/SpicePartB_SAVESUBMIT'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Content-Type': 'multipart/form-data',
    'Content-Length': '5202',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}


multipart_data = MultipartEncoder(fields={
    'data': (json.dumps(payload3_json)),
    'action': 'savesubmit',
    'operation': 'Save',
    'serveAction': 'saveForm',
    'referenceNumber': '',
    'formId': ''
})

headers['Content-Type'] = multipart_data.content_type
response = requests.post(url, headers=headers, data=multipart_data)

print(response.text)
# Out:
# {
# 		"error": "",
# 		"message": "Data Added Successfully",
#
# 		"data":	{
# 			"referenceNumber":"1-10525976755",
# 			"srn": "",
# 			"dateTime":"",
#                     "integrationId":"1-4U2W7N7",
#                     "srnStatus":"Draft/Pending Submission",
#                      "formIntegrationId":"1-4U2W7NA"
# 			}
# }

# %%
payload4_json=payload3_json

# %%
payload4_json['requestBody']['formData']['opcDetails']={'stampDuty': {'state_ut': 'Karnataka',
  'stampDutyElectronicallyPaid': 'Yes',
  'stampDutyToBePaidDetails': {'amountForm': 20,
   'amountMOA': 1000,
   'amountAOA': 1000}}}

# %%
payload4_json['requestBody']['formData']['formAttachment']=payload4_json['requestBody']['formAttachment']

# %%
url = 'https://www.mca.gov.in/bin/mca-gov/SpicePartB_SAVESUBMIT'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Content-Type': 'multipart/form-data',
    'Content-Length': '5202',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}


multipart_data = MultipartEncoder(fields={
    'data': (json.dumps(payload4_json)),
    'action': 'savesubmit',
    'operation': 'Save',
    'serveAction': 'saveForm',
    'referenceNumber': '',
    'formId': ''
})

headers['Content-Type'] = multipart_data.content_type
response = requests.post(url, headers=headers, data=multipart_data)

print(response.text)
# Out:
# {
# 		"error": "",
# 		"message": "Data Added Successfully",
#
# 		"data":	{
# 			"referenceNumber":"1-10525976755",
# 			"srn": "",
# 			"dateTime":"",
#                     "integrationId":"1-4U2W7N7",
#                     "srnStatus":"Draft/Pending Submission",
#                      "formIntegrationId":"1-4U2W7NA"
# 			}
# }

# %%
url = "https://www.mca.gov.in/bin/fillip/fillipAoCode"
pan_params = {
    "AO_NO": "2",
    "AO_CODE": "P"+"DLC",
    "RANGE_CODE": "502",
    "AO_TYPE": "WX"
}

headers = {
    "Cookie": f"alertPopup=true; cookiesession1=678B2869D727DAE036D48B6E36133C84; session-token={session_token}",
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "X-Requested-With": "XMLHttpRequest",
    "Sec-Ch-Ua-Mobile": "?0",
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.5790.102 Safari/537.36",
    "Sec-Ch-Ua-Platform": "",
    "Sec-Fetch-Site": "same-origin",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Dest": "empty",
    "Referer": "https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html?applicationHistory=eyJzcm4iOiJBQTMwODM0NTUiLCJyZWZlcmVuY2UiOiIxLTk5NTQ1MjE0OTIiLCJwdXJwb3NlIjoiIn0=",
    "Accept-Encoding": "gzip, deflate",
    "Accept-Language": "en-US,en;q=0.9"
}

response = requests.get(url, params=pan_params, headers=headers)

# Check if the request was successful (HTTP status code 200)
if response.status_code == 200:
    print("Request successful!")
    print("Response text:")
    print(response.text)
else:
    print(f"Request failed with status code: {response.status_code}")
# Out:
# Request successful!
# Response text:
# {"resCode":200,"resStr":"{\n        \t\t\n        \t\t\"message\":\"Data fetched Successfully\",\n        \t\t\"data\":{\"is_valid\":1}\n        \t}"}

# %%
pan_valid=json.loads(json.loads(response.text)['resStr'])['data']['is_valid']

# %%
pan_valid
# Out:
# 1

# %%
tan_params = {
    "AO_NO": "1",
    "AO_CODE": "T"+"KAR",
    "RANGE_CODE": "181",
    "AO_TYPE": "WT"
}

# %%
response = requests.get(url, params=tan_params, headers=headers)

# %%
response.text
# Out:
# '{"resCode":200,"resStr":"{\\n        \\t\\t\\n        \\t\\t\\"message\\":\\"Data fetched Successfully\\",\\n        \\t\\t\\"data\\":{\\"is_valid\\":1}\\n        \\t}"}'

# %%
payload5=r'''{"requestBody":{"formData":{"aoaEntrenched":"N","totalAuthorizedShareCapital":"200000","totalClassifiedAuthorizedShareCapital":"100000","totalSubscribedShareCapital":"100000","totalUnclassifiedAuthorizedShareCapital":"100000","equitynumberofClasses":"1","preferencenumberofClasses":"0","numOfMembers":"2","SpicePartBAddress":[{"line1":"#17, 2nd main road, Basaveswara layout","line2":"2nd stage, Chandra layout","pincode":"560040","addressType":"Correspondance Address","coutry":"India","area":"Chandra Lay Out","city":"Bangalore North","district":"Bangalore","state_ut":"Karnataka","mobile":"9108042546","companymailid":"ananyamadhav23@gmail.com"}],"regaddresscountry":"India","corresAddrSameRegAddr":"N","rocName":"Registrar of Companies, Karnataka","SubsrciberDINCount":"1","SubsrciberCountWithoutDIN":"1","NonIndividualCountWithoutDIN":"0","DirectorSubscriberDINCount":"1","DirectorSubscriberWithoutDINCount":"1","DirectorDINCount":"1","DirectorCountWithoutDINCount":"1","opcDetails":{"stampDuty":{"state_ut":"Karnataka","stampDutyElectronicallyPaid":"Yes","stampDutyToBePaidDetails":{"amountForm":20,"amountMOA":1000,"amountAOA":1000}}},"panTanDetails":{"PANareaCode":"DLC","PANaoType":"WX","PANrangeCode":"502","PANaoNumber":"2","TANareaCode":"KAR","TANaoType":"WT","TANrangeCode":"182","TANaoNumber":"3","incomeFromBusinessProfession":"Y","businessProfessioncode":"20"},"formIntegrationId":"1-4KMNXY0","SpicePartBShares":[{"classShare":"1","authorizedcapitalsharenumber":"10000","subscribedcapitalsharenumber":"10000","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"100000","subscribedcapitaltotalamount":"100000","sharecategory":"Equity Share"}],"spicePartBNonINDVSubscribers":[],"SpicePartBINDVSubscribers":[],"SpicePartBSubscribers":[{"SubscriberType":"Subscriber CUM Director DIN","din":"08553753","name":"HONNENAHALLY NINGAPPA SUMA","nationality":"India","firstName":"HONNENAHALLY","middleName":"NINGAPPA","category":"Individual First subscribers cum Directors","Surname":"SUMA","designation":"Director","directorCategory":"Promoter","whetherNonED":"Executive director","emailid":"hnsuma@yahoo.co.in","totalSubscribedShareCapital":"30000","equitynumofclasses":"1","DirectorInterestedEntitiescount":"0","SpicePartBSubsDeclaration":[],"inc9DeclarationFlag1":"N","SpicePartBSubscribersShares":[{"sharecategory":"Equity Share","classShare":"1","subscribedcapitalsharenumber":"3000","subscribedcapitalnominalamountpershare":"10","subscribedcapitaltotalamount":"30000"}],"pan":"","identityProofNumber":""},{"category":"Individual First subscribers cum Directors","SubscriberType":"Subscriber CUM Director No DIN","firstName":"ANANYA","Surname":"MADHAV","fatherFirstName":"MADHAVA","fatherSurName":"","gender":"Female","dateOfBirth":"12/23/1998","nationality":"India","placeofBirth":"Bangalore","citizenOfIndia":"Y","residentOfIndia":"Y","occupationType":"Professional","areaofOccupation":"Student","educationalQualificationothers":"Master degree","pan":"EEUPM6910R","designation":"Director","directorCategory":"Promoter","whetherNonED":"Executive director","MobileNo":"09108042546","emailid":"ananyamadhav23@gmail.com","ResidenseCorespondenceFlag":"Y","identityProofDocument":"Aadhar Card","identityProofNumber":"295558800889","residentialProofDocument":"Electricity Bill","residentialProofNumber":"141225235020371","Attachment1":{"fileAttachment":"EEUPM6910R_Ananya_Aadhar.jpg"},"Attachment2":{"fileAttachment":"EEUPM6910R_Ananya_electrical_bill.jpg"},"totalSubscribedShareCapital":"70000","equitynumofclasses":"1","DirectorInterestedEntitiescount":"0","SpicePartBSubsDeclaration":[],"inc9DeclarationFlag1":"N","SpicePartBSubscribersShares":[{"sharecategory":"Equity Share","classShare":"1","subscribedcapitalsharenumber":"7000","subscribedcapitalnominalamountpershare":"10","subscribedcapitaltotalamount":"70000"}],"din":"","SpicePartBSubscribersAddress":[{"addressType":"Permanent Address","line1":"17,2nd Main Road","line2":"Basaveshwara Layout 2nd stage","country":"India","pincode":"560040","area":"Chandra Lay Out","city":"Bangalore North","district":"Bangalore","state_ut":"Karnataka"},{"addressType":"Present Address","line1":"17,2nd Main Road","line2":"Basaveshwara Layout 2nd stage","country":"India","pincode":"560040","area":"Chandra Lay Out","city":"Bangalore North","district":"Bangalore","state_ut":"Karnataka","yearresidenseduration":"22","monthresidenseduration":"7"}]}]},"status":"Draft/Pending Submission","formDescription":"For Spice+PartB","formName":"SPICE + Part B","formVersion":"01","userId":"CASRIKANTH0224@GMAIL.COM","integrationId":"1-4KMNXXW","referenceNumber":"","formattachList":"[{\"attachmentLabel\":\"SpiceBproofAddress\",\"attachmentCategory\":\"Attachment\",\"activityFileName\":\"1Ananya_electrical_bill.jpg\",\"activityFileSrcType\":\"I\",\"activityFileExt\":\"jpg\",\"activityFileSize\":\"45322\",\"attachmentDMSId\":\"352989782\",\"totalNoOfPages\":\"1\",\"activityFileDate\":\"07/29/2023 16:14:51\",\"publicDocument\":\"Y\",\"activityComments\":\"174597106:SpiceBproofAddress:Document added successfully.\",\"versionNo\":\"0\",\"folderName\":\"\",\"addedBy\":\"Fo User\",\"formName\":\"\",\"folderId\":\"174597106\"},{\"attachmentLabel\":\"SpiceBcopyUtility\",\"attachmentCategory\":\"Attachment\",\"activityFileName\":\"Ananya_electrical_bill.jpg\",\"activityFileSrcType\":\"I\",\"activityFileExt\":\"jpg\",\"activityFileSize\":\"45322\",\"attachmentDMSId\":\"352989802\",\"totalNoOfPages\":\"1\",\"activityFileDate\":\"07/29/2023 16:14:51\",\"publicDocument\":\"Y\",\"activityComments\":\"174597106:SpiceBcopyUtility:Document added successfully.\",\"versionNo\":\"0\",\"folderName\":\"\",\"addedBy\":\"Fo User\",\"formName\":\"\",\"folderId\":\"174597106\"},{\"attachmentLabel\":\"SpiceBidentityPro7B\",\"attachmentCategory\":\"Attachment\",\"activityFileName\":\"EEUPM6910R_Ananya_Aadhar.jpg\",\"activityFileSrcType\":\"I\",\"activityFileExt\":\"jpg\",\"activityFileSize\":\"116918\",\"attachmentDMSId\":\"352992772\",\"totalNoOfPages\":\"1\",\"activityFileDate\":\"07/29/2023 16:14:51\",\"publicDocument\":\"Y\",\"activityComments\":\"174599562:SpiceBidentityPro7B:Document added successfully.\",\"versionNo\":\"0\",\"folderName\":\"\",\"addedBy\":\"Fo User\",\"formName\":\"\",\"folderId\":\"174599562\"},{\"attachmentLabel\":\"SpiceBProofOfResi7B\",\"attachmentCategory\":\"Attachment\",\"activityFileName\":\"EEUPM6910R_Ananya_electrical_bill.jpg\",\"activityFileSrcType\":\"I\",\"activityFileExt\":\"jpg\",\"activityFileSize\":\"45322\",\"attachmentDMSId\":\"352992780\",\"totalNoOfPages\":\"1\",\"activityFileDate\":\"07/29/2023 16:14:51\",\"publicDocument\":\"Y\",\"activityComments\":\"174599562:SpiceBProofOfResi7B:Document added successfully.\",\"versionNo\":\"0\",\"folderName\":\"\",\"addedBy\":\"Fo User\",\"formName\":\"\",\"folderId\":\"174599562\"}]","operation":"Save","action":"savesubmit","formIntegrationId":"1-4KMNXY0","formId":"","srn":"","formAttachment":[{"attachmentLabel":"SpiceBproofAddress","attachmentCategory":"Attachment","activityFileName":"1Ananya_electrical_bill.jpg","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"45322","attachmentDMSId":"352989782","totalNoOfPages":"1","activityFileDate":"07/29/2023 16:14:51","publicDocument":"Y","activityComments":"174597106:SpiceBproofAddress:Document added successfully.","versionNo":"0","folderName":"","addedBy":"Fo User","formName":"","folderId":"174597106"},{"attachmentLabel":"SpiceBcopyUtility","attachmentCategory":"Attachment","activityFileName":"Ananya_electrical_bill.jpg","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"45322","attachmentDMSId":"352989802","totalNoOfPages":"1","activityFileDate":"07/29/2023 16:14:51","publicDocument":"Y","activityComments":"174597106:SpiceBcopyUtility:Document added successfully.","versionNo":"0","folderName":"","addedBy":"Fo User","formName":"","folderId":"174597106"},{"attachmentLabel":"SpiceBidentityPro7B","attachmentCategory":"Attachment","activityFileName":"EEUPM6910R_Ananya_Aadhar.jpg","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"116918","attachmentDMSId":"352992772","totalNoOfPages":"1","activityFileDate":"07/29/2023 16:14:51","publicDocument":"Y","activityComments":"174599562:SpiceBidentityPro7B:Document added successfully.","versionNo":"0","folderName":"","addedBy":"Fo User","formName":"","folderId":"174599562"},{"attachmentLabel":"SpiceBProofOfResi7B","attachmentCategory":"Attachment","activityFileName":"EEUPM6910R_Ananya_electrical_bill.jpg","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"45322","attachmentDMSId":"352992780","totalNoOfPages":"1","activityFileDate":"07/29/2023 16:14:51","publicDocument":"Y","activityComments":"174599562:SpiceBProofOfResi7B:Document added successfully.","versionNo":"0","folderName":"","addedBy":"Fo User","formName":"","folderId":"174599562"}]}}
'''

# %%
payload5_json=json.loads(payload5)

# %%
payload4_json
# Out:
# {'requestBody': {'formData': {'aoaEntrenched': 'N',
#    'Havingsharecapital': '',
#    'totalAuthorizedShareCapital': '200000',
#    'totalClassifiedAuthorizedShareCapital': '100000',
#    'totalSubscribedShareCapital': '100000',
#    'totalUnclassifiedAuthorizedShareCapital': '100000',
#    'equitynumberofClasses': '1',
#    'preferencenumberofClasses': '0',
#    'SpicePartBAddress': [{'line1': 'C/O H N CHAMPA,#17 ',
#      'line2': 'Basaveswara HBC LYT.',
#      'pincode': '560040',
#      'addressType': 'Correspondance Address',
#      'coutry': 'India',
#      'area': 'Chandra Lay Out',
#      'city': 'Bangalore North',
#      'district': 'Bangalore',
#      'state_ut': 'Karnataka',
#      'mobile': '9108042546',
#      'companymailid': 'ananyamadhav23@gmail.com'}],
#    'regaddressline1': 'C/O H N CHAMPA,#17 ',
#    'regaddressline2': 'Basaveswara HBC LYT.',
#    'regaddresspincode': '560040',
#    'regaddresscountry': 'India',
#    'regaddresscity': 'Bangalore South',
# ...

# %%
payload5_json['requestBody']['formData']['panTanDetails']
# Out:
# {'PANareaCode': 'DLC',
#  'PANaoType': 'WX',
#  'PANrangeCode': '502',
#  'PANaoNumber': '2',
#  'TANareaCode': 'KAR',
#  'TANaoType': 'WT',
#  'TANrangeCode': '182',
#  'TANaoNumber': '3',
#  'incomeFromBusinessProfession': 'Y',
#  'businessProfessioncode': '20'}

# %%
payload5_json=payload4_json

# %%
payload5_json['requestBody']['formData']['panTanDetails']={'PANareaCode': 'DLC',
 'PANaoType': 'WX',
 'PANrangeCode': '502',
 'PANaoNumber': '2',
 'TANareaCode': 'KAR',
 'TANaoType': 'WT',
 'TANrangeCode': '181',
 'TANaoNumber': '1',
 'incomeFromBusinessProfession': 'Y',
 'businessProfessioncode': '20'}

# %%
url = 'https://www.mca.gov.in/bin/mca-gov/SpicePartB_SAVESUBMIT'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Content-Type': 'multipart/form-data',
    'Content-Length': '5202',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}


multipart_data = MultipartEncoder(fields={
    'data': (json.dumps(payload5_json)),
    'action': 'savesubmit',
    'operation': 'Save',
    'serveAction': 'saveForm',
    'referenceNumber': '',
    'formId': ''
})

headers['Content-Type'] = multipart_data.content_type
response = requests.post(url, headers=headers, data=multipart_data)

print(response.text)

# %%
payload6_json=payload5_json

# %%
payload6_json['requestBody']['formData']['directorDeclaration']={'input1': 'ANANYA MADHAV',
 'declaration7': 'Y',
 'declaration8': 'Y',
 'declaration9': 'Y',
 'declaration10': 'Y',
 'declaration11': 'Y',
 'declaration12': 'Y',
 'declaration13': 'Y',
 'input2': 'SRIKANTH REDDY',
 'dropdown1': 'a',
 'dropdown2': 'Chartered Accountant',
 'membershipNumber_declaration': '271843',
 'practiceNumber_declaration': 'FRN026299S',
 'dinPan': 'EEUPM6910R',
 'name': 'SRIKANTH REDDY',
 'institute': 'The Institute of Chartered Accountant of India',
 'OfficePlace': '171, 7th cross, 7th Main Rd, 2nd Block, Jayanagar, Bengaluru, Karnataka 560011',
 'LegalProffesion': 'Chartered Accountant',
 'associate_Fellow': 'Associate',
 'membershipNumber': '271843',
 'certificateofPracticeNumber': 'FRN026299S'}

# %%
url = 'https://www.mca.gov.in/bin/mca-gov/SpicePartB_SAVESUBMIT'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Content-Type': 'multipart/form-data',
    'Content-Length': '5202',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}


multipart_data = MultipartEncoder(fields={
    'data': (json.dumps(payload6_json)),
    'action': 'savesubmit',
    'operation': 'Save',
    'serveAction': 'saveForm',
    'referenceNumber': '',
    'formId': ''
})

headers['Content-Type'] = multipart_data.content_type
response = requests.post(url, headers=headers, data=multipart_data)

print(response.text)

# %%
payload7_json=payload6_json

# %%
payload7_json['requestBody']['formData']['directorDeclaration']['pan']='DLQPR2890H'

# %%
payload7_json['requestBody']['eMOAFlag']='Y'
payload7_json['requestBody']['inc9Flag']='Y'
payload7_json['requestBody']['eAOAFlag']='Y'
payload7_json['requestBody']['formData']['SpiceBDeclarationDINPANDetails']=[]

# %%
url = 'https://www.mca.gov.in/bin/mca-gov/SpicePartB_SAVESUBMIT'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Content-Type': 'multipart/form-data',
    'Content-Length': '5202',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}


multipart_data = MultipartEncoder(fields={
    'data': (json.dumps(payload7_json)),
    'action': 'savesubmit',
    'operation': 'Save',
    'serveAction': 'saveForm',
    'referenceNumber': '',
    'formId': ''
})

headers['Content-Type'] = multipart_data.content_type
response = requests.post(url, headers=headers, data=multipart_data)

print(response.text)

# %%
payload8_json=json.loads(r'''{"requestBody":{"formData":{"aoaEntrenched":"N","totalAuthorizedShareCapital":"200000","totalClassifiedAuthorizedShareCapital":"100000","totalSubscribedShareCapital":"100000","totalUnclassifiedAuthorizedShareCapital":"100000","equitynumberofClasses":"1","preferencenumberofClasses":"0","numOfMembers":"2","SpicePartBAddress":[{"line1":"17, 2nd main road, Basaveswara layout","line2":"2nd stage, Chandra layout","pincode":"560040","addressType":"Correspondance Address","coutry":"India","area":"Chandra Lay Out","city":"Bangalore North","district":"Bangalore","state_ut":"Karnataka","mobile":"9108042546","companymailid":"ananyamadhav23@gmail.com"}],"regaddressline1":"17, 2nd main road, Basaveswara layout","regaddressline2":"2nd stage, Chandra layout","regaddresspincode":"560040","regaddresscountry":"India","regaddresscity":"Bangalore North","regaddressdistrict":"Bangalore","regaddressstate_ut":"Karnataka","regaddresscompanymailid":"ananyamadhav23@gmail.com","regaddressarea":"Chandra Lay Out","corresAddrSameRegAddr":"Y","regaddresslongitude":"77.5305","regaddresslatitude":"12.968","rocName":"Registrar of Companies, Karnataka","SubsrciberDINCount":"1","SubsrciberCountWithoutDIN":"1","NonIndividualCountWithoutDIN":"0","DirectorSubscriberDINCount":"1","DirectorSubscriberWithoutDINCount":"1","DirectorDINCount":"1","DirectorCountWithoutDINCount":"1","opcDetails":{"stampDuty":{"state_ut":"Karnataka","stampDutyElectronicallyPaid":"Yes","stampDutyToBePaidDetails":{"amountForm":20,"amountMOA":1000,"amountAOA":1000}}},"panTanDetails":{"PANareaCode":"DLC","PANaoType":"WX","PANrangeCode":"502","PANaoNumber":"2","TANareaCode":"KAR","TANaoType":"WT","TANrangeCode":"181","TANaoNumber":"1","incomeFromBusinessProfession":"Y","businessProfessioncode":"20"},"directorDeclaration":{"input1":"ANANYA MADHAV","declaration7":"Y","declaration8":"Y","declaration9":"Y","declaration10":"Y","declaration11":"Y","declaration12":"Y","declaration13":"Y","input2":"SRIKANTH REDDY","dropdown1":"a","dropdown2":"Chartered Accountant","membershipNumber_declaration":"271843","practiceNumber_declaration":"FRN026299S","dinPan":"EEUPM6910R","name":"SRIKANTH REDDY","institute":"The Institute of Chartered Accountant of India","OfficePlace":"171, 7th cross, 7th Main Rd, 2nd Block, Jayanagar, Bengaluru, Karnataka 560011","LegalProffesion":"Chartered Accountant","associate_Fellow":"Associate","membershipNumber":"271843","certificateofPracticeNumber":"FRN026299S","pan":"DLQPR2890H"},"SpiceBDeclarationDINPANDetails":[],"formIntegrationId":"1-4KMNXY0","SpicePartBShares":[{"classShare":"1","authorizedcapitalsharenumber":"10000","subscribedcapitalsharenumber":"10000","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"100000","subscribedcapitaltotalamount":"100000","sharecategory":"Equity Share"}],"spicePartBNonINDVSubscribers":[],"SpicePartBINDVSubscribers":[],"SpicePartBSubscribers":[{"SubscriberType":"Subscriber CUM Director DIN","din":"08553753","name":"HONNENAHALLY NINGAPPA SUMA","nationality":"India","firstName":"HONNENAHALLY","middleName":"NINGAPPA","category":"Individual First subscribers cum Directors","Surname":"SUMA","designation":"Director","directorCategory":"Promoter","whetherNonED":"Executive director","emailid":"hnsuma@yahoo.co.in","totalSubscribedShareCapital":"30000","equitynumofclasses":"1","DirectorInterestedEntitiescount":"0","SpicePartBSubsDeclaration":[],"inc9DeclarationFlag1":"N","pan":"","identityProofNumber":"","SpicePartBSubscribersShares":[{"sharecategory":"Equity Share","classShare":"1","subscribedcapitalsharenumber":"3000","subscribedcapitalnominalamountpershare":"10","subscribedcapitaltotalamount":"30000"}]},{"category":"Individual First subscribers cum Directors","SubscriberType":"Subscriber CUM Director No DIN","firstName":"ANANYA","Surname":"MADHAV","fatherFirstName":"MADHAVA","fatherSurName":"","gender":"Female","dateOfBirth":"12/23/1998","nationality":"India","placeofBirth":"Bangalore","citizenOfIndia":"Y","residentOfIndia":"Y","occupationType":"Professional","areaofOccupation":"Student","educationalQualificationothers":"Master degree","pan":"EEUPM6910R","designation":"Director","directorCategory":"Promoter","whetherNonED":"Executive director","MobileNo":"09108042546","emailid":"ananyamadhav23@gmail.com","ResidenseCorespondenceFlag":"Y","identityProofDocument":"Aadhar Card","identityProofNumber":"295558800889","residentialProofDocument":"Electricity Bill","residentialProofNumber":"141225235020371","Attachment1":{"fileAttachment":"EEUPM6910R_Ananya_Aadhar.jpg"},"Attachment2":{"fileAttachment":"EEUPM6910R_Ananya_electrical_bill.jpg"},"totalSubscribedShareCapital":"70000","equitynumofclasses":"1","DirectorInterestedEntitiescount":"0","SpicePartBSubsDeclaration":[],"inc9DeclarationFlag1":"N","din":"","SpicePartBSubscribersShares":[{"sharecategory":"Equity Share","classShare":"1","subscribedcapitalsharenumber":"7000","subscribedcapitalnominalamountpershare":"10","subscribedcapitaltotalamount":"70000"}],"SpicePartBSubscribersAddress":[{"addressType":"Permanent Address","line1":"17,2nd Main Road","line2":"Basaveshwara Layout 2nd stage","country":"India","pincode":"560040","area":"Chandra Lay Out","city":"Bangalore North","district":"Bangalore","state_ut":"Karnataka"},{"addressType":"Present Address","line1":"17,2nd Main Road","line2":"Basaveshwara Layout 2nd stage","country":"India","pincode":"560040","area":"Chandra Lay Out","city":"Bangalore North","district":"Bangalore","state_ut":"Karnataka","yearresidenseduration":"22","monthresidenseduration":"7"}]}]},"status":"Draft/Pending Submission","formDescription":"For Spice+PartB","formName":"SPICE + Part B","formVersion":"1690637193416","userId":"CASRIKANTH0224@GMAIL.COM","integrationId":"1-4KMNXXW","referenceNumber":"","formattachList":"[{\"attachmentLabel\":\"SpiceBproofAddress\",\"attachmentCategory\":\"Attachment\",\"activityFileName\":\"1Ananya_electrical_bill.jpg\",\"activityFileSrcType\":\"I\",\"activityFileExt\":\"jpg\",\"activityFileSize\":\"45322\",\"attachmentDMSId\":\"353025846\",\"totalNoOfPages\":\"1\",\"activityFileDate\":\"07/29/2023 18:22:42\",\"publicDocument\":\"Y\",\"activityComments\":\"174611857:SpiceBproofAddress:Document added successfully.\",\"versionNo\":\"0\",\"folderName\":\"\",\"addedBy\":\"Fo User\",\"formName\":\"\",\"folderId\":\"174611857\"},{\"attachmentLabel\":\"SpiceBcopyUtility\",\"attachmentCategory\":\"Attachment\",\"activityFileName\":\"Ananya_electrical_bill.jpg\",\"activityFileSrcType\":\"I\",\"activityFileExt\":\"jpg\",\"activityFileSize\":\"45322\",\"attachmentDMSId\":\"353025856\",\"totalNoOfPages\":\"1\",\"activityFileDate\":\"07/29/2023 18:22:42\",\"publicDocument\":\"Y\",\"activityComments\":\"174611857:SpiceBcopyUtility:Document added successfully.\",\"versionNo\":\"0\",\"folderName\":\"\",\"addedBy\":\"Fo User\",\"formName\":\"\",\"folderId\":\"174611857\"}]","inc9Flag":"Y","eAOAFlag":"Y","eMOAFlag":"Y","operation":"Save","action":"savesubmit","formIntegrationId":"1-4KMNXY0","srn":"","formId":"","formAttachment":[{"attachmentLabel":"SpiceBproofAddress","attachmentCategory":"Attachment","activityFileName":"1Ananya_electrical_bill.jpg","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"45322","attachmentDMSId":"353025846","totalNoOfPages":"1","activityFileDate":"07/29/2023 18:22:42","publicDocument":"Y","activityComments":"174611857:SpiceBproofAddress:Document added successfully.","versionNo":"0","folderName":"","addedBy":"Fo User","formName":"","folderId":"174611857"},{"attachmentLabel":"SpiceBcopyUtility","attachmentCategory":"Attachment","activityFileName":"Ananya_electrical_bill.jpg","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"45322","attachmentDMSId":"353025856","totalNoOfPages":"1","activityFileDate":"07/29/2023 18:22:42","publicDocument":"Y","activityComments":"174611857:SpiceBcopyUtility:Document added successfully.","versionNo":"0","folderName":"","addedBy":"Fo User","formName":"","folderId":"174611857"},{"attachmentLabel":"SpiceBidentityPro7B","attachmentCategory":"Attachment","activityFileName":"EEUPM6910R_Ananya_Aadhar.jpg","activityFileSrcPath":"174611857","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"116918","attachmentDMSId":"353027177","totalNoOfPages":"1","activityFileDate":"07/29/2023","publicDocument":"Y","activityComments":"174611857:SpiceBidentityPro7B:Document added successfully.","folderName":"174611857","folderId":"174611857","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBProofOfResi7B","attachmentCategory":"Attachment","activityFileName":"EEUPM6910R_Ananya_electrical_bill.jpg","activityFileSrcPath":"174611857","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"45322","attachmentDMSId":"353027207","totalNoOfPages":"1","activityFileDate":"07/29/2023","publicDocument":"Y","activityComments":"174611857:SpiceBProofOfResi7B:Document added successfully.","folderName":"174611857","folderId":"174611857","version":"","addedBy":"Fo User"}]}}''')

# %%
payload9_json=json.loads(r'''{"requestBody":{"formData":{"aoaEntrenched":"N","totalAuthorizedShareCapital":"200000","totalClassifiedAuthorizedShareCapital":"100000","totalSubscribedShareCapital":"100000","totalUnclassifiedAuthorizedShareCapital":"100000","equitynumberofClasses":"1","preferencenumberofClasses":"0","numOfMembers":"2","SpicePartBAddress":[{"line1":"17, 2nd main road, Basaveswara layout","line2":"2nd stage, Chandra layout","pincode":"560040","addressType":"Correspondance Address","coutry":"India","area":"Chandra Lay Out","city":"Bangalore North","district":"Bangalore","state_ut":"Karnataka","mobile":"9108042546","companymailid":"ananyamadhav23@gmail.com"}],"regaddressline1":"17, 2nd main road, Basaveswara layout","regaddressline2":"2nd stage, Chandra layout","regaddresspincode":"560040","regaddresscountry":"India","regaddresscity":"Bangalore North","regaddressdistrict":"Bangalore","regaddressstate_ut":"Karnataka","regaddresscompanymailid":"ananyamadhav23@gmail.com","regaddressarea":"Chandra Lay Out","corresAddrSameRegAddr":"Y","regaddresslongitude":"77.5305","regaddresslatitude":"12.968","rocName":"Registrar of Companies, Karnataka","SubsrciberDINCount":"1","SubsrciberCountWithoutDIN":"1","NonIndividualCountWithoutDIN":"0","DirectorSubscriberDINCount":"1","DirectorSubscriberWithoutDINCount":"1","DirectorDINCount":"1","DirectorCountWithoutDINCount":"1","opcDetails":{"stampDuty":{"state_ut":"Karnataka","stampDutyElectronicallyPaid":"Yes","stampDutyToBePaidDetails":{"amountForm":20,"amountMOA":1000,"amountAOA":1000}}},"panTanDetails":{"PANareaCode":"DLC","PANaoType":"WX","PANrangeCode":"502","PANaoNumber":"2","TANareaCode":"KAR","TANaoType":"WT","TANrangeCode":"181","TANaoNumber":"1","incomeFromBusinessProfession":"Y","businessProfessioncode":"20"},"directorDeclaration":{"input1":"ANANYA MADHAV","declaration7":"Y","declaration8":"Y","declaration9":"Y","declaration10":"Y","declaration11":"Y","declaration12":"Y","declaration13":"Y","input2":"SRIKANTH REDDY","dropdown1":"a","dropdown2":"Chartered Accountant","membershipNumber_declaration":"271843","practiceNumber_declaration":"FRN026299S","dinPan":"EEUPM6910R","name":"SRIKANTH REDDY","institute":"The Institute of Chartered Accountant of India","OfficePlace":"171, 7th cross, 7th Main Rd, 2nd Block, Jayanagar, Bengaluru, Karnataka 560011","LegalProffesion":"Chartered Accountant","associate_Fellow":"Associate","membershipNumber":"271843","certificateofPracticeNumber":"FRN026299S","pan":"DLQPR2890H"},"SpiceBDeclarationDINPANDetails":[],"formIntegrationId":"1-4KMNXY0","SpicePartBShares":[{"classShare":"1","authorizedcapitalsharenumber":"10000","subscribedcapitalsharenumber":"10000","authorizedcapitalnominalamountpershare":"10","subscribedcapitalnominalamountpershare":"10","authorizedcapitaltotalamount":"100000","subscribedcapitaltotalamount":"100000","sharecategory":"Equity Share"}],"spicePartBNonINDVSubscribers":[],"SpicePartBINDVSubscribers":[],"SpicePartBSubscribers":[{"SubscriberType":"Subscriber CUM Director DIN","din":"08553753","name":"HONNENAHALLY NINGAPPA SUMA","nationality":"India","firstName":"HONNENAHALLY","middleName":"NINGAPPA","category":"Individual First subscribers cum Directors","Surname":"SUMA","designation":"Director","directorCategory":"Promoter","whetherNonED":"Executive director","emailid":"hnsuma@yahoo.co.in","totalSubscribedShareCapital":"30000","equitynumofclasses":"1","DirectorInterestedEntitiescount":"0","SpicePartBSubsDeclaration":[],"inc9DeclarationFlag1":"N","SpicePartBSubscribersShares":[{"sharecategory":"Equity Share","classShare":"1","subscribedcapitalsharenumber":"3000","subscribedcapitalnominalamountpershare":"10","subscribedcapitaltotalamount":"30000"}],"pan":"","identityProofNumber":""},{"category":"Individual First subscribers cum Directors","SubscriberType":"Subscriber CUM Director No DIN","firstName":"ANANYA","Surname":"MADHAV","fatherFirstName":"MADHAVA","fatherSurName":"","gender":"Female","dateOfBirth":"12/23/1998","nationality":"India","placeofBirth":"Bangalore","citizenOfIndia":"Y","residentOfIndia":"Y","occupationType":"Professional","areaofOccupation":"Student","educationalQualificationothers":"Master degree","pan":"EEUPM6910R","designation":"Director","directorCategory":"Promoter","whetherNonED":"Executive director","MobileNo":"09108042546","emailid":"ananyamadhav23@gmail.com","ResidenseCorespondenceFlag":"Y","identityProofDocument":"Aadhar Card","identityProofNumber":"295558800889","residentialProofDocument":"Electricity Bill","residentialProofNumber":"141225235020371","Attachment1":{"fileAttachment":"EEUPM6910R_Ananya_Aadhar.jpg"},"Attachment2":{"fileAttachment":"EEUPM6910R_Ananya_electrical_bill.jpg"},"totalSubscribedShareCapital":"70000","equitynumofclasses":"1","DirectorInterestedEntitiescount":"0","SpicePartBSubsDeclaration":[],"inc9DeclarationFlag1":"N","SpicePartBSubscribersShares":[{"sharecategory":"Equity Share","classShare":"1","subscribedcapitalsharenumber":"7000","subscribedcapitalnominalamountpershare":"10","subscribedcapitaltotalamount":"70000"}],"din":"","SpicePartBSubscribersAddress":[{"addressType":"Permanent Address","line1":"17,2nd Main Road","line2":"Basaveshwara Layout 2nd stage","country":"India","pincode":"560040","area":"Chandra Lay Out","city":"Bangalore North","district":"Bangalore","state_ut":"Karnataka"},{"addressType":"Present Address","line1":"17,2nd Main Road","line2":"Basaveshwara Layout 2nd stage","country":"India","pincode":"560040","area":"Chandra Lay Out","city":"Bangalore North","district":"Bangalore","state_ut":"Karnataka","yearresidenseduration":"22","monthresidenseduration":"7"}]}]},"status":"Draft/Pending Submission","formDescription":"For Spice+PartB","formName":"SPICE + Part B","formVersion":"1690637775366","userId":"CASRIKANTH0224@GMAIL.COM","integrationId":"1-4KMNXXW","referenceNumber":"","formattachList":"[{\"attachmentLabel\":\"SpiceBproofAddress\",\"attachmentCategory\":\"Attachment\",\"activityFileName\":\"1Ananya_electrical_bill.jpg\",\"activityFileSrcType\":\"I\",\"activityFileExt\":\"jpg\",\"activityFileSize\":\"45322\",\"attachmentDMSId\":\"353025846\",\"totalNoOfPages\":\"1\",\"activityFileDate\":\"07/29/2023 18:22:42\",\"publicDocument\":\"Y\",\"activityComments\":\"174611857:SpiceBproofAddress:Document added successfully.\",\"versionNo\":\"0\",\"folderName\":\"\",\"addedBy\":\"Fo User\",\"formName\":\"\",\"folderId\":\"174611857\"},{\"attachmentLabel\":\"SpiceBcopyUtility\",\"attachmentCategory\":\"Attachment\",\"activityFileName\":\"Ananya_electrical_bill.jpg\",\"activityFileSrcType\":\"I\",\"activityFileExt\":\"jpg\",\"activityFileSize\":\"45322\",\"attachmentDMSId\":\"353025856\",\"totalNoOfPages\":\"1\",\"activityFileDate\":\"07/29/2023 18:22:42\",\"publicDocument\":\"Y\",\"activityComments\":\"174611857:SpiceBcopyUtility:Document added successfully.\",\"versionNo\":\"0\",\"folderName\":\"\",\"addedBy\":\"Fo User\",\"formName\":\"\",\"folderId\":\"174611857\"}]","inc9Flag":"Y","eAOAFlag":"Y","eMOAFlag":"Y","operation":"Submit","comments":"","action":"Submit","srn":"","formAttachment":[{"attachmentLabel":"SpiceBproofAddress","attachmentCategory":"Attachment","activityFileName":"1Ananya_electrical_bill.jpg","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"45322","attachmentDMSId":"353025846","totalNoOfPages":"1","activityFileDate":"07/29/2023 18:22:42","publicDocument":"Y","activityComments":"174611857:SpiceBproofAddress:Document added successfully.","versionNo":"0","folderName":"","addedBy":"Fo User","formName":"","folderId":"174611857"},{"attachmentLabel":"SpiceBcopyUtility","attachmentCategory":"Attachment","activityFileName":"Ananya_electrical_bill.jpg","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"45322","attachmentDMSId":"353025856","totalNoOfPages":"1","activityFileDate":"07/29/2023 18:22:42","publicDocument":"Y","activityComments":"174611857:SpiceBcopyUtility:Document added successfully.","versionNo":"0","folderName":"","addedBy":"Fo User","formName":"","folderId":"174611857"},{"attachmentLabel":"SpiceBidentityPro7B","attachmentCategory":"Attachment","activityFileName":"EEUPM6910R_Ananya_Aadhar.jpg","activityFileSrcPath":"174611857","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"116918","attachmentDMSId":"353027177","totalNoOfPages":"1","activityFileDate":"07/29/2023","publicDocument":"Y","activityComments":"174611857:SpiceBidentityPro7B:Document added successfully.","folderName":"174611857","folderId":"174611857","version":"","addedBy":"Fo User"},{"attachmentLabel":"SpiceBProofOfResi7B","attachmentCategory":"Attachment","activityFileName":"EEUPM6910R_Ananya_electrical_bill.jpg","activityFileSrcPath":"174611857","activityFileSrcType":"I","activityFileExt":"jpg","activityFileSize":"45322","attachmentDMSId":"353027207","totalNoOfPages":"1","activityFileDate":"07/29/2023","publicDocument":"Y","activityComments":"174611857:SpiceBProofOfResi7B:Document added successfully.","folderName":"174611857","folderId":"174611857","version":"","addedBy":"Fo User"}]}}''')

# %%
# keys_in_dict2_but_not_in_dict1 = []

# for key in payload9_json['requestBody'].keys():
#     if key not in payload8_json['requestBody']:
#         keys_in_dict2_but_not_in_dict1.append(key)

# %%
payload8_json=payload7_json
payload8_json['requestBody']['comments']=''

# %%
# payload9_json['requestBody']['comments']

# %%
payload8_json
# Out:
# {'requestBody': {'formData': {'aoaEntrenched': 'N',
#    'Havingsharecapital': '',
#    'totalAuthorizedShareCapital': '200000',
#    'totalClassifiedAuthorizedShareCapital': '100000',
#    'totalSubscribedShareCapital': '100000',
#    'totalUnclassifiedAuthorizedShareCapital': '100000',
#    'equitynumberofClasses': '1',
#    'preferencenumberofClasses': '0',
#    'SpicePartBAddress': [{'line1': 'C/O H N CHAMPA,#17 ',
#      'line2': 'Basaveswara HBC LYT.',
#      'pincode': '560040',
#      'addressType': 'Correspondance Address',
#      'coutry': 'India',
#      'area': 'Chandra Lay Out',
#      'city': 'Bangalore North',
#      'district': 'Bangalore',
#      'state_ut': 'Karnataka',
#      'mobile': '9108042546',
#      'companymailid': 'ananyamadhav23@gmail.com'}],
#    'regaddressline1': 'C/O H N CHAMPA,#17 ',
#    'regaddressline2': 'Basaveswara HBC LYT.',
#    'regaddresspincode': '560040',
#    'regaddresscountry': 'India',
#    'regaddresscity': 'Bangalore South',
# ...

# %%
url = 'https://www.mca.gov.in/bin/mca-gov/SpicePartB_SAVESUBMIT'

headers = {
    'Cookie': f'cookiesession1=678B286955776DB15177E7C622CE6403; alertPopup=true; session-token={session_token}',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/114.0',
    'Accept': '*/*',
    'Accept-Language': 'en-US,en;q=0.5',
    'Accept-Encoding': 'gzip, deflate',
    'Referer': 'https://www.mca.gov.in/content/mca/global/en/mca/e-filing/incorporation/SpicePartB.html',
    'X-Requested-With': 'XMLHttpRequest',
    'Content-Type': 'multipart/form-data',
    'Content-Length': '5202',
    'Origin': 'https://www.mca.gov.in',
    'Sec-Fetch-Dest': 'empty',
    'Sec-Fetch-Mode': 'cors',
    'Sec-Fetch-Site': 'same-origin',
    'Te': 'trailers'
}


# multipart_data = MultipartEncoder(fields={
#     'data': (json.dumps(payload8_json)),
#     'action': 'savesubmit',
#     'operation': 'Save',
#     'serveAction': 'saveForm',
#     'referenceNumber': '',
#     'formId': ''
# })
multipart_data = MultipartEncoder(fields={
    'data': json.dumps(payload8_json),
    'action': 'SaveSubmitForm24',  # Updated 'action' field value
    'operation': 'Submit',  # Updated 'operation' field value
    'serveAction': 'submitForm',  # Updated 'serveAction' field value
    'integrationId': '1-DM1ICTest',  # Updated 'integrationId' field value
})

headers['Content-Type'] = multipart_data.content_type
response = requests.post(url, headers=headers, data=multipart_data)

print(response.text)
# Out:
# {
#
# ...

# %%
with open('spicebpart.json') as f:
   inp1 = json.load(f)

# %%
inp1['afData']['afUnboundData']
# Out:
# {'data': {'language-translation-radio': 'English',
#   'saveFlag01': 'N',
#   'prefillFormFlag': 'N',
#   'Validate': '0',
#   'Next': '0',
#   'sharecategorye1': 'Equity Share',
#   'correspondenceaddress_MobileNumber': '9108042546',
#   'saveFlag02': 'N',
#   'correspondenceaddress_proofOfAddress': {'fileAttachment': '11.pdf'},
#   'correspondenceaddress_copyOfUtilityBills': {'fileAttachment': 'a1.jpeg'},
#   'saveFlag03': 'N',
#   'changeFlag': 'N',
#   'prefillFlag06': 'Y',
#   'saveFlag6A': 'Y',
#   'panValidate6A': '0',
#   'Addresstype6a': 'Present Address',
#   'saveFlag6B': 'Y',
#   'panValidate6C': '1',
#   'saveFlag6C': 'Y',
#   'prefillFlag07': 'N',
#   'saveFlag7A': 'Y',
#   'emailIdBlock7A': 'hn********oo.co.in',
#   'saveFlag7B': 'Y',
#   'panValidate7B': 1,
#   'area7b1': 'Chandra Lay Out',
#   'area7b2': 'Chandra Lay Out',
#   'saveFlag7C': 'Y',
#   'saveFlag7D': 'Y',
#   'panValidate': '1',
#   'saveFlag08': 'Y',
#   'saveFlag09': 'N',
#   'saveFlag10': 'N',
# ...

# %%
afUnboundData={'data': {'language-translation-radio': 'English',
  'saveFlag01': 'N',
  'prefillFormFlag': 'N',
  'Validate': '0',
  'Next': '0',
  'sharecategorye1': 'Equity Share',
  'correspondenceaddress_MobileNumber': '9108042546',
  'saveFlag02': 'N',
  'correspondenceaddress_proofOfAddress': {'fileAttachment': '11.pdf'},
  'correspondenceaddress_copyOfUtilityBills': {'fileAttachment': 'a1.jpeg'},
  'saveFlag03': 'N',
  'changeFlag': 'N',
  'prefillFlag06': 'Y',
  'saveFlag6A': 'Y',
  'panValidate6A': '0',
  'Addresstype6a': 'Present Address',
  'saveFlag6B': 'Y',
  'panValidate6C': '1',
  'saveFlag6C': 'Y',
  'prefillFlag07': 'N',
  'saveFlag7A': 'Y',
  'emailIdBlock7A': 'hn********oo.co.in',
  'saveFlag7B': 'Y',
  'panValidate7B': 1,
  'area7b1': 'Chandra Lay Out',
  'area7b2': 'Chandra Lay Out',
  'saveFlag7C': 'Y',
  'saveFlag7D': 'Y',
  'panValidate': '1',
  'saveFlag08': 'Y',
  'saveFlag09': 'N',
  'saveFlag10': 'N',
  'txt_9PANAreaCode1stChar': 'D',
  'txt_9PANAreaCode2ndChar': 'L',
  'txt_9PANAreaCode3rdChar': 'C',
  'txt_9PANAOType1stChar': 'W',
  'txt_9PANAOType2ndChar': 'X',
  'txt_9PANRangeCode1stChar': '5',
  'txt_9PANRangeCode2ndChar': '0',
  'txt_9PANRangeCode3rdChar': '2',
  'txt_9PANAONo1stNo': '2',
  'txt_9TANAreaCode1stChar': 'K',
  'txt_9TANAreaCode2ndChar': 'A',
  'txt_9TANAreaCode3rdChar': 'R',
  'txt_9TANAOType1stChar': 'W',
  'txt_9TANAOType2ndChar': 'T',
  'txt_9TANRangeCode1stChar': '1',
  'txt_9TANRangeCode2ndChar': '8',
  'txt_9TANRangeCode3rdChar': '1',
  'txt_9TANAONo1stNo': '1',
  'saveFlag11': 'N',
  'saveFlag12': 'N',
  'radiobutton1659078368655': 'N',
  'saveFlag13': 'N',
  'prefillFlagEP': 'False',
  'Path_for_PDFGeneration': '/content/forms/af/mca-aem-forms/spice-part-b/spice-plus-part-b',
  'textbox_994190291657709626152': '11/12/2021',
  'textbox_2839656751657709715007': '11/12/2021',
  'textbox_21051849601657709790068': '11122021',
  'type4a': 'Correspondance Address',
  'prefillFlag': 'False'}}

# %%
inp1['afData']['afBoundData']
# Out:
# {'data': {'requestBody': {'formData': {'aoaEntrenched': 'N',
#     'SpicePartBArticles': [{'serialnum': '1'}],
#     'Havingsharecapital': 'Having Share Capital',
#     'totalAuthorizedShareCapital': '200000',
#     'totalClassifiedAuthorizedShareCapital': '100000',
#     'totalSubscribedShareCapital': '100000',
#     'totalUnclassifiedAuthorizedShareCapital': '100000',
#     'equitynumberofClasses': '1',
#     'spicePartBEquityShare': [{'classShare': '1',
#       'authorizedcapitalsharenumber': '10000',
#       'subscribedcapitalsharenumber': '10000',
#       'authorizedcapitalnominalamountpershare': '10',
#       'subscribedcapitalnominalamountpershare': '10',
#       'authorizedcapitaltotalamount': '100000',
#       'subscribedcapitaltotalamount': '100000',
#       'sharecategory': 'Equity Share'}],
#     'preferencenumberofClasses': '0',
#     'spicePartBPreferenceShare': [{'sharecategory': 'Preference Share',
#       'subscribedcapitalsharenumber': '0'}],
# ...
